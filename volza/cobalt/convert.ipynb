# %%
import pandas as pd

COMMODITY = 'cobalt'
PRICE_FILE = f'{COMMODITY}_prices.csv'
filename = 'Cobalt 2020-2023.xlsx'
sheet = 'Global Search Data'

df = pd.read_excel(filename, sheet_name=sheet, skiprows=1)
csv = df.to_csv(f'{COMMODITY}.csv')
df
# Out:
#             Date       HS Code  \
# 0     2020-03-03  81052029000K
# 1     2020-11-25    8105200000
# 2     2020-05-19      81052090
# 3     2020-12-14      81052000
# 4     2020-09-01      81052010
# ...          ...           ...
# 21989 2023-11-14    8105200001
# 21990 2023-11-03    8105200001
# 21991 2023-11-28      81052000
# 21992 2023-02-27    8105200000
# 21993 2023-10-09      81052001
#
#                                      Product Description  \
# 0              BRAND: HANRUI COBALT|EFS 1 GRANULATE COBA
# 1      DO 3202000987-001 DECLARATION (1-1) INVOICE: 2...
# 2                               DIAMALLOY 4060NS / 10 LB
# 3               COBALT DUST: "BEGO WIROBOND C+"-10PCS*5K
# 4                                              UNWROUGHT
# ...                                                  ...
# 21989  COBALT ALLOY POWDER   (COBALT CONTENT MORE THA...
# 21990  NEW COBALT POWDER   (CO 99.97%)  , IS NOT A FO...
# 21991              2 PALLET OF HIGH ALLOY POWDER CO BASE
# 21992  COBALT INGOTS AND OTHER INTERMEDIATE PRODUCTS ...
# 21993                                       Cobalt dust
#
#                                                Consignee Notify Party Name  \
# 0                                   TANTAL ARGENTINA SRL               NaN
# 1                         INVERSIONES RINCON MEDINA LTDA               NaN
# 2                       Ge nusantara turbine services pt               NaN
# 3                      BELADENT SRL MOLDOVA OR NISPORENI               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 21989                                        LLC ZTS DON               NaN
# 21990                                    LLC COMPANY S S               NaN
# 21991                                 KINGSHIP LINE LTDA               NaN
# 21992                             Grand Lada Company LLC               NaN
# 21993  CENTRO DE INGENIERIA AVANZADA EN TURBOMAQUINAS...               NaN
#
#                                             Shipper  Std. Quantity Std. Unit  \
# 0                                               NaN         200.00       KGS
# 1                                       GE ADDITIVE          11.00       KGS
# 2                  OERLIKON METCO SINGAPORE PTE LTD         140.00       LBR
# 3                 OOO SIMPLAND 121353 OR MOSCOVA SK          50.00       KGS
# 4                                               NaN        3000.00       KGS
# ...                                             ...            ...       ...
# 21989               NINGBO SHIMAOTONG INTERNATIONAL           0.00       UNT
# 21990  SUZHOU BINFEN NEW MATERIAL TECHNOLOGY CO LTD           0.00       UNT
# 21991                                      CARGA NV           0.00       KGS
# 21992                 SPECIALTY METALS RESOURCES SA           0.00       UNT
# 21993                     GE CONCEPT LASER ADDITIVE         149.68       KGS
#
#       Standard Unit Rate INR      Value  ... Port of Delivery Container TEU  \
# 0                          -    8561.00  ...                -             -
# 1                          -    2764.97  ...                -             -
# 2                          -    6003.83  ...                -             -
# 3                          -   19203.72  ...                -             -
# 4                          -   84258.00  ...                -             -
# ...                      ...        ...  ...              ...           ...
# 21989                      -       0.00  ...                -             -
# 21990                      -       0.00  ...                -             -
# 21991                      -  226000.00  ...                -          0.08
# 21992                      -   11020.00  ...                -             -
# 21993                      -   18654.90  ...                -             -
#
#       Freight Term  Marks Number  \
# 0                -             -
# 1                -             -
# 2                -             -
# 3                -             -
# 4                -             -
# ...            ...           ...
# 21989            -             -
# 21990            -             -
# 21991            -             -
# 21992            -             -
# 21993            -             -
#
#                                   HS Product Description Gross Weight  \
# 0                                                 OTHERS          0.0
# 1      COBALT MATTES AND OTHER INTERMEDIATE PRODUCTS ...         11.0
# 2                                                    NaN          0.0
# 3                                                    NaN          0.0
# 4                                                    NaN       3000.0
# ...                                                  ...          ...
# 21989  COBALT MATTES AND OTHER INTERMEDIATE PRODUCTS ...         13.5
# 21990  COBALT MATTES AND OTHER INTERMEDIATE PRODUCTS ...        358.0
# 21991                                                NaN        828.0
# 21992                                                NaN          0.0
# 21993                                   POLVO DE COBALTO        182.8
#
#                                        Consignee Address  \
# 0                                                    NaN
# 1                                          CRA 47 79 234
# 2      JL. PAJAJARAN NO.154, HUSEN SASTRANEGARA, KEC....
# 3                                   MOLDOVA OR NISPORENI
# 4                                                    NaN
# ...                                                  ...
# 21989                                                NaN
# 21990                                                NaN
# 21991  R SURUBIM 504 CONJ 61 CIDADE MONCOES  SAO PAUL...
# 21992    03151, Kyiv, street Ushinsky, bldg. 40, Ukraine
# 21993  AV CONSTITUYENTES PTE/120/2/EL CARRIZAL//AND M...
#
#                                          Shipper Address Notify Party Address  \
# 0                                                    NaN                  NaN
# 1             101 NORTH CAMPUS DRIVR IMPERIAL PA15126                     NaN
# 2                         SINGAPORE 508913  SG 508913 SG                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 21989  CO. LTD 9TH FLOOR, NO. 137 EAST|ZHONGSHAN ROAD...                  NaN
# 21990                                                NaN                  NaN
# 21991  HAVEN 99 - VRIESKAAI 98            2030 ANTWER...                  NaN
# 21992          RUE DE TENBOSCH 42A 1050 BRUSSELS BELGIUM                  NaN
# 21993  8556 TRADE CENTER DRIVE|SUITE 100|WEST CHESTER...                  NaN
#
#                Country Name
# 0      Argentina T2  Import
# 1      Columbia T3+  Import
# 2      Indonesia T3  Import
# 3        Moldova T3  Import
# 4         Brazil T1  Import
# ...                     ...
# 21989     Russia T3  Import
# 21990     Russia T3  Import
# 21991     Brazil T3  Import
# 21992   Ukraine T3+  Import
# 21993     Mexico T3  Import
#
# [21994 rows x 31 columns]

# %%
# Convert Price csv date format

price_df = pd.read_csv(PRICE_FILE)
 
# Convert 'Date' column to datetime format
price_df['Date'] = pd.to_datetime(price_df['Date'])

# Format 'Date' column to 'MMM DD, YYYY' format
price_df['Date'] = price_df['Date'].dt.strftime('%b %d, %Y')

price_df.to_csv(PRICE_FILE)
