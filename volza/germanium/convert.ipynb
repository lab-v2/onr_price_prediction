# %%
import pandas as pd

COMMODITY = 'germanium'
PRICE_FILE = f'{COMMODITY}_prices.csv'
filename = 'Germanium 2020-2023.xlsx'
sheet = 'Global Search Data'

df = pd.read_excel(filename, sheet_name=sheet, skiprows=1)
csv = df.to_csv(f'{COMMODITY}.csv')
df
# Out:
#            Date     HS Code  \
# 0    2020-07-01    81129295
# 1    2020-07-01    81129295
# 2    2020-06-01    81129295
# 3    2020-08-01    81129295
# 4    2020-08-01    81129295
# ...         ...         ...
# 1647 2023-09-01    81129295
# 1648 2023-09-01    81129295
# 1649 2023-09-01    81129295
# 1650 2023-09-01    81129295
# 1651 2023-11-24  8112929500
#
#                                     Product Description  Consignee  \
# 0                UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 1                UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 2                UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 3                UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 4                UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# ...                                                 ...        ...
# 1647             UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 1648             UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 1649             UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 1650             UNWROUGHT GERMANIUM; GERMANIUM POWDERS        NaN
# 1651  SINGLE CRYSTAL GERMANIUM ,  RAW IN THE FORM OF...  OOO TIDEX
#
#      Notify Party Name                           Shipper  Std. Quantity  \
# 0                  NaN                               NaN          0.005
# 1                  NaN                               NaN          0.104
# 2                  NaN                               NaN          0.000
# 3                  NaN                               NaN          0.002
# 4                  NaN                               NaN          0.000
# ...                ...                               ...            ...
# 1647               NaN                               NaN          0.000
# 1648               NaN                               NaN          0.000
# 1649               NaN                               NaN          0.000
# 1650               NaN                               NaN          0.020
# 1651               NaN  HEVAN WAVE MASTER TECHNOLOGY LTD          0.000
#
#      Std. Unit Standard Unit Rate INR      Value  ... Port of Delivery  \
# 0          TON                      -    9631.46  ...                -
# 1          TON                      -   23556.18  ...                -
# 2          TON                      -     148.89  ...                -
# 3          TON                      -    3434.12  ...                -
# 4          TON                      -      20.00  ...                -
# ...        ...                    ...        ...  ...              ...
# 1647       TON                      -     150.54  ...                -
# 1648       TON                      -     430.11  ...                -
# 1649       TON                      -    8279.57  ...                -
# 1650       TON                      -  213053.76  ...                -
# 1651       UNT                      -       0.00  ...                -
#
#      Container TEU Freight Term  Marks Number  \
# 0                -            -             -
# 1                -            -             -
# 2                -            -             -
# 3                -            -             -
# 4                -            -             -
# ...            ...          ...           ...
# 1647             -            -             -
# 1648             -            -             -
# 1649             -            -             -
# 1650             -            -             -
# 1651             -            -             -
#
#                       HS Product Description Gross Weight Consignee Address  \
# 0                                        NaN          0.0               NaN
# 1                                        NaN          0.0               NaN
# 2                                        NaN          0.0               NaN
# 3                                        NaN          0.0               NaN
# 4                                        NaN          0.0               NaN
# ...                                      ...          ...               ...
# 1647                                     NaN          0.0               NaN
# 1648                                     NaN          0.0               NaN
# 1649                                     NaN          0.0               NaN
# 1650                                     NaN          0.0               NaN
# 1651  UNWROUGHT GERMANIUM; GERMANIUM POWDERS          2.6               NaN
#
#      Shipper Address Notify Party Address            Country Name
# 0                NaN                  NaN      Germany T1  Export
# 1                NaN                  NaN      Belgium T1  Export
# 2                NaN                  NaN      Germany T1  Export
# 3                NaN                  NaN      Germany T1  Export
# 4                NaN                  NaN      Belgium T1  Export
# ...              ...                  ...                     ...
# 1647             NaN                  NaN      Belgium T1  Export
# 1648             NaN                  NaN      Germany T1  Export
# 1649             NaN                  NaN  Netherlands T1  Export
# 1650             NaN                  NaN       Latvia T1  Import
# 1651             NaN                  NaN       Russia T3  Import
#
# [1652 rows x 31 columns]

# %%
# Convert Price csv date format

price_df = pd.read_csv(PRICE_FILE)
 
# Convert 'Date' column to datetime format
price_df['Date'] = pd.to_datetime(price_df['Date'])

# Format 'Date' column to 'MMM DD, YYYY' format
price_df['Date'] = price_df['Date'].dt.strftime('%b %d, %Y')

price_df.to_csv(PRICE_FILE)
