# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install scikit-learn
# %pip install tensorflow
# %pip install -U imbalanced-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Dropout, LayerNormalization, MultiHeadAttention, Input
from tensorflow.keras.layers import Attention, Reshape
from tensorflow.keras.models import Model
# Out:
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import models
import utils
import data_processing

# %%
COMMODITY = 'cobalt'

DATE_COLUMN = 'Date'
VALUE_COLUMN = 'Value'  
QUANTITY_COLUMN = 'Std. Quantity (KG)'
UNIT_RATE_COLUMN = 'Std. Unit Rate ($/KG)'
BRENT_OIL_COLUMN = 'Brent Oil Value'
WTI_OIL_COLUMN = 'WTI Oil Value'
SHIP_COUNT_COLUMN = 'ship_count'
PORT_COUNT_COLUMN = 'popular_port_count'

VALUE_SPIKES_COLUMN = 'Value Spikes'  
QUANTITY_SPIKES_COLUMN = 'Std. Quantity (KG) Spikes'
UNIT_RATE_SPIKES_COLUMN = 'Std. Unit Rate ($/KG) Spikes'
BRENT_OIL_SPIKES_COLUMN = 'Brent Oil Value Spikes'
WTI_OIL_SPIKES_COLUMN = 'WTI Oil Value Spikes'
SHIP_COUNT_SPIKES_COLUMN = 'Ship Count Spikes'
PORT_COUNT_SPIKES_COLUMN = 'Port Count Spikes'

FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_SPIKES_COLUMN, BRENT_OIL_SPIKES_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_SPIKES_COLUMN, PORT_COUNT_SPIKES_COLUMN]
TARGET_COLUMN = 'Price'

ORIGIN_COUNTRY_COLUMN = 'Country of Origin'
DEST_COUNTRY_COLUMN = 'Country of Destination'

PETROL_FILE_PATH = '../../volza/petroleum/petrol_crude_oil_spot_price.csv'
VOLZA_FILE_PATH = f'../../volza/{COMMODITY}/{COMMODITY}.csv'
PRICE_FILE_PATH = f"../../volza/{COMMODITY}/{COMMODITY}_prices.csv"
AIS_POPULAR_FILE_PATH = f'../../ais/ais_ml_features.csv' 

NB_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (No Balancing).csv"
RUS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Under Sampling).csv"
ROS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Over Sampling).csv"


SPIKES_THRESHOLD = 2
SPIKES_WINDOW_SIZE = 20
BIN_COUNT = 10
FILL_METHOD = 'ffill'

RANDOM_STATE = 42

# %% [markdown]
# ## Dataframe Prep

# %%
from datetime import datetime

#Formatting the date and price for Volza data
volza_pd = pd.read_csv(VOLZA_FILE_PATH)
volza_pd = volza_pd[(volza_pd["Country of Origin"].notnull()) & (volza_pd["Country of Destination"].notnull())]
volza_pd = volza_pd.rename(columns={'Unnamed: 0': 'ID'})
volza_pd['Date'] = volza_pd['Date'].apply(lambda x: x.split(' ')[0])
volza_pd['Date'] = pd.to_datetime(volza_pd['Date'], errors='raise', format='%Y-%m-%d')
volza_pd = utils.convert_to_kg(volza_pd)
volza_pd.head(3)
# Out:
#    ID       Date       HS Code  \
# 0   0 2020-03-03  81052029000K
# 1   1 2020-11-25    8105200000
# 3   3 2020-12-14      81052000
#
#                                  Product Description  \
# 0          BRAND: HANRUI COBALT|EFS 1 GRANULATE COBA
# 1  DO 3202000987-001 DECLARATION (1-1) INVOICE: 2...
# 3           COBALT DUST: "BEGO WIROBOND C+"-10PCS*5K
#
#                            Consignee Notify Party Name  \
# 0               TANTAL ARGENTINA SRL               NaN
# 1     INVERSIONES RINCON MEDINA LTDA               NaN
# 3  BELADENT SRL MOLDOVA OR NISPORENI               NaN
#
#                              Shipper  Std. Quantity Std. Unit  \
# 0                                NaN          200.0       KGS
# 1                        GE ADDITIVE           11.0       KGS
# 3  OOO SIMPLAND 121353 OR MOSCOVA SK           50.0       KGS
#
#   Standard Unit Rate INR  ...  Freight Term Marks Number  \
# 0                      -  ...             -            -
# 1                      -  ...             -            -
# 3                      -  ...             -            -
#
#                               HS Product Description Gross Weight  \
# 0                                             OTHERS          0.0
# 1  COBALT MATTES AND OTHER INTERMEDIATE PRODUCTS ...         11.0
# 3                                                NaN          0.0
#
#       Consignee Address                             Shipper Address  \
# 0                   NaN                                         NaN
# 1         CRA 47 79 234  101 NORTH CAMPUS DRIVR IMPERIAL PA15126
# 3  MOLDOVA OR NISPORENI                                         NaN
#
#   Notify Party Address          Country Name Std. Quantity (KG)  \
# 0                  NaN  Argentina T2  Import              200.0
# 1                  NaN  Columbia T3+  Import               11.0
# 3                  NaN    Moldova T3  Import               50.0
#
#   Std. Unit Rate ($/KG)
# 0             42.805000
# 1            251.360909
# 3            384.074400
#
# [3 rows x 34 columns]

# %%
#Preprocessing the AIS data
ais_popular_pd = pd.read_csv(AIS_POPULAR_FILE_PATH)
ais_popular_pd['Date'] = pd.to_datetime(ais_popular_pd['Date'])
ais_popular_pd.head(3)
# Out:
#         Date  ship_count popular_port  popular_port_count
# 0 2020-11-10           8        LTKLJ                  18
# 1 2020-11-12          20        IDSKP                   8
# 2 2020-11-29           9        CNSHA                   2

# %%
#Preprocessing the price data
prices_pd = pd.read_csv(PRICE_FILE_PATH)
# prices_pd['Date'] = prices_pd['Date'].apply(lambda x: datetime.strptime(x, "%b %d, %Y").strftime("%Y-%m-%d"))
prices_pd['Date'] = pd.to_datetime(prices_pd['Date'], errors='raise', format='%m/%d/%Y')
prices_pd['Price'] = prices_pd['Price'].str.replace(',', '').astype(float)
prices_pd = prices_pd[['Date', 'Price']]
prices_pd
# Out:
#            Date    Price
# 0    2024-02-23  28288.0
# 1    2024-02-22  28288.0
# 2    2024-02-21  28288.0
# 3    2024-02-19  28137.0
# 4    2024-02-16  28137.0
# ...         ...      ...
# 1034 2020-01-08  31323.0
# 1035 2020-01-07  31578.5
# 1036 2020-01-06  31834.0
# 1037 2020-01-03  31850.0
# 1038 2020-01-02  32355.0
#
# [1039 rows x 2 columns]

# %%
#Aggregate volza data by day
date_wise_volza = volza_pd.groupby("Date")[[VALUE_COLUMN,QUANTITY_COLUMN,'Gross Weight']].sum()

# %%
# Avg of Commodity Price in Volza
avg_price_volza = volza_pd.groupby('Date')[UNIT_RATE_COLUMN].mean()
date_wise_volza = date_wise_volza.join(avg_price_volza, how='left')
date_wise_volza
# Out:
#                    Value  Std. Quantity (KG)  Gross Weight  \
# Date
# 2020-01-01  1.217433e+08        4.147777e+06       42055.0
# 2020-01-02  9.020977e+04        2.300000e+03           0.0
# 2020-01-03  4.110707e+02        1.000000e+01           0.0
# 2020-01-04  5.637466e+04        1.000000e+03           0.0
# 2020-01-05  4.051522e+04        1.140000e+03           0.0
# ...                  ...                 ...           ...
# 2023-12-25  8.913675e+04        3.000000e+03           0.0
# 2023-12-26  1.160515e+05        3.000000e+03           0.0
# 2023-12-27  5.611000e+04        1.841780e+03           0.0
# 2023-12-28  2.256061e+05        4.446500e+03           0.0
# 2023-12-29  2.908725e+04        1.000000e+03           0.0
#
#             Std. Unit Rate ($/KG)
# Date
# 2020-01-01              92.545195
# 2020-01-02              39.903707
# 2020-01-03              41.107069
# 2020-01-04              56.374664
# 2020-01-05              35.644705
# ...                           ...
# 2023-12-25              30.255888
# 2023-12-26              38.338660
# 2023-12-27              46.549676
# 2023-12-28              76.015813
# 2023-12-29              29.087250
#
# [1307 rows x 4 columns]

# %%
# Petroleum data prep
petrol_df = pd.read_csv(PETROL_FILE_PATH, delimiter=';', on_bad_lines='warn')
petrol_df['Date'] = pd.to_datetime(petrol_df['Date'])

# Split based on types of oil
brent_df = petrol_df[petrol_df['product-name']=='UK Brent Crude Oil']
wti_df = petrol_df[petrol_df['product-name']=='WTI Crude Oil']

brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\273638861.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\273638861.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)

# %%
# Combining dataframes
prices_pd = prices_pd.set_index('Date')
ais_popular_pd = ais_popular_pd.set_index('Date')
date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\1674725426.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\1674725426.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\1674725426.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_21768\1674725426.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
#            Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0    2020-01-01  1.217433e+08        4.147777e+06       42055.0
# 1    2020-01-02  9.020977e+04        2.300000e+03           0.0
# 2    2020-01-03  4.110707e+02        1.000000e+01           0.0
# 3    2020-01-04  5.637466e+04        1.000000e+03           0.0
# 4    2020-01-05  4.051522e+04        1.140000e+03           0.0
# ...         ...           ...                 ...           ...
# 1302 2023-12-25  8.913675e+04        3.000000e+03           0.0
# 1303 2023-12-26  1.160515e+05        3.000000e+03           0.0
# 1304 2023-12-27  5.611000e+04        1.841780e+03           0.0
# 1305 2023-12-28  2.256061e+05        4.446500e+03           0.0
# 1306 2023-12-29  2.908725e+04        1.000000e+03           0.0
#
#       Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 92.545195         NaN          NaN                 NaN
# 1                 39.903707         NaN          NaN                 NaN
# 2                 41.107069         NaN          NaN                 NaN
# 3                 56.374664         NaN          NaN                 NaN
# 4                 35.644705         NaN          NaN                 NaN
# ...                     ...         ...          ...                 ...
# 1302              30.255888      8925.0        USMSY              2673.0
# 1303              38.338660      8925.0        USMSY              2673.0
# 1304              46.549676      8925.0        USMSY              2673.0
# 1305              76.015813      8925.0        USMSY              2673.0
# 1306              29.087250      8925.0        USMSY              2673.0
#
#         Price  Brent Oil Value  WTI Oil Value
# 0         NaN            67.77          61.14
# 1     32355.0            67.05          61.17
# 2     31850.0            69.08          63.00
# 3     31850.0            69.08          63.00
# 4     31850.0            69.08          63.00
# ...       ...              ...            ...
# 1302  28819.0            78.89          72.16
# 1303  28819.0            78.89          72.16
# 1304  28792.5            78.89          72.16
# 1305  28787.5            78.89          72.16
# 1306  28787.5            78.89          72.16
#
# [1307 rows x 11 columns]

# %%
def detect_spikes(df, column, window_size):
    ## Detecting spikes
    moving_avg = df[column].rolling(window=window_size).mean()
    std_dev = df[column].rolling(window=window_size).std()

    # Set a threshold to identify spikes
    return (abs(aggregated_df[column] - moving_avg) > SPIKES_THRESHOLD * std_dev).astype(int)

# aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price')
# print("SPIKES : NON SPIKES = ")
# print(aggregated_df['spikes'].value_counts())
# print("PERCENT OF SPIKES", aggregated_df['spikes'].value_counts()[1]/len(aggregated_df))

# %% [markdown]
# # **Detect spikes**

# %%
# aggregated_df[VALUE_SPIKES_COLUMN] = detect_spikes(aggregated_df, VALUE_COLUMN)
# aggregated_df[QUANTITY_SPIKES_COLUMN] = detect_spikes(aggregated_df, QUANTITY_COLUMN)
# aggregated_df[UNIT_RATE_SPIKES_COLUMN] = detect_spikes(aggregated_df, UNIT_RATE_COLUMN)
# aggregated_df[WTI_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, WTI_OIL_COLUMN)
# aggregated_df[BRENT_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, BRENT_OIL_COLUMN)
# aggregated_df[SHIP_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, SHIP_COUNT_COLUMN)
# aggregated_df[PORT_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, PORT_COUNT_COLUMN)

# #Visualise Dataset

# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_SPIKES_COLUMN], label='Value Spikes', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_SPIKES_COLUMN], label='Quantity Spikes', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_SPIKES_COLUMN], label='Unit Rate Spikes', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_SPIKES_COLUMN], label='Brent Oil Value Spikes', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_SPIKES_COLUMN], label='WTI Oil Value Spikes', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Spikes', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value Spikes', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight / Brent Oil Value / WTI Oil Value / Ship Count / Port Count ', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
#remove date 2020-01-01
aggregated_df = aggregated_df[aggregated_df.index != '2020-01-01']
aggregated_df
# Out:
#            Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0    2020-01-01  1.217433e+08        4.147777e+06       42055.0
# 1    2020-01-02  9.020977e+04        2.300000e+03           0.0
# 2    2020-01-03  4.110707e+02        1.000000e+01           0.0
# 3    2020-01-04  5.637466e+04        1.000000e+03           0.0
# 4    2020-01-05  4.051522e+04        1.140000e+03           0.0
# ...         ...           ...                 ...           ...
# 1302 2023-12-25  8.913675e+04        3.000000e+03           0.0
# 1303 2023-12-26  1.160515e+05        3.000000e+03           0.0
# 1304 2023-12-27  5.611000e+04        1.841780e+03           0.0
# 1305 2023-12-28  2.256061e+05        4.446500e+03           0.0
# 1306 2023-12-29  2.908725e+04        1.000000e+03           0.0
#
#       Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 92.545195         NaN          NaN                 NaN
# 1                 39.903707         NaN          NaN                 NaN
# 2                 41.107069         NaN          NaN                 NaN
# 3                 56.374664         NaN          NaN                 NaN
# 4                 35.644705         NaN          NaN                 NaN
# ...                     ...         ...          ...                 ...
# 1302              30.255888      8925.0        USMSY              2673.0
# 1303              38.338660      8925.0        USMSY              2673.0
# 1304              46.549676      8925.0        USMSY              2673.0
# 1305              76.015813      8925.0        USMSY              2673.0
# 1306              29.087250      8925.0        USMSY              2673.0
#
#         Price  Brent Oil Value  WTI Oil Value
# 0         NaN            67.77          61.14
# 1     32355.0            67.05          61.17
# 2     31850.0            69.08          63.00
# 3     31850.0            69.08          63.00
# 4     31850.0            69.08          63.00
# ...       ...              ...            ...
# 1302  28819.0            78.89          72.16
# 1303  28819.0            78.89          72.16
# 1304  28792.5            78.89          72.16
# 1305  28787.5            78.89          72.16
# 1306  28787.5            78.89          72.16
#
# [1307 rows x 11 columns]

# %%
# #Visualise Dataset
# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
# # Plotting the price data
# plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
# plt.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='blue')

# # Highlighting spikes
# spike_indices = aggregated_df[aggregated_df['spikes'] == 1].index
# spike_prices = aggregated_df.loc[spike_indices, 'Price']
# plt.scatter(spike_indices, spike_prices, color='red', marker='^', label='Spikes')

# # Adding labels and title
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.title('Price Data with Spikes')
# plt.legend()

# # Display the plot
# # plt.show()

# %% [markdown]
# ## Baseline

# %%
# # Count % of spikes 
# total_spikes = aggregated_df['spikes'].sum()
# total_data_points = len(aggregated_df)
# percentage_of_spikes = (total_spikes / total_data_points) * 100

# print(f"Percentage of Spikes: {percentage_of_spikes:.2f}%")

# %%
# from sklearn.metrics import precision_score, recall_score

# # Probability of spike
# spike_prob = aggregated_df['spikes'].mean()

# # Random baseline predictions
# random_predictions = np.random.choice([0, 1], size=len(aggregated_df), p=[1-spike_prob, spike_prob])

# # Calculate precision and recall for the random baseline
# random_precision = precision_score(aggregated_df['spikes'], random_predictions)
# random_recall = recall_score(aggregated_df['spikes'], random_predictions)

# print(f"Random Guessing Precision: {random_precision}")
# print(f"Random Guessing Recall: {random_recall}")

# %% [markdown]
# ## Data Prep for Classification

# %%
COLUMNS = FEATURE_COLUMNS + [TARGET_COLUMN]
print(COLUMNS)
# Out:
# ['Value', 'Std. Quantity (KG)', 'Std. Unit Rate ($/KG)', 'WTI Oil Value', 'Brent Oil Value', 'ship_count', 'popular_port_count', 'Price']

# %%
# # Discretize
# from sklearn.preprocessing import KBinsDiscretizer

# def discretize(df, columns, bins):
#     est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='kmeans')
#     df[columns] = est.fit_transform(df[columns])
#     return df

# # FEATURES_1 = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN]
# # FEATURES_2 = [WTI_OIL_COLUMN, BRENT_OIL_COLUMN]

# test_df = aggregated_df.copy()
# test_df[FEATURE_COLUMNS] = test_df[FEATURE_COLUMNS].fillna(0)

# # test_df = discretize(test_df, FEATURES_1, 2)
# # test_df = discretize(test_df, FEATURES_2, BIN_COUNT)
# discretized_df = discretize(test_df, FEATURE_COLUMNS, BIN_COUNT)
# # discretized_df = test_df.copy()
# test_df.head(2)

# %%
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(test_df.index, test_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(test_df.index, test_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(test_df.index, test_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(test_df.index, test_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(test_df.index, test_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(test_df.index, test_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(test_df.index, test_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(test_df.index, test_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# plt.show()

# %%
# # Convert the discretized data into a DataFrame
# discretized_df = pd.DataFrame(discretized_df, columns=FEATURE_COLUMNS)

# unique_values = discretized_df[VALUE_COLUMN].fillna(method=FILL_METHOD).unique()
# print(unique_values)

# bin_counts = {col: discretized_df[col].value_counts() for col in FEATURE_COLUMNS}

# # Plotting
# plt.figure(figsize=(15, len(FEATURE_COLUMNS) * 5))

# for i, column in enumerate(FEATURE_COLUMNS):
#     plt.subplot(len(FEATURE_COLUMNS), 1, i + 1)
#     bin_counts[column].sort_index().plot(kind='bar', ax=plt.gca())

#     plt.title(f'{column} Distribution')
#     plt.ylabel('Frequency')
#     plt.xlabel('Bins')

# plt.tight_layout()
# plt.show()

# %%
# Clean up before passing to Arima
initial_row_count = aggregated_df.shape[0]

columns_of_interest = ['Price']  # Add other columns as necessary

aggregated_df = aggregated_df.dropna(subset=columns_of_interest)

rows_dropped = initial_row_count - aggregated_df.shape[0]

print(f"Rows dropped due to NaN values: {rows_dropped}")
# Out:
# Rows dropped due to NaN values: 1

# %% [markdown]
# ## Train / Test Set Up

# %%
from sklearn.model_selection import train_test_split
import pmdarima as pm

# Fit an Auto ARIMA model to the 'Price' series
model = pm.auto_arima(aggregated_df['Price'], seasonal=True, m=12, suppress_warnings=True, stepwise=True, error_action='ignore')

# Forecast the series using the model (in-sample prediction)
forecast = model.predict_in_sample()

# Calculate residuals (difference between actual and forecasted values)
residuals = aggregated_df['Price'] - forecast

# Append residuals to DataFrame as a new feature (using residuals as a way to detect spike / anomaly)
aggregated_df = aggregated_df.copy()
aggregated_df['ARIMA_Residuals'] = residuals

# %%
# Trying out different window sizes
SPIKE_WINDOW_SIZES = [10, 20, 30, 40, 60, 80, 100]
results_dfs = []

for window_size in SPIKE_WINDOW_SIZES:
    print(f"Evaluating window size: {window_size}")

    aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price', window_size)

    # Prepare features and target
    FEATURE_COLUMNS = [TARGET_COLUMN, 'ARIMA_Residuals']  # Adjust as needed
    X, y = data_processing.prepare_features_and_target(aggregated_df, FEATURE_COLUMNS, 'spikes')

    # Split data 
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, shuffle=False)

    # Scale features
    X_train_scaled, X_test_scaled = data_processing.scale_features(X_train_raw, X_test_raw)

    # Create sequences
    X_train, y_train = data_processing.create_sequences(X_train_scaled, y_train, window_size)
    X_test, y_test = data_processing.create_sequences(X_test_scaled, y_test, window_size)

    print(f'X train shape: {X_train.shape}')

    output_file_path = f'{COMMODITY} + arima/results_{window_size}.csv'
    pred_file_path = f'{COMMODITY} + arima/predictions/{window_size}'
    print(pred_file_path)
    results_df = models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path, pred_file_path)
    results_df['Window Size'] = window_size
    results_dfs.append(results_df)
# Out:
# Evaluating window size: 10
# X train shape: (1035, 10, 2)
# cobalt + arima/predictions/10
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/LSTM_250_layers_predictions.npy
# 8/8 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/LSTM_200_layers_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/LSTM_100_layers_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/LSTM_50_layers_predictions.npy
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/RNN_200_units_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/RNN_150_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/RNN_100_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/RNN_50_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 711us/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 0s/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/10/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/10/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 20
# X train shape: (1025, 20, 2)
# cobalt + arima/predictions/20
# 8/8 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/LSTM_250_layers_predictions.npy
# 8/8 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/LSTM_200_layers_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/LSTM_100_layers_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/LSTM_50_layers_predictions.npy
# 8/8 [==============================] - 0s 0s/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 0s/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/RNN_200_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/RNN_150_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/RNN_100_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/RNN_50_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 814us/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 988us/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 775us/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/20/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/20/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 30
# X train shape: (1015, 30, 2)
# cobalt + arima/predictions/30
# 8/8 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/LSTM_250_layers_predictions.npy
# 8/8 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/LSTM_200_layers_predictions.npy
# 8/8 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/LSTM_100_layers_predictions.npy
# 8/8 [==============================] - 1s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/LSTM_50_layers_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/RNN_200_units_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/RNN_150_units_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/RNN_100_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/RNN_50_units_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_32_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 857us/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_32_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1000us/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_32_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_64_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_64_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_64_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_128_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_128_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_128_filters_3_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_256_filters_7_kernels_predictions.npy
# 8/8 [==============================] - 1s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_256_filters_5_kernels_predictions.npy
# 8/8 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/30/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/30/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 40
# X train shape: (1005, 40, 2)
# cobalt + arima/predictions/40
# 7/7 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/LSTM_250_layers_predictions.npy
# 7/7 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/LSTM_200_layers_predictions.npy
# 7/7 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/LSTM_100_layers_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/LSTM_50_layers_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/RNN_200_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/RNN_150_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/RNN_100_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/RNN_50_units_predictions.npy
# 7/7 [==============================] - 0s 968us/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_32_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 940us/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_32_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 930us/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_32_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 893us/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_64_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_64_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_64_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_128_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_128_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_128_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_256_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_256_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/40/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/40/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 60
# X train shape: (985, 60, 2)
# cobalt + arima/predictions/60
# 7/7 [==============================] - 0s 11ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/LSTM_250_layers_predictions.npy
# 7/7 [==============================] - 0s 10ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/LSTM_200_layers_predictions.npy
# 7/7 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/LSTM_100_layers_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/LSTM_50_layers_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_32_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_32_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_32_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_64_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_64_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_64_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_128_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_128_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_128_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_256_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_256_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_Attention_256_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/RNN_200_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/RNN_150_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/RNN_100_units_predictions.npy
# 7/7 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/RNN_50_units_predictions.npy
# 7/7 [==============================] - 0s 958us/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_32_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_32_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_32_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_64_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 976us/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_64_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_64_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_128_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_128_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_128_filters_3_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_256_filters_7_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_256_filters_5_kernels_predictions.npy
# 7/7 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/60/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/60/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 80
# X train shape: (965, 80, 2)
# cobalt + arima/predictions/80
# 6/6 [==============================] - 0s 15ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 15ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/RNN_100_units_predictions.csv
# ...
# Predictions saved to CSV file: cobalt + arima/predictions/80/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/80/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/80/CNN_256_filters_3_kernels_predictions.npy
# Evaluating window size: 100
# X train shape: (945, 100, 2)
# cobalt + arima/predictions/100
# 6/6 [==============================] - 0s 19ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 17ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/LSTM_200_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6/6 [==============================] - 0s 9ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/LSTM_100_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/LSTM_50_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/RNN_200_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/RNN_150_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/RNN_100_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/RNN_50_units_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/RNN_50_units_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: cobalt + arima/predictions/100/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: cobalt + arima/predictions/100/CNN_256_filters_3_kernels_predictions.npy

# %% [markdown]
# ## Evaluation

# %%
# Display all results df
for idx, df in enumerate(results_dfs):
    print(f"Results for window size: {SPIKE_WINDOW_SIZES[idx]}")
    display(df)
# Out:
# Results for window size: 10
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.940711       0.939759
# 1                 LSTM                  200 layers  0.940711       0.939759
# 2                 LSTM                  100 layers  0.940711       0.939759
# 3                 LSTM                   50 layers  0.940711       0.939759
# 4   CNN with Attention   32 filters, kernel size 7  0.952569       0.951220
# 5   CNN with Attention   32 filters, kernel size 5  0.964427       0.962963
# 6   CNN with Attention   32 filters, kernel size 3  0.976285       0.983051
# 7   CNN with Attention   64 filters, kernel size 7  0.952569       0.951220
# 8   CNN with Attention   64 filters, kernel size 5  0.972332       0.970954
# 9   CNN with Attention   64 filters, kernel size 3  0.972332       0.978903
# 10  CNN with Attention  128 filters, kernel size 7  0.944664       0.950820
# 11  CNN with Attention  128 filters, kernel size 5  0.944664       0.947154
# 12  CNN with Attention  128 filters, kernel size 3  0.948617       0.951020
# 13  CNN with Attention  256 filters, kernel size 7  0.948617       0.947368
# 14  CNN with Attention  256 filters, kernel size 5  0.940711       0.939759
# 15  CNN with Attention  256 filters, kernel size 3  0.940711       0.943320
# 16                 RNN                   200 units  0.944664       0.947154
# 17                 RNN                   150 units  0.940711       0.939759
# 18                 RNN                   100 units  0.940711       0.939759
# 19                 RNN                    50 units  0.940711       0.939759
# 20                 CNN   32 filters, kernel size 7  0.952569       0.951220
# 21                 CNN   32 filters, kernel size 5  0.956522       0.955102
# 22                 CNN   32 filters, kernel size 3  0.940711       0.946939
# 23                 CNN   64 filters, kernel size 7  0.956522       0.955102
# 24                 CNN   64 filters, kernel size 5  0.968379       0.966942
# 25                 CNN   64 filters, kernel size 3  0.968379       0.987069
# 26                 CNN  128 filters, kernel size 7  0.952569       0.951220
# 27                 CNN  128 filters, kernel size 5  0.976285       0.978992
# 28                 CNN  128 filters, kernel size 3  0.968379       0.982906
# 29                 CNN  256 filters, kernel size 7  0.956522       0.982684
# 30                 CNN  256 filters, kernel size 5  0.972332       0.991342
# 31                 CNN  256 filters, kernel size 3  0.972332       0.970954
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     1.000000  0.968944       1.000000    0.210526  0.347826           10
# 1     1.000000  0.968944       1.000000    0.210526  0.347826           10
# 2     1.000000  0.968944       1.000000    0.210526  0.347826           10
# 3     1.000000  0.968944       1.000000    0.210526  0.347826           10
# 4     1.000000  0.975000       1.000000    0.368421  0.538462           10
# 5     1.000000  0.981132       1.000000    0.526316  0.689655           10
# 6     0.991453  0.987234       0.882353    0.789474  0.833333           10
# 7     1.000000  0.975000       1.000000    0.368421  0.538462           10
# 8     1.000000  0.985263       1.000000    0.631579  0.774194           10
# 9     0.991453  0.985138       0.875000    0.736842  0.800000           10
# 10    0.991453  0.970711       0.777778    0.368421  0.500000           10
# 11    0.995726  0.970833       0.857143    0.315789  0.461538           10
# 12    0.995726  0.972860       0.875000    0.368421  0.518519           10
# 13    1.000000  0.972973       1.000000    0.315789  0.480000           10
# 14    1.000000  0.968944       1.000000    0.210526  0.347826           10
# 15    0.995726  0.968815       0.833333    0.263158  0.400000           10
# 16    0.995726  0.970833       0.857143    0.315789  0.461538           10
# 17    1.000000  0.968944       1.000000    0.210526  0.347826           10
# 18    1.000000  0.968944       1.000000    0.210526  0.347826           10
# 19    1.000000  0.968944       1.000000    0.210526  0.347826           10
# 20    1.000000  0.975000       1.000000    0.368421  0.538462           10
# 21    1.000000  0.977035       1.000000    0.421053  0.592593           10
# 22    0.991453  0.968685       0.750000    0.315789  0.444444           10
# 23    1.000000  0.977035       1.000000    0.421053  0.592593           10
# 24    1.000000  0.983193       1.000000    0.578947  0.733333           10
# 25    0.978632  0.982833       0.761905    0.842105  0.800000           10
# 26    1.000000  0.975000       1.000000    0.368421  0.538462           10
# 27    0.995726  0.987288       0.933333    0.736842  0.823529           10
# 28    0.982906  0.982906       0.789474    0.789474  0.789474           10
# 29    0.970085  0.976344       0.681818    0.789474  0.731707           10
# 30    0.978632  0.984946       0.772727    0.894737  0.829268           10
# 31    1.000000  0.985263       1.000000    0.631579  0.774194           10
# Results for window size: 20
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.934156       0.950673
# 1                 LSTM                  200 layers  0.950617       0.947598
# 2                 LSTM                  100 layers  0.954733       0.951754
# 3                 LSTM                   50 layers  0.950617       0.947598
# 4   CNN with Attention   32 filters, kernel size 7  0.958848       0.955947
# 5   CNN with Attention   32 filters, kernel size 5  0.950617       0.951542
# 6   CNN with Attention   32 filters, kernel size 3  0.958848       0.955947
# 7   CNN with Attention   64 filters, kernel size 7  0.954733       0.951754
# 8   CNN with Attention   64 filters, kernel size 5  0.958848       0.955947
# 9   CNN with Attention   64 filters, kernel size 3  0.958848       0.955947
# 10  CNN with Attention  128 filters, kernel size 7  0.954733       0.951754
# 11  CNN with Attention  128 filters, kernel size 5  0.954733       0.951754
# 12  CNN with Attention  128 filters, kernel size 3  0.954733       0.951754
# 13  CNN with Attention  256 filters, kernel size 7  0.946502       0.943478
# 14  CNN with Attention  256 filters, kernel size 5  0.954733       0.951754
# 15  CNN with Attention  256 filters, kernel size 3  0.950617       0.951542
# 16                 RNN                   200 units  0.958848       0.955947
# 17                 RNN                   150 units  0.962963       0.960177
# 18                 RNN                   100 units  0.950617       0.947598
# 19                 RNN                    50 units  0.958848       0.955947
# 20                 CNN   32 filters, kernel size 7  0.958848       0.960000
# 21                 CNN   32 filters, kernel size 5  0.958848       0.955947
# 22                 CNN   32 filters, kernel size 3  0.954733       0.955752
# 23                 CNN   64 filters, kernel size 7  0.958848       0.960000
# 24                 CNN   64 filters, kernel size 5  0.958848       0.955947
# 25                 CNN   64 filters, kernel size 3  0.958848       0.955947
# 26                 CNN  128 filters, kernel size 7  0.962963       0.960177
# 27                 CNN  128 filters, kernel size 5  0.962963       0.960177
# 28                 CNN  128 filters, kernel size 3  0.967078       0.964444
# 29                 CNN  256 filters, kernel size 7  0.958848       0.955947
# 30                 CNN  256 filters, kernel size 5  0.958848       0.955947
# 31                 CNN  256 filters, kernel size 3  0.962963       0.960177
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.976959  0.963636       0.750000    0.576923  0.652174           20
# 1     1.000000  0.973094       1.000000    0.538462  0.700000           20
# 2     1.000000  0.975281       1.000000    0.576923  0.731707           20
# 3     1.000000  0.973094       1.000000    0.538462  0.700000           20
# 4     1.000000  0.977477       1.000000    0.615385  0.761905           20
# 5     0.995392  0.972973       0.937500    0.576923  0.714286           20
# 6     1.000000  0.977477       1.000000    0.615385  0.761905           20
# 7     1.000000  0.975281       1.000000    0.576923  0.731707           20
# 8     1.000000  0.977477       1.000000    0.615385  0.761905           20
# 9     1.000000  0.977477       1.000000    0.615385  0.761905           20
# 10    1.000000  0.975281       1.000000    0.576923  0.731707           20
# 11    1.000000  0.975281       1.000000    0.576923  0.731707           20
# 12    1.000000  0.975281       1.000000    0.576923  0.731707           20
# 13    1.000000  0.970917       1.000000    0.500000  0.666667           20
# 14    1.000000  0.975281       1.000000    0.576923  0.731707           20
# 15    0.995392  0.972973       0.937500    0.576923  0.714286           20
# 16    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 17    1.000000  0.979684       1.000000    0.653846  0.790698           20
# 18    1.000000  0.973094       1.000000    0.538462  0.700000           20
# 19    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 20    0.995392  0.977376       0.944444    0.653846  0.772727           20
# 21    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 22    0.995392  0.975169       0.941176    0.615385  0.744186           20
# 23    0.995392  0.977376       0.944444    0.653846  0.772727           20
# 24    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 25    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 26    1.000000  0.979684       1.000000    0.653846  0.790698           20
# 27    1.000000  0.979684       1.000000    0.653846  0.790698           20
# 28    1.000000  0.981900       1.000000    0.692308  0.818182           20
# 29    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 30    1.000000  0.977477       1.000000    0.615385  0.761905           20
# 31    1.000000  0.979684       1.000000    0.653846  0.790698           20
# Results for window size: 30
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.974249       0.981221
# 1                 LSTM                  200 layers  0.982833       0.985915
# 2                 LSTM                  100 layers  0.982833       0.981395
# 3                 LSTM                   50 layers  0.991416       0.990610
# 4   CNN with Attention   32 filters, kernel size 7  0.991416       0.995261
# 5   CNN with Attention   32 filters, kernel size 5  0.982833       0.990521
# 6   CNN with Attention   32 filters, kernel size 3  0.987124       0.990566
# 7   CNN with Attention   64 filters, kernel size 7  0.991416       0.995261
# 8   CNN with Attention   64 filters, kernel size 5  0.982833       0.990521
# 9   CNN with Attention   64 filters, kernel size 3  0.987124       0.990566
# 10  CNN with Attention  128 filters, kernel size 7  0.991416       0.995261
# 11  CNN with Attention  128 filters, kernel size 5  0.982833       0.990521
# 12  CNN with Attention  128 filters, kernel size 3  0.987124       0.990566
# 13  CNN with Attention  256 filters, kernel size 7  0.991416       0.995261
# 14  CNN with Attention  256 filters, kernel size 5  0.982833       0.990521
# 15  CNN with Attention  256 filters, kernel size 3  0.987124       0.990566
# 16                 RNN                   200 units  0.987124       0.995238
# 17                 RNN                   150 units  0.978541       0.981308
# 18                 RNN                   100 units  0.987124       0.985981
# 19                 RNN                    50 units  0.995708       0.995283
# 20                 CNN   32 filters, kernel size 7  0.978541       0.995192
# 21                 CNN   32 filters, kernel size 5  0.991416       0.995261
# 22                 CNN   32 filters, kernel size 3  0.987124       0.995238
# 23                 CNN   64 filters, kernel size 7  0.978541       0.995192
# 24                 CNN   64 filters, kernel size 5  0.982833       0.995215
# 25                 CNN   64 filters, kernel size 3  0.987124       0.990566
# 26                 CNN  128 filters, kernel size 7  0.991416       0.995261
# 27                 CNN  128 filters, kernel size 5  0.991416       0.995261
# 28                 CNN  128 filters, kernel size 3  0.978541       0.995192
# 29                 CNN  256 filters, kernel size 7  0.991416       0.995261
# 30                 CNN  256 filters, kernel size 5  0.991416       0.995261
# 31                 CNN  256 filters, kernel size 3  0.987124       0.990566
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.990521  0.985849       0.900000    0.818182  0.857143           30
# 1     0.995261  0.990566       0.950000    0.863636  0.904762           30
# 2     1.000000  0.990610       1.000000    0.818182  0.900000           30
# 3     1.000000  0.995283       1.000000    0.909091  0.952381           30
# 4     0.995261  0.995261       0.954545    0.954545  0.954545           30
# 5     0.990521  0.990521       0.909091    0.909091  0.909091           30
# 6     0.995261  0.992908       0.952381    0.909091  0.930233           30
# 7     0.995261  0.995261       0.954545    0.954545  0.954545           30
# 8     0.990521  0.990521       0.909091    0.909091  0.909091           30
# 9     0.995261  0.992908       0.952381    0.909091  0.930233           30
# 10    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 11    0.990521  0.990521       0.909091    0.909091  0.909091           30
# 12    0.995261  0.992908       0.952381    0.909091  0.930233           30
# 13    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 14    0.990521  0.990521       0.909091    0.909091  0.909091           30
# 15    0.995261  0.992908       0.952381    0.909091  0.930233           30
# 16    0.990521  0.992874       0.913043    0.954545  0.933333           30
# 17    0.995261  0.988235       0.947368    0.818182  0.878049           30
# 18    1.000000  0.992941       1.000000    0.863636  0.926829           30
# 19    1.000000  0.997636       1.000000    0.954545  0.976744           30
# 20    0.981043  0.988067       0.840000    0.954545  0.893617           30
# 21    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 22    0.990521  0.992874       0.913043    0.954545  0.933333           30
# 23    0.981043  0.988067       0.840000    0.954545  0.893617           30
# 24    0.985782  0.990476       0.875000    0.954545  0.913043           30
# 25    0.995261  0.992908       0.952381    0.909091  0.930233           30
# 26    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 27    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 28    0.981043  0.988067       0.840000    0.954545  0.893617           30
# 29    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 30    0.995261  0.995261       0.954545    0.954545  0.954545           30
# 31    0.995261  0.992908       0.952381    0.909091  0.930233           30
# Results for window size: 40
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.950673       0.979899
# 1                 LSTM                  200 layers  0.986547       0.985366
# 2                 LSTM                  100 layers  0.968610       0.980296
# 3                 LSTM                   50 layers  0.973094       0.975728
# 4   CNN with Attention   32 filters, kernel size 7  0.955157       0.984848
# 5   CNN with Attention   32 filters, kernel size 5  0.964126       0.985000
# 6   CNN with Attention   32 filters, kernel size 3  0.973094       0.985149
# 7   CNN with Attention   64 filters, kernel size 7  0.964126       0.985000
# 8   CNN with Attention   64 filters, kernel size 5  0.964126       0.985000
# 9   CNN with Attention   64 filters, kernel size 3  0.964126       0.985000
# 10  CNN with Attention  128 filters, kernel size 7  0.964126       0.985000
# 11  CNN with Attention  128 filters, kernel size 5  0.964126       0.985000
# 12  CNN with Attention  128 filters, kernel size 3  0.968610       0.985075
# 13  CNN with Attention  256 filters, kernel size 7  0.964126       0.985000
# 14  CNN with Attention  256 filters, kernel size 5  0.959641       0.984925
# 15  CNN with Attention  256 filters, kernel size 3  0.964126       0.980198
# 16                 RNN                   200 units  0.977578       0.975845
# 17                 RNN                   150 units  0.964126       0.975490
# 18                 RNN                   100 units  0.973094       0.980392
# 19                 RNN                    50 units  0.977578       0.985222
# 20                 CNN   32 filters, kernel size 7  0.955157       0.984848
# 21                 CNN   32 filters, kernel size 5  0.959641       0.980100
# 22                 CNN   32 filters, kernel size 3  0.955157       0.984848
# 23                 CNN   64 filters, kernel size 7  0.955157       0.984848
# 24                 CNN   64 filters, kernel size 5  0.955157       0.984848
# 25                 CNN   64 filters, kernel size 3  0.955157       0.980000
# 26                 CNN  128 filters, kernel size 7  0.964126       0.985000
# 27                 CNN  128 filters, kernel size 5  0.959641       0.984925
# 28                 CNN  128 filters, kernel size 3  0.959641       0.984925
# 29                 CNN  256 filters, kernel size 7  0.959641       0.984925
# 30                 CNN  256 filters, kernel size 5  0.959641       0.980100
# 31                 CNN  256 filters, kernel size 3  0.964126       0.985000
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.965347  0.972569       0.708333    0.809524  0.755556           40
# 1     1.000000  0.992629       1.000000    0.857143  0.923077           40
# 2     0.985149  0.982716       0.850000    0.809524  0.829268           40
# 3     0.995050  0.985294       0.941176    0.761905  0.842105           40
# 4     0.965347  0.975000       0.720000    0.857143  0.782609           40
# 5     0.975248  0.980100       0.782609    0.857143  0.818182           40
# 6     0.985149  0.985149       0.857143    0.857143  0.857143           40
# 7     0.975248  0.980100       0.782609    0.857143  0.818182           40
# 8     0.975248  0.980100       0.782609    0.857143  0.818182           40
# 9     0.975248  0.980100       0.782609    0.857143  0.818182           40
# 10    0.975248  0.980100       0.782609    0.857143  0.818182           40
# 11    0.975248  0.980100       0.782609    0.857143  0.818182           40
# 12    0.980198  0.982630       0.818182    0.857143  0.837209           40
# 13    0.975248  0.980100       0.782609    0.857143  0.818182           40
# 14    0.970297  0.977556       0.750000    0.857143  0.800000           40
# 15    0.980198  0.980198       0.809524    0.809524  0.809524           40
# 16    1.000000  0.987775       1.000000    0.761905  0.864865           40
# 17    0.985149  0.980296       0.842105    0.761905  0.800000           40
# 18    0.990099  0.985222       0.894737    0.809524  0.850000           40
# 19    0.990099  0.987654       0.900000    0.857143  0.878049           40
# 20    0.965347  0.975000       0.720000    0.857143  0.782609           40
# 21    0.975248  0.977667       0.772727    0.809524  0.790698           40
# 22    0.965347  0.975000       0.720000    0.857143  0.782609           40
# 23    0.965347  0.975000       0.720000    0.857143  0.782609           40
# 24    0.965347  0.975000       0.720000    0.857143  0.782609           40
# 25    0.970297  0.975124       0.739130    0.809524  0.772727           40
# 26    0.975248  0.980100       0.782609    0.857143  0.818182           40
# 27    0.970297  0.977556       0.750000    0.857143  0.800000           40
# 28    0.970297  0.977556       0.750000    0.857143  0.800000           40
# 29    0.970297  0.977556       0.750000    0.857143  0.800000           40
# 30    0.975248  0.977667       0.772727    0.809524  0.790698           40
# 31    0.975248  0.980100       0.782609    0.857143  0.818182           40
# Results for window size: 60
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.965517       0.971910
# 1                 LSTM                  200 layers  0.965517       0.971910
# 2                 LSTM                  100 layers  0.970443       0.977401
# 3                 LSTM                   50 layers  0.960591       0.982659
# 4   CNN with Attention   32 filters, kernel size 7  0.960591       0.988304
# 5   CNN with Attention   32 filters, kernel size 5  0.965517       0.988372
# 6   CNN with Attention   32 filters, kernel size 3  0.955665       0.988235
# 7   CNN with Attention   64 filters, kernel size 7  0.970443       0.988439
# 8   CNN with Attention   64 filters, kernel size 5  0.965517       0.988372
# 9   CNN with Attention   64 filters, kernel size 3  0.960591       0.988304
# 10  CNN with Attention  128 filters, kernel size 7  0.970443       0.988439
# 11  CNN with Attention  128 filters, kernel size 5  0.965517       0.988372
# 12  CNN with Attention  128 filters, kernel size 3  0.970443       0.988439
# 13  CNN with Attention  256 filters, kernel size 7  0.970443       0.988439
# 14  CNN with Attention  256 filters, kernel size 5  0.960591       0.988304
# 15  CNN with Attention  256 filters, kernel size 3  0.965517       0.988372
# 16                 RNN                   200 units  0.862069       0.920000
# 17                 RNN                   150 units  0.857143       0.910112
# 18                 RNN                   100 units  0.896552       0.947674
# 19                 RNN                    50 units  0.881773       0.946746
# 20                 CNN   32 filters, kernel size 7  0.960591       0.988304
# 21                 CNN   32 filters, kernel size 5  0.955665       0.988235
# 22                 CNN   32 filters, kernel size 3  0.945813       0.976744
# 23                 CNN   64 filters, kernel size 7  0.955665       0.988235
# 24                 CNN   64 filters, kernel size 5  0.965517       0.988372
# 25                 CNN   64 filters, kernel size 3  0.955665       0.988235
# 26                 CNN  128 filters, kernel size 7  0.965517       0.988372
# 27                 CNN  128 filters, kernel size 5  0.965517       0.988372
# 28                 CNN  128 filters, kernel size 3  0.960591       0.988304
# 29                 CNN  256 filters, kernel size 7  0.960591       0.988304
# 30                 CNN  256 filters, kernel size 5  0.960591       0.988304
# 31                 CNN  256 filters, kernel size 3  0.960591       0.988304
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.988571  0.980170       0.920000    0.821429  0.867925           60
# 1     0.988571  0.980170       0.920000    0.821429  0.867925           60
# 2     0.988571  0.982955       0.923077    0.857143  0.888889           60
# 3     0.971429  0.977011       0.833333    0.892857  0.862069           60
# 4     0.965714  0.976879       0.812500    0.928571  0.866667           60
# 5     0.971429  0.979827       0.838710    0.928571  0.881356           60
# 6     0.960000  0.973913       0.787879    0.928571  0.852459           60
# 7     0.977143  0.982759       0.866667    0.928571  0.896552           60
# 8     0.971429  0.979827       0.838710    0.928571  0.881356           60
# 9     0.965714  0.976879       0.812500    0.928571  0.866667           60
# 10    0.977143  0.982759       0.866667    0.928571  0.896552           60
# 11    0.971429  0.979827       0.838710    0.928571  0.881356           60
# 12    0.977143  0.982759       0.866667    0.928571  0.896552           60
# 13    0.977143  0.982759       0.866667    0.928571  0.896552           60
# 14    0.965714  0.976879       0.812500    0.928571  0.866667           60
# 15    0.971429  0.979827       0.838710    0.928571  0.881356           60
# 16    0.920000  0.920000       0.500000    0.500000  0.500000           60
# 17    0.925714  0.917847       0.480000    0.428571  0.452830           60
# 18    0.931429  0.939481       0.612903    0.678571  0.644068           60
# 19    0.914286  0.930233       0.558824    0.678571  0.612903           60
# 20    0.965714  0.976879       0.812500    0.928571  0.866667           60
# 21    0.960000  0.973913       0.787879    0.928571  0.852459           60
# 22    0.960000  0.968300       0.774194    0.857143  0.813559           60
# 23    0.960000  0.973913       0.787879    0.928571  0.852459           60
# 24    0.971429  0.979827       0.838710    0.928571  0.881356           60
# 25    0.960000  0.973913       0.787879    0.928571  0.852459           60
# 26    0.971429  0.979827       0.838710    0.928571  0.881356           60
# 27    0.971429  0.979827       0.838710    0.928571  0.881356           60
# 28    0.965714  0.976879       0.812500    0.928571  0.866667           60
# 29    0.965714  0.976879       0.812500    0.928571  0.866667           60
# 30    0.965714  0.976879       0.812500    0.928571  0.866667           60
# 31    0.965714  0.976879       0.812500    0.928571  0.866667           60
# Results for window size: 80
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.928962       0.949045
# 1                 LSTM                  200 layers  0.890710       0.889535
# 2                 LSTM                  100 layers  0.770492       0.854430
# 3                 LSTM                   50 layers  0.754098       0.830303
# 4   CNN with Attention   32 filters, kernel size 7  0.918033       0.926380
# 5   CNN with Attention   32 filters, kernel size 5  0.923497       0.954545
# 6   CNN with Attention   32 filters, kernel size 3  0.907104       0.930818
# 7   CNN with Attention   64 filters, kernel size 7  0.923497       0.943038
# 8   CNN with Attention   64 filters, kernel size 5  0.912568       0.948052
# 9   CNN with Attention   64 filters, kernel size 3  0.885246       0.913043
# 10  CNN with Attention  128 filters, kernel size 7  0.923497       0.948718
# 11  CNN with Attention  128 filters, kernel size 5  0.912568       0.936709
# 12  CNN with Attention  128 filters, kernel size 3  0.912568       0.931250
# 13  CNN with Attention  256 filters, kernel size 7  0.918033       0.942675
# 14  CNN with Attention  256 filters, kernel size 5  0.934426       0.961039
# 15  CNN with Attention  256 filters, kernel size 3  0.923497       0.943038
# 16                 RNN                   200 units  0.803279       0.859756
# 17                 RNN                   150 units  0.775956       0.838323
# 18                 RNN                   100 units  0.786885       0.840237
# 19                 RNN                    50 units  0.803279       0.835227
# 20                 CNN   32 filters, kernel size 7  0.885246       0.913043
# 21                 CNN   32 filters, kernel size 5  0.901639       0.925000
# 22                 CNN   32 filters, kernel size 3  0.912568       0.942308
# 23                 CNN   64 filters, kernel size 7  0.912568       0.936709
# 24                 CNN   64 filters, kernel size 5  0.907104       0.941935
# 25                 CNN   64 filters, kernel size 3  0.863388       0.890909
# 26                 CNN  128 filters, kernel size 7  0.912568       0.942308
# 27                 CNN  128 filters, kernel size 5  0.901639       0.935897
# 28                 CNN  128 filters, kernel size 3  0.907104       0.936306
# 29                 CNN  256 filters, kernel size 7  0.928962       0.943396
# 30                 CNN  256 filters, kernel size 5  0.912568       0.948052
# 31                 CNN  256 filters, kernel size 3  0.918033       0.942675
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.967532  0.958199       0.807692    0.724138  0.763636           80
# 1     0.993506  0.938650       0.909091    0.344828  0.500000           80
# 2     0.876623  0.865385       0.240000    0.206897  0.222222           80
# 3     0.889610  0.858934       0.055556    0.034483  0.042553           80
# 4     0.980519  0.952681       0.850000    0.586207  0.693878           80
# 5     0.954545  0.954545       0.758621    0.758621  0.758621           80
# 6     0.961039  0.945687       0.750000    0.620690  0.679245           80
# 7     0.967532  0.955128       0.800000    0.689655  0.740741           80
# 8     0.948052  0.948052       0.724138    0.724138  0.724138           80
# 9     0.954545  0.933333       0.681818    0.517241  0.588235           80
# 10    0.961039  0.954839       0.777778    0.724138  0.750000           80
# 11    0.961039  0.948718       0.760000    0.655172  0.703704           80
# 12    0.967532  0.949045       0.782609    0.620690  0.692308           80
# 13    0.961039  0.951768       0.769231    0.689655  0.727273           80
# 14    0.961039  0.961039       0.793103    0.793103  0.793103           80
# 15    0.967532  0.955128       0.800000    0.689655  0.740741           80
# 16    0.915584  0.886792       0.315789    0.206897  0.250000           80
# 17    0.909091  0.872274       0.125000    0.068966  0.088889           80
# 18    0.922078  0.879257       0.142857    0.068966  0.093023           80
# 19    0.954545  0.890909       0.000000    0.000000  0.000000           80
# 20    0.954545  0.933333       0.681818    0.517241  0.588235           80
# 21    0.961039  0.942675       0.739130    0.586207  0.653846           80
# 22    0.954545  0.948387       0.740741    0.689655  0.714286           80
# 23    0.961039  0.948718       0.760000    0.655172  0.703704           80
# 24    0.948052  0.944984       0.714286    0.689655  0.701754           80
# 25    0.954545  0.921630       0.611111    0.379310  0.468085           80
# 26    0.954545  0.948387       0.740741    0.689655  0.714286           80
# 27    0.948052  0.941935       0.703704    0.655172  0.678571           80
# 28    0.954545  0.945338       0.730769    0.655172  0.690909           80
# 29    0.974026  0.958466       0.833333    0.689655  0.754717           80
# 30    0.948052  0.948052       0.724138    0.724138  0.724138           80
# 31    0.961039  0.951768       0.769231    0.689655  0.727273           80
# Results for window size: 100
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.932515       0.926667
# 1                 LSTM                  200 layers  0.852761       0.852761
# 2                 LSTM                  100 layers  0.852761       0.852761
# 3                 LSTM                   50 layers  0.852761       0.852761
# 4   CNN with Attention   32 filters, kernel size 7  0.901840       0.948905
# 5   CNN with Attention   32 filters, kernel size 5  0.846626       0.870130
# 6   CNN with Attention   32 filters, kernel size 3  0.883436       0.900000
# 7   CNN with Attention   64 filters, kernel size 7  0.914110       0.956204
# 8   CNN with Attention   64 filters, kernel size 5  0.895706       0.917808
# 9   CNN with Attention   64 filters, kernel size 3  0.920245       0.963235
# 10  CNN with Attention  128 filters, kernel size 7  0.907975       0.942857
# 11  CNN with Attention  128 filters, kernel size 5  0.926380       0.956835
# 12  CNN with Attention  128 filters, kernel size 3  0.938650       0.964029
# 13  CNN with Attention  256 filters, kernel size 7  0.914110       0.949640
# 14  CNN with Attention  256 filters, kernel size 5  0.914110       0.943262
# 15  CNN with Attention  256 filters, kernel size 3  0.926380       0.956835
# 16                 RNN                   200 units  0.742331       0.834483
# 17                 RNN                   150 units  0.822086       0.848101
# 18                 RNN                   100 units  0.742331       0.834483
# 19                 RNN                    50 units  0.852761       0.852761
# 20                 CNN   32 filters, kernel size 7  0.932515       0.944444
# 21                 CNN   32 filters, kernel size 5  0.895706       0.917808
# 22                 CNN   32 filters, kernel size 3  0.907975       0.930556
# 23                 CNN   64 filters, kernel size 7  0.907975       0.930556
# 24                 CNN   64 filters, kernel size 5  0.889571       0.906040
# 25                 CNN   64 filters, kernel size 3  0.907975       0.930556
# 26                 CNN  128 filters, kernel size 7  0.840491       0.850932
# 27                 CNN  128 filters, kernel size 5  0.895706       0.923611
# 28                 CNN  128 filters, kernel size 3  0.865031       0.892617
# 29                 CNN  256 filters, kernel size 7  0.901840       0.955556
# 30                 CNN  256 filters, kernel size 5  0.865031       0.882353
# 31                 CNN  256 filters, kernel size 3  0.889571       0.923077
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     1.000000  0.961938       1.000000    0.541667  0.702703          100
# 1     1.000000  0.920530       0.000000    0.000000  0.000000          100
# 2     1.000000  0.920530       0.000000    0.000000  0.000000          100
# 3     1.000000  0.920530       0.000000    0.000000  0.000000          100
# 4     0.935252  0.942029       0.653846    0.708333  0.680000          100
# 5     0.964029  0.914676       0.444444    0.166667  0.242424          100
# 6     0.971223  0.934256       0.692308    0.375000  0.486486          100
# 7     0.942446  0.949275       0.692308    0.750000  0.720000          100
# 8     0.964029  0.940351       0.705882    0.500000  0.585366          100
# 9     0.942446  0.952727       0.703704    0.791667  0.745098          100
# 10    0.949640  0.946237       0.695652    0.666667  0.680851          100
# 11    0.956835  0.956835       0.750000    0.750000  0.750000          100
# 12    0.964029  0.964029       0.791667    0.791667  0.791667          100
# 13    0.949640  0.949640       0.708333    0.708333  0.708333          100
# 14    0.956835  0.950000       0.727273    0.666667  0.695652          100
# 15    0.956835  0.956835       0.750000    0.750000  0.750000          100
# 16    0.870504  0.852113       0.000000    0.000000  0.000000          100
# 17    0.964029  0.902357       0.000000    0.000000  0.000000          100
# 18    0.870504  0.852113       0.000000    0.000000  0.000000          100
# 19    1.000000  0.920530       0.000000    0.000000  0.000000          100
# 20    0.978417  0.961131       0.842105    0.666667  0.744186          100
# 21    0.964029  0.940351       0.705882    0.500000  0.585366          100
# 22    0.964029  0.946996       0.736842    0.583333  0.651163          100
# 23    0.964029  0.946996       0.736842    0.583333  0.651163          100
# 24    0.971223  0.937500       0.714286    0.416667  0.526316          100
# 25    0.964029  0.946996       0.736842    0.583333  0.651163          100
# 26    0.985612  0.913333       0.000000    0.000000  0.000000          100
# 27    0.956835  0.939929       0.684211    0.541667  0.604651          100
# 28    0.956835  0.923611       0.571429    0.333333  0.421053          100
# 29    0.928058  0.941606       0.642857    0.750000  0.692308          100
# 30    0.971223  0.924658       0.600000    0.250000  0.352941          100
# 31    0.949640  0.936170       0.650000    0.541667  0.590909          100

# %% [markdown]
# ### **Random Under Sampling**

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler


# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomOverSampler BEFORE creating sequences
# random_under_sampler = RandomUnderSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_under_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# # Proceed with model training and evaluation
# evaluate_all_models(RUS_OUTPUT_PATH)

# %% [markdown]
# ### **Random Over Sampling**

# %%
# from imblearn.over_sampling import RandomOverSampler

# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomUnderSampler BEFORE creating sequences
# random_over_sampler = RandomOverSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_over_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# evaluate_all_models(ROS_OUTPUT_PATH)
