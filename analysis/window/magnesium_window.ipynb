# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install scikit-learn
# %pip install tensorflow
# %pip install -U imbalanced-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Dropout, LayerNormalization, MultiHeadAttention, Input
from tensorflow.keras.layers import Attention, Reshape
from tensorflow.keras.models import Model

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import models
import utils
import data_processing

# %%
COMMODITY = 'magnesium'

DATE_COLUMN = 'Date'
VALUE_COLUMN = 'Value'  
QUANTITY_COLUMN = 'Std. Quantity (KG)'
UNIT_RATE_COLUMN = 'Std. Unit Rate ($/KG)'
BRENT_OIL_COLUMN = 'Brent Oil Value'
WTI_OIL_COLUMN = 'WTI Oil Value'
SHIP_COUNT_COLUMN = 'ship_count'
PORT_COUNT_COLUMN = 'popular_port_count'

VALUE_SPIKES_COLUMN = 'Value Spikes'  
QUANTITY_SPIKES_COLUMN = 'Std. Quantity (KG) Spikes'
UNIT_RATE_SPIKES_COLUMN = 'Std. Unit Rate ($/KG) Spikes'
BRENT_OIL_SPIKES_COLUMN = 'Brent Oil Value Spikes'
WTI_OIL_SPIKES_COLUMN = 'WTI Oil Value Spikes'
SHIP_COUNT_SPIKES_COLUMN = 'Ship Count Spikes'
PORT_COUNT_SPIKES_COLUMN = 'Port Count Spikes'

FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_SPIKES_COLUMN, BRENT_OIL_SPIKES_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_SPIKES_COLUMN, PORT_COUNT_SPIKES_COLUMN]
TARGET_COLUMN = 'Price'

ORIGIN_COUNTRY_COLUMN = 'Country of Origin'
DEST_COUNTRY_COLUMN = 'Country of Destination'

PETROL_FILE_PATH = '../../volza/petroleum/petrol_crude_oil_spot_price.csv'
VOLZA_FILE_PATH = f'../../volza/{COMMODITY}/{COMMODITY}.csv'
PRICE_FILE_PATH = f"../../volza/{COMMODITY}/{COMMODITY}_prices.csv"
AIS_POPULAR_FILE_PATH = f'../../ais/ais_ml_features.csv' 

NB_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (No Balancing).csv"
RUS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Under Sampling).csv"
ROS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Over Sampling).csv"


SPIKES_THRESHOLD = 2
SPIKES_WINDOW_SIZE = 20
BIN_COUNT = 10
FILL_METHOD = 'ffill'

RANDOM_STATE = 42

# %% [markdown]
# ## Dataframe Prep

# %%
from datetime import datetime

#Formatting the date and price for Volza data
volza_pd = pd.read_csv(VOLZA_FILE_PATH)
volza_pd = volza_pd[(volza_pd["Country of Origin"].notnull()) & (volza_pd["Country of Destination"].notnull())]
volza_pd = volza_pd.rename(columns={'Unnamed: 0': 'ID'})
volza_pd['Date'] = volza_pd['Date'].apply(lambda x: x.split(' ')[0])
volza_pd['Date'] = pd.to_datetime(volza_pd['Date'], errors='raise', format='%Y-%m-%d')
volza_pd = utils.convert_to_kg(volza_pd)
volza_pd.head(3)
# Out:
#    ID       Date     HS Code               Product Description  \
# 0   0 2020-06-09  8104110000                MAGNESIUM METALLIC
# 1   1 2020-11-25  8104110000  MAGNESIUM METALLIC INGOTS 99.95%
# 3   3 2020-07-30    81041100                   MAGNESIUM INGOT
#
#                                        Consignee Notify Party Name  \
# 0  CORPORACION ECUATORIANA DE ALUMINIO S A CEDAL               NaN
# 1  CORPORACION ECUATORIANA DE ALUMINIO S A CEDAL               NaN
# 3                             PT LAUTAN LUAS TBK               NaN
#
#                            Shipper  Std. Quantity Std. Unit  \
# 0  Ningbo Distant Chemicals Co Ltd         5984.0       KGS
# 1  Ningbo Distant Chemicals Co Ltd         3000.0       KGS
# 3         POINTER INVESTEMT HK LTD           25.0       TNE
#
#   Standard Unit Rate INR  ...  Freight Term Marks Number  \
# 0                      -  ...             -            -
# 1                      -  ...             -            -
# 3                      -  ...             -            -
#
#                               HS Product Description Gross Weight  \
# 0  Con un contenido de magnesio superior o igual ...          0.0
# 1  Con un contenido de magnesio superior o igual ...          0.0
# 3                                                NaN          0.0
#
#                                    Consignee Address  \
# 0                                                NaN
# 1                                                NaN
# 3  Graha Indramas, Gedung, Jl. Ks. Tubun No.77, R...
#
#                                      Shipper Address Notify Party Address  \
# 0  Jingjia Road 188 Long Unit, Jiangdong, Ningbo,...                  NaN
# 1  Jingjia Road 188 Long Unit, Jiangdong, Ningbo,...                  NaN
# 3  RM 3408 CHINA MERCHANTS TOWER|SHUN TAK CENTRE ...                  NaN
#
#            Country Name Std. Quantity (KG) Std. Unit Rate ($/KG)
# 0   Ecuador T3+  Import             5984.0              3.025790
# 1   Ecuador T3+  Import             3000.0              3.057833
# 3  Indonesia T3  Import            25000.0              1.940000
#
# [3 rows x 34 columns]

# %%
#Preprocessing the AIS data
ais_popular_pd = pd.read_csv(AIS_POPULAR_FILE_PATH)
ais_popular_pd['Date'] = pd.to_datetime(ais_popular_pd['Date'])
ais_popular_pd.head(3)
# Out:
#         Date  ship_count popular_port  popular_port_count
# 0 2020-11-10           8        LTKLJ                  18
# 1 2020-11-12          20        IDSKP                   8
# 2 2020-11-29           9        CNSHA                   2

# %%
#Preprocessing the price data
prices_pd = pd.read_csv(PRICE_FILE_PATH)
prices_pd['Date'] = prices_pd['Date'].apply(lambda x: datetime.strptime(x, "%b %d, %Y").strftime("%Y-%m-%d"))
prices_pd['Date'] = pd.to_datetime(prices_pd['Date'], errors='raise', format='%Y-%m-%d')
prices_pd['Price'] = prices_pd['Price'].str.replace(',', '').astype(float)
prices_pd = prices_pd[['Date','Price']]
prices_pd.head(3)
# Out:
#         Date    Price
# 0 2022-12-30  21650.0
# 1 2022-12-29  21650.0
# 2 2022-12-28  21650.0

# %%
#Aggregate volza data by day
date_wise_volza = volza_pd.groupby("Date")[[VALUE_COLUMN,QUANTITY_COLUMN,'Gross Weight']].sum()

# %%
# Avg of Commodity Price in Volza
avg_price_volza = volza_pd.groupby('Date')[UNIT_RATE_COLUMN].mean()
date_wise_volza = date_wise_volza.join(avg_price_volza, how='left')
date_wise_volza
# Out:
#                    Value  Std. Quantity (KG)  Gross Weight  \
# Date
# 2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 2020-01-04  2.950597e+05        1.350000e+05           0.0
# 2020-01-05  4.420000e+04        2.000000e+04           0.0
# ...                  ...                 ...           ...
# 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#             Std. Unit Rate ($/KG)
# Date
# 2020-01-01               8.582012
# 2020-01-02               2.250000
# 2020-01-03             768.449153
# 2020-01-04               2.188610
# 2020-01-05               2.210000
# ...                           ...
# 2022-12-27               3.849999
# 2022-12-28               5.656118
# 2022-12-29               3.490332
# 2022-12-30               3.949859
# 2022-12-31               3.429595
#
# [969 rows x 4 columns]

# %%
# Petroleum data prep
petrol_df = pd.read_csv(PETROL_FILE_PATH, delimiter=';', on_bad_lines='warn')
petrol_df['Date'] = pd.to_datetime(petrol_df['Date'])

# Split based on types of oil
brent_df = petrol_df[petrol_df['product-name']=='UK Brent Crude Oil']
wti_df = petrol_df[petrol_df['product-name']=='WTI Crude Oil']

brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\273638861.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\273638861.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)

# %%
# Combining dataframes
prices_pd = prices_pd.set_index('Date')
ais_popular_pd = ais_popular_pd.set_index('Date')
date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\1674725426.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\1674725426.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\1674725426.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_20024\1674725426.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
#           Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0   2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 1   2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2   2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 3   2020-01-04  2.950597e+05        1.350000e+05           0.0
# 4   2020-01-05  4.420000e+04        2.000000e+04           0.0
# ..         ...           ...                 ...           ...
# 964 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 965 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 966 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 967 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 968 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#      Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 8.582012         NaN          NaN                 NaN
# 1                 2.250000         NaN          NaN                 NaN
# 2               768.449153         NaN          NaN                 NaN
# 3                 2.188610         NaN          NaN                 NaN
# 4                 2.210000         NaN          NaN                 NaN
# ..                     ...         ...          ...                 ...
# 964               3.849999     27245.0        SGSIN              9195.0
# 965               5.656118     26021.0        SGSIN              9233.0
# 966               3.490332     24039.0        SGSIN              8861.0
# 967               3.949859     19952.0        SGSIN              8118.0
# 968               3.429595      8925.0        USMSY              2673.0
#
#        Price  Brent Oil Value  WTI Oil Value
# 0        NaN            67.77          61.14
# 1    14150.0            67.05          61.17
# 2    14100.0            69.08          63.00
# 3    14100.0            69.08          63.00
# 4    14100.0            69.08          63.00
# ..       ...              ...            ...
# 964  21700.0            82.45          79.45
# 965  21650.0            81.70          78.89
# 966  21650.0            80.96          78.43
# 967  21650.0            82.82          80.16
# 968  21650.0            82.82          80.16
#
# [969 rows x 11 columns]

# %%
def detect_spikes(df, column, window_size):
    ## Detecting spikes
    moving_avg = df[column].rolling(window=window_size).mean()
    std_dev = df[column].rolling(window=window_size).std()

    # Set a threshold to identify spikes
    return (abs(aggregated_df[column] - moving_avg) > SPIKES_THRESHOLD * std_dev).astype(int)

# aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price')
# print("SPIKES : NON SPIKES = ")
# print(aggregated_df['spikes'].value_counts())
# print("PERCENT OF SPIKES", aggregated_df['spikes'].value_counts()[1]/len(aggregated_df))

# %% [markdown]
# # **Detect spikes**

# %%
# aggregated_df[VALUE_SPIKES_COLUMN] = detect_spikes(aggregated_df, VALUE_COLUMN)
# aggregated_df[QUANTITY_SPIKES_COLUMN] = detect_spikes(aggregated_df, QUANTITY_COLUMN)
# aggregated_df[UNIT_RATE_SPIKES_COLUMN] = detect_spikes(aggregated_df, UNIT_RATE_COLUMN)
# aggregated_df[WTI_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, WTI_OIL_COLUMN)
# aggregated_df[BRENT_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, BRENT_OIL_COLUMN)
# aggregated_df[SHIP_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, SHIP_COUNT_COLUMN)
# aggregated_df[PORT_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, PORT_COUNT_COLUMN)

# #Visualise Dataset

# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_SPIKES_COLUMN], label='Value Spikes', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_SPIKES_COLUMN], label='Quantity Spikes', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_SPIKES_COLUMN], label='Unit Rate Spikes', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_SPIKES_COLUMN], label='Brent Oil Value Spikes', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_SPIKES_COLUMN], label='WTI Oil Value Spikes', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Spikes', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value Spikes', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight / Brent Oil Value / WTI Oil Value / Ship Count / Port Count ', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
#remove date 2020-01-01
aggregated_df = aggregated_df[aggregated_df.index != '2020-01-01']
aggregated_df
# Out:
#           Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0   2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 1   2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2   2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 3   2020-01-04  2.950597e+05        1.350000e+05           0.0
# 4   2020-01-05  4.420000e+04        2.000000e+04           0.0
# ..         ...           ...                 ...           ...
# 964 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 965 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 966 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 967 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 968 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#      Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 8.582012         NaN          NaN                 NaN
# 1                 2.250000         NaN          NaN                 NaN
# 2               768.449153         NaN          NaN                 NaN
# 3                 2.188610         NaN          NaN                 NaN
# 4                 2.210000         NaN          NaN                 NaN
# ..                     ...         ...          ...                 ...
# 964               3.849999     27245.0        SGSIN              9195.0
# 965               5.656118     26021.0        SGSIN              9233.0
# 966               3.490332     24039.0        SGSIN              8861.0
# 967               3.949859     19952.0        SGSIN              8118.0
# 968               3.429595      8925.0        USMSY              2673.0
#
#        Price  Brent Oil Value  WTI Oil Value
# 0        NaN            67.77          61.14
# 1    14150.0            67.05          61.17
# 2    14100.0            69.08          63.00
# 3    14100.0            69.08          63.00
# 4    14100.0            69.08          63.00
# ..       ...              ...            ...
# 964  21700.0            82.45          79.45
# 965  21650.0            81.70          78.89
# 966  21650.0            80.96          78.43
# 967  21650.0            82.82          80.16
# 968  21650.0            82.82          80.16
#
# [969 rows x 11 columns]

# %%
# #Visualise Dataset
# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
# # Plotting the price data
# plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
# plt.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='blue')

# # Highlighting spikes
# spike_indices = aggregated_df[aggregated_df['spikes'] == 1].index
# spike_prices = aggregated_df.loc[spike_indices, 'Price']
# plt.scatter(spike_indices, spike_prices, color='red', marker='^', label='Spikes')

# # Adding labels and title
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.title('Price Data with Spikes')
# plt.legend()

# # Display the plot
# # plt.show()

# %% [markdown]
# ## Baseline

# %%
# # Count % of spikes 
# total_spikes = aggregated_df['spikes'].sum()
# total_data_points = len(aggregated_df)
# percentage_of_spikes = (total_spikes / total_data_points) * 100

# print(f"Percentage of Spikes: {percentage_of_spikes:.2f}%")

# %%
# from sklearn.metrics import precision_score, recall_score

# # Probability of spike
# spike_prob = aggregated_df['spikes'].mean()

# # Random baseline predictions
# random_predictions = np.random.choice([0, 1], size=len(aggregated_df), p=[1-spike_prob, spike_prob])

# # Calculate precision and recall for the random baseline
# random_precision = precision_score(aggregated_df['spikes'], random_predictions)
# random_recall = recall_score(aggregated_df['spikes'], random_predictions)

# print(f"Random Guessing Precision: {random_precision}")
# print(f"Random Guessing Recall: {random_recall}")

# %% [markdown]
# ## Data Prep for Classification

# %%
COLUMNS = FEATURE_COLUMNS + [TARGET_COLUMN]
print(COLUMNS)
# Out:
# ['Value', 'Std. Quantity (KG)', 'Std. Unit Rate ($/KG)', 'WTI Oil Value', 'Brent Oil Value', 'ship_count', 'popular_port_count', 'Price']

# %%
# # Discretize
# from sklearn.preprocessing import KBinsDiscretizer

# def discretize(df, columns, bins):
#     est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='kmeans')
#     df[columns] = est.fit_transform(df[columns])
#     return df

# # FEATURES_1 = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN]
# # FEATURES_2 = [WTI_OIL_COLUMN, BRENT_OIL_COLUMN]

# test_df = aggregated_df.copy()
# test_df[FEATURE_COLUMNS] = test_df[FEATURE_COLUMNS].fillna(0)

# # test_df = discretize(test_df, FEATURES_1, 2)
# # test_df = discretize(test_df, FEATURES_2, BIN_COUNT)
# discretized_df = discretize(test_df, FEATURE_COLUMNS, BIN_COUNT)
# # discretized_df = test_df.copy()
# test_df.head(2)

# %%
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(test_df.index, test_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(test_df.index, test_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(test_df.index, test_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(test_df.index, test_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(test_df.index, test_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(test_df.index, test_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(test_df.index, test_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(test_df.index, test_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# plt.show()

# %%
# # Convert the discretized data into a DataFrame
# discretized_df = pd.DataFrame(discretized_df, columns=FEATURE_COLUMNS)

# unique_values = discretized_df[VALUE_COLUMN].fillna(method=FILL_METHOD).unique()
# print(unique_values)

# bin_counts = {col: discretized_df[col].value_counts() for col in FEATURE_COLUMNS}

# # Plotting
# plt.figure(figsize=(15, len(FEATURE_COLUMNS) * 5))

# for i, column in enumerate(FEATURE_COLUMNS):
#     plt.subplot(len(FEATURE_COLUMNS), 1, i + 1)
#     bin_counts[column].sort_index().plot(kind='bar', ax=plt.gca())

#     plt.title(f'{column} Distribution')
#     plt.ylabel('Frequency')
#     plt.xlabel('Bins')

# plt.tight_layout()
# plt.show()

# %%
# Clean up before passing to Arima
initial_row_count = aggregated_df.shape[0]

columns_of_interest = ['Price']  # Add other columns as necessary

aggregated_df = aggregated_df.dropna(subset=columns_of_interest)

rows_dropped = initial_row_count - aggregated_df.shape[0]

print(f"Rows dropped due to NaN values: {rows_dropped}")
# Out:
# Rows dropped due to NaN values: 1

# %% [markdown]
# ## Train / Test Set Up

# %%
from sklearn.model_selection import train_test_split
import pmdarima as pm

# Fit an Auto ARIMA model to the 'Price' series
model = pm.auto_arima(aggregated_df['Price'], seasonal=True, m=12, suppress_warnings=True, stepwise=True, error_action='ignore')

# Forecast the series using the model (in-sample prediction)
forecast = model.predict_in_sample()

# Calculate residuals (difference between actual and forecasted values)
residuals = aggregated_df['Price'] - forecast

# Append residuals to DataFrame as a new feature (using residuals as a way to detect spike / anomaly)
aggregated_df = aggregated_df.copy()
aggregated_df['ARIMA_Residuals'] = residuals

# %%
# Trying out different window sizes
SPIKE_WINDOW_SIZES = [10, 20, 30, 40, 60, 80, 100]
results_dfs = []

for window_size in SPIKE_WINDOW_SIZES:
    print(f"Evaluating window size: {window_size}")

    aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price', window_size)

    # Prepare features and target
    FEATURE_COLUMNS = [TARGET_COLUMN, 'ARIMA_Residuals']  # Adjust as needed
    X, y = data_processing.prepare_features_and_target(aggregated_df, FEATURE_COLUMNS, 'spikes')

    # Split data 
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, shuffle=False)

    # Scale features
    X_train_scaled, X_test_scaled = data_processing.scale_features(X_train_raw, X_test_raw)

    # Create sequences
    X_train, y_train = data_processing.create_sequences(X_train_scaled, y_train, window_size)
    X_test, y_test = data_processing.create_sequences(X_test_scaled, y_test, window_size)

    print(f'X train shape: {X_train.shape}')

    output_file_path = f'{COMMODITY}/results_{window_size}.csv'
    pred_file_path = f'{COMMODITY}/predictions/{window_size}'
    print(pred_file_path)
    results_df = models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path, pred_file_path)
    results_df['Window Size'] = window_size
    results_dfs.append(results_df)
# Out:
# Evaluating window size: 10
# X train shape: (765, 10, 2)
# magnesium/predictions/10
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 20
# X train shape: (755, 20, 2)
# magnesium/predictions/20
# 6/6 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 30
# X train shape: (745, 30, 2)
# magnesium/predictions/30
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: magnesium/predictions/30/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: magnesium/predictions/30/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/30/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/30/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/30/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/30/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 40
# X train shape: (735, 40, 2)
# magnesium/predictions/40
# 5/5 [==============================] - 0s 10ms/step
# Predictions saved to CSV file: magnesium/predictions/40/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/LSTM_250_layers_predictions.npy
# 5/5 [==============================] - 0s 9ms/step
# Predictions saved to CSV file: magnesium/predictions/40/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/LSTM_200_layers_predictions.npy
# 5/5 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/40/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/LSTM_100_layers_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/40/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/LSTM_50_layers_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/RNN_200_units_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/RNN_150_units_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/RNN_100_units_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/40/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/40/RNN_50_units_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 60
# X train shape: (715, 60, 2)
# magnesium/predictions/60
# 5/5 [==============================] - 0s 19ms/step
# Predictions saved to CSV file: magnesium/predictions/60/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/LSTM_250_layers_predictions.npy
# 5/5 [==============================] - 0s 13ms/step
# Predictions saved to CSV file: magnesium/predictions/60/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/LSTM_200_layers_predictions.npy
# 5/5 [==============================] - 1s 9ms/step
# Predictions saved to CSV file: magnesium/predictions/60/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/LSTM_100_layers_predictions.npy
# 5/5 [==============================] - 1s 8ms/step
# Predictions saved to CSV file: magnesium/predictions/60/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/LSTM_50_layers_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_32_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_32_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_32_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_64_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_64_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_64_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_128_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_128_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_128_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_256_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_256_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/CNN_Attention_256_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/60/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/RNN_200_units_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/60/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/RNN_150_units_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/60/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/RNN_100_units_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/60/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/60/RNN_50_units_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 5/5 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 80
# X train shape: (695, 80, 2)
# magnesium/predictions/80
# 4/4 [==============================] - 1s 21ms/step
# Predictions saved to CSV file: magnesium/predictions/80/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/LSTM_250_layers_predictions.npy
# 4/4 [==============================] - 0s 17ms/step
# Predictions saved to CSV file: magnesium/predictions/80/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/LSTM_200_layers_predictions.npy
# 4/4 [==============================] - 0s 9ms/step
# Predictions saved to CSV file: magnesium/predictions/80/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/LSTM_100_layers_predictions.npy
# 4/4 [==============================] - 1s 8ms/step
# Predictions saved to CSV file: magnesium/predictions/80/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/LSTM_50_layers_predictions.npy
# 4/4 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_32_filters_7_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_32_filters_5_kernels_predictions.npy
# 4/4 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_32_filters_3_kernels_predictions.npy
# 4/4 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_64_filters_7_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_64_filters_5_kernels_predictions.npy
# 4/4 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_64_filters_3_kernels_predictions.npy
# 4/4 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_128_filters_7_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_128_filters_5_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_128_filters_3_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_256_filters_7_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_256_filters_5_kernels_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/CNN_Attention_256_filters_3_kernels_predictions.npy
# 4/4 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: magnesium/predictions/80/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/RNN_200_units_predictions.npy
# 4/4 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/80/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/RNN_150_units_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/RNN_100_units_predictions.npy
# 4/4 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/80/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/80/RNN_50_units_predictions.npy
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 4/4 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 100
# X train shape: (675, 100, 2)
# magnesium/predictions/100
# 3/3 [==============================] - 1s 25ms/step
# Predictions saved to CSV file: magnesium/predictions/100/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/LSTM_250_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 3/3 [==============================] - 1s 29ms/step
# Predictions saved to CSV file: magnesium/predictions/100/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/LSTM_200_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 3/3 [==============================] - 0s 12ms/step
# Predictions saved to CSV file: magnesium/predictions/100/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/LSTM_100_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E0EAD802C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: magnesium/predictions/100/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/LSTM_50_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E0EAF3DB20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_32_filters_7_kernels_predictions.npy
# 3/3 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_32_filters_5_kernels_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_32_filters_3_kernels_predictions.npy
# 3/3 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_64_filters_7_kernels_predictions.npy
# 3/3 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_64_filters_5_kernels_predictions.npy
# 3/3 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_64_filters_3_kernels_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_128_filters_7_kernels_predictions.npy
# 3/3 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_128_filters_5_kernels_predictions.npy
# 3/3 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_128_filters_3_kernels_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_256_filters_7_kernels_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_256_filters_5_kernels_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/CNN_Attention_256_filters_3_kernels_predictions.npy
# 3/3 [==============================] - 0s 7ms/step
# Predictions saved to CSV file: magnesium/predictions/100/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/RNN_200_units_predictions.npy
# 3/3 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: magnesium/predictions/100/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/RNN_150_units_predictions.npy
# 3/3 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/predictions/100/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/RNN_100_units_predictions.npy
# 3/3 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/100/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/100/RNN_50_units_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 3/3 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'

# %% [markdown]
# ## Evaluation

# %%
# Display all results df
for idx, df in enumerate(results_dfs):
    print(f"Results for window size: {SPIKE_WINDOW_SIZES[idx]}")
    display(df)
# Out:
# Results for window size: 10
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.816216       0.958333
# 1                 LSTM                  200 layers  0.854054       0.954248
# 2                 LSTM                  100 layers  0.886486       0.950311
# 3                 LSTM                   50 layers  0.935135       0.937500
# 4   CNN with Attention   32 filters, kernel size 7  0.967568       0.987805
# 5   CNN with Attention   32 filters, kernel size 5  0.956757       0.964706
# 6   CNN with Attention   32 filters, kernel size 3  0.956757       0.964706
# 7   CNN with Attention   64 filters, kernel size 7  0.951351       0.993711
# 8   CNN with Attention   64 filters, kernel size 5  0.972973       0.982036
# 9   CNN with Attention   64 filters, kernel size 3  0.956757       0.964706
# 10  CNN with Attention  128 filters, kernel size 7  0.967568       0.976190
# 11  CNN with Attention  128 filters, kernel size 5  0.962162       0.964912
# 12  CNN with Attention  128 filters, kernel size 3  0.962162       0.964912
# 13  CNN with Attention  256 filters, kernel size 7  0.940541       0.937853
# 14  CNN with Attention  256 filters, kernel size 5  0.962162       0.959538
# 15  CNN with Attention  256 filters, kernel size 3  0.962162       0.959538
# 16                 RNN                   200 units  0.897297       0.940120
# 17                 RNN                   150 units  0.918919       0.963190
# 18                 RNN                   100 units  0.913514       0.946429
# 19                 RNN                    50 units  0.908108       0.940828
# 20                 CNN   32 filters, kernel size 7  0.956757       0.970238
# 21                 CNN   32 filters, kernel size 5  0.962162       0.964912
# 22                 CNN   32 filters, kernel size 3  0.956757       0.954023
# 23                 CNN   64 filters, kernel size 7  0.962162       0.993789
# 24                 CNN   64 filters, kernel size 5  0.962162       0.964912
# 25                 CNN   64 filters, kernel size 3  0.972973       0.982036
# 26                 CNN  128 filters, kernel size 7  0.913514       0.993421
# 27                 CNN  128 filters, kernel size 5  0.972973       0.987879
# 28                 CNN  128 filters, kernel size 3  0.962162       0.964912
# 29                 CNN  256 filters, kernel size 7  0.967568       1.000000
# 30                 CNN  256 filters, kernel size 5  0.978378       1.000000
# 31                 CNN  256 filters, kernel size 3  0.956757       0.964706
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.831325  0.890323       0.317073    0.684211  0.433333           10
# 1     0.879518  0.915361       0.375000    0.631579  0.470588           10
# 2     0.921687  0.935780       0.458333    0.578947  0.511628           10
# 3     0.993976  0.964912       0.888889    0.421053  0.571429           10
# 4     0.975904  0.981818       0.809524    0.894737  0.850000           10
# 5     0.987952  0.976190       0.866667    0.684211  0.764706           10
# 6     0.987952  0.976190       0.866667    0.684211  0.764706           10
# 7     0.951807  0.972308       0.692308    0.947368  0.800000           10
# 8     0.987952  0.984985       0.888889    0.842105  0.864865           10
# 9     0.987952  0.976190       0.866667    0.684211  0.764706           10
# 10    0.987952  0.982036       0.882353    0.789474  0.833333           10
# 11    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 12    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 13    1.000000  0.967930       1.000000    0.421053  0.592593           10
# 14    1.000000  0.979351       1.000000    0.631579  0.774194           10
# 15    1.000000  0.979351       1.000000    0.631579  0.774194           10
# 16    0.945783  0.942943       0.500000    0.473684  0.486486           10
# 17    0.945783  0.954407       0.590909    0.684211  0.634146           10
# 18    0.957831  0.952096       0.588235    0.526316  0.555556           10
# 19    0.957831  0.949254       0.562500    0.473684  0.514286           10
# 20    0.981928  0.976048       0.823529    0.736842  0.777778           10
# 21    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 22    1.000000  0.976471       1.000000    0.578947  0.733333           10
# 23    0.963855  0.978593       0.750000    0.947368  0.837209           10
# 24    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 25    0.987952  0.984985       0.888889    0.842105  0.864865           10
# 26    0.909639  0.949686       0.545455    0.947368  0.692308           10
# 27    0.981928  0.984894       0.850000    0.894737  0.871795           10
# 28    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 29    0.963855  0.981595       0.760000    1.000000  0.863636           10
# 30    0.975904  0.987805       0.826087    1.000000  0.904762           10
# 31    0.987952  0.976190       0.866667    0.684211  0.764706           10
# Results for window size: 20
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.891429       0.911950
# 1                 LSTM                  200 layers  0.914286       0.929936
# 2                 LSTM                  100 layers  0.851429       0.930556
# 3                 LSTM                   50 layers  0.640000       0.967742
# 4   CNN with Attention   32 filters, kernel size 7  0.931429       0.948052
# 5   CNN with Attention   32 filters, kernel size 5  0.920000       0.935897
# 6   CNN with Attention   32 filters, kernel size 3  0.931429       0.948052
# 7   CNN with Attention   64 filters, kernel size 7  0.937143       0.960265
# 8   CNN with Attention   64 filters, kernel size 5  0.920000       0.947368
# 9   CNN with Attention   64 filters, kernel size 3  0.937143       0.948387
# 10  CNN with Attention  128 filters, kernel size 7  0.937143       0.960265
# 11  CNN with Attention  128 filters, kernel size 5  0.925714       0.947712
# 12  CNN with Attention  128 filters, kernel size 3  0.925714       0.947712
# 13  CNN with Attention  256 filters, kernel size 7  0.948571       0.966887
# 14  CNN with Attention  256 filters, kernel size 5  0.937143       0.948387
# 15  CNN with Attention  256 filters, kernel size 3  0.925714       0.941935
# 16                 RNN                   200 units  0.885714       0.891566
# 17                 RNN                   150 units  0.908571       0.903614
# 18                 RNN                   100 units  0.902857       0.923567
# 19                 RNN                    50 units  0.868571       0.889571
# 20                 CNN   32 filters, kernel size 7  0.925714       0.941935
# 21                 CNN   32 filters, kernel size 5  0.925714       0.936306
# 22                 CNN   32 filters, kernel size 3  0.920000       0.935897
# 23                 CNN   64 filters, kernel size 7  0.931429       0.948052
# 24                 CNN   64 filters, kernel size 5  0.937143       0.948387
# 25                 CNN   64 filters, kernel size 3  0.937143       0.948387
# 26                 CNN  128 filters, kernel size 7  0.925714       0.947712
# 27                 CNN  128 filters, kernel size 5  0.925714       0.947712
# 28                 CNN  128 filters, kernel size 3  0.931429       0.942308
# 29                 CNN  256 filters, kernel size 7  0.908571       0.952703
# 30                 CNN  256 filters, kernel size 5  0.931429       0.948052
# 31                 CNN  256 filters, kernel size 3  0.925714       0.947712
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.966667  0.938511       0.687500        0.44  0.536585           20
# 1     0.973333  0.951140       0.777778        0.56  0.651163           20
# 2     0.893333  0.911565       0.483871        0.60  0.535714           20
# 3     0.600000  0.740741       0.268293        0.88  0.411215           20
# 4     0.973333  0.960526       0.809524        0.68  0.739130           20
# 5     0.973333  0.954248       0.789474        0.60  0.681818           20
# 6     0.973333  0.960526       0.809524        0.68  0.739130           20
# 7     0.966667  0.963455       0.791667        0.76  0.775510           20
# 8     0.960000  0.953642       0.739130        0.68  0.708333           20
# 9     0.980000  0.963934       0.850000        0.68  0.755556           20
# 10    0.966667  0.963455       0.791667        0.76  0.775510           20
# 11    0.966667  0.957096       0.772727        0.68  0.723404           20
# 12    0.966667  0.957096       0.772727        0.68  0.723404           20
# 13    0.973333  0.970100       0.833333        0.80  0.816327           20
# 14    0.980000  0.963934       0.850000        0.68  0.755556           20
# 15    0.973333  0.957377       0.800000        0.64  0.711111           20
# 16    0.986667  0.936709       0.777778        0.28  0.411765           20
# 17    1.000000  0.949367       1.000000        0.36  0.529412           20
# 18    0.966667  0.944625       0.722222        0.52  0.604651           20
# 19    0.966667  0.926518       0.583333        0.28  0.378378           20
# 20    0.973333  0.957377       0.800000        0.64  0.711111           20
# 21    0.980000  0.957655       0.833333        0.60  0.697674           20
# 22    0.973333  0.954248       0.789474        0.60  0.681818           20
# 23    0.973333  0.960526       0.809524        0.68  0.739130           20
# 24    0.980000  0.963934       0.850000        0.68  0.755556           20
# 25    0.980000  0.963934       0.850000        0.68  0.755556           20
# 26    0.966667  0.957096       0.772727        0.68  0.723404           20
# 27    0.966667  0.957096       0.772727        0.68  0.723404           20
# 28    0.980000  0.960784       0.842105        0.64  0.727273           20
# 29    0.940000  0.946309       0.666667        0.72  0.692308           20
# 30    0.973333  0.960526       0.809524        0.68  0.739130           20
# 31    0.966667  0.957096       0.772727        0.68  0.723404           20
# Results for window size: 30
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.927273       0.958042
# 1                 LSTM                  200 layers  0.939394       0.934641
# 2                 LSTM                  100 layers  0.939394       0.971631
# 3                 LSTM                   50 layers  0.830303       0.896552
# 4   CNN with Attention   32 filters, kernel size 7  0.915152       0.992366
# 5   CNN with Attention   32 filters, kernel size 5  0.951515       1.000000
# 6   CNN with Attention   32 filters, kernel size 3  0.909091       0.992308
# 7   CNN with Attention   64 filters, kernel size 7  0.933333       0.985294
# 8   CNN with Attention   64 filters, kernel size 5  0.915152       1.000000
# 9   CNN with Attention   64 filters, kernel size 3  0.866667       0.991870
# 10  CNN with Attention  128 filters, kernel size 7  0.939394       0.992593
# 11  CNN with Attention  128 filters, kernel size 5  0.842424       1.000000
# 12  CNN with Attention  128 filters, kernel size 3  0.793939       1.000000
# 13  CNN with Attention  256 filters, kernel size 7  0.921212       0.992424
# 14  CNN with Attention  256 filters, kernel size 5  0.896970       1.000000
# 15  CNN with Attention  256 filters, kernel size 3  0.800000       0.991071
# 16                 RNN                   200 units  0.890909       0.888199
# 17                 RNN                   150 units  0.896970       0.893750
# 18                 RNN                   100 units  0.878788       0.886792
# 19                 RNN                    50 units  0.903030       0.937931
# 20                 CNN   32 filters, kernel size 7  0.927273       1.000000
# 21                 CNN   32 filters, kernel size 5  0.927273       1.000000
# 22                 CNN   32 filters, kernel size 3  0.921212       0.985075
# 23                 CNN   64 filters, kernel size 7  0.915152       0.992366
# 24                 CNN   64 filters, kernel size 5  0.927273       0.992481
# 25                 CNN   64 filters, kernel size 3  0.787879       0.990909
# 26                 CNN  128 filters, kernel size 7  0.933333       0.992537
# 27                 CNN  128 filters, kernel size 5  0.915152       1.000000
# 28                 CNN  128 filters, kernel size 3  0.878788       0.992000
# 29                 CNN  256 filters, kernel size 7  0.927273       0.985185
# 30                 CNN  256 filters, kernel size 5  0.945455       1.000000
# 31                 CNN  256 filters, kernel size 3  0.824242       1.000000
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.958042  0.958042       0.727273    0.727273  0.727273           30
# 1     1.000000  0.966216       1.000000    0.545455  0.705882           30
# 2     0.958042  0.964789       0.750000    0.818182  0.782609           30
# 3     0.909091  0.902778       0.350000    0.318182  0.333333           30
# 4     0.909091  0.948905       0.617647    0.954545  0.750000           30
# 5     0.944056  0.971223       0.733333    1.000000  0.846154           30
# 6     0.902098  0.945055       0.600000    0.954545  0.736842           30
# 7     0.937063  0.960573       0.689655    0.909091  0.784314           30
# 8     0.902098  0.948529       0.611111    1.000000  0.758621           30
# 9     0.853147  0.917293       0.500000    0.954545  0.656250           30
# 10    0.937063  0.964029       0.700000    0.954545  0.807692           30
# 11    0.818182  0.900000       0.458333    1.000000  0.628571           30
# 12    0.762238  0.865079       0.392857    1.000000  0.564103           30
# 13    0.916084  0.952727       0.636364    0.954545  0.763636           30
# 14    0.881119  0.936803       0.564103    1.000000  0.721311           30
# 15    0.776224  0.870588       0.396226    0.954545  0.560000           30
# 16    1.000000  0.940789       1.000000    0.181818  0.307692           30
# 17    1.000000  0.943894       1.000000    0.227273  0.370370           30
# 18    0.986014  0.933775       0.666667    0.181818  0.285714           30
# 19    0.951049  0.944444       0.650000    0.590909  0.619048           30
# 20    0.916084  0.956204       0.647059    1.000000  0.785714           30
# 21    0.916084  0.956204       0.647059    1.000000  0.785714           30
# 22    0.923077  0.953069       0.645161    0.909091  0.754717           30
# 23    0.909091  0.948905       0.617647    0.954545  0.750000           30
# 24    0.923077  0.956522       0.656250    0.954545  0.777778           30
# 25    0.762238  0.861660       0.381818    0.954545  0.545455           30
# 26    0.930070  0.960289       0.677419    0.954545  0.792453           30
# 27    0.902098  0.948529       0.611111    1.000000  0.758621           30
# 28    0.867133  0.925373       0.525000    0.954545  0.677419           30
# 29    0.930070  0.956835       0.666667    0.909091  0.769231           30
# 30    0.937063  0.967509       0.709677    1.000000  0.830189           30
# 31    0.797203  0.887160       0.431373    1.000000  0.602740           30
# Results for window size: 40
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.870968       0.885906
# 1                 LSTM                  200 layers  0.806452       0.872340
# 2                 LSTM                  100 layers  0.767742       0.930435
# 3                 LSTM                   50 layers  0.683871       0.957447
# 4   CNN with Attention   32 filters, kernel size 7  0.832258       0.973913
# 5   CNN with Attention   32 filters, kernel size 5  0.838710       0.950820
# 6   CNN with Attention   32 filters, kernel size 3  0.748387       0.961538
# 7   CNN with Attention   64 filters, kernel size 7  0.806452       0.964602
# 8   CNN with Attention   64 filters, kernel size 5  0.754839       0.961905
# 9   CNN with Attention   64 filters, kernel size 3  0.709677       0.959184
# 10  CNN with Attention  128 filters, kernel size 7  0.825806       0.973684
# 11  CNN with Attention  128 filters, kernel size 5  0.729032       0.969697
# 12  CNN with Attention  128 filters, kernel size 3  0.793548       0.963964
# 13  CNN with Attention  256 filters, kernel size 7  0.787097       0.972222
# 14  CNN with Attention  256 filters, kernel size 5  0.812903       0.973214
# 15  CNN with Attention  256 filters, kernel size 3  0.677419       0.956989
# 16                 RNN                   200 units  0.800000       0.888060
# 17                 RNN                   150 units  0.548387       0.891566
# 18                 RNN                   100 units  0.800000       0.926230
# 19                 RNN                    50 units  0.870968       0.880795
# 20                 CNN   32 filters, kernel size 7  0.858065       0.959350
# 21                 CNN   32 filters, kernel size 5  0.774194       0.971698
# 22                 CNN   32 filters, kernel size 3  0.554839       0.958333
# 23                 CNN   64 filters, kernel size 7  0.825806       0.982143
# 24                 CNN   64 filters, kernel size 5  0.806452       0.964602
# 25                 CNN   64 filters, kernel size 3  0.709677       0.978723
# 26                 CNN  128 filters, kernel size 7  0.838710       0.982456
# 27                 CNN  128 filters, kernel size 5  0.800000       0.972727
# 28                 CNN  128 filters, kernel size 3  0.696774       0.958333
# 29                 CNN  256 filters, kernel size 7  0.851613       0.982759
# 30                 CNN  256 filters, kernel size 5  0.858065       0.982906
# 31                 CNN  256 filters, kernel size 3  0.825806       0.973684
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.977778  0.929577       0.500000        0.15  0.230769           40
# 1     0.911111  0.891304       0.142857        0.10  0.117647           40
# 2     0.792593  0.856000       0.300000        0.60  0.400000           40
# 3     0.666667  0.786026       0.262295        0.80  0.395062           40
# 4     0.829630  0.896000       0.425000        0.85  0.566667           40
# 5     0.859259  0.902724       0.424242        0.70  0.528302           40
# 6     0.740741  0.836820       0.313725        0.80  0.450704           40
# 7     0.807407  0.879032       0.380952        0.80  0.516129           40
# 8     0.748148  0.841667       0.320000        0.80  0.457143           40
# 9     0.696296  0.806867       0.280702        0.80  0.415584           40
# 10    0.822222  0.891566       0.414634        0.85  0.557377           40
# 11    0.711111  0.820513       0.303571        0.85  0.447368           40
# 12    0.792593  0.869919       0.363636        0.80  0.500000           40
# 13    0.777778  0.864198       0.361702        0.85  0.507463           40
# 14    0.807407  0.882591       0.395349        0.85  0.539683           40
# 15    0.659259  0.780702       0.258065        0.80  0.390244           40
# 16    0.881481  0.884758       0.238095        0.25  0.243902           40
# 17    0.548148  0.678899       0.152778        0.55  0.239130           40
# 18    0.837037  0.879377       0.333333        0.55  0.415094           40
# 19    0.985185  0.930070       0.500000        0.10  0.166667           40
# 20    0.874074  0.914729       0.468750        0.75  0.576923           40
# 21    0.762963  0.854772       0.346939        0.85  0.492754           40
# 22    0.511111  0.666667       0.204819        0.85  0.330097           40
# 23    0.814815  0.890688       0.418605        0.90  0.571429           40
# 24    0.807407  0.879032       0.380952        0.80  0.516129           40
# 25    0.681481  0.803493       0.295082        0.90  0.444444           40
# 26    0.829630  0.899598       0.439024        0.90  0.590164           40
# 27    0.792593  0.873469       0.377778        0.85  0.523077           40
# 28    0.681481  0.796537       0.271186        0.80  0.405063           40
# 29    0.844444  0.908367       0.461538        0.90  0.610169           40
# 30    0.851852  0.912698       0.473684        0.90  0.620690           40
# 31    0.822222  0.891566       0.414634        0.85  0.557377           40
# Results for window size: 60
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.792593       0.838710
# 1                 LSTM                  200 layers  0.844444       0.869919
# 2                 LSTM                  100 layers  0.822222       0.958333
# 3                 LSTM                   50 layers  0.718519       0.808333
# 4   CNN with Attention   32 filters, kernel size 7  0.866667       0.898305
# 5   CNN with Attention   32 filters, kernel size 5  0.851852       0.903509
# 6   CNN with Attention   32 filters, kernel size 3  0.777778       0.886792
# 7   CNN with Attention   64 filters, kernel size 7  0.859259       0.904348
# 8   CNN with Attention   64 filters, kernel size 5  0.822222       0.915094
# 9   CNN with Attention   64 filters, kernel size 3  0.800000       0.912621
# 10  CNN with Attention  128 filters, kernel size 7  0.777778       0.886792
# 11  CNN with Attention  128 filters, kernel size 5  0.770370       0.893204
# 12  CNN with Attention  128 filters, kernel size 3  0.681481       0.925926
# 13  CNN with Attention  256 filters, kernel size 7  0.792593       0.875000
# 14  CNN with Attention  256 filters, kernel size 5  0.770370       0.900990
# 15  CNN with Attention  256 filters, kernel size 3  0.733333       0.880000
# 16                 RNN                   200 units  0.725926       1.000000
# 17                 RNN                   150 units  0.622222       0.984127
# 18                 RNN                   100 units  0.777778       0.820312
# 19                 RNN                    50 units  0.562963       0.884058
# 20                 CNN   32 filters, kernel size 7  0.881481       0.900000
# 21                 CNN   32 filters, kernel size 5  0.837037       0.932692
# 22                 CNN   32 filters, kernel size 3  0.785185       0.887850
# 23                 CNN   64 filters, kernel size 7  0.800000       0.882883
# 24                 CNN   64 filters, kernel size 5  0.733333       0.931818
# 25                 CNN   64 filters, kernel size 3  0.740741       0.896907
# 26                 CNN  128 filters, kernel size 7  0.814815       0.899083
# 27                 CNN  128 filters, kernel size 5  0.807407       0.930000
# 28                 CNN  128 filters, kernel size 3  0.614815       0.905405
# 29                 CNN  256 filters, kernel size 7  0.844444       0.895652
# 30                 CNN  256 filters, kernel size 5  0.711111       0.939759
# 31                 CNN  256 filters, kernel size 3  0.851852       0.918182
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.928571  0.881356       0.272727    0.130435  0.176471           60
# 1     0.955357  0.910638       0.583333    0.304348  0.400000           60
# 2     0.821429  0.884615       0.487179    0.826087  0.612903           60
# 3     0.866071  0.836207       0.000000    0.000000  0.000000           60
# 4     0.946429  0.921739       0.647059    0.478261  0.550000           60
# 5     0.919643  0.911504       0.571429    0.521739  0.545455           60
# 6     0.839286  0.862385       0.379310    0.478261  0.423077           60
# 7     0.928571  0.916300       0.600000    0.521739  0.558140           60
# 8     0.866071  0.889908       0.482759    0.608696  0.538462           60
# 9     0.839286  0.874419       0.437500    0.608696  0.509091           60
# 10    0.839286  0.862385       0.379310    0.478261  0.423077           60
# 11    0.821429  0.855814       0.375000    0.521739  0.436364           60
# 12    0.669643  0.777202       0.314815    0.739130  0.441558           60
# 13    0.875000  0.875000       0.391304    0.391304  0.391304           60
# 14    0.812500  0.854460       0.382353    0.565217  0.456140           60
# 15    0.785714  0.830189       0.314286    0.478261  0.379310           60
# 16    0.669643  0.802139       0.383333    1.000000  0.554217           60
# 17    0.553571  0.708571       0.305556    0.956522  0.463158           60
# 18    0.937500  0.875000       0.000000    0.000000  0.000000           60
# 19    0.544643  0.674033       0.227273    0.652174  0.337079           60
# 20    0.964286  0.931034       0.733333    0.478261  0.578947           60
# 21    0.866071  0.898148       0.516129    0.695652  0.592593           60
# 22    0.848214  0.867580       0.392857    0.478261  0.431373           60
# 23    0.875000  0.878924       0.416667    0.434783  0.425532           60
# 24    0.732143  0.820000       0.361702    0.739130  0.485714           60
# 25    0.776786  0.832536       0.342105    0.565217  0.426230           60
# 26    0.875000  0.886878       0.461538    0.521739  0.489796           60
# 27    0.830357  0.877358       0.457143    0.695652  0.551724           60
# 28    0.598214  0.720430       0.262295    0.695652  0.380952           60
# 29    0.919643  0.907489       0.550000    0.478261  0.511628           60
# 30    0.696429  0.800000       0.346154    0.782609  0.480000           60
# 31    0.901786  0.909910       0.560000    0.608696  0.583333           60
# Results for window size: 80
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.791304       0.805310
# 1                 LSTM                  200 layers  0.765217       0.800000
# 2                 LSTM                  100 layers  0.295652       0.928571
# 3                 LSTM                   50 layers  0.539130       0.777778
# 4   CNN with Attention   32 filters, kernel size 7  0.930435       0.977528
# 5   CNN with Attention   32 filters, kernel size 5  0.904348       0.965909
# 6   CNN with Attention   32 filters, kernel size 3  0.817391       0.928571
# 7   CNN with Attention   64 filters, kernel size 7  0.886957       0.944444
# 8   CNN with Attention   64 filters, kernel size 5  0.860870       0.952941
# 9   CNN with Attention   64 filters, kernel size 3  0.834783       0.920455
# 10  CNN with Attention  128 filters, kernel size 7  0.878261       0.924731
# 11  CNN with Attention  128 filters, kernel size 5  0.800000       0.916667
# 12  CNN with Attention  128 filters, kernel size 3  0.765217       0.892857
# 13  CNN with Attention  256 filters, kernel size 7  0.860870       0.987342
# 14  CNN with Attention  256 filters, kernel size 5  0.826087       0.892473
# 15  CNN with Attention  256 filters, kernel size 3  0.739130       0.800000
# 16                 RNN                   200 units  0.234783       1.000000
# 17                 RNN                   150 units  0.608696       0.766667
# 18                 RNN                   100 units  0.608696       0.760870
# 19                 RNN                    50 units  0.321739       1.000000
# 20                 CNN   32 filters, kernel size 7  0.834783       0.862745
# 21                 CNN   32 filters, kernel size 5  0.852174       0.963415
# 22                 CNN   32 filters, kernel size 3  0.739130       0.870588
# 23                 CNN   64 filters, kernel size 7  0.904348       0.910000
# 24                 CNN   64 filters, kernel size 5  0.808696       0.890110
# 25                 CNN   64 filters, kernel size 3  0.765217       0.843750
# 26                 CNN  128 filters, kernel size 7  0.921739       0.977273
# 27                 CNN  128 filters, kernel size 5  0.826087       0.910112
# 28                 CNN  128 filters, kernel size 3  0.643478       0.817073
# 29                 CNN  256 filters, kernel size 7  0.869565       0.987500
# 30                 CNN  256 filters, kernel size 5  0.800000       0.972973
# 31                 CNN  256 filters, kernel size 3  0.765217       0.902439
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.978495  0.883495       0.000000    0.000000  0.000000           80
# 1     0.946237  0.866995       0.000000    0.000000  0.000000           80
# 2     0.139785  0.242991       0.207921    0.954545  0.341463           80
# 3     0.602151  0.678788       0.139535    0.272727  0.184615           80
# 4     0.935484  0.956044       0.769231    0.909091  0.833333           80
# 5     0.913978  0.939227       0.703704    0.863636  0.775510           80
# 6     0.838710  0.881356       0.516129    0.727273  0.603774           80
# 7     0.913978  0.928962       0.680000    0.772727  0.723404           80
# 8     0.870968  0.910112       0.600000    0.818182  0.692308           80
# 9     0.870968  0.895028       0.555556    0.681818  0.612245           80
# 10    0.924731  0.924731       0.681818    0.681818  0.681818           80
# 11    0.827957  0.870056       0.483871    0.681818  0.566038           80
# 12    0.806452  0.847458       0.419355    0.590909  0.490566           80
# 13    0.838710  0.906977       0.583333    0.954545  0.724138           80
# 14    0.892473  0.892473       0.545455    0.545455  0.545455           80
# 15    0.903226  0.848485       0.100000    0.045455  0.062500           80
# 16    0.053763  0.102041       0.200000    1.000000  0.333333           80
# 17    0.741935  0.754098       0.040000    0.045455  0.042553           80
# 18    0.752688  0.756757       0.000000    0.000000  0.000000           80
# 19    0.161290  0.277778       0.220000    1.000000  0.360656           80
# 20    0.946237  0.902564       0.615385    0.363636  0.457143           80
# 21    0.849462  0.902857       0.575758    0.863636  0.690909           80
# 22    0.795699  0.831461       0.366667    0.500000  0.423077           80
# 23    0.978495  0.943005       0.866667    0.590909  0.702703           80
# 24    0.870968  0.880435       0.500000    0.545455  0.521739           80
# 25    0.870968  0.857143       0.368421    0.318182  0.341463           80
# 26    0.924731  0.950276       0.740741    0.909091  0.816327           80
# 27    0.870968  0.890110       0.538462    0.636364  0.583333           80
# 28    0.720430  0.765714       0.212121    0.318182  0.254545           80
# 29    0.849462  0.913295       0.600000    0.954545  0.736842           80
# 30    0.774194  0.862275       0.487805    0.909091  0.634921           80
# 31    0.795699  0.845714       0.424242    0.636364  0.509091           80
# Results for window size: 100
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.715789       0.715789
# 1                 LSTM                  200 layers  0.715789       0.715789
# 2                 LSTM                  100 layers  0.715789       0.715789
# 3                 LSTM                   50 layers  0.715789       0.715789
# 4   CNN with Attention   32 filters, kernel size 7  0.821053       0.849315
# 5   CNN with Attention   32 filters, kernel size 5  0.810526       0.820513
# 6   CNN with Attention   32 filters, kernel size 3  0.800000       0.818182
# 7   CNN with Attention   64 filters, kernel size 7  0.821053       0.831169
# 8   CNN with Attention   64 filters, kernel size 5  0.863158       0.923077
# 9   CNN with Attention   64 filters, kernel size 3  0.789474       0.800000
# 10  CNN with Attention  128 filters, kernel size 7  0.810526       0.828947
# 11  CNN with Attention  128 filters, kernel size 5  0.789474       0.807692
# 12  CNN with Attention  128 filters, kernel size 3  0.863158       0.876712
# 13  CNN with Attention  256 filters, kernel size 7  0.789474       0.779070
# 14  CNN with Attention  256 filters, kernel size 5  0.884211       0.925373
# 15  CNN with Attention  256 filters, kernel size 3  0.800000       0.810127
# 16                 RNN                   200 units  0.705263       0.712766
# 17                 RNN                   150 units  0.484211       1.000000
# 18                 RNN                   100 units  0.705263       0.712766
# 19                 RNN                    50 units  0.715789       0.715789
# 20                 CNN   32 filters, kernel size 7  0.747368       0.750000
# 21                 CNN   32 filters, kernel size 5  0.757895       0.771084
# 22                 CNN   32 filters, kernel size 3  0.747368       0.755814
# 23                 CNN   64 filters, kernel size 7  0.726316       0.744186
# 24                 CNN   64 filters, kernel size 5  0.778947       0.776471
# 25                 CNN   64 filters, kernel size 3  0.800000       0.845070
# 26                 CNN  128 filters, kernel size 7  0.757895       0.771084
# 27                 CNN  128 filters, kernel size 5  0.778947       0.797468
# 28                 CNN  128 filters, kernel size 3  0.821053       0.840000
# 29                 CNN  256 filters, kernel size 7  0.789474       0.779070
# 30                 CNN  256 filters, kernel size 5  0.789474       0.792683
# 31                 CNN  256 filters, kernel size 3  0.821053       0.831169
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 1     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 2     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 3     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 4     0.911765  0.879433       0.727273    0.592593  0.653061          100
# 5     0.941176  0.876712       0.764706    0.481481  0.590909          100
# 6     0.926471  0.868966       0.722222    0.481481  0.577778          100
# 7     0.941176  0.882759       0.777778    0.518519  0.622222          100
# 8     0.882353  0.902256       0.733333    0.814815  0.771930          100
# 9     0.941176  0.864865       0.733333    0.407407  0.523810          100
# 10    0.926471  0.875000       0.736842    0.518519  0.608696          100
# 11    0.926471  0.863014       0.705882    0.444444  0.545455          100
# 12    0.941176  0.907801       0.818182    0.666667  0.734694          100
# 13    0.985294  0.870130       0.888889    0.296296  0.444444          100
# 14    0.911765  0.918519       0.785714    0.814815  0.800000          100
# 15    0.941176  0.870748       0.750000    0.444444  0.558140          100
# 16    0.985294  0.827160       0.000000    0.000000  0.000000          100
# 17    0.279412  0.436782       0.355263    1.000000  0.524272          100
# 18    0.985294  0.827160       0.000000    0.000000  0.000000          100
# 19    1.000000  0.834356       0.000000    0.000000  0.000000          100
# 20    0.970588  0.846154       0.714286    0.185185  0.294118          100
# 21    0.941176  0.847682       0.666667    0.296296  0.410256          100
# 22    0.955882  0.844156       0.666667    0.222222  0.333333          100
# 23    0.941176  0.831169       0.555556    0.185185  0.277778          100
# 24    0.970588  0.862745       0.800000    0.296296  0.432432          100
# 25    0.882353  0.863309       0.666667    0.592593  0.627451          100
# 26    0.941176  0.847682       0.666667    0.296296  0.410256          100
# 27    0.926471  0.857143       0.687500    0.407407  0.511628          100
# 28    0.926471  0.881119       0.750000    0.555556  0.638298          100
# 29    0.985294  0.870130       0.888889    0.296296  0.444444          100
# 30    0.955882  0.866667       0.769231    0.370370  0.500000          100
# 31    0.941176  0.882759       0.777778    0.518519  0.622222          100

# %% [markdown]
# ### **Random Under Sampling**

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler


# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomOverSampler BEFORE creating sequences
# random_under_sampler = RandomUnderSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_under_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# # Proceed with model training and evaluation
# evaluate_all_models(RUS_OUTPUT_PATH)

# %% [markdown]
# ### **Random Over Sampling**

# %%
# from imblearn.over_sampling import RandomOverSampler

# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomUnderSampler BEFORE creating sequences
# random_over_sampler = RandomOverSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_over_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# evaluate_all_models(ROS_OUTPUT_PATH)
