# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install scikit-learn
# %pip install tensorflow
# %pip install -U imbalanced-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Dropout, LayerNormalization, MultiHeadAttention, Input
from tensorflow.keras.layers import Attention, Reshape
from tensorflow.keras.models import Model
# Out:
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import models
import utils
import data_processing

# %%
COMMODITY = 'magnesium'

DATE_COLUMN = 'Date'
VALUE_COLUMN = 'Value'  
QUANTITY_COLUMN = 'Std. Quantity (KG)'
UNIT_RATE_COLUMN = 'Std. Unit Rate ($/KG)'
BRENT_OIL_COLUMN = 'Brent Oil Value'
WTI_OIL_COLUMN = 'WTI Oil Value'
SHIP_COUNT_COLUMN = 'ship_count'
PORT_COUNT_COLUMN = 'popular_port_count'

VALUE_SPIKES_COLUMN = 'Value Spikes'  
QUANTITY_SPIKES_COLUMN = 'Std. Quantity (KG) Spikes'
UNIT_RATE_SPIKES_COLUMN = 'Std. Unit Rate ($/KG) Spikes'
BRENT_OIL_SPIKES_COLUMN = 'Brent Oil Value Spikes'
WTI_OIL_SPIKES_COLUMN = 'WTI Oil Value Spikes'
SHIP_COUNT_SPIKES_COLUMN = 'Ship Count Spikes'
PORT_COUNT_SPIKES_COLUMN = 'Port Count Spikes'

FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_SPIKES_COLUMN, BRENT_OIL_SPIKES_COLUMN]
# FEATURE_COLUMNS = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN,  WTI_OIL_COLUMN, BRENT_OIL_COLUMN, SHIP_COUNT_SPIKES_COLUMN, PORT_COUNT_SPIKES_COLUMN]
TARGET_COLUMN = 'Price'

ORIGIN_COUNTRY_COLUMN = 'Country of Origin'
DEST_COUNTRY_COLUMN = 'Country of Destination'

PETROL_FILE_PATH = '../../volza/petroleum/petrol_crude_oil_spot_price.csv'
VOLZA_FILE_PATH = f'../../volza/{COMMODITY}/{COMMODITY}.csv'
PRICE_FILE_PATH = f"../../volza/{COMMODITY}/{COMMODITY}_prices.csv"
AIS_POPULAR_FILE_PATH = f'../../ais/ais_ml_features.csv' 

NB_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (No Balancing).csv"
RUS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Under Sampling).csv"
ROS_OUTPUT_PATH = f"{COMMODITY}/{COMMODITY}_model_performance (Random Over Sampling).csv"


SPIKES_THRESHOLD = 2
SPIKES_WINDOW_SIZE = 20
BIN_COUNT = 10
FILL_METHOD = 'ffill'

RANDOM_STATE = 42

# %% [markdown]
# ## Dataframe Prep

# %%
from datetime import datetime

#Formatting the date and price for Volza data
volza_pd = pd.read_csv(VOLZA_FILE_PATH)
volza_pd = volza_pd[(volza_pd["Country of Origin"].notnull()) & (volza_pd["Country of Destination"].notnull())]
volza_pd = volza_pd.rename(columns={'Unnamed: 0': 'ID'})
volza_pd['Date'] = volza_pd['Date'].apply(lambda x: x.split(' ')[0])
volza_pd['Date'] = pd.to_datetime(volza_pd['Date'], errors='raise', format='%Y-%m-%d')
volza_pd = utils.convert_to_kg(volza_pd)
volza_pd.head(3)
# Out:
#    ID       Date     HS Code               Product Description  \
# 0   0 2020-06-09  8104110000                MAGNESIUM METALLIC
# 1   1 2020-11-25  8104110000  MAGNESIUM METALLIC INGOTS 99.95%
# 3   3 2020-07-30    81041100                   MAGNESIUM INGOT
#
#                                        Consignee Notify Party Name  \
# 0  CORPORACION ECUATORIANA DE ALUMINIO S A CEDAL               NaN
# 1  CORPORACION ECUATORIANA DE ALUMINIO S A CEDAL               NaN
# 3                             PT LAUTAN LUAS TBK               NaN
#
#                            Shipper  Std. Quantity Std. Unit  \
# 0  Ningbo Distant Chemicals Co Ltd         5984.0       KGS
# 1  Ningbo Distant Chemicals Co Ltd         3000.0       KGS
# 3         POINTER INVESTEMT HK LTD           25.0       TNE
#
#   Standard Unit Rate INR  ...  Freight Term Marks Number  \
# 0                      -  ...             -            -
# 1                      -  ...             -            -
# 3                      -  ...             -            -
#
#                               HS Product Description Gross Weight  \
# 0  Con un contenido de magnesio superior o igual ...          0.0
# 1  Con un contenido de magnesio superior o igual ...          0.0
# 3                                                NaN          0.0
#
#                                    Consignee Address  \
# 0                                                NaN
# 1                                                NaN
# 3  Graha Indramas, Gedung, Jl. Ks. Tubun No.77, R...
#
#                                      Shipper Address Notify Party Address  \
# 0  Jingjia Road 188 Long Unit, Jiangdong, Ningbo,...                  NaN
# 1  Jingjia Road 188 Long Unit, Jiangdong, Ningbo,...                  NaN
# 3  RM 3408 CHINA MERCHANTS TOWER|SHUN TAK CENTRE ...                  NaN
#
#            Country Name Std. Quantity (KG) Std. Unit Rate ($/KG)
# 0   Ecuador T3+  Import             5984.0              3.025790
# 1   Ecuador T3+  Import             3000.0              3.057833
# 3  Indonesia T3  Import            25000.0              1.940000
#
# [3 rows x 34 columns]

# %%
#Preprocessing the AIS data
ais_popular_pd = pd.read_csv(AIS_POPULAR_FILE_PATH)
ais_popular_pd['Date'] = pd.to_datetime(ais_popular_pd['Date'])
ais_popular_pd.head(3)
# Out:
#         Date  ship_count popular_port  popular_port_count
# 0 2020-11-10           8        LTKLJ                  18
# 1 2020-11-12          20        IDSKP                   8
# 2 2020-11-29           9        CNSHA                   2

# %%
#Preprocessing the price data
prices_pd = pd.read_csv(PRICE_FILE_PATH)
prices_pd['Date'] = prices_pd['Date'].apply(lambda x: datetime.strptime(x, "%b %d, %Y").strftime("%Y-%m-%d"))
prices_pd['Date'] = pd.to_datetime(prices_pd['Date'], errors='raise', format='%Y-%m-%d')
prices_pd['Price'] = prices_pd['Price'].str.replace(',', '').astype(float)
prices_pd = prices_pd[['Date','Price']]
prices_pd.head(3)
# Out:
#         Date    Price
# 0 2022-12-30  21650.0
# 1 2022-12-29  21650.0
# 2 2022-12-28  21650.0

# %%
#Aggregate volza data by day
date_wise_volza = volza_pd.groupby("Date")[[VALUE_COLUMN,QUANTITY_COLUMN,'Gross Weight']].sum()

# %%
# Avg of Commodity Price in Volza
avg_price_volza = volza_pd.groupby('Date')[UNIT_RATE_COLUMN].mean()
date_wise_volza = date_wise_volza.join(avg_price_volza, how='left')
date_wise_volza
# Out:
#                    Value  Std. Quantity (KG)  Gross Weight  \
# Date
# 2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 2020-01-04  2.950597e+05        1.350000e+05           0.0
# 2020-01-05  4.420000e+04        2.000000e+04           0.0
# ...                  ...                 ...           ...
# 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#             Std. Unit Rate ($/KG)
# Date
# 2020-01-01               8.582012
# 2020-01-02               2.250000
# 2020-01-03             768.449153
# 2020-01-04               2.188610
# 2020-01-05               2.210000
# ...                           ...
# 2022-12-27               3.849999
# 2022-12-28               5.656118
# 2022-12-29               3.490332
# 2022-12-30               3.949859
# 2022-12-31               3.429595
#
# [969 rows x 4 columns]

# %%
# Petroleum data prep
petrol_df = pd.read_csv(PETROL_FILE_PATH, delimiter=';', on_bad_lines='warn')
petrol_df['Date'] = pd.to_datetime(petrol_df['Date'])

# Split based on types of oil
brent_df = petrol_df[petrol_df['product-name']=='UK Brent Crude Oil']
wti_df = petrol_df[petrol_df['product-name']=='WTI Crude Oil']

brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\273638861.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={'Value':'Brent Oil Value'}, inplace=True)
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\273638861.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={'Value':'WTI Oil Value'}, inplace=True)

# %%
# Combining dataframes
prices_pd = prices_pd.set_index('Date')
ais_popular_pd = ais_popular_pd.set_index('Date')
date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
aggregated_df
# Out:
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\1674725426.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\1674725426.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\1674725426.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(brent_df[[DATE_COLUMN, BRENT_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
# C:\Users\manim\AppData\Local\Temp\ipykernel_19432\1674725426.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = aggregated_df.merge(wti_df[[DATE_COLUMN, WTI_OIL_COLUMN]], on='Date', how='left').fillna(method=FILL_METHOD)
#           Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0   2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 1   2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2   2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 3   2020-01-04  2.950597e+05        1.350000e+05           0.0
# 4   2020-01-05  4.420000e+04        2.000000e+04           0.0
# ..         ...           ...                 ...           ...
# 964 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 965 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 966 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 967 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 968 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#      Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 8.582012         NaN          NaN                 NaN
# 1                 2.250000         NaN          NaN                 NaN
# 2               768.449153         NaN          NaN                 NaN
# 3                 2.188610         NaN          NaN                 NaN
# 4                 2.210000         NaN          NaN                 NaN
# ..                     ...         ...          ...                 ...
# 964               3.849999     27245.0        SGSIN              9195.0
# 965               5.656118     26021.0        SGSIN              9233.0
# 966               3.490332     24039.0        SGSIN              8861.0
# 967               3.949859     19952.0        SGSIN              8118.0
# 968               3.429595      8925.0        USMSY              2673.0
#
#        Price  Brent Oil Value  WTI Oil Value
# 0        NaN            67.77          61.14
# 1    14150.0            67.05          61.17
# 2    14100.0            69.08          63.00
# 3    14100.0            69.08          63.00
# 4    14100.0            69.08          63.00
# ..       ...              ...            ...
# 964  21700.0            82.45          79.45
# 965  21650.0            81.70          78.89
# 966  21650.0            80.96          78.43
# 967  21650.0            82.82          80.16
# 968  21650.0            82.82          80.16
#
# [969 rows x 11 columns]

# %%
def detect_spikes(df, column, window_size):
    ## Detecting spikes
    moving_avg = df[column].rolling(window=window_size).mean()
    std_dev = df[column].rolling(window=window_size).std()

    # Set a threshold to identify spikes
    return (abs(aggregated_df[column] - moving_avg) > SPIKES_THRESHOLD * std_dev).astype(int)

# aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price')
# print("SPIKES : NON SPIKES = ")
# print(aggregated_df['spikes'].value_counts())
# print("PERCENT OF SPIKES", aggregated_df['spikes'].value_counts()[1]/len(aggregated_df))

# %% [markdown]
# # **Detect spikes**

# %%
# aggregated_df[VALUE_SPIKES_COLUMN] = detect_spikes(aggregated_df, VALUE_COLUMN)
# aggregated_df[QUANTITY_SPIKES_COLUMN] = detect_spikes(aggregated_df, QUANTITY_COLUMN)
# aggregated_df[UNIT_RATE_SPIKES_COLUMN] = detect_spikes(aggregated_df, UNIT_RATE_COLUMN)
# aggregated_df[WTI_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, WTI_OIL_COLUMN)
# aggregated_df[BRENT_OIL_SPIKES_COLUMN] = detect_spikes(aggregated_df, BRENT_OIL_COLUMN)
# aggregated_df[SHIP_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, SHIP_COUNT_COLUMN)
# aggregated_df[PORT_COUNT_SPIKES_COLUMN] = detect_spikes(aggregated_df, PORT_COUNT_COLUMN)

# #Visualise Dataset

# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_SPIKES_COLUMN], label='Value Spikes', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_SPIKES_COLUMN], label='Quantity Spikes', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_SPIKES_COLUMN], label='Unit Rate Spikes', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_SPIKES_COLUMN], label='Brent Oil Value Spikes', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_SPIKES_COLUMN], label='WTI Oil Value Spikes', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Spikes', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value Spikes', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight / Brent Oil Value / WTI Oil Value / Ship Count / Port Count ', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
#remove date 2020-01-01
aggregated_df = aggregated_df[aggregated_df.index != '2020-01-01']
aggregated_df
# Out:
#           Date         Value  Std. Quantity (KG)  Gross Weight  \
# 0   2020-01-01  3.716627e+07        1.451213e+07      275000.0
# 1   2020-01-02  1.125000e+05        5.000000e+04       50080.0
# 2   2020-01-03  8.744076e+05        1.001723e+05       25040.0
# 3   2020-01-04  2.950597e+05        1.350000e+05           0.0
# 4   2020-01-05  4.420000e+04        2.000000e+04           0.0
# ..         ...           ...                 ...           ...
# 964 2022-12-27  9.624998e+04        2.500000e+04       25040.0
# 965 2022-12-28  1.122651e+06        2.869969e+05       80306.0
# 966 2022-12-29  1.303649e+06        3.568780e+05           0.0
# 967 2022-12-30  9.095473e+05        2.128420e+05       44080.0
# 968 2022-12-31  3.984595e+05        1.150000e+05           0.0
#
#      Std. Unit Rate ($/KG)  ship_count popular_port  popular_port_count  \
# 0                 8.582012         NaN          NaN                 NaN
# 1                 2.250000         NaN          NaN                 NaN
# 2               768.449153         NaN          NaN                 NaN
# 3                 2.188610         NaN          NaN                 NaN
# 4                 2.210000         NaN          NaN                 NaN
# ..                     ...         ...          ...                 ...
# 964               3.849999     27245.0        SGSIN              9195.0
# 965               5.656118     26021.0        SGSIN              9233.0
# 966               3.490332     24039.0        SGSIN              8861.0
# 967               3.949859     19952.0        SGSIN              8118.0
# 968               3.429595      8925.0        USMSY              2673.0
#
#        Price  Brent Oil Value  WTI Oil Value
# 0        NaN            67.77          61.14
# 1    14150.0            67.05          61.17
# 2    14100.0            69.08          63.00
# 3    14100.0            69.08          63.00
# 4    14100.0            69.08          63.00
# ..       ...              ...            ...
# 964  21700.0            82.45          79.45
# 965  21650.0            81.70          78.89
# 966  21650.0            80.96          78.43
# 967  21650.0            82.82          80.16
# 968  21650.0            82.82          80.16
#
# [969 rows x 11 columns]

# %%
# #Visualise Dataset
# # Plotting the graph
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(aggregated_df.index, aggregated_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(aggregated_df.index, aggregated_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(aggregated_df.index, aggregated_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(aggregated_df.index, aggregated_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(aggregated_df.index, aggregated_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(aggregated_df.index, aggregated_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(aggregated_df.index, aggregated_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# # plt.show()

# %%
# # Plotting the price data
# plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
# plt.plot(aggregated_df.index, aggregated_df['Price'], label='Price', color='blue')

# # Highlighting spikes
# spike_indices = aggregated_df[aggregated_df['spikes'] == 1].index
# spike_prices = aggregated_df.loc[spike_indices, 'Price']
# plt.scatter(spike_indices, spike_prices, color='red', marker='^', label='Spikes')

# # Adding labels and title
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.title('Price Data with Spikes')
# plt.legend()

# # Display the plot
# # plt.show()

# %% [markdown]
# ## Baseline

# %%
# # Count % of spikes 
# total_spikes = aggregated_df['spikes'].sum()
# total_data_points = len(aggregated_df)
# percentage_of_spikes = (total_spikes / total_data_points) * 100

# print(f"Percentage of Spikes: {percentage_of_spikes:.2f}%")

# %%
# from sklearn.metrics import precision_score, recall_score

# # Probability of spike
# spike_prob = aggregated_df['spikes'].mean()

# # Random baseline predictions
# random_predictions = np.random.choice([0, 1], size=len(aggregated_df), p=[1-spike_prob, spike_prob])

# # Calculate precision and recall for the random baseline
# random_precision = precision_score(aggregated_df['spikes'], random_predictions)
# random_recall = recall_score(aggregated_df['spikes'], random_predictions)

# print(f"Random Guessing Precision: {random_precision}")
# print(f"Random Guessing Recall: {random_recall}")

# %% [markdown]
# ## Data Prep for Classification

# %%
COLUMNS = FEATURE_COLUMNS + [TARGET_COLUMN]
print(COLUMNS)
# Out:
# ['Value', 'Std. Quantity (KG)', 'Std. Unit Rate ($/KG)', 'WTI Oil Value', 'Brent Oil Value', 'ship_count', 'popular_port_count', 'Price']

# %%
# # Discretize
# from sklearn.preprocessing import KBinsDiscretizer

# def discretize(df, columns, bins):
#     est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='kmeans')
#     df[columns] = est.fit_transform(df[columns])
#     return df

# # FEATURES_1 = [VALUE_COLUMN, QUANTITY_COLUMN, UNIT_RATE_COLUMN]
# # FEATURES_2 = [WTI_OIL_COLUMN, BRENT_OIL_COLUMN]

# test_df = aggregated_df.copy()
# test_df[FEATURE_COLUMNS] = test_df[FEATURE_COLUMNS].fillna(0)

# # test_df = discretize(test_df, FEATURES_1, 2)
# # test_df = discretize(test_df, FEATURES_2, BIN_COUNT)
# discretized_df = discretize(test_df, FEATURE_COLUMNS, BIN_COUNT)
# # discretized_df = test_df.copy()
# test_df.head(2)

# %%
# fig, ax1 = plt.subplots(figsize=(12, 6))

# # Plotting 'Value', 'Quantity', and 'Gross Weight' on the left y-axis
# ax1.plot(test_df.index, test_df[VALUE_COLUMN], label='Value', color='b')
# ax1.plot(test_df.index, test_df[QUANTITY_COLUMN], label='Quantity', color='g')
# ax1.plot(test_df.index, test_df[UNIT_RATE_COLUMN], label='Unit Rate', color='k')
# ax1.plot(test_df.index, test_df[BRENT_OIL_COLUMN], label='Brent Oil Value', color='m')
# ax1.plot(test_df.index, test_df[WTI_OIL_COLUMN], label='WTI Oil Value', color='c')
# ax1.plot(test_df.index, test_df[SHIP_COUNT_COLUMN], label='Ship Count Value', color='darkorange')
# ax1.plot(test_df.index, test_df[PORT_COUNT_COLUMN], label='Port Count Value', color='violet')

# ax1.set_xlabel('Date')
# ax1.set_ylabel('Value / Quantity / Gross Weight', color='b')
# ax1.tick_params('y', colors='b')

# # Creating a second y-axis for 'Price'
# ax2 = ax1.twinx()
# ax2.plot(test_df.index, test_df['Price'], label='Price', color='orange')
# ax2.set_ylabel('Price', color='orange')
# ax2.tick_params('y', colors='orange')

# # Display legend
# fig.tight_layout()
# fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))

# # Display the graph
# plt.show()

# %%
# # Convert the discretized data into a DataFrame
# discretized_df = pd.DataFrame(discretized_df, columns=FEATURE_COLUMNS)

# unique_values = discretized_df[VALUE_COLUMN].fillna(method=FILL_METHOD).unique()
# print(unique_values)

# bin_counts = {col: discretized_df[col].value_counts() for col in FEATURE_COLUMNS}

# # Plotting
# plt.figure(figsize=(15, len(FEATURE_COLUMNS) * 5))

# for i, column in enumerate(FEATURE_COLUMNS):
#     plt.subplot(len(FEATURE_COLUMNS), 1, i + 1)
#     bin_counts[column].sort_index().plot(kind='bar', ax=plt.gca())

#     plt.title(f'{column} Distribution')
#     plt.ylabel('Frequency')
#     plt.xlabel('Bins')

# plt.tight_layout()
# plt.show()

# %%
# Clean up before passing to Arima
initial_row_count = aggregated_df.shape[0]

columns_of_interest = ['Price']  # Add other columns as necessary

aggregated_df = aggregated_df.dropna(subset=columns_of_interest)

rows_dropped = initial_row_count - aggregated_df.shape[0]

print(f"Rows dropped due to NaN values: {rows_dropped}")
# Out:
# Rows dropped due to NaN values: 1

# %% [markdown]
# ## Train / Test Set Up

# %%
from sklearn.model_selection import train_test_split
import pmdarima as pm

# Fit an Auto ARIMA model to the 'Price' series
model = pm.auto_arima(aggregated_df['Price'], seasonal=True, m=12, suppress_warnings=True, stepwise=True, error_action='ignore')

# Forecast the series using the model (in-sample prediction)
forecast = model.predict_in_sample()

# Calculate residuals (difference between actual and forecasted values)
residuals = aggregated_df['Price'] - forecast

# Append residuals to DataFrame as a new feature (using residuals as a way to detect spike / anomaly)
aggregated_df = aggregated_df.copy()
aggregated_df['ARIMA_Residuals'] = residuals

# %%
# Trying out different window sizes
SPIKE_WINDOW_SIZES = [10, 20, 30, 40, 60, 80, 100]
results_dfs = []

for window_size in SPIKE_WINDOW_SIZES:
    print(f"Evaluating window size: {window_size}")

    aggregated_df['spikes'] = detect_spikes(aggregated_df, 'Price', window_size)

    # Prepare features and target
    FEATURE_COLUMNS = [TARGET_COLUMN, 'ARIMA_Residuals']  # Adjust as needed
    X, y = data_processing.prepare_features_and_target(aggregated_df, FEATURE_COLUMNS, 'spikes')

    # Split data 
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, shuffle=False)

    # Scale features
    X_train_scaled, X_test_scaled = data_processing.scale_features(X_train_raw, X_test_raw)

    # Create sequences
    X_train, y_train = data_processing.create_sequences(X_train_scaled, y_train, window_size)
    X_test, y_test = data_processing.create_sequences(X_test_scaled, y_test, window_size)

    print(f'X train shape: {X_train.shape}')

    output_file_path = f'{COMMODITY}/results_{window_size}.csv'
    pred_file_path = f'{COMMODITY}/predictions/{window_size}'
    print(pred_file_path)
    results_df = models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path, pred_file_path)
    results_df['Window Size'] = window_size
    results_dfs.append(results_df)
# Out:
# Evaluating window size: 10
# X train shape: (765, 10, 2)
# magnesium/predictions/10
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 1s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/LSTM_50_layers_predictions.npy
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 0s 1ms/step
#  2. Failed to save predictions for CNN_Attention_32_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 489us/step
#  2. Failed to save predictions for CNN_Attention_32_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 408us/step
#  2. Failed to save predictions for CNN_Attention_32_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 1ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 1ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 879us/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/10/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/10/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 309us/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 3ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 128 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 256 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# Evaluating window size: 20
# X train shape: (755, 20, 2)
# magnesium/predictions/20
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_32_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_32_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_32_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_64_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_128_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_7_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 3ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_5_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
#  2. Failed to save predictions for CNN_Attention_256_filters_3_kernels: All arrays must be of the same length
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 412us/step
# Predictions saved to CSV file: magnesium/predictions/20/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/predictions/20/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 704us/step
# Failed to evaluate CNN with 32 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 624us/step
# Failed to evaluate CNN with 32 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 32 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 1ms/step
# Failed to evaluate CNN with 64 filters and 5 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 64 filters and 3 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'
# 6/6 [==============================] - 0s 2ms/step
# Failed to evaluate CNN with 128 filters and 7 kernel size: save_predictions_to_file() missing 1 required positional argument: 'directory_path'

# %% [markdown]
# ## Evaluation

# %%
# Display all results df
for idx, df in enumerate(results_dfs):
    print(f"Results for window size: {SPIKE_WINDOW_SIZES[idx]}")
    display(df)
# Out:
# Results for window size: 10
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.805405       0.951389
# 1                 LSTM                  200 layers  0.837838       0.953333
# 2                 LSTM                  100 layers  0.832432       0.965517
# 3                 LSTM                   50 layers  0.886486       0.955975
# 4   CNN with Attention   32 filters, kernel size 7  0.956757       0.975904
# 5   CNN with Attention   32 filters, kernel size 5  0.962162       0.981818
# 6   CNN with Attention   32 filters, kernel size 3  0.962162       0.981818
# 7   CNN with Attention   64 filters, kernel size 7  0.978378       0.993902
# 8   CNN with Attention   64 filters, kernel size 5  0.967568       0.981928
# 9   CNN with Attention   64 filters, kernel size 3  0.962162       0.970414
# 10  CNN with Attention  128 filters, kernel size 7  0.962162       0.976048
# 11  CNN with Attention  128 filters, kernel size 5  0.956757       0.959302
# 12  CNN with Attention  128 filters, kernel size 3  0.962162       0.964912
# 13  CNN with Attention  256 filters, kernel size 7  0.951351       0.948571
# 14  CNN with Attention  256 filters, kernel size 5  0.956757       0.959302
# 15  CNN with Attention  256 filters, kernel size 3  0.956757       0.954023
# 16                 RNN                   200 units  0.913514       0.957317
# 17                 RNN                   150 units  0.886486       0.939394
# 18                 RNN                   100 units  0.935135       0.975309
# 19                 RNN                    50 units  0.897297       0.940120
# 20                 CNN   32 filters, kernel size 7  0.940541       0.964072
# 21                 CNN   32 filters, kernel size 5  0.951351       0.959064
# 22                 CNN   32 filters, kernel size 3  0.967568       0.965116
# 23                 CNN   64 filters, kernel size 7  0.945946       0.993671
# 24                 CNN   64 filters, kernel size 5  0.967568       0.993827
# 25                 CNN   64 filters, kernel size 3  0.967568       0.965116
# 26                 CNN  128 filters, kernel size 7  0.962162       0.993789
# 27                 CNN  128 filters, kernel size 5  0.967568       0.987805
# 28                 CNN  128 filters, kernel size 3  0.972973       0.970760
# 29                 CNN  256 filters, kernel size 7  0.962162       1.000000
# 30                 CNN  256 filters, kernel size 5  0.956757       0.987654
# 31                 CNN  256 filters, kernel size 3  0.967568       0.965116
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.825301  0.883871       0.292683    0.631579  0.400000           10
# 1     0.861446  0.905063       0.342857    0.631579  0.444444           10
# 2     0.843373  0.900322       0.350000    0.736842  0.474576           10
# 3     0.915663  0.935385       0.461538    0.631579  0.533333           10
# 4     0.975904  0.975904       0.789474    0.789474  0.789474           10
# 5     0.975904  0.978852       0.800000    0.842105  0.820513           10
# 6     0.975904  0.978852       0.800000    0.842105  0.820513           10
# 7     0.981928  0.987879       0.857143    0.947368  0.900000           10
# 8     0.981928  0.981928       0.842105    0.842105  0.842105           10
# 9     0.987952  0.979104       0.875000    0.736842  0.800000           10
# 10    0.981928  0.978979       0.833333    0.789474  0.810811           10
# 11    0.993976  0.976331       0.923077    0.631579  0.750000           10
# 12    0.993976  0.979228       0.928571    0.684211  0.787879           10
# 13    1.000000  0.973607       1.000000    0.526316  0.689655           10
# 14    0.993976  0.976331       0.923077    0.631579  0.750000           10
# 15    1.000000  0.976471       1.000000    0.578947  0.733333           10
# 16    0.945783  0.951515       0.571429    0.631579  0.600000           10
# 17    0.933735  0.936556       0.450000    0.473684  0.461538           10
# 18    0.951807  0.963415       0.652174    0.789474  0.714286           10
# 19    0.945783  0.942943       0.500000    0.473684  0.486486           10
# 20    0.969880  0.966967       0.722222    0.684211  0.702703           10
# 21    0.987952  0.973294       0.857143    0.631579  0.727273           10
# 22    1.000000  0.982249       1.000000    0.684211  0.812500           10
# 23    0.945783  0.969136       0.666667    0.947368  0.782609           10
# 24    0.969880  0.981707       0.782609    0.947368  0.857143           10
# 25    1.000000  0.982249       1.000000    0.684211  0.812500           10
# 26    0.963855  0.978593       0.750000    0.947368  0.837209           10
# 27    0.975904  0.981818       0.809524    0.894737  0.850000           10
# 28    1.000000  0.985163       1.000000    0.736842  0.848485           10
# 29    0.957831  0.978462       0.730769    1.000000  0.844444           10
# 30    0.963855  0.975610       0.739130    0.894737  0.809524           10
# 31    1.000000  0.982249       1.000000    0.684211  0.812500           10
# Results for window size: 20
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.874286       0.932432
# 1                 LSTM                  200 layers  0.902857       0.918239
# 2                 LSTM                  100 layers  0.891429       0.896970
# 3                 LSTM                   50 layers  0.862857       0.920000
# 4   CNN with Attention   32 filters, kernel size 7  0.931429       0.948052
# 5   CNN with Attention   32 filters, kernel size 5  0.931429       0.948052
# 6   CNN with Attention   32 filters, kernel size 3  0.937143       0.954248
# 7   CNN with Attention   64 filters, kernel size 7  0.937143       0.948387
# 8   CNN with Attention   64 filters, kernel size 5  0.925714       0.947712
# 9   CNN with Attention   64 filters, kernel size 3  0.925714       0.947712
# 10  CNN with Attention  128 filters, kernel size 7  0.925714       0.947712
# 11  CNN with Attention  128 filters, kernel size 5  0.925714       0.947712
# 12  CNN with Attention  128 filters, kernel size 3  0.925714       0.947712
# 13  CNN with Attention  256 filters, kernel size 7  0.942857       0.960526
# 14  CNN with Attention  256 filters, kernel size 5  0.931429       0.960000
# 15  CNN with Attention  256 filters, kernel size 3  0.925714       0.947712
# 16                 RNN                   200 units  0.874286       0.900000
# 17                 RNN                   150 units  0.908571       0.908537
# 18                 RNN                   100 units  0.885714       0.886905
# 19                 RNN                    50 units  0.880000       0.881657
# 20                 CNN   32 filters, kernel size 7  0.925714       0.941935
# 21                 CNN   32 filters, kernel size 5  0.931429       0.948052
# 22                 CNN   32 filters, kernel size 3  0.914286       0.941176
# 23                 CNN   64 filters, kernel size 7  0.931429       0.948052
# 24                 CNN   64 filters, kernel size 5  0.925714       0.947712
# 25                 CNN   64 filters, kernel size 3  0.925714       0.947712
# 26                 CNN  128 filters, kernel size 7  0.937143       0.960265
# 27                 CNN  128 filters, kernel size 5  0.931429       0.948052
# 28                 CNN  128 filters, kernel size 3  0.937143       0.948387
# 29                 CNN  256 filters, kernel size 7  0.931429       0.948052
# 30                 CNN  256 filters, kernel size 5  0.931429       0.948052
# 31                 CNN  256 filters, kernel size 3  0.914286       0.941176
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.920000  0.926174       0.555556        0.60  0.576923           20
# 1     0.973333  0.944984       0.750000        0.48  0.585366           20
# 2     0.986667  0.939683       0.800000        0.32  0.457143           20
# 3     0.920000  0.920000       0.520000        0.52  0.520000           20
# 4     0.973333  0.960526       0.809524        0.68  0.739130           20
# 5     0.973333  0.960526       0.809524        0.68  0.739130           20
# 6     0.973333  0.963696       0.818182        0.72  0.765957           20
# 7     0.980000  0.963934       0.850000        0.68  0.755556           20
# 8     0.966667  0.957096       0.772727        0.68  0.723404           20
# 9     0.966667  0.957096       0.772727        0.68  0.723404           20
# 10    0.966667  0.957096       0.772727        0.68  0.723404           20
# 11    0.966667  0.957096       0.772727        0.68  0.723404           20
# 12    0.966667  0.957096       0.772727        0.68  0.723404           20
# 13    0.973333  0.966887       0.826087        0.76  0.791667           20
# 14    0.960000  0.960000       0.760000        0.76  0.760000           20
# 15    0.966667  0.957096       0.772727        0.68  0.723404           20
# 16    0.960000  0.929032       0.600000        0.36  0.450000           20
# 17    0.993333  0.949045       0.909091        0.40  0.555556           20
# 18    0.993333  0.937107       0.857143        0.24  0.375000           20
# 19    0.993333  0.934169       0.833333        0.20  0.322581           20
# 20    0.973333  0.957377       0.800000        0.64  0.711111           20
# 21    0.973333  0.960526       0.809524        0.68  0.739130           20
# 22    0.960000  0.950495       0.727273        0.64  0.680851           20
# 23    0.973333  0.960526       0.809524        0.68  0.739130           20
# 24    0.966667  0.957096       0.772727        0.68  0.723404           20
# 25    0.966667  0.957096       0.772727        0.68  0.723404           20
# 26    0.966667  0.963455       0.791667        0.76  0.775510           20
# 27    0.973333  0.960526       0.809524        0.68  0.739130           20
# 28    0.980000  0.963934       0.850000        0.68  0.755556           20
# 29    0.973333  0.960526       0.809524        0.68  0.739130           20
# 30    0.973333  0.960526       0.809524        0.68  0.739130           20
# 31    0.960000  0.950495       0.727273        0.64  0.680851           20
# Results for window size: 30
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.951515       0.947020
# 1                 LSTM                  200 layers  0.836364       0.871795
# 2                 LSTM                  100 layers  0.866667       0.906040
# 3                 LSTM                   50 layers  0.872727       0.935714
# 4   CNN with Attention   32 filters, kernel size 7  0.933333       0.992537
# 5   CNN with Attention   32 filters, kernel size 5  0.945455       1.000000
# 6   CNN with Attention   32 filters, kernel size 3  0.860606       0.983871
# 7   CNN with Attention   64 filters, kernel size 7  0.927273       0.978102
# 8   CNN with Attention   64 filters, kernel size 5  0.933333       1.000000
# 9   CNN with Attention   64 filters, kernel size 3  0.775758       1.000000
# 10  CNN with Attention  128 filters, kernel size 7  0.927273       0.985185
# 11  CNN with Attention  128 filters, kernel size 5  0.921212       1.000000
# 12  CNN with Attention  128 filters, kernel size 3  0.824242       0.991379
# 13  CNN with Attention  256 filters, kernel size 7  0.915152       0.984962
# 14  CNN with Attention  256 filters, kernel size 5  0.896970       1.000000
# 15  CNN with Attention  256 filters, kernel size 3  0.745455       1.000000
# 16                 RNN                   200 units  0.927273       0.964539
# 17                 RNN                   150 units  0.933333       0.934211
# 18                 RNN                   100 units  0.896970       0.937500
# 19                 RNN                    50 units  0.951515       0.953020
# 20                 CNN   32 filters, kernel size 7  0.896970       0.977273
# 21                 CNN   32 filters, kernel size 5  0.921212       0.985075
# 22                 CNN   32 filters, kernel size 3  0.818182       0.991304
# 23                 CNN   64 filters, kernel size 7  0.927273       0.985185
# 24                 CNN   64 filters, kernel size 5  0.909091       1.000000
# 25                 CNN   64 filters, kernel size 3  0.848485       0.991667
# 26                 CNN  128 filters, kernel size 7  0.921212       0.985075
# 27                 CNN  128 filters, kernel size 5  0.939394       0.985401
# 28                 CNN  128 filters, kernel size 3  0.854545       0.983740
# 29                 CNN  256 filters, kernel size 7  0.909091       0.992308
# 30                 CNN  256 filters, kernel size 5  0.909091       1.000000
# 31                 CNN  256 filters, kernel size 3  0.866667       0.991870
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     1.000000  0.972789       1.000000    0.636364  0.777778           30
# 1     0.951049  0.909699       0.222222    0.090909  0.129032           30
# 2     0.944056  0.924658       0.500000    0.363636  0.421053           30
# 3     0.916084  0.925795       0.520000    0.590909  0.553191           30
# 4     0.930070  0.960289       0.677419    0.954545  0.792453           30
# 5     0.937063  0.967509       0.709677    1.000000  0.830189           30
# 6     0.853147  0.913858       0.487805    0.909091  0.634921           30
# 7     0.937063  0.957143       0.678571    0.863636  0.760000           30
# 8     0.923077  0.960000       0.666667    1.000000  0.800000           30
# 9     0.741259  0.851406       0.372881    1.000000  0.543210           30
# 10    0.930070  0.956835       0.666667    0.909091  0.769231           30
# 11    0.909091  0.952381       0.628571    1.000000  0.771930           30
# 12    0.804196  0.888031       0.428571    0.954545  0.591549           30
# 13    0.916084  0.949275       0.625000    0.909091  0.740741           30
# 14    0.881119  0.936803       0.564103    1.000000  0.721311           30
# 15    0.706294  0.827869       0.343750    1.000000  0.511628           30
# 16    0.951049  0.957746       0.708333    0.772727  0.739130           30
# 17    0.993007  0.962712       0.923077    0.545455  0.685714           30
# 18    0.944056  0.940767       0.619048    0.590909  0.604651           30
# 19    0.993007  0.972603       0.937500    0.681818  0.789474           30
# 20    0.902098  0.938182       0.575758    0.863636  0.690909           30
# 21    0.923077  0.953069       0.645161    0.909091  0.754717           30
# 22    0.797203  0.883721       0.420000    0.954545  0.583333           30
# 23    0.930070  0.956835       0.666667    0.909091  0.769231           30
# 24    0.895105  0.944649       0.594595    1.000000  0.745763           30
# 25    0.832168  0.904943       0.466667    0.954545  0.626866           30
# 26    0.923077  0.953069       0.645161    0.909091  0.754717           30
# 27    0.944056  0.964286       0.714286    0.909091  0.800000           30
# 28    0.846154  0.909774       0.476190    0.909091  0.625000           30
# 29    0.902098  0.945055       0.600000    0.954545  0.736842           30
# 30    0.895105  0.944649       0.594595    1.000000  0.745763           30
# 31    0.853147  0.917293       0.500000    0.954545  0.656250           30
# Results for window size: 40
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.812903       0.920635
# 1                 LSTM                  200 layers  0.838710       0.887324
# 2                 LSTM                  100 layers  0.767742       0.915966
# 3                 LSTM                   50 layers  0.645161       0.900000
# 4   CNN with Attention   32 filters, kernel size 7  0.877419       0.967742
# 5   CNN with Attention   32 filters, kernel size 5  0.825806       0.973684
# 6   CNN with Attention   32 filters, kernel size 3  0.793548       0.963964
# 7   CNN with Attention   64 filters, kernel size 7  0.845161       0.966387
# 8   CNN with Attention   64 filters, kernel size 5  0.851613       0.974576
# 9   CNN with Attention   64 filters, kernel size 3  0.670968       0.966667
# 10  CNN with Attention  128 filters, kernel size 7  0.812903       0.973214
# 11  CNN with Attention  128 filters, kernel size 5  0.819355       0.973451
# 12  CNN with Attention  128 filters, kernel size 3  0.658065       0.965909
# 13  CNN with Attention  256 filters, kernel size 7  0.787097       0.972222
# 14  CNN with Attention  256 filters, kernel size 5  0.819355       0.973451
# 15  CNN with Attention  256 filters, kernel size 3  0.735484       0.970000
# 16                 RNN                   200 units  0.587097       0.890110
# 17                 RNN                   150 units  0.793548       0.912000
# 18                 RNN                   100 units  0.683871       0.947917
# 19                 RNN                    50 units  0.819355       0.884892
# 20                 CNN   32 filters, kernel size 7  0.800000       0.981481
# 21                 CNN   32 filters, kernel size 5  0.793548       0.963964
# 22                 CNN   32 filters, kernel size 3  0.625806       0.952941
# 23                 CNN   64 filters, kernel size 7  0.838710       0.974138
# 24                 CNN   64 filters, kernel size 5  0.793548       0.972477
# 25                 CNN   64 filters, kernel size 3  0.677419       0.929293
# 26                 CNN  128 filters, kernel size 7  0.864516       0.983051
# 27                 CNN  128 filters, kernel size 5  0.787097       0.972222
# 28                 CNN  128 filters, kernel size 3  0.690323       0.967742
# 29                 CNN  256 filters, kernel size 7  0.819355       0.981982
# 30                 CNN  256 filters, kernel size 5  0.825806       0.982143
# 31                 CNN  256 filters, kernel size 3  0.793548       0.981308
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.859259  0.888889       0.344828        0.50  0.408163           40
# 1     0.933333  0.909747       0.307692        0.20  0.242424           40
# 2     0.807407  0.858268       0.277778        0.50  0.357143           40
# 3     0.666667  0.765957       0.181818        0.50  0.266667           40
# 4     0.888889  0.926641       0.516129        0.80  0.627451           40
# 5     0.822222  0.891566       0.414634        0.85  0.557377           40
# 6     0.792593  0.869919       0.363636        0.80  0.500000           40
# 7     0.851852  0.905512       0.444444        0.80  0.571429           40
# 8     0.851852  0.909091       0.459459        0.85  0.596491           40
# 9     0.644444  0.773333       0.261538        0.85  0.400000           40
# 10    0.807407  0.882591       0.395349        0.85  0.539683           40
# 11    0.814815  0.887097       0.404762        0.85  0.548387           40
# 12    0.629630  0.762332       0.253731        0.85  0.390805           40
# 13    0.777778  0.864198       0.361702        0.85  0.507463           40
# 14    0.814815  0.887097       0.404762        0.85  0.548387           40
# 15    0.718519  0.825532       0.309091        0.85  0.453333           40
# 16    0.600000  0.716814       0.156250        0.50  0.238095           40
# 17    0.844444  0.876923       0.300000        0.45  0.360000           40
# 18    0.674074  0.787879       0.254237        0.75  0.379747           40
# 19    0.911111  0.897810       0.250000        0.20  0.222222           40
# 20    0.785185  0.872428       0.382979        0.90  0.537313           40
# 21    0.792593  0.869919       0.363636        0.80  0.500000           40
# 22    0.600000  0.736364       0.228571        0.80  0.355556           40
# 23    0.837037  0.900398       0.435897        0.85  0.576271           40
# 24    0.785185  0.868852       0.369565        0.85  0.515152           40
# 25    0.681481  0.786325       0.232143        0.65  0.342105           40
# 26    0.859259  0.916996       0.486486        0.90  0.631579           40
# 27    0.777778  0.864198       0.361702        0.85  0.507463           40
# 28    0.666667  0.789474       0.274194        0.85  0.414634           40
# 29    0.807407  0.886179       0.409091        0.90  0.562500           40
# 30    0.814815  0.890688       0.418605        0.90  0.571429           40
# 31    0.777778  0.867769       0.375000        0.90  0.529412           40
# Results for window size: 60
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.800000       0.834646
# 1                 LSTM                  200 layers  0.837037       0.868852
# 2                 LSTM                  100 layers  0.800000       0.824427
# 3                 LSTM                   50 layers  0.829630       0.829630
# 4   CNN with Attention   32 filters, kernel size 7  0.859259       0.897436
# 5   CNN with Attention   32 filters, kernel size 5  0.822222       0.892857
# 6   CNN with Attention   32 filters, kernel size 3  0.792593       0.875000
# 7   CNN with Attention   64 filters, kernel size 7  0.851852       0.896552
# 8   CNN with Attention   64 filters, kernel size 5  0.837037       0.887931
# 9   CNN with Attention   64 filters, kernel size 3  0.777778       0.910000
# 10  CNN with Attention  128 filters, kernel size 7  0.792593       0.896226
# 11  CNN with Attention  128 filters, kernel size 5  0.792593       0.911765
# 12  CNN with Attention  128 filters, kernel size 3  0.733333       0.895833
# 13  CNN with Attention  256 filters, kernel size 7  0.785185       0.873874
# 14  CNN with Attention  256 filters, kernel size 5  0.725926       0.894737
# 15  CNN with Attention  256 filters, kernel size 3  0.733333       0.913043
# 16                 RNN                   200 units  0.474074       0.859649
# 17                 RNN                   150 units  0.555556       0.782609
# 18                 RNN                   100 units  0.740741       0.813008
# 19                 RNN                    50 units  0.762963       0.833333
# 20                 CNN   32 filters, kernel size 7  0.837037       0.901786
# 21                 CNN   32 filters, kernel size 5  0.814815       0.878261
# 22                 CNN   32 filters, kernel size 3  0.829630       0.893805
# 23                 CNN   64 filters, kernel size 7  0.896296       0.915254
# 24                 CNN   64 filters, kernel size 5  0.844444       0.895652
# 25                 CNN   64 filters, kernel size 3  0.807407       0.905660
# 26                 CNN  128 filters, kernel size 7  0.881481       0.928571
# 27                 CNN  128 filters, kernel size 5  0.822222       0.900000
# 28                 CNN  128 filters, kernel size 3  0.733333       0.922222
# 29                 CNN  256 filters, kernel size 7  0.844444       0.909910
# 30                 CNN  256 filters, kernel size 5  0.859259       0.918919
# 31                 CNN  256 filters, kernel size 3  0.829630       0.900901
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.946429  0.887029       0.250000    0.086957  0.129032           60
# 1     0.946429  0.905983       0.538462    0.304348  0.388889           60
# 2     0.964286  0.888889       0.000000    0.000000  0.000000           60
# 3     1.000000  0.906883       0.000000    0.000000  0.000000           60
# 4     0.937500  0.917031       0.611111    0.478261  0.536585           60
# 5     0.892857  0.892857       0.478261    0.478261  0.478261           60
# 6     0.875000  0.875000       0.391304    0.391304  0.391304           60
# 7     0.928571  0.912281       0.578947    0.478261  0.523810           60
# 8     0.919643  0.903509       0.526316    0.434783  0.476190           60
# 9     0.812500  0.858491       0.400000    0.608696  0.482759           60
# 10    0.848214  0.871560       0.413793    0.521739  0.461538           60
# 11    0.830357  0.869159       0.424242    0.608696  0.500000           60
# 12    0.767857  0.826923       0.333333    0.565217  0.419355           60
# 13    0.866071  0.869955       0.375000    0.391304  0.382979           60
# 14    0.758929  0.821256       0.325000    0.565217  0.412698           60
# 15    0.750000  0.823529       0.348837    0.652174  0.454545           60
# 16    0.437500  0.579882       0.192308    0.652174  0.297030           60
# 17    0.642857  0.705882       0.069767    0.130435  0.090909           60
# 18    0.892857  0.851064       0.000000    0.000000  0.000000           60
# 19    0.892857  0.862069       0.200000    0.130435  0.157895           60
# 20    0.901786  0.901786       0.521739    0.521739  0.521739           60
# 21    0.901786  0.889868       0.450000    0.391304  0.418605           60
# 22    0.901786  0.897778       0.500000    0.478261  0.488889           60
# 23    0.964286  0.939130       0.764706    0.565217  0.650000           60
# 24    0.919643  0.907489       0.550000    0.478261  0.511628           60
# 25    0.857143  0.880734       0.448276    0.565217  0.500000           60
# 26    0.928571  0.928571       0.652174    0.652174  0.652174           60
# 27    0.883929  0.891892       0.480000    0.521739  0.500000           60
# 28    0.741071  0.821782       0.355556    0.695652  0.470588           60
# 29    0.901786  0.905830       0.541667    0.565217  0.553191           60
# 30    0.910714  0.914798       0.583333    0.608696  0.595745           60
# 31    0.892857  0.896861       0.500000    0.521739  0.510638           60
# Results for window size: 80
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.843478       0.850467
# 1                 LSTM                  200 layers  0.808696       0.808696
# 2                 LSTM                  100 layers  0.382609       1.000000
# 3                 LSTM                   50 layers  0.808696       0.808696
# 4   CNN with Attention   32 filters, kernel size 7  0.904348       0.936170
# 5   CNN with Attention   32 filters, kernel size 5  0.826087       0.929412
# 6   CNN with Attention   32 filters, kernel size 3  0.800000       0.880435
# 7   CNN with Attention   64 filters, kernel size 7  0.904348       0.945652
# 8   CNN with Attention   64 filters, kernel size 5  0.843478       0.974684
# 9   CNN with Attention   64 filters, kernel size 3  0.826087       0.919540
# 10  CNN with Attention  128 filters, kernel size 7  0.843478       0.931034
# 11  CNN with Attention  128 filters, kernel size 5  0.843478       0.962963
# 12  CNN with Attention  128 filters, kernel size 3  0.773913       0.894118
# 13  CNN with Attention  256 filters, kernel size 7  0.860870       0.888889
# 14  CNN with Attention  256 filters, kernel size 5  0.791304       0.828571
# 15  CNN with Attention  256 filters, kernel size 3  0.704348       0.817204
# 16                 RNN                   200 units  0.191304       0.000000
# 17                 RNN                   150 units  0.200000       1.000000
# 18                 RNN                   100 units  0.704348       0.786408
# 19                 RNN                    50 units  0.339130       0.644068
# 20                 CNN   32 filters, kernel size 7  0.878261       0.891089
# 21                 CNN   32 filters, kernel size 5  0.800000       0.872340
# 22                 CNN   32 filters, kernel size 3  0.773913       0.876404
# 23                 CNN   64 filters, kernel size 7  0.860870       0.905263
# 24                 CNN   64 filters, kernel size 5  0.817391       0.900000
# 25                 CNN   64 filters, kernel size 3  0.686957       0.870130
# 26                 CNN  128 filters, kernel size 7  0.878261       0.964706
# 27                 CNN  128 filters, kernel size 5  0.895652       0.945055
# 28                 CNN  128 filters, kernel size 3  0.808696       0.844660
# 29                 CNN  256 filters, kernel size 7  0.886957       0.976190
# 30                 CNN  256 filters, kernel size 5  0.773913       1.000000
# 31                 CNN  256 filters, kernel size 3  0.721739       0.917808
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     0.978495  0.910000       0.750000    0.272727  0.400000           80
# 1     1.000000  0.894231       0.000000    0.000000  0.000000           80
# 2     0.236559  0.382609       0.236559    1.000000  0.382609           80
# 3     1.000000  0.894231       0.000000    0.000000  0.000000           80
# 4     0.946237  0.941176       0.761905    0.727273  0.744186           80
# 5     0.849462  0.887640       0.533333    0.727273  0.615385           80
# 6     0.870968  0.875676       0.478261    0.500000  0.488889           80
# 7     0.935484  0.940541       0.739130    0.772727  0.755556           80
# 8     0.827957  0.895349       0.555556    0.909091  0.689655           80
# 9     0.860215  0.888889       0.535714    0.681818  0.600000           80
# 10    0.870968  0.900000       0.571429    0.727273  0.640000           80
# 11    0.838710  0.896552       0.558824    0.863636  0.678571           80
# 12    0.817204  0.853933       0.433333    0.590909  0.500000           80
# 13    0.946237  0.916667       0.687500    0.500000  0.578947           80
# 14    0.935484  0.878788       0.400000    0.181818  0.250000           80
# 15    0.817204  0.817204       0.227273    0.227273  0.227273           80
# 16    0.000000  0.000000       0.191304    1.000000  0.321168           80
# 17    0.010753  0.021277       0.192982    1.000000  0.323529           80
# 18    0.870968  0.826531       0.000000    0.000000  0.000000           80
# 19    0.408602  0.500000       0.017857    0.045455  0.025641           80
# 20    0.967742  0.927835       0.785714    0.500000  0.611111           80
# 21    0.881720  0.877005       0.476190    0.454545  0.465116           80
# 22    0.838710  0.857143       0.423077    0.500000  0.458333           80
# 23    0.924731  0.914894       0.650000    0.590909  0.619048           80
# 24    0.870968  0.885246       0.520000    0.590909  0.553191           80
# 25    0.720430  0.788235       0.315789    0.545455  0.400000           80
# 26    0.881720  0.921348       0.633333    0.863636  0.730769           80
# 27    0.924731  0.934783       0.708333    0.772727  0.739130           80
# 28    0.935484  0.887755       0.500000    0.272727  0.352941           80
# 29    0.881720  0.926554       0.645161    0.909091  0.754717           80
# 30    0.720430  0.837500       0.458333    1.000000  0.628571           80
# 31    0.720430  0.807229       0.380952    0.727273  0.500000           80
# Results for window size: 100
#                   Name                      Params  Accuracy  Precision (0)  \
# 0                 LSTM                  250 layers  0.715789       0.715789
# 1                 LSTM                  200 layers  0.115789       0.264706
# 2                 LSTM                  100 layers  0.715789       0.715789
# 3                 LSTM                   50 layers  0.694737       0.709677
# 4   CNN with Attention   32 filters, kernel size 7  0.831579       0.833333
# 5   CNN with Attention   32 filters, kernel size 5  0.852632       0.875000
# 6   CNN with Attention   32 filters, kernel size 3  0.905263       0.927536
# 7   CNN with Attention   64 filters, kernel size 7  0.800000       0.802469
# 8   CNN with Attention   64 filters, kernel size 5  0.863158       0.876712
# 9   CNN with Attention   64 filters, kernel size 3  0.873684       0.924242
# 10  CNN with Attention  128 filters, kernel size 7  0.810526       0.812500
# 11  CNN with Attention  128 filters, kernel size 5  0.821053       0.849315
# 12  CNN with Attention  128 filters, kernel size 3  0.873684       0.900000
# 13  CNN with Attention  256 filters, kernel size 7  0.778947       0.776471
# 14  CNN with Attention  256 filters, kernel size 5  0.789474       0.792683
# 15  CNN with Attention  256 filters, kernel size 3  0.810526       0.837838
# 16                 RNN                   200 units  0.284211       0.500000
# 17                 RNN                   150 units  0.431579       0.602941
# 18                 RNN                   100 units  0.157895       0.300000
# 19                 RNN                    50 units  0.094737       0.250000
# 20                 CNN   32 filters, kernel size 7  0.726316       0.750000
# 21                 CNN   32 filters, kernel size 5  0.757895       0.771084
# 22                 CNN   32 filters, kernel size 3  0.726316       0.769231
# 23                 CNN   64 filters, kernel size 7  0.715789       0.715789
# 24                 CNN   64 filters, kernel size 5  0.705263       0.727273
# 25                 CNN   64 filters, kernel size 3  0.778947       0.783133
# 26                 CNN  128 filters, kernel size 7  0.852632       0.909091
# 27                 CNN  128 filters, kernel size 5  0.757895       0.771084
# 28                 CNN  128 filters, kernel size 3  0.789474       0.800000
# 29                 CNN  256 filters, kernel size 7  0.768421       0.773810
# 30                 CNN  256 filters, kernel size 5  0.789474       0.807692
# 31                 CNN  256 filters, kernel size 3  0.768421       0.773810
#
#     Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  Window Size
# 0     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 1     0.132353  0.176471       0.032787    0.074074  0.045455          100
# 2     1.000000  0.834356       0.000000    0.000000  0.000000          100
# 3     0.970588  0.819876       0.000000    0.000000  0.000000          100
# 4     0.955882  0.890411       0.823529    0.518519  0.636364          100
# 5     0.926471  0.900000       0.782609    0.666667  0.720000          100
# 6     0.941176  0.934307       0.846154    0.814815  0.830189          100
# 7     0.955882  0.872483       0.785714    0.407407  0.536585          100
# 8     0.941176  0.907801       0.818182    0.666667  0.734694          100
# 9     0.897059  0.910448       0.758621    0.814815  0.785714          100
# 10    0.955882  0.878378       0.800000    0.444444  0.571429          100
# 11    0.911765  0.879433       0.727273    0.592593  0.653061          100
# 12    0.926471  0.913043       0.800000    0.740741  0.769231          100
# 13    0.970588  0.862745       0.800000    0.296296  0.432432          100
# 14    0.955882  0.866667       0.769231    0.370370  0.500000          100
# 15    0.911765  0.873239       0.714286    0.555556  0.625000          100
# 16    0.323529  0.392857       0.098039    0.185185  0.128205          100
# 17    0.602941  0.602941       0.000000    0.000000  0.000000          100
# 18    0.132353  0.183673       0.092308    0.222222  0.130435          100
# 19    0.132353  0.173077       0.000000    0.000000  0.000000          100
# 20    0.926471  0.828947       0.545455    0.222222  0.315789          100
# 21    0.941176  0.847682       0.666667    0.296296  0.410256          100
# 22    0.882353  0.821918       0.529412    0.333333  0.409091          100
# 23    1.000000  0.834356       0.000000    0.000000  0.000000          100
# 24    0.941176  0.820513       0.428571    0.111111  0.176471          100
# 25    0.955882  0.860927       0.750000    0.333333  0.461538          100
# 26    0.882353  0.895522       0.724138    0.777778  0.750000          100
# 27    0.941176  0.847682       0.666667    0.296296  0.410256          100
# 28    0.941176  0.864865       0.733333    0.407407  0.523810          100
# 29    0.955882  0.855263       0.727273    0.296296  0.421053          100
# 30    0.926471  0.863014       0.705882    0.444444  0.545455          100
# 31    0.955882  0.855263       0.727273    0.296296  0.421053          100

# %% [markdown]
# ### **Random Under Sampling**

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler


# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomOverSampler BEFORE creating sequences
# random_under_sampler = RandomUnderSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_under_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# # Proceed with model training and evaluation
# evaluate_all_models(RUS_OUTPUT_PATH)

# %% [markdown]
# ### **Random Over Sampling**

# %%
# from imblearn.over_sampling import RandomOverSampler

# time_series_df = aggregated_df.copy()

# # Drop rows with NaN in the 'spikes' column
# time_series_df = time_series_df.dropna(subset=['spikes'])
# discretized_df = discretize(time_series_df[FEATURE_COLUMNS], FEATURE_COLUMNS, BIN_COUNT)
# time_series_df[FEATURE_COLUMNS] = discretized_df

# # Extract features and target variable BEFORE creating sequences
# X = time_series_df[FEATURE_COLUMNS].values
# y = time_series_df['spikes'].values

# # Feature scaling using StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Apply RandomUnderSampler BEFORE creating sequences
# random_over_sampler = RandomOverSampler(random_state=RANDOM_STATE)
# X_scaled_resampled, y_resampled = random_over_sampler.fit_resample(X_scaled, y)

# # Recreate sequences with resampled data
# X_sequences_resampled, y_sequences_resampled = [], []
# for i in range(len(X_scaled_resampled) - SPIKES_WINDOW_SIZE + 1):
#     X_sequences_resampled.append(X_scaled_resampled[i:i + SPIKES_WINDOW_SIZE, :])
#     y_sequences_resampled.append(y_resampled[i + SPIKES_WINDOW_SIZE - 1])

# X_sequences_resampled, y_sequences_resampled = np.array(X_sequences_resampled), np.array(y_sequences_resampled)

# # Split the resampled sequences into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_sequences_resampled, y_sequences_resampled, test_size=0.2, random_state=50)

# evaluate_all_models(ROS_OUTPUT_PATH)
