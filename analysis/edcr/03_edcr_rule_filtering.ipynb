# %%
import sys
sys.path.append('../')

import os
import pandas as pd
import warnings
import utils.edcr_helper as ep
from utils import rule_filter as rf
warnings.filterwarnings('ignore')

# %%
OUTPUT_DIR = 'evaluation_results'
os.makedirs(f'{OUTPUT_DIR}/top_f1', exist_ok=True)
os.makedirs(f'{OUTPUT_DIR}/threshold', exist_ok=True)
os.makedirs("data", exist_ok=True)

# %% [markdown]
# ### Model Select
# - This algorithm is used to select Base Models for our experiments.
# - The idea is that we want to apply EDCR to models of extremeties. Like models with peak F1, Recall, Precision. Or even the "worst" models (lowest F1).

# %%
# Model select test
model_check = ep.model_select(f'model_results/cobalt_shift_20d/metrics.csv')
print(model_check)
# Out:
# Highest F1: {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286} at model - CNN_256_filters_3_kernels_predictions
# Highest Recall: {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286} at model - CNN_256_filters_3_kernels_predictions
# Highest Precision: {'Precision (1)': 0.9375, 'Recall (1)': 0.1923076923076923, 'F1 (1)': 0.3191489361702128} at model - CNN_Attention_128_filters_5_kernels_predictions
# Lowest F1: {'Precision (1)': 0.25, 'Recall (1)': 0.0128205128205128, 'F1 (1)': 0.024390243902439} at model - LSTM_32_layers_predictions
# {'Highest F1': {'model': 'CNN_256_filters_3_kernels_predictions', 'metrics': {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286}}, 'Highest Recall': {'model': 'CNN_256_filters_3_kernels_predictions', 'metrics': {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286}}, 'Highest Precision': {'model': 'CNN_Attention_128_filters_5_kernels_predictions', 'metrics': {'Precision (1)': 0.9375, 'Recall (1)': 0.1923076923076923, 'F1 (1)': 0.3191489361702128}}, 'Lowest F1': {'model': 'LSTM_32_layers_predictions', 'metrics': {'Precision (1)': 0.25, 'Recall (1)': 0.0128205128205128, 'F1 (1)': 0.024390243902439}}}

# %%
# %%capture

# COMMODITY = 'nickel_no_val_20'
# MODEL = CNNA
# RULE_NUM = 10
# confidence_levels = [0.4, 0.45, 0.5, 0.55, 0.6, 0.7, 0.8, 0.9, 0.95]

def exclude_zero(series):
    temp = series.copy()
    temp = temp[temp != 0]
    temp = temp[temp != 1]
    return temp

# A function for providing useful labels for the results
def label(results, row):
    labels = []
    max_base_model_precision = exclude_zero(results["Precision (Base Model)"]).max()
    max_base_model_recall = exclude_zero(results["Recall (Base Model)"]).max()
    max_base_model_f1 = exclude_zero(results["F1 (Base Model)"]).max()
    min_base_model_f1 = exclude_zero(results["F1 (Base Model)"]).min()

    if max_base_model_precision == row["Precision (Base Model)"]: labels.append("Best Precision")
    if max_base_model_recall == row["Recall (Base Model)"]: labels.append("Best Recall")
    if max_base_model_f1 == row["F1 (Base Model)"]: labels.append("Best F1")
    if min_base_model_f1 == row["F1 (Base Model)"]: labels.append("Worst F1")
    return ', '.join(labels)

def evaluate_df(df, properties={}):
    # Base model metrics are now passed directly in properties
    precision = properties.get('Base Precision', 0)
    recall = properties.get('Base Recall', 0)
    f1 = properties.get('Base F1', 0)
    prior = df["corr"].sum() / len(df) if len(df) else 0

    df.to_numpy().dump('data/test.npy')
    df = ep.run_edcr()  # APPLYING EDCR

    new_precision = df.iloc[50]["pre"] if len(df) > 50 else 0
    new_recall = df.iloc[50]["recall"] if len(df) > 50 else 0
    new_f1 = df.iloc[50]["F1"] if len(df) > 50 else 0

    percent_precision = ((new_precision - precision) / precision) if precision != 0 else 0
    percent_recall = ((new_recall - recall) / recall) if recall != 0 else 0
    percent_f1 = ((new_f1 - f1) / f1) if f1 != 0 else 0

    return {
        **properties,
        "Precision (Base Model)": precision,
        "Recall (Base Model)": recall,
        "F1 (Base Model)": f1,
        "Prior": prior,
        "Precision (EDCR)": new_precision,
        "Recall (EDCR)": new_recall,
        "F1 (EDCR)": new_f1,
        "Precision Improvement": new_precision - precision,
        "Recall Improvement": new_recall - recall,
        "F1 Improvement": new_f1 - f1,
        "Precision Improvement (%)": percent_precision,
        "Recall Improvement (%)": percent_recall,
        "F1 Improvement (%)": percent_f1
    }

# %% [markdown]
# ### Rule Filtering Algorithm 1: Top N selection.
# - What this algorithm does is we select the top N ruleX that have the best F1-Score. You can use other metrics, but F1 is a balance of Recall and Precision, and due to some of our results, we found this metric work best for us anyway.

# %%
for COMMODITY in [
    'cobalt_shift_20d', 
    'copper_shift_20d', 
    'magnesium_shift_20d', 
    'nickel_shift_20d',
]:
    results = []
    model_metrics = ep.model_select(f'model_results/{COMMODITY}/metrics.csv')
    print(f'({COMMODITY}): {model_metrics}')
    
    for model_key, model_info in model_metrics.items():
        model_name = model_info['model']
        base_metrics = model_info['metrics']
        
        for ALGO in ['correction', 'detection_correction']:
            for RULE_NUM in [200]:
                # for ablate_models in ['RNN']:
                for ablate_models in [None,'LSTM', 'CNNA', 'CNN', 'RNN']:
                # for ablate_models in ['LSTM', 'CNNA', 'CNN', 'RNN']:
                    df_path = f'model_results/{COMMODITY}/predictions/test/{model_name}.csv'

                    df = rf.npy_to_top_n_f1_bowpy(df_path, f'model_results/{COMMODITY}/predictions/test_{ALGO}', RULE_NUM, ablate_models)
                    df.to_numpy().dump('data/test.npy')

                    # Pass the model's base metrics along with other properties to evaluate_df
                    properties = {
                        "Model": model_name,
                        "Exclude": ablate_models,
                        "Algorithm": ALGO,
                        "Rule Num": RULE_NUM,
                        "Base Precision": base_metrics['Precision (1)'],
                        "Base Recall": base_metrics['Recall (1)'],
                        "Base F1": base_metrics['F1 (1)'],
                    }
                    result = evaluate_df(df, properties)
                    results.append(result)

    results_df = pd.DataFrame(results)
    results_df['Label'] = results_df.apply(lambda x: label(results_df, x), axis=1)
    results_df.to_excel(f'evaluation_results/top_f1/{COMMODITY}_results.xlsx', index=False)

# %% [markdown]
# ### Rule Filtering Algorithm 2: Threshold selection.
# - What this algorithm does is we select any number of rules from the ruleX pool that exceed the F1 threshold that we defined.

# %%
rule_usage_data = []

# %%
for COMMODITY in [
    'cobalt_shift_20d', 
    'copper_shift_20d', 
    'magnesium_shift_20d', 
    'nickel_shift_20d',
]:
    results = []
    model_metrics = ep.model_select(f'model_results/{COMMODITY}/metrics.csv')
    print(f'({COMMODITY}): {model_metrics}')

    for model_key, model_info in model_metrics.items():
        model_name = model_info['model']
        base_metrics = model_info['metrics']

        for ALGO in ['correction', 'detection_correction']:
            # for THRESHOLD in [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]:
            for THRESHOLD in [0.5]:
                for ablate_models in [None,'LSTM', 'CNNA', 'CNN', 'RNN']:
                    df_path = f'model_results/{COMMODITY}/predictions/test/{model_name}.csv'
                    
                    df, rules_used, rule_count = rf.npy_to_threshold_f1_bowpy(df_path, f'model_results/{COMMODITY}/predictions/test_{ALGO}', THRESHOLD, ablate_models)
                    df.to_numpy().dump('data/test.npy')

                    # Pass the model's base metrics along with other properties to evaluate_df
                    properties = {
                        "Model": model_name,
                        "Exclude": ablate_models,
                        "Algorithm": ALGO,
                        "Threshold": THRESHOLD,
                        "Base Precision": base_metrics['Precision (1)'],
                        "Base Recall": base_metrics['Recall (1)'],
                        "Base F1": base_metrics['F1 (1)'],
                    }
                    result = evaluate_df(df, properties)
                    results.append(result)

                    rule_usage_data.append({
                        "COMMODITY": COMMODITY,
                        "Model": model_name,
                        "Algorithm": ALGO,
                        "Threshold": THRESHOLD,
                        "Exclude": ablate_models,
                        "Rules Used": rules_used,
                        "Original Rule No.": rule_count
                    })

    results_df = pd.DataFrame(results)
    results_df['Label'] = results_df.apply(lambda x: label(results_df, x), axis=1)
    results_df.to_excel(f'evaluation_results/threshold/{COMMODITY}_results.xlsx', index=False)
# Out:
# Highest F1: {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286} at model - CNN_256_filters_3_kernels_predictions
# Highest Recall: {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286} at model - CNN_256_filters_3_kernels_predictions
# Highest Precision: {'Precision (1)': 0.9375, 'Recall (1)': 0.1923076923076923, 'F1 (1)': 0.3191489361702128} at model - CNN_Attention_128_filters_5_kernels_predictions
# Lowest F1: {'Precision (1)': 0.25, 'Recall (1)': 0.0128205128205128, 'F1 (1)': 0.024390243902439} at model - LSTM_32_layers_predictions
# (cobalt_shift_20d): {'Highest F1': {'model': 'CNN_256_filters_3_kernels_predictions', 'metrics': {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286}}, 'Highest Recall': {'model': 'CNN_256_filters_3_kernels_predictions', 'metrics': {'Precision (1)': 0.8225806451612904, 'Recall (1)': 0.6538461538461539, 'F1 (1)': 0.7285714285714286}}, 'Highest Precision': {'model': 'CNN_Attention_128_filters_5_kernels_predictions', 'metrics': {'Precision (1)': 0.9375, 'Recall (1)': 0.1923076923076923, 'F1 (1)': 0.3191489361702128}}, 'Lowest F1': {'model': 'LSTM_32_layers_predictions', 'metrics': {'Precision (1)': 0.25, 'Recall (1)': 0.0128205128205128, 'F1 (1)': 0.024390243902439}}}
# Excluded 117 rules due to F1 filtering
# Excluded 0 rules due to model filtering
# Excluded 0 rules due to problematic formatting
# Rules used: 627 out of 744
# TP:51, FP:12, TN:414, FN:27
# ep:0.001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.003
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.005
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.006
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.007
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.008
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.009000000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.01
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.011
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.012
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.013000000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.014
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.015
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.016
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.017
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.018000000000000002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.019
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.02
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.021
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.022
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.023
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.024
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.025
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.026000000000000002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.027
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.028
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.029
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.03
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.031
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.032
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.033
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.034
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.035
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.036000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.037
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.038
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.039
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.04
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.041
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.042
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.043000000000000003
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.044
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.045
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.046
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.047
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.048
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.049
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.05
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.051000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.052000000000000005
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.053
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.054
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.055
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.056
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.057
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.058
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.059000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.06
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.061
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.062
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.063
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.064
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.065
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.066
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.067
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.068
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.069
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07100000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07200000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.073
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.074
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.075
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.076
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.077
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.078
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.079
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.081
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.082
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.083
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.084
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.085
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08600000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08700000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.088
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.089
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.09
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.091
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.092
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.093
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.094
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.095
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.096
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.097
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.098
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.099
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# Excluded: Confident 0.1 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.9 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.9 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.9 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.9 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule LSTM_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule LSTM_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule LSTM_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule LSTM_64 for CNN_256_3_predictions.csv
# Excluded 105 rules due to F1 filtering
# Excluded 48 rules due to model filtering
# Excluded 0 rules due to problematic formatting
# Rules used: 591 out of 744
# TP:51, FP:12, TN:414, FN:27
# ep:0.001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.003
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.005
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.006
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.007
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.008
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.009000000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.01
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.011
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.012
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.013000000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.014
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.015
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.016
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.017
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.018000000000000002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.019
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.02
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.021
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.022
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.023
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.024
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.025
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.026000000000000002
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.027
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.028
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.029
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.03
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.031
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.032
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.033
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.034
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.035
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.036000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.037
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.038
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.039
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.04
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.041
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.042
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.043000000000000003
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.044
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.045
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.046
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.047
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.048
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.049
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.05
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.051000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.052000000000000005
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.053
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.054
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.055
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.056
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.057
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.058
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.059000000000000004
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.06
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.061
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.062
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.063
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.064
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.065
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.066
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.067
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.068
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.069
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07100000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.07200000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.073
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.074
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.075
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.076
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.077
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.078
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.079
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.081
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.082
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.083
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.084
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.085
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08600000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.08700000000000001
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.088
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.089
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.09
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.091
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.092
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.093
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.094
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.095
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.096
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.097
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.098
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# TP:51, FP:12, TN:414, FN:27
# ep:0.099
# [0.8095238095238095, 0.6538461538461539, 0.723404255319149, 0, 1, 0, 13]
# Excluded: Confident 0.1 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_256_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNNA_64_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_128_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_128_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_128_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_128_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_128_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_128_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_256_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_256_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_256_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_32_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_32_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_32_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.5 Rule CNN_256_3 for CNN_32_3_predictions.csv
# ...
# Excluded: Confident 0.95 Rule CNN_256_3 for CNNA_64_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNNA_64_5_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNNA_64_7_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_128_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_128_5_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_128_7_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_256_5_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_256_7_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_32_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_32_5_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_32_7_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_64_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_64_5_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for CNN_64_7_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for LSTM_128_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for LSTM_256_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for LSTM_32_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for LSTM_64_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for RNN_128_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for RNN_256_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for RNN_32_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_3 for RNN_64_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_256_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_32_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_32_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_32_7 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_64_3 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_64_5 for CNN_256_3_predictions.csv
# Excluded: Confident 0.95 Rule CNN_64_7 for CNN_256_3_predictions.csv
# Excluded 52 rules due to F1 filtering
# Excluded 504 rules due to model filtering
# Excluded 0 rules due to problematic formatting
# Rules used: 188 out of 744
# TP:51, FP:11, TN:415, FN:27
# ep:0.001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.002
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.003
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.004
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.005
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.006
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.007
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.008
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.009000000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.01
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.011
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.012
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.013000000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.014
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.015
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.016
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.017
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.018000000000000002
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.019
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.02
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.021
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.022
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.023
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.024
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.025
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.026000000000000002
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.027
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.028
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.029
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.03
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.031
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.032
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.033
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.034
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.035
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.036000000000000004
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.037
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.038
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.039
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.04
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.041
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.042
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.043000000000000003
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.044
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.045
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.046
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.047
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.048
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.049
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.05
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.051000000000000004
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.052000000000000005
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.053
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.054
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.055
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.056
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.057
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.058
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.059000000000000004
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.06
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.061
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.062
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.063
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.064
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.065
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.066
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.067
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.068
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.069
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.07
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.07100000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.07200000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.073
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.074
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.075
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.076
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.077
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.078
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.079
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.08
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.081
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.082
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.083
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.084
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.085
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.08600000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.08700000000000001
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.088
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.089
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.09
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.091
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.092
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.093
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.094
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.095
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.096
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.097
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.098
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# TP:51, FP:11, TN:415, FN:27
# ep:0.099
# [0.8225806451612904, 0.6538461538461539, 0.7285714285714285, 0, 0, 0, 0]
# Excluded: Confident 0.1 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.1 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.2 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.3 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.4 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.45 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.5 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.55 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.6 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.7 Rule RNN_64 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule RNN_128 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule RNN_256 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule RNN_32 for CNN_256_3_predictions.csv
# Excluded: Confident 0.8 Rule RNN_64 for CNN_256_3_predictions.csv

# %%
rule_usage_df = pd.DataFrame(rule_usage_data)

# %%
rule_usage_df
rule_usage_df_filtered = rule_usage_df[
    (rule_usage_df['Exclude'].isnull()) & (rule_usage_df['Algorithm'] == 'detection_correction')
]
rule_usage_df_filtered
# Out:
#                   COMMODITY                                            Model  \
# 5       cobalt_shift_new_20            CNN_256_filters_3_kernels_predictions
# 15      cobalt_shift_new_20            CNN_256_filters_3_kernels_predictions
# 25      cobalt_shift_new_20  CNN_Attention_128_filters_5_kernels_predictions
# 35      cobalt_shift_new_20                       LSTM_32_layers_predictions
# 45      copper_shift_new_20   CNN_Attention_32_filters_5_kernels_predictions
# 55      copper_shift_new_20             CNN_32_filters_3_kernels_predictions
# 65      copper_shift_new_20             CNN_64_filters_7_kernels_predictions
# 75      copper_shift_new_20  CNN_Attention_256_filters_5_kernels_predictions
# 85   magnesium_shift_new_20             CNN_32_filters_7_kernels_predictions
# 95   magnesium_shift_new_20                        RNN_256_units_predictions
# 105  magnesium_shift_new_20             CNN_32_filters_5_kernels_predictions
# 115  magnesium_shift_new_20                       LSTM_32_layers_predictions
# 125     nickel_shift_new_20   CNN_Attention_64_filters_5_kernels_predictions
# 135     nickel_shift_new_20            CNN_128_filters_3_kernels_predictions
# 145     nickel_shift_new_20  CNN_Attention_128_filters_5_kernels_predictions
# 155     nickel_shift_new_20                       LSTM_32_layers_predictions
#
#                 Algorithm  Threshold Exclude  Rules Used
# 5    detection_correction        0.5    None         542
# 15   detection_correction        0.5    None         542
# 25   detection_correction        0.5    None         120
# 35   detection_correction        0.5    None         120
# 45   detection_correction        0.5    None         543
# 55   detection_correction        0.5    None         530
# 65   detection_correction        0.5    None         533
# 75   detection_correction        0.5    None         145
# 85   detection_correction        0.5    None         330
# 95   detection_correction        0.5    None          12
# 105  detection_correction        0.5    None          19
# 115  detection_correction        0.5    None          12
# 125  detection_correction        0.5    None         426
# 135  detection_correction        0.5    None          46
# 145  detection_correction        0.5    None         115
# 155  detection_correction        0.5    None          40
