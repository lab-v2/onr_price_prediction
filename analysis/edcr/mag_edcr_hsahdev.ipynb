# %%
import numpy as np
import numpy
import torch
# from speed_rule import MaxRule
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, classification_report
import matplotlib.pyplot as plt
import sys

# %%
MODEL = "LSTM_100_layers"

# %%
pred_data = np.load(f'results/magnesium/pred/{MODEL}_predictions.npy')
pred_data = pred_data.flatten()

true_data = np.load(f'results/magnesium/true/{MODEL}_true_labels.npy')
true_data = true_data.flatten()

# %%
cla1_data = pred_data
cla0_data = np.logical_xor(pred_data, 1).astype(int)

# %%
n_classes = 2
count = 0
c1 = 0
# maxRules = MaxRule("confidents_obj.pkl")
charts = []
# print(maxRules.dic_conf)
#confidences = sorted(maxRules.dic_conf.keys())
confidences = [i * 0.01 for i in range(1, 100, 10)]
pr_curve = []
print(f"confidences:{confidences}")
cla_datas = [cla0_data, cla1_data]   # neural network binary result
high_scores = [0.95, 0.98]  # >0.95 is one rule, >0.98 is another rule, in total 4*5
low_scores = [0.05, 0.02]
#high_scores = [0.8]
#low_scores = [0.2]

def rules1(i):
    rule_scores = []
    for cls in cla_datas:
        for score in high_scores:
            if cls[i] > score:
                rule_scores.append(1)
            else:
                rule_scores.append(0)
        for score in low_scores:
            if cls[i] < score:
                rule_scores.append(1)
            else:
                rule_scores.append(0)
    return rule_scores
# Out:
# confidences:[0.01, 0.11, 0.21, 0.31, 0.41000000000000003, 0.51, 0.61, 0.71, 0.81, 0.91]

# %%
m = true_data.shape[0]
for i in range(m):
    tmp_charts = []
    tmp_charts.extend([pred_data[i], true_data[i]])
    tmp_charts += rules1(i)
    charts.append(tmp_charts)

# %%
# Functions

def get_scores(y_true, y_pred):
    try:
        y_actual = y_true
        y_hat = y_pred
        TP = 0
        FP = 0
        TN = 0
        FN = 0

        for i in range(len(y_hat)): 
            if y_actual[i]==y_hat[i]==1:
               TP += 1
            if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
               FP += 1
            if y_actual[i]==y_hat[i]==0:
               TN += 1
            if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
               FN += 1
        print(f"TP:{TP}, FP:{FP}, TN:{TN}, FN:{FN}")
        
        pre = precision_score(y_true, y_pred)
        rec = recall_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred)
        return [pre, rec, f1]
    except:
        pre = accuracy_score(y_true, y_pred)
        f1 =         f1_score(y_true, y_pred, average='macro')
        f1micro =         f1_score(y_true, y_pred, average='micro')
        return [pre, f1, f1micro]


def generate_chart(charts):
    all_charts = [[] for _ in range(n_classes)]
    for data in charts:
        for count, jj in enumerate(all_charts):
            # pred, corr, tp, fp, cond1, cond2 ... condn
            each_items = []
            for d in data[:2]:
                if d == count:
                    each_items.append(1)
                else:
                    each_items.append(0)

            if each_items[0] == 1 and each_items[1] == 1:
                each_items.append(1)
            else:
                each_items.append(0)
            if each_items[0] == 1 and each_items[1] == 0:
                each_items.append(1)
            else:
                each_items.append(0)
            each_items.extend(data[2:])
            jj.append(each_items)
    return all_charts

def DetUSMPosRuleSelect(i, all_charts):
    count = i
    chart = all_charts[i]
    chart = np.array(chart)
    rule_indexs = [i for i in range(4, len(chart[0]))]
    each_sum = np.sum(chart, axis = 0)
    tpi = each_sum[2]
    fpi = each_sum[3]
    pi = tpi * 1.0 /(tpi + fpi)

    pb_scores = []
    for ri in rule_indexs:
        posi = np.sum(chart[:,1] * chart[:,ri], axis = 0)
        bodyi = np.sum(chart[:,ri], axis = 0)
        score = posi * 1.0 / bodyi
        if score > pi:
            pb_scores.append((score, ri))
    pb_scores = sorted(pb_scores)
    cci = []
    ccn = pb_scores
    for (score, ri) in pb_scores:

        cii = 0
        ciij = 0
        for (cs, ci) in cci:
            cii = cii | chart[:,ci]
        POScci = np.sum(cii * chart[:, 1], axis = 0)
        BODcci = np.sum(cii, axis = 0)
        POSccij = np.sum((cii | chart[:,ri]) * chart[:, 1], axis = 0)
        BODccij = np.sum((cii | chart[:,ri]), axis = 0)

        cni = 0
        cnij = 0
        for (cs, ci) in ccn:
            cni = (cni | chart[:,ci])
            if ci == ri:
                continue
            cnij = (cnij | chart[:, ci])
        POScni = np.sum(cni * chart[:, 1], axis = 0)
        BODcni = np.sum(cni, axis = 0)
        POScnij = np.sum(cnij * chart[:, 1], axis = 0)
        BODcnij = np.sum(cnij, axis = 0)

        a = POSccij * 1.0 / (BODccij + 0.001) - POScci * 1.0 / (BODcci + 0.001)
        b = POScnij * 1.0 / (BODcnij + 0.001) - POScni * 1.0 / (BODcni + 0.001)
        if a >= b:
            cci.append((score, ri))
        else:
            ccn.remove((score, ri))

    cii = 0
    for (cs, ci) in cci:
        cii = cii | chart[:,ci]
    POScci = np.sum(cii * chart[:, 1], axis = 0)
    BODcci = np.sum(cii, axis = 0)
    new_pre = POScci * 1.0 / (BODcci + 0.001)
    if new_pre < pi:
        cci = []
    cci = [c[1] for c in cci]
    print(f"class{count}, cci:{cci}, new_pre:{new_pre}, pre:{pi}")
    return cci


import itertools
def GreedyNegRuleSelect(i, epsilon, all_charts):
    count = i
    chart = all_charts[i]
    chart = np.array(chart)
    rule_indexs = [i for i in range(4, len(chart[0]))]
    len_rules = len(rule_indexs)
    each_sum = np.sum(chart, axis = 0)
    tpi = each_sum[2]
    fpi = each_sum[3]
    pi = tpi * 1.0 /(tpi + fpi)
    ri = tpi * 1.0 / each_sum[1]
    ni = each_sum[0]
    quantity = epsilon * ni * pi / ri
    print(f"class{count}, quantity:{quantity}")

    best_combins = []
    NCi = []
    NCn = []
    for rule in rule_indexs:
        negi_score = np.sum(chart[:,2] * chart[:,rule])
        if negi_score < quantity:
            NCn.append(rule)

    while(NCn):
        best_score = -1
        best_index = -1
        for c in NCn:
            tem_cond = 0
            for cc in NCi:
                tem_cond |= chart[:,cc]
            tem_cond |= chart[:,c]
            posi_score = np.sum(chart[:,3] * tem_cond)
            if best_score < posi_score:
                best_score = posi_score
                best_index = c
        NCi.append(best_index)
        NCn.remove(best_index)
        tem_cond = 0
        for cc in NCi:
            tem_cond |= chart[:,cc]
        tmp_NCn = []
        for c in NCn:
            tem = tem_cond | chart[:,c]
            negi_score = np.sum(chart[:,2] * tem)
            if negi_score < quantity:
                tmp_NCn.append(c)
        NCn = tmp_NCn
    print(f"class:{count}, NCi:{NCi}")
    return NCi

    for r in range(1,len_rules + 1):
        combinations = list(itertools.combinations(rule_indexs, r))
        max_score = [0, 0, 0]
        max_combi = tuple()
        for cond in combinations:
            tmp_cond = 0
            for c in cond:
                tmp_cond |= chart[:,c]
            negi = chart[:,2] * tmp_cond 
            negi_score = np.sum(negi)
            if negi_score < quantity:
                posi = chart[:,3] * tmp_cond
                posi_score = np.sum(posi)
                if posi_score - negi_score > max_score[0]:
                    max_score[0] = posi_score - negi_score
                    max_score[1] = negi_score
                    max_score[2] = posi_score
                    max_combi = cond
        print(f"class{count}, r:{r}, max_score:{max_score[0]}, negi:{max_score[1]}, posi:{max_score[2]}, max_combi:{max_combi}")
        if max_combi:
            best_combins.append(max_combi)
    return best_combins

def GreedyNegRules(all_charts):
    epsilon = 0.01
    for count, chart in enumerate(all_charts):
        GreedyNegRuleSelect(count, epsilon, all_charts)
            
def DetUSMPosRules(all_charts):
    for count, chart in enumerate(all_charts):
        DetUSMPosRuleSelect(count, all_charts)

def ruleForPNCorrection(all_charts, epsilon):
    results = []
    total_results = np.copy(pred_data)
    for count, chart in enumerate(all_charts):
        chart = np.array(chart)
        negi_count = 0
        posi_count = 0

        predict_result = np.copy(chart[:,0])
        CCi = []
        CCi = DetUSMPosRuleSelect(count, all_charts)
        tem_cond = 0
        for cc in CCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct]:
                    if not predict_result[ct]:
                        posi_count += 1
                        predict_result[ct] = 1
                        total_results[ct] = count

        NCi = GreedyNegRuleSelect(count, epsilon, all_charts)

        tem_cond = 0
        for cc in NCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct] and predict_result[ct]:
                    negi_count += 1
                    predict_result[ct] = 0


        scores_cor = get_scores(chart[:,1], predict_result)
        results.extend(scores_cor + [ negi_count, posi_count, len(NCi), len(CCi) ])
    results.extend(get_scores(true_data, total_results))
    return results

def ruleForNegativeCorrection(all_charts, epsilon):   #how to use
    results = []
    total_results = np.copy(pred_data)
    for count, chart in enumerate(all_charts):
        chart = np.array(chart)
        NCi = GreedyNegRuleSelect(count, epsilon, all_charts)
        negi_count = 0
        posi_count = 0

        predict_result = np.copy(chart[:,0])
        tem_cond = 0
        for cc in NCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct] and predict_result[ct]:
                    negi_count += 1
                    predict_result[ct] = 0

        CCi = []
        scores_cor = get_scores(chart[:,1], predict_result)
        results.extend(scores_cor + [ negi_count, posi_count, len(NCi), len(CCi) ])
    results.extend(get_scores(true_data, total_results))
    return results

def ruleForNPCorrection(all_charts, epsilon):
    results = []
    total_results = np.copy(pred_data)
    for count, chart in enumerate(all_charts):
        chart = np.array(chart)
        NCi = GreedyNegRuleSelect(count, epsilon, all_charts)
        negi_count = 0
        posi_count = 0

        predict_result = np.copy(chart[:,0])
        tem_cond = 0
        for cc in NCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct] and predict_result[ct]:
                    negi_count += 1
                    predict_result[ct] = 0

        CCi = []
        CCi = DetUSMPosRuleSelect(count, all_charts)
        tem_cond = 0
        rec_true = []
        rec_pred = []
        for cc in CCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct]:
                    if not predict_result[ct]:
                        posi_count += 1
                        predict_result[ct] = 1
                        total_results[ct] = count
                else:
                    rec_true.append(cv[1])
                    rec_pred.append(cv[0])

        scores_cor = get_scores(chart[:,1], predict_result)
        results.extend(scores_cor + [ negi_count, posi_count, len(NCi), len(CCi) ])
    results.extend(get_scores(true_data, total_results))
    return results


def PosNegRuleLearn(all_charts):
    epsilon = 0.01
    #pi = [[] for _ in range(6)]
    #CCall = [[] for _ in range(6)]
    pi = []
    CCall = []
    CCall_set = []
    for count, chart in enumerate(all_charts):
        chart = np.array(chart)
        NCi = GreedyNegRuleSelect(count, epsilon, all_charts)

        tem_cond = 0
        for cc in NCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct] and cv[0]:
                    pi.append(ct)

        CCall.extend(NCi)
        CCall_set.extend(NCi)
    CCall_set = list(set(CCall_set))
    print(f"size of Neg PI:{len(pi)}")
    print(f"CCall:{CCall_set}")

    for count, chart in enumerate(all_charts):
        chart = np.array(chart)
        tmp_CCi = DetUSMPosRuleSelect(count, all_charts)
        CCi = []
        for i in tmp_CCi:
            if i in CCall_set:
                CCi.append(i)
        tem_cond = 0
        for cc in CCi:
            tem_cond |= chart[:,cc]
        if np.sum(tem_cond) > 0:
            for ct,cv in enumerate(chart):
                if tem_cond[ct] and not cv[0]:
                    pi.append(ct)
    print(f"size of Neg + pos PI:{len(pi)}")
    return pi



        #for nc in NCi:
        #    ncs.extend(nc)
        #ncs = list(set(ncs))
        #CCall.extend(ncs)
        #print(f"class:{count}, NCs:{ncs}")

# ignore this "generate_prf1_curve" function
def generate_prf1_curve(all_charts):
    for count, chart in enumerate(all_charts):
        scores = []
        #chart = np.array(chart)
        for c, i in enumerate(confidences):
            pred = []
            true = []
            for d in chart:
                if d[0] == 1 and d[2+c] == True:
                    continue
                pred.append(d[0])
                true.append(d[1])
            print(f"chart:{len(chart)},pred:{len(pred)}, truth:{len(true)}")
            scores.append([i] + get_scores(true, pred))
        plt.figure()
        scores = np.array(scores)
        print(scores)
        plt.plot(scores[:,0],scores[:,1], color = 'r', label = "Precision")
        plt.plot(scores[:,0],scores[:,2], color = 'b', label = "Recall")
        plt.plot(scores[:,0],scores[:,3], color = 'k', label = "F1")
        plt.legend()
        plt.title(f"{count}_class")
        plt.savefig(f"{count}_class.png")
        plt.close()

# %%
all_charts = generate_chart(charts)
#print("Negative rules:")
#greedy_rules = GreedyNegRules(all_charts)
#print("Positive rules:")
#positive_rules = DetUSMPosRules(all_charts)
results = []
result0 = [0]
for count, chart in enumerate(all_charts):
    chart = np.array(chart)
    result0.extend(get_scores(chart[:,1],chart[:,0]))
    result0.extend([0,0, 0 ,0])
result0.extend(get_scores(true_data, pred_data))
results.append(result0)
epsilon = [0.001 * i for i in range(1, 100, 1)]

for ep in epsilon:
    #result = PosNegRuleLearn(all_charts, epsilon)
    result = ruleForNegativeCorrection(all_charts, ep)
    results.append([ep] + result)
    print(f"ep:{ep}\n{result}")
col = ['pre', 'recall', 'F1', 'NSC', 'PSC', 'NRC', 'PRC']
df = pd.DataFrame(results, columns = ['epsilon'] + col * n_classes + ['acc', 'macro-F1', 'micro-F1'])
df.to_csv("rule_for_Negativecorrection.csv")
# Out:
# TP:151, FP:12, TN:19, FN:8
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# class0, quantity:0.159
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.031
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.318
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.062
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.4769999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.093
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.003
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.636
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.124
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.795
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.15500000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.005
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.9539999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.186
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.006
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.113
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.217
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.007
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.272
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.248
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.008
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.431
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.279
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.009000000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.59
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.31000000000000005
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.01
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.7489999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.34099999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.011
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.9079999999999997
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.372
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.012
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.067
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.403
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.013000000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.226
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.434
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.014
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.385
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.46499999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.015
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.544
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.496
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.016
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.7030000000000003
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.527
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.017
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.862
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.558
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.018000000000000002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.021
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.5890000000000001
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.019
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.18
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6200000000000001
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.02
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.339
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6510000000000001
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.021
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.4979999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6819999999999999
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.022
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.657
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.713
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.023
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.8159999999999994
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.744
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.024
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.9749999999999996
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.775
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.025
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.134
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.806
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.026000000000000002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.293
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.837
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.027
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.452
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.868
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.028
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.611000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.899
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.029
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.77
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.9299999999999999
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.03
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.929
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.961
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.031
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.088
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.992
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.032
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.247000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.023
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.033
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.406000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.054
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.034
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.565000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.085
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.035
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.724
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.116
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.036000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.883
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.147
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.037
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.042
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.1780000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.038
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.2010000000000005
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.209
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.039
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.36
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.2400000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.04
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.519000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.2710000000000001
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.041
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.678
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3020000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.042
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.837000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3330000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.043000000000000003
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.9959999999999996
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3639999999999999
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.044
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.155
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3949999999999998
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.045
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.314
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.426
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.046
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.472999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.4569999999999999
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.047
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.631999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.488
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.048
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.791
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.519
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.049
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.949999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.55
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.05
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.109
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.581
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.051000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.268
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.612
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.052000000000000005
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.427
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.6430000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.053
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.586
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.674
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.054
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.745
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.7050000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.055
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.904
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.736
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.056
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.062999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.7670000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.057
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.222000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.798
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.058
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.381
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.8290000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.059000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.54
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.8599999999999999
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.06
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.699
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.891
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.061
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.858
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.922
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.062
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.017
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.953
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.063
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.176
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.984
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.064
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.334999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.015
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.065
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.494000000000002
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.046
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.066
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.653
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.077
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.067
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.812000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.108
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.068
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.971
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.1390000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.069
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.130000000000003
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.17
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.289
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.201
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07100000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.448
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.232
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07200000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.607
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.263
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.073
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.766
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.294
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.074
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.924999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.325
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.075
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.084
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.3560000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.076
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.243
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.387
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.077
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.402000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.418
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.078
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.561
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.4490000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.079
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.72
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.4800000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.879000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.511
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.081
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.038000000000002
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.5420000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.082
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.197
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.5730000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.083
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.356
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6040000000000005
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.084
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.515
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6350000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.085
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.674000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6660000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08600000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.833
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6970000000000005
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08700000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.991999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.7279999999999998
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.088
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.151
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.759
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.089
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.31
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.7899999999999996
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.09
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.469
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.8209999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.091
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.628
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.852
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.092
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.787
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.883
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.093
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.945999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.9139999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.094
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.104999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.945
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.095
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.263999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.976
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.096
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.423
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:3.007
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.097
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.582
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:3.038
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.098
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.741
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:3.069
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.099
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]

# %%
results = []
results.append(result0)
for ep in epsilon:
    #result = PosNegRuleLearn(all_charts, epsilon)
    result = ruleForNPCorrection(all_charts, ep)
    results.append([ep] + result)
    print(f"ep:{ep}\n{result}")
col = ['pre', 'recall', 'F1', 'NSC', 'PSC', 'NRC', 'PRC']
df = pd.DataFrame(results, columns = ['epsilon'] + col * n_classes + ['acc', 'macro-F1', 'micro-F1'])
df.to_csv("rule_for_NPcorrection.csv")

results = []
results.append(result0)
for ep in epsilon:
    #result = PosNegRuleLearn(all_charts, epsilon)
    result = ruleForPNCorrection(all_charts, ep)
    results.append([ep] + result)
    print(f"ep:{ep}\n{result}")
df = pd.DataFrame(results, columns = ['epsilon'] + col * n_classes + ['acc', 'macro-F1', 'micro-F1'])
df.to_csv( "rule_for_PNcorrection.csv")
# Out:
# class0, quantity:0.159
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.031
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.318
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.062
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.4769999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.093
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.003
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.636
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.124
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.795
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.15500000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.005
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:0.9539999999999998
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.186
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.006
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.113
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.217
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.007
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.272
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.248
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.008
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.431
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.279
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.009000000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.59
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.31000000000000005
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.01
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.7489999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.34099999999999997
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.011
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:1.9079999999999997
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.372
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.012
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.067
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.403
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.013000000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.226
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.434
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.014
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.385
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.46499999999999997
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.015
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.544
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.496
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.016
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.7030000000000003
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.527
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.017
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:2.862
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.558
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.018000000000000002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.021
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.5890000000000001
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.019
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.18
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6200000000000001
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.02
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.339
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6510000000000001
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.021
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.4979999999999998
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.6819999999999999
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.022
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.657
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.713
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.023
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.8159999999999994
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.744
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.024
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:3.9749999999999996
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.775
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.025
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.134
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.806
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.026000000000000002
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.293
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.837
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.027
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.452
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.868
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.028
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.611000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.899
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.029
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.77
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.9299999999999999
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.03
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:4.929
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.961
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.031
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.088
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:0.992
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.032
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.247000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.023
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.033
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.406000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.054
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.034
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.565000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.085
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.035
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.724
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.116
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.036000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:5.883
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.147
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.037
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.042
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.1780000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.038
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.2010000000000005
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.209
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.039
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.36
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.2400000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.04
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.519000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.2710000000000001
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.041
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.678
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3020000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.042
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.837000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3330000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.043000000000000003
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:6.9959999999999996
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3639999999999999
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.044
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.155
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.3949999999999998
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.045
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.314
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.426
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.046
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.472999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.4569999999999999
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.047
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.631999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.488
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.048
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.791
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.519
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.049
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:7.949999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.55
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.05
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.109
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.581
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.051000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.268
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.612
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.052000000000000005
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.427
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.6430000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.053
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.586
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.674
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.054
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.745
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.7050000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.055
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:8.904
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.736
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.056
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.062999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.7670000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.057
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.222000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.798
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.058
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.381
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.8290000000000004
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.059000000000000004
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.54
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.8599999999999999
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.06
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.699
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.891
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.061
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:9.858
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.922
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.062
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.017
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.953
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.063
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.176
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:1.984
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.064
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.334999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.015
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.065
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.494000000000002
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.046
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.066
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.653
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.077
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.067
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.812000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.108
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.068
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:10.971
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.1390000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.069
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.130000000000003
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.17
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.289
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.201
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07100000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.448
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.232
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07200000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.607
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.263
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.073
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.766
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.294
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.074
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:11.924999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.325
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.075
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.084
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.3560000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.076
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.243
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.387
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.077
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.402000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.418
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.078
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.561
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.4490000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.079
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.72
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.4800000000000004
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:12.879000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.511
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.081
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.038000000000002
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.5420000000000003
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.082
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.197
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.5730000000000004
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.083
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.356
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6040000000000005
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.084
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.515
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6350000000000002
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.085
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.674000000000001
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6660000000000004
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08600000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.833
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.6970000000000005
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08700000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:13.991999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.7279999999999998
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.088
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.151
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.759
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.089
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.31
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.7899999999999996
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.09
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.469
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.8209999999999997
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.091
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.628
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.852
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.092
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.787
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.883
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.093
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:14.945999999999998
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.9139999999999997
# class:1, NCi:[4, 5, 10, 11]
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.094
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, quantity:15.104999999999999
# class:0, NCi:[6, 7, 8, 9]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# TP:151, FP:12, TN:19, FN:8
# class1, quantity:2.945
# class:1, NCi:[4, 5, 10, 11]
# ...
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:10.971
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.1390000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.069
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.130000000000003
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.17
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.289
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.201
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07100000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.448
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.232
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.07200000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.607
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.263
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.073
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.766
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.294
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.074
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:11.924999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.325
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.075
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.084
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.3560000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.076
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.243
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.387
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.077
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.402000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.418
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.078
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.561
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.4490000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.079
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.72
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.4800000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:12.879000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.511
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.081
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.038000000000002
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.5420000000000003
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.082
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.197
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.5730000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.083
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.356
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.6040000000000005
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.084
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.515
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.6350000000000002
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.085
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.674000000000001
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.6660000000000004
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08600000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.833
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.6970000000000005
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.08700000000000001
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:13.991999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.7279999999999998
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.088
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.151
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.759
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.089
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.31
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.7899999999999996
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.09
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.469
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.8209999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.091
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.628
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.852
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.092
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.787
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.883
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.093
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:14.945999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.9139999999999997
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.094
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:15.104999999999999
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.945
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.095
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:15.263999999999998
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:2.976
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.096
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:15.423
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:3.007
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.097
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:15.582
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:3.038
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.098
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
# class0, cci:[], new_pre:0.0, pre:0.9263803680981595
# class0, quantity:15.741
# class:0, NCi:[6, 7, 8, 9]
# TP:151, FP:12, TN:19, FN:8
# class1, cci:[], new_pre:0.0, pre:0.7037037037037037
# class1, quantity:3.069
# class:1, NCi:[4, 5, 10, 11]
# TP:19, FP:8, TN:151, FN:12
# TP:19, FP:8, TN:151, FN:12
# ep:0.099
# [0.9263803680981595, 0.949685534591195, 0.937888198757764, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035, 0, 0, 4, 0, 0.7037037037037037, 0.6129032258064516, 0.6551724137931035]
