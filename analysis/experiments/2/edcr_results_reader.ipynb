# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from IPython.display import display

# %%
COMMODITY = 'copper'

EDCR_RESULTS_PATH = f'{COMMODITY}/test/predictions/test'
OG_RESULTS_PATH = f'{COMMODITY}/test/results_test.csv'

# %%
def extract_info_from_filename(filename):
    parts = filename.split("Rule")
    epsilon = parts[0].split()[-1]
    models_base = parts[1].split("for")
    models = models_base[0].strip()
    base = models_base[1].split("_predictions")[0].strip()
    return base, models, epsilon

# %%
def calculate_metrics(df):
    y_true = df['True']
    y_pred = df['Predicted']
    accuracy = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0, 1])
    prior = pd.read_csv(OG_RESULTS_PATH, nrows=1)['Prior'].iloc[0]
    return accuracy, precision, recall, f1, prior

# %%
def process_files(path):
    all_results = []  
    for filename in os.listdir(path):
        if filename.startswith('Confident') and filename.endswith("_predictions.csv"):
            base, models, epsilon = extract_info_from_filename(filename)
            df = pd.read_csv(os.path.join(path, filename))
            accuracy, precision, recall, f1, prior = calculate_metrics(df)
            row = {
                'Base': base,
                'Models': models,
                'Epsilon': epsilon,
                'Accuracy': accuracy,
                'Precision (0)': precision[0],
                'Recall (0)': recall[0],
                'F1 (0)': f1[0],
                'Precision (1)': precision[1],
                'Recall (1)': recall[1],
                'F1 (1)': f1[1],
                'Prior': prior  
            }
            all_results.append(row)
    
    # Convert the list of results to a DataFrame
    return pd.DataFrame(all_results)

# %%
results_df = process_files(EDCR_RESULTS_PATH)
# Out:
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nocet\OneDrive\Documents\Projects\lab-v2\ezra\venv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results_df_one = results_df[results_df['Models'] != 'all']
# pd.set_option('display.max_rows', 200)
results_df_one
# Out:
#          Base      Models Epsilon  Accuracy  Precision (0)  Recall (0)  \
# 4    CNN_64_7  CNNA_128_3     0.5  0.481586       0.936416    0.485030
# 5    CNN_64_7   CNNA_32_3     0.5  0.481586       0.936416    0.485030
# 6    CNN_64_7   CNNA_32_7     0.5  0.484419       0.936782    0.488024
# 7    CNN_64_7   CNNA_64_7     0.5  0.796034       0.951724    0.826347
# 8   CNNA_64_7   CNN_128_7     0.5  0.498584       0.938547    0.502994
# 9    CNN_64_7   CNN_128_7     0.5  0.518414       0.940860    0.523952
# 10  CNNA_64_7    CNN_64_7     0.5  0.606232       0.945205    0.619760
# 11  CNNA_64_7    LSTM_256     0.5  0.243626       0.913580    0.221557
# 12  CNNA_64_7     LSTM_32     0.5  0.521246       0.941176    0.526946
# 13  CNNA_64_7     LSTM_64     0.5  0.552408       0.953608    0.553892
# 18   CNN_64_7  CNNA_128_3     0.6  0.487252       0.937143    0.491018
# 19   CNN_64_7   CNNA_32_3     0.6  0.484419       0.936782    0.488024
# 20   CNN_64_7   CNNA_32_7     0.6  0.507082       0.939560    0.511976
# 21   CNN_64_7   CNNA_64_7     0.6  0.855524       0.946372    0.898204
# 22  CNNA_64_7   CNN_128_7     0.6  0.507082       0.939560    0.511976
# 23   CNN_64_7   CNN_128_7     0.6  0.541076       0.943299    0.547904
# 24  CNNA_64_7    CNN_64_7     0.6  0.725212       0.940520    0.757485
# 25  CNNA_64_7    LSTM_256     0.6  0.246459       0.904762    0.227545
# 26  CNNA_64_7     LSTM_32     0.6  0.546742       0.943878    0.553892
# 27  CNNA_64_7     LSTM_64     0.6  0.552408       0.953608    0.553892
# 32   CNN_64_7  CNNA_128_3     0.7  0.490085       0.937500    0.494012
# 33   CNN_64_7   CNNA_32_3     0.7  0.490085       0.937500    0.494012
# 34   CNN_64_7   CNNA_32_7     0.7  0.549575       0.939698    0.559880
# 35   CNN_64_7   CNNA_64_7     0.7  0.898017       0.946108    0.946108
# 36  CNNA_64_7   CNN_128_7     0.7  0.526912       0.941799    0.532934
# 37   CNN_64_7   CNN_128_7     0.7  0.597734       0.944444    0.610778
# 38  CNNA_64_7    CNN_64_7     0.7  0.835694       0.945161    0.877246
# 39  CNNA_64_7    LSTM_256     0.7  0.249292       0.905882    0.230539
# 40  CNNA_64_7     LSTM_32     0.7  0.563739       0.945545    0.571856
# 41  CNNA_64_7     LSTM_64     0.7  0.558074       0.954082    0.559880
# 46   CNN_64_7  CNNA_128_3     0.8  0.501416       0.938889    0.505988
# 47   CNN_64_7   CNNA_32_3     0.8  0.495751       0.938202    0.500000
# 48   CNN_64_7   CNNA_32_7     0.8  0.643059       0.944444    0.661677
# 49   CNN_64_7   CNNA_64_7     0.8  0.929178       0.945245    0.982036
# 50  CNNA_64_7   CNN_128_7     0.8  0.558074       0.940594    0.568862
# 51   CNN_64_7   CNN_128_7     0.8  0.645892       0.944681    0.664671
# 52  CNNA_64_7    CNN_64_7     0.8  0.917847       0.947214    0.967066
# 53  CNNA_64_7    LSTM_256     0.8  0.249292       0.896552    0.233533
# 54  CNNA_64_7     LSTM_32     0.8  0.575071       0.933962    0.592814
# 55  CNNA_64_7     LSTM_64     0.8  0.560907       0.954315    0.562874
# 60   CNN_64_7  CNNA_128_3    0.95  0.671388       0.946721    0.691617
# 61   CNN_64_7   CNNA_32_3    0.95  0.597734       0.948598    0.607784
# 62   CNN_64_7   CNNA_32_7    0.95  0.798867       0.939799    0.841317
# 63   CNN_64_7   CNNA_64_7    0.95  0.946176       0.946176    1.000000
# 64  CNNA_64_7   CNN_128_7    0.95  0.764873       0.953069    0.790419
# 65   CNN_64_7   CNN_128_7    0.95  0.793201       0.948454    0.826347
# 66  CNNA_64_7    CNN_64_7    0.95  0.946176       0.946176    1.000000
# 67  CNNA_64_7    LSTM_256    0.95  0.277620       0.907216    0.263473
# 68  CNNA_64_7     LSTM_32    0.95  0.603399       0.933036    0.625749
# 69  CNNA_64_7     LSTM_64    0.95  0.569405       0.955000    0.571856
# 74   CNN_64_7  CNNA_128_3     0.9  0.600567       0.940639    0.616766
# 75   CNN_64_7   CNNA_32_3     0.9  0.532578       0.942408    0.538922
# 76   CNN_64_7   CNNA_32_7     0.9  0.742210       0.945055    0.772455
# 77   CNN_64_7   CNNA_64_7     0.9  0.937677       0.945714    0.991018
# 78  CNNA_64_7   CNN_128_7     0.9  0.688385       0.948000    0.709581
# 79   CNN_64_7   CNN_128_7     0.9  0.745042       0.948529    0.772455
# 80  CNNA_64_7    CNN_64_7     0.9  0.934844       0.945559    0.988024
# 81  CNNA_64_7    LSTM_256     0.9  0.266289       0.903226    0.251497
# 82  CNNA_64_7     LSTM_32     0.9  0.594901       0.932127    0.616766
# 83  CNNA_64_7     LSTM_64     0.9  0.566572       0.954774    0.568862
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 4   0.639053       0.044444    0.421053  0.080402   0.05
# 5   0.639053       0.044444    0.421053  0.080402   0.05
# 6   0.641732       0.044693    0.421053  0.080808   0.05
# 7   0.884615       0.079365    0.263158  0.121951   0.05
# 8   0.654971       0.045977    0.421053  0.082902   0.05
# 9   0.673077       0.047904    0.421053  0.086022   0.05
# 10  0.748644       0.052239    0.368421  0.091503   0.05
# 11  0.356627       0.044118    0.631579  0.082474   0.05
# 12  0.675624       0.048193    0.421053  0.086486   0.05
# 13  0.700758       0.062893    0.526316  0.112360   0.05
# 18  0.644401       0.044944    0.421053  0.081218   0.05
# 19  0.641732       0.044693    0.421053  0.080808   0.05
# 20  0.662791       0.046784    0.421053  0.084211   0.05
# 21  0.921659       0.055556    0.105263  0.072727   0.05
# 22  0.662791       0.046784    0.421053  0.084211   0.05
# 23  0.693182       0.050314    0.421053  0.089888   0.05
# 24  0.839138       0.035714    0.157895  0.058252   0.05
# 25  0.363636       0.040892    0.578947  0.076389   0.05
# 26  0.698113       0.050955    0.421053  0.090909   0.05
# 27  0.700758       0.062893    0.526316  0.112360   0.05
# 32  0.647059       0.045198    0.421053  0.081633   0.05
# 33  0.647059       0.045198    0.421053  0.081633   0.05
# 34  0.701689       0.045455    0.368421  0.080925   0.05
# 35  0.946108       0.052632    0.052632  0.052632   0.05
# 36  0.680688       0.048780    0.421053  0.087432   0.05
# 37  0.741818       0.051095    0.368421  0.089744   0.05
# 38  0.909938       0.046512    0.105263  0.064516   0.05
# 39  0.367542       0.041045    0.578947  0.076655   0.05
# 40  0.712687       0.052980    0.421053  0.094118   0.05
# 41  0.705660       0.063694    0.526316  0.113636   0.05
# 46  0.657588       0.046243    0.421053  0.083333   0.05
# 47  0.652344       0.045714    0.421053  0.082474   0.05
# 48  0.778169       0.050420    0.315789  0.086957   0.05
# 49  0.963289       0.000000    0.000000  0.000000   0.05
# 50  0.708955       0.046358    0.368421  0.082353   0.05
# 51  0.780316       0.050847    0.315789  0.087591   0.05
# 52  0.957037       0.083333    0.052632  0.064516   0.05
# 53  0.370546       0.037594    0.526316  0.070175   0.05
# 54  0.725275       0.035461    0.263158  0.062500   0.05
# 55  0.708098       0.064103    0.526316  0.114286   0.05
# 60  0.799308       0.055046    0.315789  0.093750   0.05
# 61  0.740876       0.057554    0.421053  0.101266   0.05
# 62  0.887836       0.018519    0.052632  0.027397   0.05
# 63  0.972344       0.000000    0.000000  0.000000   0.05
# 64  0.864157       0.078947    0.315789  0.126316   0.05
# 65  0.883200       0.064516    0.210526  0.098765   0.05
# 66  0.972344       0.000000    0.000000  0.000000   0.05
# 67  0.408353       0.039062    0.526316  0.072727   0.05
# 68  0.749104       0.031008    0.210526  0.054054   0.05
# 69  0.715356       0.065359    0.526316  0.116279   0.05
# 74  0.745027       0.044776    0.315789  0.078431   0.05
# 75  0.685714       0.049383    0.421053  0.088398   0.05
# 76  0.850082       0.050000    0.210526  0.080808   0.05
# 77  0.967836       0.000000    0.000000  0.000000   0.05
# 78  0.811644       0.058252    0.315789  0.098361   0.05
# 79  0.851485       0.061728    0.263158  0.100000   0.05
# 80  0.966325       0.000000    0.000000  0.000000   0.05
# 81  0.393443       0.038462    0.526316  0.071685   0.05
# 82  0.742342       0.030303    0.210526  0.052980   0.05
# 83  0.712946       0.064935    0.526316  0.115607   0.05

# %% [markdown]
# ### Base Model

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] != "dumb_spikes") & (results_df['Base'] != "dumb_non_spikes")]
results_df_all
# Out:
#          Base Models Epsilon  Accuracy  Precision (0)  Recall (0)    F1 (0)  \
# 0   CNNA_64_7    all     0.5  0.121813       0.961538    0.074850  0.138889
# 1    CNN_64_7    all     0.5  0.461756       0.933735    0.464072  0.620000
# 14  CNNA_64_7    all     0.6  0.121813       0.961538    0.074850  0.138889
# 15   CNN_64_7    all     0.6  0.464589       0.934132    0.467066  0.622754
# 28  CNNA_64_7    all     0.7  0.121813       0.961538    0.074850  0.138889
# 29   CNN_64_7    all     0.7  0.470255       0.934911    0.473054  0.628231
# 42  CNNA_64_7    all     0.8  0.121813       0.961538    0.074850  0.138889
# 43   CNN_64_7    all     0.8  0.475921       0.935673    0.479042  0.633663
# 56  CNNA_64_7    all    0.95  0.124646       0.962963    0.077844  0.144044
# 57   CNN_64_7    all    0.95  0.580737       0.947115    0.589820  0.726937
# 70  CNNA_64_7    all     0.9  0.124646       0.962963    0.077844  0.144044
# 71   CNN_64_7    all     0.9  0.512748       0.940217    0.517964  0.667954
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 0        0.055046    0.947368  0.104046   0.05
# 1        0.042781    0.421053  0.077670   0.05
# 14       0.055046    0.947368  0.104046   0.05
# 15       0.043011    0.421053  0.078049   0.05
# 28       0.055046    0.947368  0.104046   0.05
# 29       0.043478    0.421053  0.078818   0.05
# 42       0.055046    0.947368  0.104046   0.05
# 43       0.043956    0.421053  0.079602   0.05
# 56       0.055215    0.947368  0.104348   0.05
# 57       0.055172    0.421053  0.097561   0.05
# 70       0.055215    0.947368  0.104348   0.05
# 71       0.047337    0.421053  0.085106   0.05

# %% [markdown]
# ### Dumb Model (Only Predicts Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_spikes")]
results_df_all
# Out:
#            Base Models Epsilon  Accuracy  Precision (0)  Recall (0)  F1 (0)  \
# 3   dumb_spikes    all     0.5  0.053824            0.0         0.0     0.0
# 17  dumb_spikes    all     0.6  0.053824            0.0         0.0     0.0
# 31  dumb_spikes    all     0.7  0.053824            0.0         0.0     0.0
# 45  dumb_spikes    all     0.8  0.053824            0.0         0.0     0.0
# 59  dumb_spikes    all    0.95  0.053824            0.0         0.0     0.0
# 73  dumb_spikes    all     0.9  0.053824            0.0         0.0     0.0
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 3        0.053824         1.0  0.102151   0.05
# 17       0.053824         1.0  0.102151   0.05
# 31       0.053824         1.0  0.102151   0.05
# 45       0.053824         1.0  0.102151   0.05
# 59       0.053824         1.0  0.102151   0.05
# 73       0.053824         1.0  0.102151   0.05

# %% [markdown]
# ### Dumb Model (Only Predicts Non-Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_non_spikes")]
results_df_all
# Out:
#                Base Models Epsilon  Accuracy  Precision (0)  Recall (0)  \
# 2   dumb_non_spikes    all     0.5  0.461756       0.933735    0.464072
# 16  dumb_non_spikes    all     0.6  0.464589       0.934132    0.467066
# 30  dumb_non_spikes    all     0.7  0.470255       0.934911    0.473054
# 44  dumb_non_spikes    all     0.8  0.475921       0.935673    0.479042
# 58  dumb_non_spikes    all    0.95  0.580737       0.947115    0.589820
# 72  dumb_non_spikes    all     0.9  0.512748       0.940217    0.517964
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 2   0.620000       0.042781    0.421053  0.077670   0.05
# 16  0.622754       0.043011    0.421053  0.078049   0.05
# 30  0.628231       0.043478    0.421053  0.078818   0.05
# 44  0.633663       0.043956    0.421053  0.079602   0.05
# 58  0.726937       0.055172    0.421053  0.097561   0.05
# 72  0.667954       0.047337    0.421053  0.085106   0.05

# %% [markdown]
# ### Display All

# %%
og_df = pd.read_csv(OG_RESULTS_PATH)
og_df = og_df.drop('Unnamed: 0', axis=1)
pd.set_option('display.max_rows', 200)
og_df
# Out:
#                   Name                                     Params  Accuracy  \
# 0                 LSTM                                 256 layers  0.246459
# 1                 LSTM                                 128 layers  0.739377
# 2                 LSTM                                  64 layers  0.317280
# 3                 LSTM                                  32 layers  0.490085
# 4   CNN with Attention                  32 filters, kernel size 7  0.484419
# 5   CNN with Attention                  32 filters, kernel size 5  0.402266
# 6   CNN with Attention                  32 filters, kernel size 3  0.481586
# 7   CNN with Attention                  64 filters, kernel size 7  0.796034
# 8   CNN with Attention                  64 filters, kernel size 5  0.407932
# 9   CNN with Attention                  64 filters, kernel size 3  0.804533
# 10  CNN with Attention                 128 filters, kernel size 7  0.464589
# 11  CNN with Attention                 128 filters, kernel size 5  0.467422
# 12  CNN with Attention                 128 filters, kernel size 3  0.481586
# 13  CNN with Attention                 256 filters, kernel size 7  0.801700
# 14  CNN with Attention                 256 filters, kernel size 5  0.385269
# 15  CNN with Attention                 256 filters, kernel size 3  0.385269
# 16                 RNN                                  256 units  0.444759
# 17                 RNN                                  128 units  0.424929
# 18                 RNN                                   64 units  0.447592
# 19                 RNN                                   32 units  0.441926
# 20                 CNN                  32 filters, kernel size 7  0.456091
# 21                 CNN                  32 filters, kernel size 5  0.427762
# 22                 CNN                  32 filters, kernel size 3  0.458924
# 23                 CNN                  64 filters, kernel size 7  0.946176
# 24                 CNN                  64 filters, kernel size 5  0.450425
# 25                 CNN                  64 filters, kernel size 3  0.439093
# 26                 CNN                 128 filters, kernel size 7  0.518414
# 27                 CNN                 128 filters, kernel size 5  0.453258
# 28                 CNN                 128 filters, kernel size 3  0.453258
# 29                 CNN                 256 filters, kernel size 7  0.742210
# 30                 CNN                 256 filters, kernel size 5  0.368272
# 31                 CNN                 256 filters, kernel size 3  0.456091
# 32          Dumb Model                                     spikes  0.053824
# 33          Dumb Model                                 non_spikes  0.946176
# 34                EDCR    Confident 0.5Rule CNNA_64_7for CNN_64_7  0.796034
# 35                EDCR    Confident 0.5Rule CNN_128_7for CNN_64_7  0.518414
# 36                EDCR    Confident 0.5Rule CNNA_32_7for CNN_64_7  0.484419
# 37                EDCR   Confident 0.5Rule CNNA_128_3for CNN_64_7  0.481586
# 38                EDCR    Confident 0.5Rule CNNA_32_3for CNN_64_7  0.481586
# 39                EDCR          Confident 0.5Rule allfor CNN_64_7  0.461756
# 40                EDCR       Confident 0.5Rule allfor dumb_spikes  0.053824
# 41                EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.461756
# 42                EDCR    Confident 0.6Rule CNNA_64_7for CNN_64_7  0.855524
# 43                EDCR    Confident 0.6Rule CNN_128_7for CNN_64_7  0.541076
# 44                EDCR    Confident 0.6Rule CNNA_32_7for CNN_64_7  0.507082
# 45                EDCR   Confident 0.6Rule CNNA_128_3for CNN_64_7  0.487252
# 46                EDCR    Confident 0.6Rule CNNA_32_3for CNN_64_7  0.484419
# 47                EDCR          Confident 0.6Rule allfor CNN_64_7  0.464589
# 48                EDCR       Confident 0.6Rule allfor dumb_spikes  0.053824
# 49                EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.464589
# 50                EDCR    Confident 0.7Rule CNNA_64_7for CNN_64_7  0.898017
# 51                EDCR    Confident 0.7Rule CNN_128_7for CNN_64_7  0.597734
# 52                EDCR    Confident 0.7Rule CNNA_32_7for CNN_64_7  0.549575
# 53                EDCR   Confident 0.7Rule CNNA_128_3for CNN_64_7  0.490085
# 54                EDCR    Confident 0.7Rule CNNA_32_3for CNN_64_7  0.490085
# 55                EDCR          Confident 0.7Rule allfor CNN_64_7  0.470255
# 56                EDCR       Confident 0.7Rule allfor dumb_spikes  0.053824
# 57                EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.470255
# 58                EDCR    Confident 0.8Rule CNNA_64_7for CNN_64_7  0.929178
# 59                EDCR    Confident 0.8Rule CNN_128_7for CNN_64_7  0.645892
# 60                EDCR    Confident 0.8Rule CNNA_32_7for CNN_64_7  0.643059
# 61                EDCR   Confident 0.8Rule CNNA_128_3for CNN_64_7  0.501416
# 62                EDCR    Confident 0.8Rule CNNA_32_3for CNN_64_7  0.495751
# 63                EDCR          Confident 0.8Rule allfor CNN_64_7  0.475921
# 64                EDCR       Confident 0.8Rule allfor dumb_spikes  0.053824
# 65                EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.475921
# 66                EDCR    Confident 0.9Rule CNNA_64_7for CNN_64_7  0.937677
# 67                EDCR    Confident 0.9Rule CNN_128_7for CNN_64_7  0.745042
# 68                EDCR    Confident 0.9Rule CNNA_32_7for CNN_64_7  0.742210
# 69                EDCR   Confident 0.9Rule CNNA_128_3for CNN_64_7  0.600567
# 70                EDCR    Confident 0.9Rule CNNA_32_3for CNN_64_7  0.532578
# 71                EDCR          Confident 0.9Rule allfor CNN_64_7  0.512748
# 72                EDCR       Confident 0.9Rule allfor dumb_spikes  0.053824
# 73                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.512748
# 74                EDCR   Confident 0.95Rule CNNA_64_7for CNN_64_7  0.946176
# 75                EDCR   Confident 0.95Rule CNN_128_7for CNN_64_7  0.793201
# 76                EDCR   Confident 0.95Rule CNNA_32_7for CNN_64_7  0.798867
# 77                EDCR  Confident 0.95Rule CNNA_128_3for CNN_64_7  0.671388
# 78                EDCR   Confident 0.95Rule CNNA_32_3for CNN_64_7  0.597734
# 79                EDCR         Confident 0.95Rule allfor CNN_64_7  0.580737
# 80                EDCR      Confident 0.95Rule allfor dumb_spikes  0.053824
# 81                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.580737
#
#     Precision (0)  Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  \
# 0        0.895349    0.230539  0.366667       0.037453    0.526316  0.069930
# 1        0.935252    0.778443  0.849673       0.013333    0.052632  0.021277
# 2        0.918919    0.305389  0.458427       0.041322    0.526316  0.076628
# 3        0.932584    0.497006  0.648438       0.040000    0.368421  0.072165
# 4        0.936782    0.488024  0.641732       0.044693    0.421053  0.080808
# 5        0.924138    0.401198  0.559499       0.038462    0.421053  0.070485
# 6        0.936416    0.485030  0.639053       0.044444    0.421053  0.080402
# 7        0.951724    0.826347  0.884615       0.079365    0.263158  0.121951
# 8        0.925170    0.407186  0.565489       0.038835    0.421053  0.071111
# 9        0.940199    0.847305  0.891339       0.019231    0.052632  0.028169
# 10       0.934132    0.467066  0.622754       0.043011    0.421053  0.078049
# 11       0.934524    0.470060  0.625498       0.043243    0.421053  0.078431
# 12       0.936416    0.485030  0.639053       0.044444    0.421053  0.080402
# 13       0.937086    0.847305  0.889937       0.000000    0.000000  0.000000
# 14       0.920863    0.383234  0.541226       0.037383    0.421053  0.068670
# 15       0.920863    0.383234  0.541226       0.037383    0.421053  0.068670
# 16       0.931250    0.446108  0.603239       0.041451    0.421053  0.075472
# 17       0.928105    0.425150  0.583162       0.040000    0.421053  0.073059
# 18       0.931677    0.449102  0.606061       0.041667    0.421053  0.075829
# 19       0.930818    0.443114  0.600406       0.041237    0.421053  0.075117
# 20       0.932927    0.458084  0.614458       0.042328    0.421053  0.076923
# 21       0.928571    0.428144  0.586066       0.040201    0.421053  0.073394
# 22       0.933333    0.461078  0.617234       0.042553    0.421053  0.077295
# 23       0.946176    1.000000  0.972344       0.000000    0.000000  0.000000
# 24       0.932099    0.452096  0.608871       0.041885    0.421053  0.076190
# 25       0.930380    0.440120  0.597561       0.041026    0.421053  0.074766
# 26       0.940860    0.523952  0.673077       0.047904    0.421053  0.086022
# 27       0.932515    0.455090  0.611670       0.042105    0.421053  0.076555
# 28       0.932515    0.455090  0.611670       0.042105    0.421053  0.076555
# 29       0.941818    0.775449  0.850575       0.038462    0.157895  0.061856
# 30       0.917293    0.365269  0.522484       0.036364    0.421053  0.066946
# 31       0.932927    0.458084  0.614458       0.042328    0.421053  0.076923
# 32       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 33       0.946176    1.000000  0.972344       0.000000    0.000000  0.000000
# 34       0.951724    0.826347  0.884615       0.079365    0.263158  0.121951
# 35       0.940860    0.523952  0.673077       0.047904    0.421053  0.086022
# 36       0.936782    0.488024  0.641732       0.044693    0.421053  0.080808
# 37       0.936416    0.485030  0.639053       0.044444    0.421053  0.080402
# 38       0.936416    0.485030  0.639053       0.044444    0.421053  0.080402
# 39       0.933735    0.464072  0.620000       0.042781    0.421053  0.077670
# 40       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 41       0.933735    0.464072  0.620000       0.042781    0.421053  0.077670
# 42       0.946372    0.898204  0.921659       0.055556    0.105263  0.072727
# 43       0.943299    0.547904  0.693182       0.050314    0.421053  0.089888
# 44       0.939560    0.511976  0.662791       0.046784    0.421053  0.084211
# 45       0.937143    0.491018  0.644401       0.044944    0.421053  0.081218
# 46       0.936782    0.488024  0.641732       0.044693    0.421053  0.080808
# 47       0.934132    0.467066  0.622754       0.043011    0.421053  0.078049
# 48       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 49       0.934132    0.467066  0.622754       0.043011    0.421053  0.078049
# 50       0.946108    0.946108  0.946108       0.052632    0.052632  0.052632
# 51       0.944444    0.610778  0.741818       0.051095    0.368421  0.089744
# 52       0.939698    0.559880  0.701689       0.045455    0.368421  0.080925
# 53       0.937500    0.494012  0.647059       0.045198    0.421053  0.081633
# 54       0.937500    0.494012  0.647059       0.045198    0.421053  0.081633
# 55       0.934911    0.473054  0.628231       0.043478    0.421053  0.078818
# 56       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 57       0.934911    0.473054  0.628231       0.043478    0.421053  0.078818
# 58       0.945245    0.982036  0.963289       0.000000    0.000000  0.000000
# 59       0.944681    0.664671  0.780316       0.050847    0.315789  0.087591
# 60       0.944444    0.661677  0.778169       0.050420    0.315789  0.086957
# 61       0.938889    0.505988  0.657588       0.046243    0.421053  0.083333
# 62       0.938202    0.500000  0.652344       0.045714    0.421053  0.082474
# 63       0.935673    0.479042  0.633663       0.043956    0.421053  0.079602
# 64       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 65       0.935673    0.479042  0.633663       0.043956    0.421053  0.079602
# 66       0.945714    0.991018  0.967836       0.000000    0.000000  0.000000
# 67       0.948529    0.772455  0.851485       0.061728    0.263158  0.100000
# 68       0.945055    0.772455  0.850082       0.050000    0.210526  0.080808
# 69       0.940639    0.616766  0.745027       0.044776    0.315789  0.078431
# 70       0.942408    0.538922  0.685714       0.049383    0.421053  0.088398
# 71       0.940217    0.517964  0.667954       0.047337    0.421053  0.085106
# 72       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 73       0.940217    0.517964  0.667954       0.047337    0.421053  0.085106
# 74       0.946176    1.000000  0.972344       0.000000    0.000000  0.000000
# 75       0.948454    0.826347  0.883200       0.064516    0.210526  0.098765
# 76       0.939799    0.841317  0.887836       0.018519    0.052632  0.027397
# 77       0.946721    0.691617  0.799308       0.055046    0.315789  0.093750
# 78       0.948598    0.607784  0.740876       0.057554    0.421053  0.101266
# 79       0.947115    0.589820  0.726937       0.055172    0.421053  0.097561
# 80       0.000000    0.000000  0.000000       0.053824    1.000000  0.102151
# 81       0.947115    0.589820  0.726937       0.055172    0.421053  0.097561
#
#     Prior
# 0    0.05
# 1    0.05
# 2    0.05
# 3    0.05
# 4    0.05
# 5    0.05
# 6    0.05
# 7    0.05
# 8    0.05
# 9    0.05
# 10   0.05
# 11   0.05
# 12   0.05
# 13   0.05
# 14   0.05
# 15   0.05
# 16   0.05
# 17   0.05
# 18   0.05
# 19   0.05
# 20   0.05
# 21   0.05
# 22   0.05
# 23   0.05
# 24   0.05
# 25   0.05
# 26   0.05
# 27   0.05
# 28   0.05
# 29   0.05
# 30   0.05
# 31   0.05
# 32   0.05
# 33   0.05
# 34   0.05
# 35   0.05
# 36   0.05
# 37   0.05
# 38   0.05
# 39   0.05
# 40   0.05
# 41   0.05
# 42   0.05
# 43   0.05
# 44   0.05
# 45   0.05
# 46   0.05
# 47   0.05
# 48   0.05
# 49   0.05
# 50   0.05
# 51   0.05
# 52   0.05
# 53   0.05
# 54   0.05
# 55   0.05
# 56   0.05
# 57   0.05
# 58   0.05
# 59   0.05
# 60   0.05
# 61   0.05
# 62   0.05
# 63   0.05
# 64   0.05
# 65   0.05
# 66   0.05
# 67   0.05
# 68   0.05
# 69   0.05
# 70   0.05
# 71   0.05
# 72   0.05
# 73   0.05
# 74   0.05
# 75   0.05
# 76   0.05
# 77   0.05
# 78   0.05
# 79   0.05
# 80   0.05
# 81   0.05
