# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from IPython.display import display

# %%
COMMODITY = 'magnesium'

EDCR_RESULTS_PATH = f'{COMMODITY}/test/predictions/test'
OG_RESULTS_PATH = f'{COMMODITY}/test/results_test.csv'

# %%
def extract_info_from_filename(filename):
    parts = filename.split("Rule")
    epsilon = parts[0].split()[-1]
    models_base = parts[1].split("for")
    models = models_base[0].strip()
    base = models_base[1].split("_predictions")[0].strip()
    return base, models, epsilon

# %%
def calculate_metrics(df):
    y_true = df['True']
    y_pred = df['Predicted']
    accuracy = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0, 1])
    prior = pd.read_csv(OG_RESULTS_PATH, nrows=1)['Prior'].iloc[0]
    return accuracy, precision, recall, f1, prior

# %%
def process_files(path):
    all_results = []  
    for filename in os.listdir(path):
        if filename.startswith('Confident') and filename.endswith("_predictions.csv"):
            base, models, epsilon = extract_info_from_filename(filename)
            df = pd.read_csv(os.path.join(path, filename))
            accuracy, precision, recall, f1, prior = calculate_metrics(df)
            row = {
                'Base': base,
                'Models': models,
                'Epsilon': epsilon,
                'Accuracy': accuracy,
                'Precision (0)': precision[0],
                'Recall (0)': recall[0],
                'F1 (0)': f1[0],
                'Precision (1)': precision[1],
                'Recall (1)': recall[1],
                'F1 (1)': f1[1],
                'Prior': prior  
            }
            all_results.append(row)
    
    # Convert the list of results to a DataFrame
    return pd.DataFrame(all_results)

# %%
results_df = process_files(EDCR_RESULTS_PATH)

# %%
results_df_one = results_df[results_df['Models'] != 'all']
# pd.set_option('display.max_rows', 200)
results_df_one
# Out:
#          Base     Models Epsilon  Accuracy  Precision (0)  Recall (0)  \
# 4   CNNA_32_7  CNNA_64_3     0.5  0.569405       0.946078    0.577844
# 5   CNNA_32_7   CNN_32_3     0.5  0.688385       0.948000    0.709581
# 6   CNNA_32_7   CNN_64_7     0.5  0.543909       0.943590    0.550898
# 7   CNNA_32_7   LSTM_128     0.5  0.504249       0.939227    0.508982
# 8   CNNA_32_7    LSTM_64     0.5  0.631728       0.947368    0.646707
# 13  CNNA_32_7  CNNA_64_3     0.6  0.657224       0.949367    0.673653
# 14  CNNA_32_7   CNN_32_3     0.6  0.762040       0.952899    0.787425
# 15  CNNA_32_7   CNN_64_7     0.6  0.572238       0.946341    0.580838
# 16  CNNA_32_7   LSTM_128     0.6  0.507082       0.939560    0.511976
# 17  CNNA_32_7    LSTM_64     0.6  0.634561       0.947598    0.649701
# 22  CNNA_32_7  CNNA_64_3     0.7  0.711048       0.946154    0.736527
# 23  CNNA_32_7   CNN_32_3     0.7  0.810198       0.946488    0.847305
# 24  CNNA_32_7   CNN_64_7     0.7  0.609065       0.945455    0.622754
# 25  CNNA_32_7   LSTM_128     0.7  0.507082       0.939560    0.511976
# 26  CNNA_32_7    LSTM_64     0.7  0.643059       0.948276    0.658683
# 31  CNNA_32_7  CNNA_64_3     0.8  0.776204       0.944251    0.811377
# 32  CNNA_32_7   CNN_32_3     0.8  0.847025       0.945860    0.889222
# 33  CNNA_32_7   CNN_64_7     0.8  0.657224       0.945607    0.676647
# 34  CNNA_32_7   LSTM_128     0.8  0.541076       0.938776    0.550898
# 35  CNNA_32_7    LSTM_64     0.8  0.654391       0.949153    0.670659
# 40  CNNA_32_7  CNNA_64_3    0.95  0.926346       0.945087    0.979042
# 41  CNNA_32_7   CNN_32_3    0.95  0.943343       0.946023    0.997006
# 42  CNNA_32_7   CNN_64_7    0.95  0.798867       0.945763    0.835329
# 43  CNNA_32_7   LSTM_128    0.95  0.722380       0.950382    0.745509
# 44  CNNA_32_7    LSTM_64    0.95  0.674221       0.950617    0.691617
# 49  CNNA_32_7  CNNA_64_3     0.9  0.895184       0.943284    0.946108
# 50  CNNA_32_7   CNN_32_3     0.9  0.923513       0.947522    0.973054
# 51  CNNA_32_7   CNN_64_7     0.9  0.722380       0.946970    0.748503
# 52  CNNA_32_7   LSTM_128     0.9  0.594901       0.940092    0.610778
# 53  CNNA_32_7    LSTM_64     0.9  0.665722       0.950000    0.682635
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 4   0.717472       0.053691    0.421053  0.095238   0.05
# 5   0.811644       0.058252    0.315789  0.098361   0.05
# 6   0.695652       0.050633    0.421053  0.090395   0.05
# 7   0.660194       0.046512    0.421053  0.083770   0.05
# 8   0.768683       0.056000    0.368421  0.097222   0.05
# 13  0.788091       0.060345    0.368421  0.103704   0.05
# 14  0.862295       0.077922    0.315789  0.125000   0.05
# 15  0.719852       0.054054    0.421053  0.095808   0.05
# 16  0.662791       0.046784    0.421053  0.084211   0.05
# 17  0.770870       0.056452    0.368421  0.097902   0.05
# 22  0.828283       0.053763    0.263158  0.089286   0.05
# 23  0.894155       0.055556    0.157895  0.082192   0.05
# 24  0.750903       0.052632    0.368421  0.092105   0.05
# 25  0.662791       0.046784    0.421053  0.084211   0.05
# 26  0.777385       0.057851    0.368421  0.100000   0.05
# 31  0.872786       0.045455    0.157895  0.070588   0.05
# 32  0.916667       0.051282    0.105263  0.068966   0.05
# 33  0.788831       0.052632    0.315789  0.090226   0.05
# 34  0.694340       0.044586    0.368421  0.079545   0.05
# 35  0.785965       0.059829    0.368421  0.102941   0.05
# 40  0.961765       0.000000    0.000000  0.000000   0.05
# 41  0.970845       0.000000    0.000000  0.000000   0.05
# 42  0.887122       0.051724    0.157895  0.077922   0.05
# 43  0.835570       0.065934    0.315789  0.109091   0.05
# 44  0.800693       0.063636    0.368421  0.108527   0.05
# 49  0.944694       0.000000    0.000000  0.000000   0.05
# 50  0.960118       0.100000    0.052632  0.068966   0.05
# 51  0.836120       0.056180    0.263158  0.092593   0.05
# 52  0.740472       0.044118    0.315789  0.077419   0.05
# 53  0.794425       0.061947    0.368421  0.106061   0.05

# %% [markdown]
# ### Base Model

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] != "dumb_spikes") & (results_df['Base'] != "dumb_non_spikes")]
results_df_all
# Out:
#                                   Base Models Epsilon  Accuracy  \
# 0                            CNNA_32_7    all     0.5  0.195467
# 1             CNN_32_filters_3_kernels    all     0.5  0.195467
# 2   CNN_Attention_32_filters_3_kernels    all     0.5  0.172805
# 9                            CNNA_32_7    all     0.6  0.201133
# 10            CNN_32_filters_3_kernels    all     0.6  0.201133
# 11  CNN_Attention_32_filters_3_kernels    all     0.6  0.175637
# 18                           CNNA_32_7    all     0.7  0.212465
# 19            CNN_32_filters_3_kernels    all     0.7  0.212465
# 20  CNN_Attention_32_filters_3_kernels    all     0.7  0.184136
# 27                           CNNA_32_7    all     0.8  0.254958
# 28            CNN_32_filters_3_kernels    all     0.8  0.243626
# 29  CNN_Attention_32_filters_3_kernels    all     0.8  0.195467
# 36                           CNNA_32_7    all    0.95  0.439093
# 37            CNN_32_filters_3_kernels    all    0.95  0.371105
# 38  CNN_Attention_32_filters_3_kernels    all    0.95  0.215297
# 45                           CNNA_32_7    all     0.9  0.305949
# 46            CNN_32_filters_3_kernels    all     0.9  0.286119
# 47  CNN_Attention_32_filters_3_kernels    all     0.9  0.206799
#
#     Precision (0)  Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  \
# 0        0.931034    0.161677  0.275510       0.050847    0.789474  0.095541
# 1        0.931034    0.161677  0.275510       0.050847    0.789474  0.095541
# 2        0.920000    0.137725  0.239583       0.049505    0.789474  0.093168
# 9        0.933333    0.167665  0.284264       0.051195    0.789474  0.096154
# 10       0.933333    0.167665  0.284264       0.051195    0.789474  0.096154
# 11       0.921569    0.140719  0.244156       0.049669    0.789474  0.093458
# 18       0.937500    0.179641  0.301508       0.051903    0.789474  0.097403
# 19       0.937500    0.179641  0.301508       0.051903    0.789474  0.097403
# 20       0.925926    0.149701  0.257732       0.050167    0.789474  0.094340
# 27       0.938272    0.227545  0.366265       0.051471    0.736842  0.096220
# 28       0.935065    0.215569  0.350365       0.050725    0.736842  0.094915
# 29       0.931034    0.161677  0.275510       0.050847    0.789474  0.095541
# 36       0.959459    0.425150  0.589212       0.063415    0.684211  0.116071
# 37       0.959016    0.350299  0.513158       0.060606    0.736842  0.112000
# 38       0.938462    0.182635  0.305764       0.052083    0.789474  0.097720
# 45       0.940594    0.284431  0.436782       0.051587    0.684211  0.095941
# 46       0.945652    0.260479  0.408451       0.053640    0.736842  0.100000
# 47       0.935484    0.173653  0.292929       0.051546    0.789474  0.096774
#
#     Prior
# 0    0.05
# 1    0.05
# 2    0.05
# 9    0.05
# 10   0.05
# 11   0.05
# 18   0.05
# 19   0.05
# 20   0.05
# 27   0.05
# 28   0.05
# 29   0.05
# 36   0.05
# 37   0.05
# 38   0.05
# 45   0.05
# 46   0.05
# 47   0.05

# %% [markdown]
# ### Dumb Model (Only Predicts Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_spikes")]
results_df_all
# Out:
# Empty DataFrame
# Columns: [Base, Models, Epsilon, Accuracy, Precision (0), Recall (0), F1 (0), Precision (1), Recall (1), F1 (1), Prior]
# Index: []

# %% [markdown]
# ### Dumb Model (Only Predicts Non-Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_non_spikes")]
results_df_all
# Out:
#                Base Models Epsilon  Accuracy  Precision (0)  Recall (0)  \
# 3   dumb_non_spikes    all     0.5  0.195467       0.931034    0.161677
# 12  dumb_non_spikes    all     0.6  0.201133       0.933333    0.167665
# 21  dumb_non_spikes    all     0.7  0.212465       0.937500    0.179641
# 30  dumb_non_spikes    all     0.8  0.254958       0.938272    0.227545
# 39  dumb_non_spikes    all    0.95  0.439093       0.959459    0.425150
# 48  dumb_non_spikes    all     0.9  0.305949       0.940594    0.284431
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 3   0.275510       0.050847    0.789474  0.095541   0.05
# 12  0.284264       0.051195    0.789474  0.096154   0.05
# 21  0.301508       0.051903    0.789474  0.097403   0.05
# 30  0.366265       0.051471    0.736842  0.096220   0.05
# 39  0.589212       0.063415    0.684211  0.116071   0.05
# 48  0.436782       0.051587    0.684211  0.095941   0.05

# %% [markdown]
# ### Display All

# %%
og_df = pd.read_csv(OG_RESULTS_PATH)
og_df = og_df.drop('Unnamed: 0', axis=1)
pd.set_option('display.max_rows', 200)
og_df
# Out:
#                   Name                                             Params  \
# 0                 LSTM                                         256 layers
# 1                 LSTM                                         128 layers
# 2                 LSTM                                          64 layers
# 3                 LSTM                                          32 layers
# 4   CNN with Attention                          32 filters, kernel size 7
# 5   CNN with Attention                          32 filters, kernel size 5
# 6   CNN with Attention                          32 filters, kernel size 3
# 7   CNN with Attention                          64 filters, kernel size 7
# 8   CNN with Attention                          64 filters, kernel size 5
# 9   CNN with Attention                          64 filters, kernel size 3
# 10  CNN with Attention                         128 filters, kernel size 7
# 11  CNN with Attention                         128 filters, kernel size 5
# 12  CNN with Attention                         128 filters, kernel size 3
# 13  CNN with Attention                         256 filters, kernel size 7
# 14  CNN with Attention                         256 filters, kernel size 5
# 15  CNN with Attention                         256 filters, kernel size 3
# 16                 RNN                                          256 units
# 17                 RNN                                          128 units
# 18                 RNN                                           64 units
# 19                 RNN                                           32 units
# 20                 CNN                          32 filters, kernel size 7
# 21                 CNN                          32 filters, kernel size 5
# 22                 CNN                          32 filters, kernel size 3
# 23                 CNN                          64 filters, kernel size 7
# 24                 CNN                          64 filters, kernel size 5
# 25                 CNN                          64 filters, kernel size 3
# 26                 CNN                         128 filters, kernel size 7
# 27                 CNN                         128 filters, kernel size 5
# 28                 CNN                         128 filters, kernel size 3
# 29                 CNN                         256 filters, kernel size 7
# 30                 CNN                         256 filters, kernel size 5
# 31                 CNN                         256 filters, kernel size 3
# 32          Dumb Model                                             spikes
# 33          Dumb Model                                         non_spikes
# 34                EDCR            Confident 0.5Rule CNN_32_3for CNNA_32_7
# 35                EDCR             Confident 0.5Rule LSTM_64for CNNA_32_7
# 36                EDCR           Confident 0.5Rule CNNA_64_3for CNNA_32_7
# 37                EDCR            Confident 0.5Rule CNN_64_7for CNNA_32_7
# 38                EDCR            Confident 0.5Rule LSTM_128for CNNA_32_7
# 39                EDCR                 Confident 0.5Rule allfor CNNA_32_7
# 40                EDCR           Confident 0.5Rule allfor dumb_non_spikes
# 41                EDCR  Confident 0.5Rule allfor CNN_32_filters_3_kern...
# 42                EDCR  Confident 0.5Rule allfor CNN_Attention_32_filt...
# 43                EDCR            Confident 0.6Rule CNN_32_3for CNNA_32_7
# 44                EDCR             Confident 0.6Rule LSTM_64for CNNA_32_7
# 45                EDCR           Confident 0.6Rule CNNA_64_3for CNNA_32_7
# 46                EDCR            Confident 0.6Rule CNN_64_7for CNNA_32_7
# 47                EDCR            Confident 0.6Rule LSTM_128for CNNA_32_7
# 48                EDCR                 Confident 0.6Rule allfor CNNA_32_7
# 49                EDCR           Confident 0.6Rule allfor dumb_non_spikes
# 50                EDCR  Confident 0.6Rule allfor CNN_32_filters_3_kern...
# 51                EDCR  Confident 0.6Rule allfor CNN_Attention_32_filt...
# 52                EDCR            Confident 0.7Rule CNN_32_3for CNNA_32_7
# 53                EDCR             Confident 0.7Rule LSTM_64for CNNA_32_7
# 54                EDCR           Confident 0.7Rule CNNA_64_3for CNNA_32_7
# 55                EDCR            Confident 0.7Rule CNN_64_7for CNNA_32_7
# 56                EDCR            Confident 0.7Rule LSTM_128for CNNA_32_7
# 57                EDCR                 Confident 0.7Rule allfor CNNA_32_7
# 58                EDCR           Confident 0.7Rule allfor dumb_non_spikes
# 59                EDCR  Confident 0.7Rule allfor CNN_32_filters_3_kern...
# 60                EDCR  Confident 0.7Rule allfor CNN_Attention_32_filt...
# 61                EDCR            Confident 0.8Rule CNN_32_3for CNNA_32_7
# 62                EDCR             Confident 0.8Rule LSTM_64for CNNA_32_7
# 63                EDCR           Confident 0.8Rule CNNA_64_3for CNNA_32_7
# 64                EDCR            Confident 0.8Rule CNN_64_7for CNNA_32_7
# 65                EDCR            Confident 0.8Rule LSTM_128for CNNA_32_7
# 66                EDCR                 Confident 0.8Rule allfor CNNA_32_7
# 67                EDCR           Confident 0.8Rule allfor dumb_non_spikes
# 68                EDCR  Confident 0.8Rule allfor CNN_32_filters_3_kern...
# 69                EDCR  Confident 0.8Rule allfor CNN_Attention_32_filt...
# 70                EDCR            Confident 0.9Rule CNN_32_3for CNNA_32_7
# 71                EDCR             Confident 0.9Rule LSTM_64for CNNA_32_7
# 72                EDCR           Confident 0.9Rule CNNA_64_3for CNNA_32_7
# 73                EDCR            Confident 0.9Rule CNN_64_7for CNNA_32_7
# 74                EDCR            Confident 0.9Rule LSTM_128for CNNA_32_7
# 75                EDCR                 Confident 0.9Rule allfor CNNA_32_7
# 76                EDCR           Confident 0.9Rule allfor dumb_non_spikes
# 77                EDCR  Confident 0.9Rule allfor CNN_32_filters_3_kern...
# 78                EDCR  Confident 0.9Rule allfor CNN_Attention_32_filt...
# 79                EDCR           Confident 0.95Rule CNN_32_3for CNNA_32_7
# 80                EDCR            Confident 0.95Rule LSTM_64for CNNA_32_7
# 81                EDCR          Confident 0.95Rule CNNA_64_3for CNNA_32_7
# 82                EDCR           Confident 0.95Rule CNN_64_7for CNNA_32_7
# 83                EDCR           Confident 0.95Rule LSTM_128for CNNA_32_7
# 84                EDCR                Confident 0.95Rule allfor CNNA_32_7
# 85                EDCR          Confident 0.95Rule allfor dumb_non_spikes
# 86                EDCR  Confident 0.95Rule allfor CNN_32_filters_3_ker...
# 87                EDCR  Confident 0.95Rule allfor CNN_Attention_32_fil...
#
#     Accuracy  Precision (0)  Recall (0)    F1 (0)  Precision (1)  Recall (1)  \
# 0   0.303116       0.915094    0.290419  0.440909       0.040486    0.526316
# 1   0.504249       0.939227    0.508982  0.660194       0.046512    0.421053
# 2   0.631728       0.947368    0.646707  0.768683       0.056000    0.368421
# 3   0.490085       0.937500    0.494012  0.647059       0.045198    0.421053
# 4   0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 5   0.444759       0.931250    0.446108  0.603239       0.041451    0.421053
# 6   0.441926       0.930818    0.443114  0.600406       0.041237    0.421053
# 7   0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 8   0.436261       0.929936    0.437126  0.594705       0.040816    0.421053
# 9   0.569405       0.946078    0.577844  0.717472       0.053691    0.421053
# 10  0.470255       0.934911    0.473054  0.628231       0.043478    0.421053
# 11  0.461756       0.933735    0.464072  0.620000       0.042781    0.421053
# 12  0.433428       0.929487    0.434132  0.591837       0.040609    0.421053
# 13  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 14  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 15  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 16  0.444759       0.931250    0.446108  0.603239       0.041451    0.421053
# 17  0.487252       0.937143    0.491018  0.644401       0.044944    0.421053
# 18  0.433428       0.929487    0.434132  0.591837       0.040609    0.421053
# 19  0.464589       0.934132    0.467066  0.622754       0.043011    0.421053
# 20  0.481586       0.936416    0.485030  0.639053       0.044444    0.421053
# 21  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 22  0.688385       0.948000    0.709581  0.811644       0.058252    0.315789
# 23  0.543909       0.943590    0.550898  0.695652       0.050633    0.421053
# 24  0.416431       0.926667    0.416168  0.574380       0.039409    0.421053
# 25  0.943343       0.946023    0.997006  0.970845       0.000000    0.000000
# 26  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 27  0.478754       0.936047    0.482036  0.636364       0.044199    0.421053
# 28  0.439093       0.930380    0.440120  0.597561       0.041026    0.421053
# 29  0.943343       0.946023    0.997006  0.970845       0.000000    0.000000
# 30  0.458924       0.933333    0.461078  0.617234       0.042553    0.421053
# 31  0.943343       0.946023    0.997006  0.970845       0.000000    0.000000
# 32  0.053824       0.000000    0.000000  0.000000       0.053824    1.000000
# 33  0.946176       0.946176    1.000000  0.972344       0.000000    0.000000
# 34  0.688385       0.948000    0.709581  0.811644       0.058252    0.315789
# 35  0.631728       0.947368    0.646707  0.768683       0.056000    0.368421
# 36  0.569405       0.946078    0.577844  0.717472       0.053691    0.421053
# 37  0.543909       0.943590    0.550898  0.695652       0.050633    0.421053
# 38  0.504249       0.939227    0.508982  0.660194       0.046512    0.421053
# 39  0.195467       0.931034    0.161677  0.275510       0.050847    0.789474
# 40  0.195467       0.931034    0.161677  0.275510       0.050847    0.789474
# 41  0.195467       0.931034    0.161677  0.275510       0.050847    0.789474
# 42  0.172805       0.920000    0.137725  0.239583       0.049505    0.789474
# 43  0.762040       0.952899    0.787425  0.862295       0.077922    0.315789
# 44  0.634561       0.947598    0.649701  0.770870       0.056452    0.368421
# 45  0.657224       0.949367    0.673653  0.788091       0.060345    0.368421
# 46  0.572238       0.946341    0.580838  0.719852       0.054054    0.421053
# 47  0.507082       0.939560    0.511976  0.662791       0.046784    0.421053
# 48  0.201133       0.933333    0.167665  0.284264       0.051195    0.789474
# 49  0.201133       0.933333    0.167665  0.284264       0.051195    0.789474
# 50  0.201133       0.933333    0.167665  0.284264       0.051195    0.789474
# 51  0.175637       0.921569    0.140719  0.244156       0.049669    0.789474
# 52  0.810198       0.946488    0.847305  0.894155       0.055556    0.157895
# 53  0.643059       0.948276    0.658683  0.777385       0.057851    0.368421
# 54  0.711048       0.946154    0.736527  0.828283       0.053763    0.263158
# 55  0.609065       0.945455    0.622754  0.750903       0.052632    0.368421
# 56  0.507082       0.939560    0.511976  0.662791       0.046784    0.421053
# 57  0.212465       0.937500    0.179641  0.301508       0.051903    0.789474
# 58  0.212465       0.937500    0.179641  0.301508       0.051903    0.789474
# 59  0.212465       0.937500    0.179641  0.301508       0.051903    0.789474
# 60  0.184136       0.925926    0.149701  0.257732       0.050167    0.789474
# 61  0.847025       0.945860    0.889222  0.916667       0.051282    0.105263
# 62  0.654391       0.949153    0.670659  0.785965       0.059829    0.368421
# 63  0.776204       0.944251    0.811377  0.872786       0.045455    0.157895
# 64  0.657224       0.945607    0.676647  0.788831       0.052632    0.315789
# 65  0.541076       0.938776    0.550898  0.694340       0.044586    0.368421
# 66  0.254958       0.938272    0.227545  0.366265       0.051471    0.736842
# 67  0.254958       0.938272    0.227545  0.366265       0.051471    0.736842
# 68  0.243626       0.935065    0.215569  0.350365       0.050725    0.736842
# 69  0.195467       0.931034    0.161677  0.275510       0.050847    0.789474
# 70  0.923513       0.947522    0.973054  0.960118       0.100000    0.052632
# 71  0.665722       0.950000    0.682635  0.794425       0.061947    0.368421
# 72  0.895184       0.943284    0.946108  0.944694       0.000000    0.000000
# 73  0.722380       0.946970    0.748503  0.836120       0.056180    0.263158
# 74  0.594901       0.940092    0.610778  0.740472       0.044118    0.315789
# 75  0.305949       0.940594    0.284431  0.436782       0.051587    0.684211
# 76  0.305949       0.940594    0.284431  0.436782       0.051587    0.684211
# 77  0.286119       0.945652    0.260479  0.408451       0.053640    0.736842
# 78  0.206799       0.935484    0.173653  0.292929       0.051546    0.789474
# 79  0.943343       0.946023    0.997006  0.970845       0.000000    0.000000
# 80  0.674221       0.950617    0.691617  0.800693       0.063636    0.368421
# 81  0.926346       0.945087    0.979042  0.961765       0.000000    0.000000
# 82  0.798867       0.945763    0.835329  0.887122       0.051724    0.157895
# 83  0.722380       0.950382    0.745509  0.835570       0.065934    0.315789
# 84  0.439093       0.959459    0.425150  0.589212       0.063415    0.684211
# 85  0.439093       0.959459    0.425150  0.589212       0.063415    0.684211
# 86  0.371105       0.959016    0.350299  0.513158       0.060606    0.736842
# 87  0.215297       0.938462    0.182635  0.305764       0.052083    0.789474
#
#       F1 (1)  Prior
# 0   0.075188   0.05
# 1   0.083770   0.05
# 2   0.097222   0.05
# 3   0.081633   0.05
# 4   0.000000   0.05
# 5   0.075472   0.05
# 6   0.075117   0.05
# 7   0.000000   0.05
# 8   0.074419   0.05
# 9   0.095238   0.05
# 10  0.078818   0.05
# 11  0.077670   0.05
# 12  0.074074   0.05
# 13  0.000000   0.05
# 14  0.000000   0.05
# 15  0.000000   0.05
# 16  0.075472   0.05
# 17  0.081218   0.05
# 18  0.074074   0.05
# 19  0.078049   0.05
# 20  0.080402   0.05
# 21  0.000000   0.05
# 22  0.098361   0.05
# 23  0.090395   0.05
# 24  0.072072   0.05
# 25  0.000000   0.05
# 26  0.000000   0.05
# 27  0.080000   0.05
# 28  0.074766   0.05
# 29  0.000000   0.05
# 30  0.077295   0.05
# 31  0.000000   0.05
# 32  0.102151   0.05
# 33  0.000000   0.05
# 34  0.098361   0.05
# 35  0.097222   0.05
# 36  0.095238   0.05
# 37  0.090395   0.05
# 38  0.083770   0.05
# 39  0.095541   0.05
# 40  0.095541   0.05
# 41  0.095541   0.05
# 42  0.093168   0.05
# 43  0.125000   0.05
# 44  0.097902   0.05
# 45  0.103704   0.05
# 46  0.095808   0.05
# 47  0.084211   0.05
# 48  0.096154   0.05
# 49  0.096154   0.05
# 50  0.096154   0.05
# 51  0.093458   0.05
# 52  0.082192   0.05
# 53  0.100000   0.05
# 54  0.089286   0.05
# 55  0.092105   0.05
# 56  0.084211   0.05
# 57  0.097403   0.05
# 58  0.097403   0.05
# 59  0.097403   0.05
# 60  0.094340   0.05
# 61  0.068966   0.05
# 62  0.102941   0.05
# 63  0.070588   0.05
# 64  0.090226   0.05
# 65  0.079545   0.05
# 66  0.096220   0.05
# 67  0.096220   0.05
# 68  0.094915   0.05
# 69  0.095541   0.05
# 70  0.068966   0.05
# 71  0.106061   0.05
# 72  0.000000   0.05
# 73  0.092593   0.05
# 74  0.077419   0.05
# 75  0.095941   0.05
# 76  0.095941   0.05
# 77  0.100000   0.05
# 78  0.096774   0.05
# 79  0.000000   0.05
# 80  0.108527   0.05
# 81  0.000000   0.05
# 82  0.077922   0.05
# 83  0.109091   0.05
# 84  0.116071   0.05
# 85  0.116071   0.05
# 86  0.112000   0.05
# 87  0.097720   0.05
