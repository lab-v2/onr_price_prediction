# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from IPython.display import display

# %%
COMMODITY = 'copper'
METRIC = 'F1'
ALGO = 'detection'

EDCR_RESULTS_PATH = f'{COMMODITY}/test/predictions/test_{METRIC}_{ALGO}'
OG_RESULTS_PATH = f'{COMMODITY}/test/results_test.csv'

# %%
def extract_info_from_filename(filename):
    parts = filename.split("Rule")
    epsilon = parts[0].split()[-1]
    models_base = parts[1].split("for")
    models = models_base[0].strip()
    base = models_base[1].split("_predictions")[0].strip()
    return base, models, epsilon

# %%
def calculate_metrics(df):
    y_true = df['True']
    y_pred = df['Predicted']
    accuracy = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0, 1])
    prior = pd.read_csv(OG_RESULTS_PATH, nrows=1)['Prior'].iloc[0]
    return accuracy, precision, recall, f1, prior

# %%
def process_files(path):
    all_results = []  
    for filename in os.listdir(path):
        if filename.startswith('Confident') and filename.endswith("_predictions.csv"):
            base, models, confidence = extract_info_from_filename(filename)
            df = pd.read_csv(os.path.join(path, filename))
            accuracy, precision, recall, f1, prior = calculate_metrics(df)
            row = {
                'Base': base,
                'Models': models,
                'Confidence': confidence,
                'Accuracy': accuracy,
                'Precision (0)': precision[0],
                'Recall (0)': recall[0],
                'F1 (0)': f1[0],
                'Precision (1)': precision[1],
                'Recall (1)': recall[1],
                'F1 (1)': f1[1],
                'Prior': prior  
            }
            all_results.append(row)
    
    # Convert the list of results to a DataFrame
    return pd.DataFrame(all_results)

# %%
results_df = process_files(EDCR_RESULTS_PATH)

# %%
results_df_one = results_df[results_df['Models'] != 'all']
# pd.set_option('display.max_rows', 200)
results_df_one
# Out:
#       Base     Models Confidence  Accuracy  Precision (0)  Recall (0)  \
# 3   RNN_64  CNN_128_3        0.5  0.806306       0.860000    0.919786
# 4   RNN_64  CNN_256_7        0.5  0.788288       0.860825    0.893048
# 5   RNN_64   LSTM_128        0.5  0.229730       0.766667    0.122995
# 6   RNN_64    LSTM_32        0.5  0.774775       0.866310    0.866310
# 7   RNN_64     RNN_32        0.5  0.774775       0.870270    0.860963
# 11  RNN_64  CNN_128_3        0.6  0.833333       0.864078    0.951872
# 12  RNN_64  CNN_256_7        0.6  0.819820       0.862069    0.935829
# 13  RNN_64   LSTM_128        0.6  0.851351       0.859813    0.983957
# 14  RNN_64    LSTM_32        0.6  0.810811       0.864322    0.919786
# 15  RNN_64     RNN_32        0.6  0.833333       0.857143    0.962567
# 19  RNN_64  CNN_128_3        0.7  0.846847       0.859155    0.978610
# 20  RNN_64  CNN_256_7        0.7  0.828829       0.863415    0.946524
# 21  RNN_64   LSTM_128        0.7  0.864865       0.861751    1.000000
# 22  RNN_64    LSTM_32        0.7  0.842342       0.861905    0.967914
# 23  RNN_64     RNN_32        0.7  0.860360       0.861111    0.994652
# 27  RNN_64  CNN_128_3        0.8  0.860360       0.861111    0.994652
# 28  RNN_64  CNN_256_7        0.8  0.851351       0.863208    0.978610
# 29  RNN_64   LSTM_128        0.8  0.864865       0.861751    1.000000
# 30  RNN_64    LSTM_32        0.8  0.851351       0.863208    0.978610
# 31  RNN_64     RNN_32        0.8  0.864865       0.861751    1.000000
# 35  RNN_64  CNN_128_3       0.95  0.864865       0.861751    1.000000
# 36  RNN_64  CNN_256_7       0.95  0.860360       0.861111    0.994652
# 37  RNN_64   LSTM_128       0.95  0.864865       0.861751    1.000000
# 38  RNN_64    LSTM_32       0.95  0.864865       0.861751    1.000000
# 39  RNN_64     RNN_32       0.95  0.864865       0.861751    1.000000
# 43  RNN_64  CNN_128_3        0.9  0.864865       0.861751    1.000000
# 44  RNN_64  CNN_256_7        0.9  0.860360       0.861111    0.994652
# 45  RNN_64   LSTM_128        0.9  0.864865       0.861751    1.000000
# 46  RNN_64    LSTM_32        0.9  0.860360       0.861111    0.994652
# 47  RNN_64     RNN_32        0.9  0.864865       0.861751    1.000000
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 3   0.888889       0.318182    0.200000  0.245614   0.16
# 4   0.876640       0.285714    0.228571  0.253968   0.16
# 5   0.211982       0.145833    0.800000  0.246696   0.16
# 6   0.866310       0.285714    0.285714  0.285714   0.16
# 7   0.865591       0.297297    0.314286  0.305556   0.16
# 11  0.905852       0.437500    0.200000  0.274510   0.16
# 12  0.897436       0.368421    0.200000  0.259259   0.16
# 13  0.917706       0.625000    0.142857  0.232558   0.16
# 14  0.891192       0.347826    0.228571  0.275862   0.16
# 15  0.906801       0.416667    0.142857  0.212766   0.16
# 19  0.915000       0.555556    0.142857  0.227273   0.16
# 20  0.903061       0.411765    0.200000  0.269231   0.16
# 21  0.925743       1.000000    0.142857  0.250000   0.16
# 22  0.911839       0.500000    0.171429  0.255319   0.16
# 23  0.923077       0.833333    0.142857  0.243902   0.16
# 27  0.923077       0.833333    0.142857  0.243902   0.16
# 28  0.917293       0.600000    0.171429  0.266667   0.16
# 29  0.925743       1.000000    0.142857  0.250000   0.16
# 30  0.917293       0.600000    0.171429  0.266667   0.16
# 31  0.925743       1.000000    0.142857  0.250000   0.16
# 35  0.925743       1.000000    0.142857  0.250000   0.16
# 36  0.923077       0.833333    0.142857  0.243902   0.16
# 37  0.925743       1.000000    0.142857  0.250000   0.16
# 38  0.925743       1.000000    0.142857  0.250000   0.16
# 39  0.925743       1.000000    0.142857  0.250000   0.16
# 43  0.925743       1.000000    0.142857  0.250000   0.16
# 44  0.923077       0.833333    0.142857  0.243902   0.16
# 45  0.925743       1.000000    0.142857  0.250000   0.16
# 46  0.923077       0.833333    0.142857  0.243902   0.16
# 47  0.925743       1.000000    0.142857  0.250000   0.16

# %%
df = pd.read_csv(OG_RESULTS_PATH)
df = df[(df['Name']=='RNN') & (df['Params'] == '64 units')]
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#    Name    Params  Accuracy  Precision (0)  Recall (0)    F1 (0)  \
# 18  RNN  64 units  0.828829       0.859903    0.951872  0.903553
#
#     Precision (1)  Recall (1)  F1 (1)  Prior
# 18            0.4    0.171429    0.24   0.16

# %% [markdown]
# ### Base Model

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] != "dumb_spikes") & (results_df['Base'] != "dumb_non_spikes")]
results_df_all
# Out:
#       Base Models Confidence  Accuracy  Precision (0)  Recall (0)    F1 (0)  \
# 2   RNN_64    all        0.5  0.225225       0.857143    0.096257  0.173077
# 10  RNN_64    all        0.6  0.792793       0.865285    0.893048  0.878947
# 18  RNN_64    all        0.7  0.828829       0.863415    0.946524  0.903061
# 26  RNN_64    all        0.8  0.846847       0.862559    0.973262  0.914573
# 34  RNN_64    all       0.95  0.860360       0.861111    0.994652  0.923077
# 42  RNN_64    all        0.9  0.860360       0.861111    0.994652  0.923077
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 2        0.159204    0.914286  0.271186   0.16
# 10       0.310345    0.257143  0.281250   0.16
# 18       0.411765    0.200000  0.269231   0.16
# 26       0.545455    0.171429  0.260870   0.16
# 34       0.833333    0.142857  0.243902   0.16
# 42       0.833333    0.142857  0.243902   0.16

# %% [markdown]
# ### Dumb Model (Only Predicts Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_spikes")]
results_df_all
# Out:
#            Base Models Confidence  Accuracy  Precision (0)  Recall (0)  \
# 1   dumb_spikes    all        0.5  0.234234       0.947368    0.096257
# 9   dumb_spikes    all        0.6  0.905405       0.994048    0.893048
# 17  dumb_spikes    all        0.7  0.950450       0.994382    0.946524
# 25  dumb_spikes    all        0.8  0.972973       0.994536    0.973262
# 33  dumb_spikes    all       0.95  0.990991       0.994652    0.994652
# 41  dumb_spikes    all        0.9  0.990991       0.994652    0.994652
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 1   0.174757       0.167488    0.971429  0.285714   0.16
# 9   0.940845       0.629630    0.971429  0.764045   0.16
# 17  0.969863       0.772727    0.971429  0.860759   0.16
# 25  0.983784       0.871795    0.971429  0.918919   0.16
# 33  0.994652       0.971429    0.971429  0.971429   0.16
# 41  0.994652       0.971429    0.971429  0.971429   0.16

# %% [markdown]
# ### Dumb Model (Only Predicts Non-Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_non_spikes")]
results_df_all
# Out:
#                Base Models Confidence  Accuracy  Precision (0)  Recall (0)  \
# 0   dumb_non_spikes    all        0.5  0.225225       0.857143    0.096257
# 8   dumb_non_spikes    all        0.6  0.792793       0.865285    0.893048
# 16  dumb_non_spikes    all        0.7  0.828829       0.863415    0.946524
# 24  dumb_non_spikes    all        0.8  0.846847       0.862559    0.973262
# 32  dumb_non_spikes    all       0.95  0.837838       0.841629    0.994652
# 40  dumb_non_spikes    all        0.9  0.846847       0.849315    0.994652
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 0   0.173077       0.159204    0.914286  0.271186   0.16
# 8   0.878947       0.310345    0.257143  0.281250   0.16
# 16  0.903061       0.411765    0.200000  0.269231   0.16
# 24  0.914573       0.545455    0.171429  0.260870   0.16
# 32  0.911765       0.000000    0.000000  0.000000   0.16
# 40  0.916256       0.666667    0.057143  0.105263   0.16

# %% [markdown]
# ### Display All

# %%
og_df = pd.read_csv(OG_RESULTS_PATH)
og_df = og_df.drop('Unnamed: 0', axis=1)
pd.set_option('display.max_rows', 400)
og_df
# Out:
#                    Name                                     Params  Accuracy  \
# 0                  LSTM                                 256 layers  0.216216
# 1                  LSTM                                 128 layers  0.229730
# 2                  LSTM                                  64 layers  0.617117
# 3                  LSTM                                  32 layers  0.774775
# 4    CNN with Attention                  32 filters, kernel size 7  0.680180
# 5    CNN with Attention                  32 filters, kernel size 5  0.540541
# 6    CNN with Attention                  32 filters, kernel size 3  0.423423
# 7    CNN with Attention                  64 filters, kernel size 7  0.806306
# 8    CNN with Attention                  64 filters, kernel size 5  0.666667
# 9    CNN with Attention                  64 filters, kernel size 3  0.734234
# 10   CNN with Attention                 128 filters, kernel size 7  0.612613
# 11   CNN with Attention                 128 filters, kernel size 5  0.328829
# 12   CNN with Attention                 128 filters, kernel size 3  0.639640
# 13   CNN with Attention                 256 filters, kernel size 7  0.630631
# 14   CNN with Attention                 256 filters, kernel size 5  0.689189
# 15   CNN with Attention                 256 filters, kernel size 3  0.459459
# 16                  RNN                                  256 units  0.400901
# 17                  RNN                                  128 units  0.364865
# 18                  RNN                                   64 units  0.828829
# 19                  RNN                                   32 units  0.770270
# 20                  CNN                  32 filters, kernel size 7  0.702703
# 21                  CNN                  32 filters, kernel size 5  0.743243
# 22                  CNN                  32 filters, kernel size 3  0.806306
# 23                  CNN                  64 filters, kernel size 7  0.761261
# 24                  CNN                  64 filters, kernel size 5  0.626126
# 25                  CNN                  64 filters, kernel size 3  0.783784
# 26                  CNN                 128 filters, kernel size 7  0.725225
# 27                  CNN                 128 filters, kernel size 5  0.675676
# 28                  CNN                 128 filters, kernel size 3  0.806306
# 29                  CNN                 256 filters, kernel size 7  0.788288
# 30                  CNN                 256 filters, kernel size 5  0.549550
# 31                  CNN                 256 filters, kernel size 3  0.788288
# 32           Dumb Model                                     spikes  0.157658
# 33           Dumb Model                                 non_spikes  0.842342
# 34                 EDCR        Confident 0.5Rule LSTM_32for RNN_64  0.774775
# 35                 EDCR        Confident 0.5Rule LSTM_32for RNN_64  0.774775
# 36                 EDCR         Confident 0.5Rule RNN_32for RNN_64  0.774775
# 37                 EDCR         Confident 0.5Rule RNN_32for RNN_64  0.774775
# 38                 EDCR      Confident 0.5Rule CNN_256_7for RNN_64  0.783784
# 39                 EDCR      Confident 0.5Rule CNN_256_7for RNN_64  0.788288
# 40                 EDCR       Confident 0.5Rule LSTM_128for RNN_64  0.229730
# 41                 EDCR       Confident 0.5Rule LSTM_128for RNN_64  0.229730
# 42                 EDCR      Confident 0.5Rule CNN_128_3for RNN_64  0.801802
# 43                 EDCR      Confident 0.5Rule CNN_128_3for RNN_64  0.806306
# 44                 EDCR            Confident 0.5Rule allfor RNN_64  0.225225
# 45                 EDCR            Confident 0.5Rule allfor RNN_64  0.225225
# 46                 EDCR       Confident 0.5Rule allfor dumb_spikes  0.157658
# 47                 EDCR       Confident 0.5Rule allfor dumb_spikes  0.234234
# 48                 EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.225225
# 49                 EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.225225
# 50                 EDCR        Confident 0.6Rule LSTM_32for RNN_64  0.810811
# 51                 EDCR        Confident 0.6Rule LSTM_32for RNN_64  0.810811
# 52                 EDCR         Confident 0.6Rule RNN_32for RNN_64  0.833333
# 53                 EDCR         Confident 0.6Rule RNN_32for RNN_64  0.833333
# 54                 EDCR      Confident 0.6Rule CNN_256_7for RNN_64  0.815315
# 55                 EDCR      Confident 0.6Rule CNN_256_7for RNN_64  0.819820
# 56                 EDCR       Confident 0.6Rule LSTM_128for RNN_64  0.824324
# 57                 EDCR       Confident 0.6Rule LSTM_128for RNN_64  0.851351
# 58                 EDCR      Confident 0.6Rule CNN_128_3for RNN_64  0.819820
# 59                 EDCR      Confident 0.6Rule CNN_128_3for RNN_64  0.833333
# 60                 EDCR            Confident 0.6Rule allfor RNN_64  0.792793
# 61                 EDCR            Confident 0.6Rule allfor RNN_64  0.792793
# 62                 EDCR       Confident 0.6Rule allfor dumb_spikes  0.157658
# 63                 EDCR       Confident 0.6Rule allfor dumb_spikes  0.905405
# 64                 EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.792793
# 65                 EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.792793
# 66                 EDCR        Confident 0.7Rule LSTM_32for RNN_64  0.833333
# 67                 EDCR        Confident 0.7Rule LSTM_32for RNN_64  0.842342
# 68                 EDCR         Confident 0.7Rule RNN_32for RNN_64  0.828829
# 69                 EDCR         Confident 0.7Rule RNN_32for RNN_64  0.860360
# 70                 EDCR      Confident 0.7Rule CNN_256_7for RNN_64  0.824324
# 71                 EDCR      Confident 0.7Rule CNN_256_7for RNN_64  0.828829
# 72                 EDCR       Confident 0.7Rule LSTM_128for RNN_64  0.828829
# 73                 EDCR       Confident 0.7Rule LSTM_128for RNN_64  0.864865
# 74                 EDCR      Confident 0.7Rule CNN_128_3for RNN_64  0.828829
# 75                 EDCR      Confident 0.7Rule CNN_128_3for RNN_64  0.846847
# 76                 EDCR            Confident 0.7Rule allfor RNN_64  0.824324
# 77                 EDCR            Confident 0.7Rule allfor RNN_64  0.828829
# 78                 EDCR       Confident 0.7Rule allfor dumb_spikes  0.157658
# 79                 EDCR       Confident 0.7Rule allfor dumb_spikes  0.950450
# 80                 EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.828829
# 81                 EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.828829
# 82                 EDCR        Confident 0.8Rule LSTM_32for RNN_64  0.833333
# 83                 EDCR        Confident 0.8Rule LSTM_32for RNN_64  0.851351
# 84                 EDCR         Confident 0.8Rule RNN_32for RNN_64  0.828829
# 85                 EDCR         Confident 0.8Rule RNN_32for RNN_64  0.864865
# 86                 EDCR      Confident 0.8Rule CNN_256_7for RNN_64  0.833333
# 87                 EDCR      Confident 0.8Rule CNN_256_7for RNN_64  0.851351
# 88                 EDCR       Confident 0.8Rule LSTM_128for RNN_64  0.828829
# 89                 EDCR       Confident 0.8Rule LSTM_128for RNN_64  0.864865
# 90                 EDCR      Confident 0.8Rule CNN_128_3for RNN_64  0.828829
# 91                 EDCR      Confident 0.8Rule CNN_128_3for RNN_64  0.860360
# 92                 EDCR            Confident 0.8Rule allfor RNN_64  0.833333
# 93                 EDCR            Confident 0.8Rule allfor RNN_64  0.846847
# 94                 EDCR       Confident 0.8Rule allfor dumb_spikes  0.157658
# 95                 EDCR       Confident 0.8Rule allfor dumb_spikes  0.972973
# 96                 EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.846847
# 97                 EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.846847
# 98                 EDCR        Confident 0.9Rule LSTM_32for RNN_64  0.828829
# 99                 EDCR        Confident 0.9Rule LSTM_32for RNN_64  0.860360
# 100                EDCR         Confident 0.9Rule RNN_32for RNN_64  0.828829
# 101                EDCR         Confident 0.9Rule RNN_32for RNN_64  0.864865
# 102                EDCR      Confident 0.9Rule CNN_256_7for RNN_64  0.828829
# 103                EDCR      Confident 0.9Rule CNN_256_7for RNN_64  0.860360
# 104                EDCR       Confident 0.9Rule LSTM_128for RNN_64  0.828829
# 105                EDCR       Confident 0.9Rule LSTM_128for RNN_64  0.864865
# 106                EDCR      Confident 0.9Rule CNN_128_3for RNN_64  0.828829
# 107                EDCR      Confident 0.9Rule CNN_128_3for RNN_64  0.864865
# 108                EDCR            Confident 0.9Rule allfor RNN_64  0.828829
# 109                EDCR            Confident 0.9Rule allfor RNN_64  0.860360
# 110                EDCR       Confident 0.9Rule allfor dumb_spikes  0.157658
# 111                EDCR       Confident 0.9Rule allfor dumb_spikes  0.990991
# 112                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.846847
# 113                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.846847
# 114                EDCR       Confident 0.95Rule LSTM_32for RNN_64  0.828829
# 115                EDCR       Confident 0.95Rule LSTM_32for RNN_64  0.864865
# 116                EDCR        Confident 0.95Rule RNN_32for RNN_64  0.828829
# 117                EDCR        Confident 0.95Rule RNN_32for RNN_64  0.864865
# 118                EDCR     Confident 0.95Rule CNN_256_7for RNN_64  0.828829
# 119                EDCR     Confident 0.95Rule CNN_256_7for RNN_64  0.860360
# 120                EDCR      Confident 0.95Rule LSTM_128for RNN_64  0.828829
# 121                EDCR      Confident 0.95Rule LSTM_128for RNN_64  0.864865
# 122                EDCR     Confident 0.95Rule CNN_128_3for RNN_64  0.828829
# 123                EDCR     Confident 0.95Rule CNN_128_3for RNN_64  0.864865
# 124                EDCR           Confident 0.95Rule allfor RNN_64  0.828829
# 125                EDCR           Confident 0.95Rule allfor RNN_64  0.860360
# 126                EDCR      Confident 0.95Rule allfor dumb_spikes  0.157658
# 127                EDCR      Confident 0.95Rule allfor dumb_spikes  0.990991
# 128                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.837838
# 129                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.837838
# 130                EDCR       Confident 0.5Rule LSTM_128for RNN_64  0.229730
# 131                EDCR       Confident 0.5Rule LSTM_128for RNN_64  0.229730
# 132                EDCR       Confident 0.5Rule LSTM_256for RNN_64  0.220721
# 133                EDCR       Confident 0.5Rule LSTM_256for RNN_64  0.220721
# 134                EDCR     Confident 0.5Rule CNNA_128_5for RNN_64  0.328829
# 135                EDCR     Confident 0.5Rule CNNA_128_5for RNN_64  0.328829
# 136                EDCR      Confident 0.5Rule CNNA_32_3for RNN_64  0.423423
# 137                EDCR      Confident 0.5Rule CNNA_32_3for RNN_64  0.423423
# 138                EDCR        Confident 0.5Rule RNN_128for RNN_64  0.360360
# 139                EDCR        Confident 0.5Rule RNN_128for RNN_64  0.364865
# 140                EDCR            Confident 0.5Rule allfor RNN_64  0.207207
# 141                EDCR            Confident 0.5Rule allfor RNN_64  0.207207
# 142                EDCR       Confident 0.5Rule allfor dumb_spikes  0.157658
# 143                EDCR       Confident 0.5Rule allfor dumb_spikes  0.234234
# 144                EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.207207
# 145                EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.207207
# 146                EDCR       Confident 0.6Rule LSTM_128for RNN_64  0.824324
# 147                EDCR       Confident 0.6Rule LSTM_128for RNN_64  0.851351
# 148                EDCR       Confident 0.6Rule LSTM_256for RNN_64  0.828829
# 149                EDCR       Confident 0.6Rule LSTM_256for RNN_64  0.864865
# 150                EDCR     Confident 0.6Rule CNNA_128_5for RNN_64  0.765766
# 151                EDCR     Confident 0.6Rule CNNA_128_5for RNN_64  0.765766
# 152                EDCR      Confident 0.6Rule CNNA_32_3for RNN_64  0.806306
# 153                EDCR      Confident 0.6Rule CNNA_32_3for RNN_64  0.810811
# 154                EDCR        Confident 0.6Rule RNN_128for RNN_64  0.828829
# 155                EDCR        Confident 0.6Rule RNN_128for RNN_64  0.860360
# 156                EDCR            Confident 0.6Rule allfor RNN_64  0.761261
# 157                EDCR            Confident 0.6Rule allfor RNN_64  0.761261
# 158                EDCR       Confident 0.6Rule allfor dumb_spikes  0.157658
# 159                EDCR       Confident 0.6Rule allfor dumb_spikes  0.882883
# 160                EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.761261
# 161                EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.761261
# 162                EDCR       Confident 0.7Rule LSTM_128for RNN_64  0.828829
# 163                EDCR       Confident 0.7Rule LSTM_128for RNN_64  0.864865
# 164                EDCR       Confident 0.7Rule LSTM_256for RNN_64  0.828829
# 165                EDCR       Confident 0.7Rule LSTM_256for RNN_64  0.864865
# 166                EDCR     Confident 0.7Rule CNNA_128_5for RNN_64  0.828829
# 167                EDCR     Confident 0.7Rule CNNA_128_5for RNN_64  0.860360
# 168                EDCR      Confident 0.7Rule CNNA_32_3for RNN_64  0.828829
# 169                EDCR      Confident 0.7Rule CNNA_32_3for RNN_64  0.855856
# 170                EDCR        Confident 0.7Rule RNN_128for RNN_64  0.828829
# 171                EDCR        Confident 0.7Rule RNN_128for RNN_64  0.864865
# 172                EDCR            Confident 0.7Rule allfor RNN_64  0.828829
# 173                EDCR            Confident 0.7Rule allfor RNN_64  0.855856
# 174                EDCR       Confident 0.7Rule allfor dumb_spikes  0.157658
# 175                EDCR       Confident 0.7Rule allfor dumb_spikes  0.986486
# 176                EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.837838
# 177                EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.837838
# 178                EDCR       Confident 0.8Rule LSTM_128for RNN_64  0.828829
# 179                EDCR       Confident 0.8Rule LSTM_128for RNN_64  0.864865
# 180                EDCR       Confident 0.8Rule LSTM_256for RNN_64  0.828829
# 181                EDCR       Confident 0.8Rule LSTM_256for RNN_64  0.864865
# 182                EDCR     Confident 0.8Rule CNNA_128_5for RNN_64  0.828829
# 183                EDCR     Confident 0.8Rule CNNA_128_5for RNN_64  0.864865
# 184                EDCR      Confident 0.8Rule CNNA_32_3for RNN_64  0.828829
# 185                EDCR      Confident 0.8Rule CNNA_32_3for RNN_64  0.864865
# 186                EDCR        Confident 0.8Rule RNN_128for RNN_64  0.828829
# 187                EDCR        Confident 0.8Rule RNN_128for RNN_64  0.864865
# 188                EDCR            Confident 0.8Rule allfor RNN_64  0.828829
# 189                EDCR            Confident 0.8Rule allfor RNN_64  0.864865
# 190                EDCR       Confident 0.8Rule allfor dumb_spikes  0.157658
# 191                EDCR       Confident 0.8Rule allfor dumb_spikes  0.995495
# 192                EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.842342
# 193                EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.842342
# 194                EDCR       Confident 0.9Rule LSTM_128for RNN_64  0.828829
# 195                EDCR       Confident 0.9Rule LSTM_128for RNN_64  0.864865
# 196                EDCR       Confident 0.9Rule LSTM_256for RNN_64  0.828829
# 197                EDCR       Confident 0.9Rule LSTM_256for RNN_64  0.864865
# 198                EDCR     Confident 0.9Rule CNNA_128_5for RNN_64  0.828829
# 199                EDCR     Confident 0.9Rule CNNA_128_5for RNN_64  0.864865
# 200                EDCR      Confident 0.9Rule CNNA_32_3for RNN_64  0.828829
# 201                EDCR      Confident 0.9Rule CNNA_32_3for RNN_64  0.864865
# 202                EDCR        Confident 0.9Rule RNN_128for RNN_64  0.828829
# 203                EDCR        Confident 0.9Rule RNN_128for RNN_64  0.864865
# 204                EDCR            Confident 0.9Rule allfor RNN_64  0.828829
# 205                EDCR            Confident 0.9Rule allfor RNN_64  0.864865
# 206                EDCR       Confident 0.9Rule allfor dumb_spikes  0.157658
# 207                EDCR       Confident 0.9Rule allfor dumb_spikes  0.995495
# 208                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.842342
# 209                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.842342
# 210                EDCR      Confident 0.95Rule LSTM_128for RNN_64  0.828829
# 211                EDCR      Confident 0.95Rule LSTM_128for RNN_64  0.864865
# 212                EDCR      Confident 0.95Rule LSTM_256for RNN_64  0.828829
# 213                EDCR      Confident 0.95Rule LSTM_256for RNN_64  0.864865
# 214                EDCR    Confident 0.95Rule CNNA_128_5for RNN_64  0.828829
# 215                EDCR    Confident 0.95Rule CNNA_128_5for RNN_64  0.864865
# 216                EDCR     Confident 0.95Rule CNNA_32_3for RNN_64  0.828829
# 217                EDCR     Confident 0.95Rule CNNA_32_3for RNN_64  0.864865
# 218                EDCR       Confident 0.95Rule RNN_128for RNN_64  0.828829
# 219                EDCR       Confident 0.95Rule RNN_128for RNN_64  0.864865
# 220                EDCR           Confident 0.95Rule allfor RNN_64  0.828829
# 221                EDCR           Confident 0.95Rule allfor RNN_64  0.864865
# 222                EDCR      Confident 0.95Rule allfor dumb_spikes  0.157658
# 223                EDCR      Confident 0.95Rule allfor dumb_spikes  0.995495
# 224                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.842342
# 225                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.842342
# 226                EDCR      Confident 0.5Rule CNNA_64_7for RNN_64  0.801802
# 227                EDCR      Confident 0.5Rule CNNA_64_7for RNN_64  0.806306
# 228                EDCR      Confident 0.5Rule CNN_128_3for RNN_64  0.801802
# 229                EDCR      Confident 0.5Rule CNN_128_3for RNN_64  0.806306
# 230                EDCR       Confident 0.5Rule CNN_32_3for RNN_64  0.797297
# 231                EDCR       Confident 0.5Rule CNN_32_3for RNN_64  0.806306
# 232                EDCR        Confident 0.5Rule LSTM_32for RNN_64  0.774775
# 233                EDCR        Confident 0.5Rule LSTM_32for RNN_64  0.774775
# 234                EDCR      Confident 0.5Rule CNN_256_7for RNN_64  0.783784
# 235                EDCR      Confident 0.5Rule CNN_256_7for RNN_64  0.788288
# 236                EDCR            Confident 0.5Rule allfor RNN_64  0.711712
# 237                EDCR            Confident 0.5Rule allfor RNN_64  0.711712
# 238                EDCR       Confident 0.5Rule allfor dumb_spikes  0.157658
# 239                EDCR       Confident 0.5Rule allfor dumb_spikes  0.815315
# 240                EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.711712
# 241                EDCR   Confident 0.5Rule allfor dumb_non_spikes  0.711712
# 242                EDCR      Confident 0.6Rule CNNA_64_7for RNN_64  0.810811
# 243                EDCR      Confident 0.6Rule CNNA_64_7for RNN_64  0.819820
# 244                EDCR      Confident 0.6Rule CNN_128_3for RNN_64  0.819820
# 245                EDCR      Confident 0.6Rule CNN_128_3for RNN_64  0.833333
# 246                EDCR       Confident 0.6Rule CNN_32_3for RNN_64  0.824324
# 247                EDCR       Confident 0.6Rule CNN_32_3for RNN_64  0.837838
# 248                EDCR        Confident 0.6Rule LSTM_32for RNN_64  0.810811
# 249                EDCR        Confident 0.6Rule LSTM_32for RNN_64  0.810811
# 250                EDCR      Confident 0.6Rule CNN_256_7for RNN_64  0.815315
# 251                EDCR      Confident 0.6Rule CNN_256_7for RNN_64  0.819820
# 252                EDCR            Confident 0.6Rule allfor RNN_64  0.783784
# 253                EDCR            Confident 0.6Rule allfor RNN_64  0.783784
# 254                EDCR       Confident 0.6Rule allfor dumb_spikes  0.157658
# 255                EDCR       Confident 0.6Rule allfor dumb_spikes  0.900901
# 256                EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.783784
# 257                EDCR   Confident 0.6Rule allfor dumb_non_spikes  0.783784
# 258                EDCR      Confident 0.7Rule CNNA_64_7for RNN_64  0.819820
# 259                EDCR      Confident 0.7Rule CNNA_64_7for RNN_64  0.833333
# 260                EDCR      Confident 0.7Rule CNN_128_3for RNN_64  0.828829
# 261                EDCR      Confident 0.7Rule CNN_128_3for RNN_64  0.846847
# 262                EDCR       Confident 0.7Rule CNN_32_3for RNN_64  0.828829
# 263                EDCR       Confident 0.7Rule CNN_32_3for RNN_64  0.860360
# 264                EDCR        Confident 0.7Rule LSTM_32for RNN_64  0.833333
# 265                EDCR        Confident 0.7Rule LSTM_32for RNN_64  0.842342
# 266                EDCR      Confident 0.7Rule CNN_256_7for RNN_64  0.824324
# 267                EDCR      Confident 0.7Rule CNN_256_7for RNN_64  0.828829
# 268                EDCR            Confident 0.7Rule allfor RNN_64  0.819820
# 269                EDCR            Confident 0.7Rule allfor RNN_64  0.824324
# 270                EDCR       Confident 0.7Rule allfor dumb_spikes  0.157658
# 271                EDCR       Confident 0.7Rule allfor dumb_spikes  0.945946
# 272                EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.824324
# 273                EDCR   Confident 0.7Rule allfor dumb_non_spikes  0.824324
# 274                EDCR      Confident 0.8Rule CNNA_64_7for RNN_64  0.824324
# 275                EDCR      Confident 0.8Rule CNNA_64_7for RNN_64  0.855856
# 276                EDCR      Confident 0.8Rule CNN_128_3for RNN_64  0.828829
# 277                EDCR      Confident 0.8Rule CNN_128_3for RNN_64  0.860360
# 278                EDCR       Confident 0.8Rule CNN_32_3for RNN_64  0.828829
# 279                EDCR       Confident 0.8Rule CNN_32_3for RNN_64  0.864865
# 280                EDCR        Confident 0.8Rule LSTM_32for RNN_64  0.833333
# 281                EDCR        Confident 0.8Rule LSTM_32for RNN_64  0.851351
# 282                EDCR      Confident 0.8Rule CNN_256_7for RNN_64  0.833333
# 283                EDCR      Confident 0.8Rule CNN_256_7for RNN_64  0.851351
# 284                EDCR            Confident 0.8Rule allfor RNN_64  0.828829
# 285                EDCR            Confident 0.8Rule allfor RNN_64  0.842342
# 286                EDCR       Confident 0.8Rule allfor dumb_spikes  0.157658
# 287                EDCR       Confident 0.8Rule allfor dumb_spikes  0.968468
# 288                EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.842342
# 289                EDCR   Confident 0.8Rule allfor dumb_non_spikes  0.842342
# 290                EDCR      Confident 0.9Rule CNNA_64_7for RNN_64  0.828829
# 291                EDCR      Confident 0.9Rule CNNA_64_7for RNN_64  0.864865
# 292                EDCR      Confident 0.9Rule CNN_128_3for RNN_64  0.828829
# 293                EDCR      Confident 0.9Rule CNN_128_3for RNN_64  0.864865
# 294                EDCR       Confident 0.9Rule CNN_32_3for RNN_64  0.828829
# 295                EDCR       Confident 0.9Rule CNN_32_3for RNN_64  0.864865
# 296                EDCR        Confident 0.9Rule LSTM_32for RNN_64  0.828829
# 297                EDCR        Confident 0.9Rule LSTM_32for RNN_64  0.860360
# 298                EDCR      Confident 0.9Rule CNN_256_7for RNN_64  0.828829
# 299                EDCR      Confident 0.9Rule CNN_256_7for RNN_64  0.860360
# 300                EDCR            Confident 0.9Rule allfor RNN_64  0.828829
# 301                EDCR            Confident 0.9Rule allfor RNN_64  0.860360
# 302                EDCR       Confident 0.9Rule allfor dumb_spikes  0.157658
# 303                EDCR       Confident 0.9Rule allfor dumb_spikes  0.990991
# 304                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.846847
# 305                EDCR   Confident 0.9Rule allfor dumb_non_spikes  0.846847
# 306                EDCR     Confident 0.95Rule CNNA_64_7for RNN_64  0.828829
# 307                EDCR     Confident 0.95Rule CNNA_64_7for RNN_64  0.864865
# 308                EDCR     Confident 0.95Rule CNN_128_3for RNN_64  0.828829
# 309                EDCR     Confident 0.95Rule CNN_128_3for RNN_64  0.864865
# 310                EDCR      Confident 0.95Rule CNN_32_3for RNN_64  0.828829
# 311                EDCR      Confident 0.95Rule CNN_32_3for RNN_64  0.864865
# 312                EDCR       Confident 0.95Rule LSTM_32for RNN_64  0.828829
# 313                EDCR       Confident 0.95Rule LSTM_32for RNN_64  0.864865
# 314                EDCR     Confident 0.95Rule CNN_256_7for RNN_64  0.828829
# 315                EDCR     Confident 0.95Rule CNN_256_7for RNN_64  0.860360
# 316                EDCR           Confident 0.95Rule allfor RNN_64  0.828829
# 317                EDCR           Confident 0.95Rule allfor RNN_64  0.860360
# 318                EDCR      Confident 0.95Rule allfor dumb_spikes  0.157658
# 319                EDCR      Confident 0.95Rule allfor dumb_spikes  0.990991
# 320                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.837838
# 321                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.837838
#
#      Precision (0)  Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  \
# 0         0.709677    0.117647  0.201835       0.136126    0.742857  0.230088
# 1         0.766667    0.122995  0.211982       0.145833    0.800000  0.246696
# 2         0.835526    0.679144  0.749263       0.142857    0.285714  0.190476
# 3         0.866310    0.866310  0.866310       0.285714    0.285714  0.285714
# 4         0.845238    0.759358  0.800000       0.166667    0.257143  0.202247
# 5         0.829457    0.572193  0.677215       0.139785    0.371429  0.203125
# 6         0.804124    0.417112  0.549296       0.128000    0.457143  0.200000
# 7         0.860000    0.919786  0.888889       0.318182    0.200000  0.245614
# 8         0.838323    0.748663  0.790960       0.145455    0.228571  0.177778
# 9         0.851648    0.828877  0.840108       0.200000    0.228571  0.213333
# 10        0.848276    0.657754  0.740964       0.168831    0.371429  0.232143
# 11        0.816667    0.262032  0.396761       0.148148    0.685714  0.243655
# 12        0.845161    0.700535  0.766082       0.164179    0.314286  0.215686
# 13        0.838710    0.695187  0.760234       0.149254    0.285714  0.196078
# 14        0.839080    0.780749  0.808864       0.145833    0.200000  0.168675
# 15        0.807339    0.470588  0.594595       0.123894    0.400000  0.189189
# 16        0.770000    0.411765  0.536585       0.098361    0.342857  0.152866
# 17        0.761364    0.358289  0.487273       0.104478    0.400000  0.165680
# 18        0.859903    0.951872  0.903553       0.400000    0.171429  0.240000
#