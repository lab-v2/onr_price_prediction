# %%
import os
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from IPython.display import display

# %%
COMMODITY = 'copper'
METRIC = 'Recall'
ALGO = 'direct'

EDCR_RESULTS_PATH = f'{COMMODITY}/test/predictions/test_{METRIC}_{ALGO}'
OG_RESULTS_PATH = f'{COMMODITY}/test/results_test.csv'

# %%
def extract_info_from_filename(filename):
    parts = filename.split("Rule")
    epsilon = parts[0].split()[-1]
    models_base = parts[1].split("for")
    models = models_base[0].strip()
    base = models_base[1].split("_predictions")[0].strip()
    return base, models, epsilon

# %%
def calculate_metrics(df):
    y_true = df['True']
    y_pred = df['Predicted']
    accuracy = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0, 1])
    prior = pd.read_csv(OG_RESULTS_PATH, nrows=1)['Prior'].iloc[0]
    return accuracy, precision, recall, f1, prior

# %%
def process_files(path):
    all_results = []  
    for filename in os.listdir(path):
        if filename.startswith('Confident') and filename.endswith("_predictions.csv"):
            base, models, epsilon = extract_info_from_filename(filename)
            df = pd.read_csv(os.path.join(path, filename))
            accuracy, precision, recall, f1, prior = calculate_metrics(df)
            row = {
                'Base': base,
                'Models': models,
                'Epsilon': epsilon,
                'Accuracy': accuracy,
                'Precision (0)': precision[0],
                'Recall (0)': recall[0],
                'F1 (0)': f1[0],
                'Precision (1)': precision[1],
                'Recall (1)': recall[1],
                'F1 (1)': f1[1],
                'Prior': prior  
            }
            all_results.append(row)
    
    # Convert the list of results to a DataFrame
    return pd.DataFrame(all_results)

# %%
results_df = process_files(EDCR_RESULTS_PATH)
# Out:
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results_df_one = results_df[results_df['Models'] != 'all']
# pd.set_option('display.max_rows', 200)
results_df_one
# Out:
#        Base     Models Epsilon  Accuracy  Precision (0)  Recall (0)    F1 (0)  \
# 3   RNN_256  CNNA_64_3     0.5  0.495495       0.831858    0.502674  0.626667
# 4   RNN_256  CNN_128_3     0.5  0.590090       0.852941    0.620321  0.718266
# 5   RNN_256  CNN_128_5     0.5  0.518018       0.838983    0.529412  0.649180
# 6   RNN_256  CNN_128_7     0.5  0.590090       0.852941    0.620321  0.718266
# 7   RNN_256     RNN_64     0.5  0.468468       0.834951    0.459893  0.593103
# 11  RNN_256  CNNA_64_3     0.6  0.824324       0.877551    0.919786  0.898172
# 12  RNN_256  CNN_128_3     0.6  0.752252       0.870787    0.828877  0.849315
# 13  RNN_256  CNN_128_5     0.6  0.707207       0.863095    0.775401  0.816901
# 14  RNN_256  CNN_128_7     0.6  0.774775       0.874317    0.855615  0.864865
# 15  RNN_256     RNN_64     0.6  0.765766       0.877095    0.839572  0.857923
# 19  RNN_256  CNNA_64_3     0.7  0.851351       0.881188    0.951872  0.915167
# 20  RNN_256  CNN_128_3     0.7  0.837838       0.879397    0.935829  0.906736
# 21  RNN_256  CNN_128_5     0.7  0.828829       0.878173    0.925134  0.901042
# 22  RNN_256  CNN_128_7     0.7  0.833333       0.878788    0.930481  0.903896
# 23  RNN_256     RNN_64     0.7  0.851351       0.881188    0.951872  0.915167
# 27  RNN_256  CNNA_64_3     0.8  0.851351       0.881188    0.951872  0.915167
# 28  RNN_256  CNN_128_3     0.8  0.851351       0.881188    0.951872  0.915167
# 29  RNN_256  CNN_128_5     0.8  0.851351       0.881188    0.951872  0.915167
# 30  RNN_256  CNN_128_7     0.8  0.851351       0.881188    0.951872  0.915167
# 31  RNN_256     RNN_64     0.8  0.851351       0.881188    0.951872  0.915167
# 35  RNN_256  CNNA_64_3    0.95  0.851351       0.881188    0.951872  0.915167
# 36  RNN_256  CNN_128_3    0.95  0.851351       0.881188    0.951872  0.915167
# 37  RNN_256  CNN_128_5    0.95  0.851351       0.881188    0.951872  0.915167
# 38  RNN_256  CNN_128_7    0.95  0.851351       0.881188    0.951872  0.915167
# 39  RNN_256     RNN_64    0.95  0.851351       0.881188    0.951872  0.915167
# 43  RNN_256  CNNA_64_3     0.9  0.851351       0.881188    0.951872  0.915167
# 44  RNN_256  CNN_128_3     0.9  0.851351       0.881188    0.951872  0.915167
# 45  RNN_256  CNN_128_5     0.9  0.851351       0.881188    0.951872  0.915167
# 46  RNN_256  CNN_128_7     0.9  0.851351       0.881188    0.951872  0.915167
# 47  RNN_256     RNN_64     0.9  0.851351       0.881188    0.951872  0.915167
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 3        0.146789    0.457143  0.222222   0.16
# 4        0.174419    0.428571  0.247934   0.16
# 5        0.153846    0.457143  0.230216   0.16
# 6        0.174419    0.428571  0.247934   0.16
# 7        0.151261    0.514286  0.233766   0.16
# 11       0.423077    0.314286  0.360656   0.16
# 12       0.272727    0.342857  0.303797   0.16
# 13       0.222222    0.342857  0.269663   0.16
# 14       0.307692    0.342857  0.324324   0.16
# 15       0.302326    0.371429  0.333333   0.16
# 19       0.550000    0.314286  0.400000   0.16
# 20       0.478261    0.314286  0.379310   0.16
# 21       0.440000    0.314286  0.366667   0.16
# 22       0.458333    0.314286  0.372881   0.16
# 23       0.550000    0.314286  0.400000   0.16
# 27       0.550000    0.314286  0.400000   0.16
# 28       0.550000    0.314286  0.400000   0.16
# 29       0.550000    0.314286  0.400000   0.16
# 30       0.550000    0.314286  0.400000   0.16
# 31       0.550000    0.314286  0.400000   0.16
# 35       0.550000    0.314286  0.400000   0.16
# 36       0.550000    0.314286  0.400000   0.16
# 37       0.550000    0.314286  0.400000   0.16
# 38       0.550000    0.314286  0.400000   0.16
# 39       0.550000    0.314286  0.400000   0.16
# 43       0.550000    0.314286  0.400000   0.16
# 44       0.550000    0.314286  0.400000   0.16
# 45       0.550000    0.314286  0.400000   0.16
# 46       0.550000    0.314286  0.400000   0.16
# 47       0.550000    0.314286  0.400000   0.16

# %% [markdown]
# ### Base Model

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] != "dumb_spikes") & (results_df['Base'] != "dumb_non_spikes")]
results_df_all
# Out:
#        Base Models Epsilon  Accuracy  Precision (0)  Recall (0)    F1 (0)  \
# 2   RNN_256    all     0.5  0.310811       0.757576    0.267380  0.395257
# 10  RNN_256    all     0.6  0.626126       0.851351    0.673797  0.752239
# 18  RNN_256    all     0.7  0.824324       0.877551    0.919786  0.898172
# 26  RNN_256    all     0.8  0.851351       0.881188    0.951872  0.915167
# 34  RNN_256    all    0.95  0.851351       0.881188    0.951872  0.915167
# 42  RNN_256    all     0.9  0.851351       0.881188    0.951872  0.915167
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 2        0.121795    0.542857  0.198953   0.16
# 10       0.175676    0.371429  0.238532   0.16
# 18       0.423077    0.314286  0.360656   0.16
# 26       0.550000    0.314286  0.400000   0.16
# 34       0.550000    0.314286  0.400000   0.16
# 42       0.550000    0.314286  0.400000   0.16

# %% [markdown]
# ### Dumb Model (Only Predicts Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_spikes")]
results_df_all
# Out:
#            Base Models Epsilon  Accuracy  Precision (0)  Recall (0)  F1 (0)  \
# 1   dumb_spikes    all     0.5  0.157658            0.0         0.0     0.0
# 9   dumb_spikes    all     0.6  0.157658            0.0         0.0     0.0
# 17  dumb_spikes    all     0.7  0.157658            0.0         0.0     0.0
# 25  dumb_spikes    all     0.8  0.157658            0.0         0.0     0.0
# 33  dumb_spikes    all    0.95  0.157658            0.0         0.0     0.0
# 41  dumb_spikes    all     0.9  0.157658            0.0         0.0     0.0
#
#     Precision (1)  Recall (1)    F1 (1)  Prior
# 1        0.157658         1.0  0.272374   0.16
# 9        0.157658         1.0  0.272374   0.16
# 17       0.157658         1.0  0.272374   0.16
# 25       0.157658         1.0  0.272374   0.16
# 33       0.157658         1.0  0.272374   0.16
# 41       0.157658         1.0  0.272374   0.16

# %% [markdown]
# ### Dumb Model (Only Predicts Non-Spikes)

# %%
results_df_all = results_df[(results_df['Models'] == 'all') & (results_df['Base'] == "dumb_non_spikes")]
results_df_all
# Out:
#                Base Models Epsilon  Accuracy  Precision (0)  Recall (0)  \
# 0   dumb_non_spikes    all     0.5  0.297297       0.724638    0.267380
# 8   dumb_non_spikes    all     0.6  0.612613       0.834437    0.673797
# 16  dumb_non_spikes    all     0.7  0.815315       0.861386    0.930481
# 24  dumb_non_spikes    all     0.8  0.846847       0.859155    0.978610
# 32  dumb_non_spikes    all    0.95  0.842342       0.842342    1.000000
# 40  dumb_non_spikes    all     0.9  0.842342       0.842342    1.000000
#
#       F1 (0)  Precision (1)  Recall (1)    F1 (1)  Prior
# 0   0.390625       0.104575    0.457143  0.170213   0.16
# 8   0.745562       0.140845    0.285714  0.188679   0.16
# 16  0.894602       0.350000    0.200000  0.254545   0.16
# 24  0.915000       0.555556    0.142857  0.227273   0.16
# 32  0.914425       0.000000    0.000000  0.000000   0.16
# 40  0.914425       0.000000    0.000000  0.000000   0.16

# %% [markdown]
# ### Display All

# %%
og_df = pd.read_csv(OG_RESULTS_PATH)
og_df = og_df.drop('Unnamed: 0', axis=1)
pd.set_option('display.max_rows', 200)
og_df
# Out:
#                    Name                                     Params  Accuracy  \
# 0                  LSTM                                 256 layers  0.549550
# 1                  LSTM                                 128 layers  0.540541
# 2                  LSTM                                  64 layers  0.797297
# 3                  LSTM                                  32 layers  0.626126
# 4    CNN with Attention                  32 filters, kernel size 7  0.680180
# ..                  ...                                        ...       ...
# 317                EDCR          Confident 0.95Rule allfor RNN_256  0.891892
# 318                EDCR      Confident 0.95Rule allfor dumb_spikes  0.157658
# 319                EDCR      Confident 0.95Rule allfor dumb_spikes  1.000000
# 320                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.842342
# 321                EDCR  Confident 0.95Rule allfor dumb_non_spikes  0.842342
#
#      Precision (0)  Recall (0)    F1 (0)  Precision (1)  Recall (1)    F1 (1)  \
# 0         0.817518    0.598930  0.691358       0.117647    0.285714  0.166667
# 1         0.801418    0.604278  0.689024       0.086420    0.200000  0.120690
# 2         0.855000    0.914439  0.883721       0.272727    0.171429  0.210526
# 3         0.837662    0.689840  0.756598       0.147059    0.285714  0.194175
# 4         0.833333    0.775401  0.803324       0.125000    0.171429  0.144578
# ..             ...         ...       ...            ...         ...       ...
# 317       0.886256    1.000000  0.939698       1.000000    0.314286  0.478261
# 318       0.000000    0.000000  0.000000       0.157658    1.000000  0.272374
# 319       1.000000    1.000000  1.000000       1.000000    1.000000  1.000000
# 320       0.842342    1.000000  0.914425       0.000000    0.000000  0.000000
# 321       0.842342    1.000000  0.914425       0.000000    0.000000  0.000000
#
#      Prior
# 0     0.16
# 1     0.16
# 2     0.16
# 3     0.16
# 4     0.16
# ..     ...
# 317   0.16
# 318   0.16
# 319   0.16
# 320   0.16
# 321   0.16
#
# [322 rows x 10 columns]
