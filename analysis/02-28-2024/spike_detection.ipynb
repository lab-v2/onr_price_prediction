# %%
import sys
import os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import models
import utils
import data_processing

from constants import (
    VALUE_COLUMN,
    UNIT_RATE_COLUMN,
    QUANTITY_COLUMN,
    GROSS_WEIGHT_COLUMN,
    SHIP_COUNT_COLUMN,
    PORT_COUNT_COLUMN,
    FILL_METHOD,
    TARGET_COLUMN
)
import pandas as pd
import constants
from datetime import datetime
from build_data import get_data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
# Out:
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
COMMODITY = "magnesium"
SPIKES_WINDOW_SIZE = 20

VOLZA_FILE_PATH = f"../../volza/{COMMODITY}/{COMMODITY}.csv"
PRICE_FILE_PATH = f"../../volza/{COMMODITY}/{COMMODITY}_prices.csv"

# %%
# Trying out different window sizes
SPIKE_WINDOW_SIZES = [10, 20, 30, 40]
results_dfs = []

for window_size in SPIKE_WINDOW_SIZES:
    SPIKES_WINDOW_SIZE = window_size
    aggregated_df = get_data(VOLZA_FILE_PATH, PRICE_FILE_PATH, SPIKES_WINDOW_SIZE)
    VOLZA_FEATURES = [VALUE_COLUMN, UNIT_RATE_COLUMN, QUANTITY_COLUMN, GROSS_WEIGHT_COLUMN]
    X, y = data_processing.prepare_features_and_target(aggregated_df, VOLZA_FEATURES, 'spikes')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    X_train, X_test = data_processing.scale_features(X_train, X_test)

    X_train, y_train = data_processing.create_sequences(X_train, y_train, SPIKES_WINDOW_SIZE)
    X_test, y_test = data_processing.create_sequences(X_test, y_test, SPIKES_WINDOW_SIZE)
    
    print(f'X train shape: {X_train.shape}')

    output_file_path = f'{COMMODITY}/volza/results_{window_size}.csv'
    pred_file_path = f'{COMMODITY}/volza/predictions/{window_size}'
    print(pred_file_path)
    results_df = models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path, pred_file_path)
    results_df['Window Size'] = window_size
    results_dfs.append(results_df)
# Out:
# Building data...
# Detecting spikes... 10
# X train shape: (766, 10, 4)
# magnesium/volza/predictions/10
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={"Value": "Brent Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={"Value": "WTI Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:76: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:82: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:85: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 846us/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/LSTM_50_layers_predictions.npy
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 994us/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 856us/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 937us/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 998us/step
# Predictions saved to CSV file: magnesium/volza/predictions/10/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/10/CNN_256_filters_3_kernels_predictions.npy
# Building data...
# Detecting spikes... 20
# X train shape: (756, 20, 4)
# magnesium/volza/predictions/20
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={"Value": "Brent Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={"Value": "WTI Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:76: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:82: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:85: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 828us/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/20/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/20/CNN_256_filters_3_kernels_predictions.npy
# Building data...
# Detecting spikes... 30
# X train shape: (746, 30, 4)
# magnesium/volza/predictions/30
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={"Value": "Brent Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={"Value": "WTI Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:76: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:82: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:85: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# 6/6 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/LSTM_250_layers_predictions.npy
# 6/6 [==============================] - 0s 6ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/LSTM_200_layers_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/LSTM_100_layers_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/LSTM_50_layers_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_Attention_256_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/RNN_200_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/RNN_150_units_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/RNN_100_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/RNN_50_units_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_32_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_32_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 999us/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_32_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 983us/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_64_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_64_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_64_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_128_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_128_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_128_filters_3_kernels_predictions.npy
# 6/6 [==============================] - 0s 968us/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_256_filters_7_kernels_predictions.npy
# 6/6 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_256_filters_5_kernels_predictions.npy
# 6/6 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/30/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/30/CNN_256_filters_3_kernels_predictions.npy
# Building data...
# Detecting spikes... 40
# X train shape: (736, 40, 4)
# magnesium/volza/predictions/40
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brent_df.rename(columns={"Value": "Brent Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wti_df.rename(columns={"Value": "WTI Oil Value"}, inplace=True)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:76: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   date_wise_volza = date_wise_volza.join(ais_popular_pd, how="left").fillna(
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aggregated_df = date_wise_volza.join(prices_pd, how="left").fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:82: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\analysis\build_data.py:85: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).fillna(method=FILL_METHOD)
# 5/5 [==============================] - 0s 7ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/LSTM_250_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/LSTM_250_layers_predictions.npy
# 5/5 [==============================] - 0s 8ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/LSTM_200_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/LSTM_200_layers_predictions.npy
# 5/5 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/LSTM_100_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/LSTM_100_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/LSTM_50_layers_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/LSTM_50_layers_predictions.npy
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\manim\LabV2\ONR-Price-Prediction\onr_price_prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_32_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_32_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_32_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_64_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_64_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_64_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_128_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_128_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_128_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_256_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_256_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 2ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_Attention_256_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/RNN_200_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/RNN_200_units_predictions.npy
# 5/5 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/RNN_150_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/RNN_150_units_predictions.npy
# 5/5 [==============================] - 0s 773us/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/RNN_100_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/RNN_100_units_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/RNN_50_units_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/RNN_50_units_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_32_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_32_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 4ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_32_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_32_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_32_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_32_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_64_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_64_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 5ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_64_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_64_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 620us/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_64_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_64_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_128_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_128_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_128_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_128_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 757us/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_128_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_128_filters_3_kernels_predictions.npy
# 5/5 [==============================] - 0s 1ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_256_filters_7_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_256_filters_7_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_256_filters_5_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_256_filters_5_kernels_predictions.npy
# 5/5 [==============================] - 0s 3ms/step
# Predictions saved to CSV file: magnesium/volza/predictions/40/CNN_256_filters_3_kernels_predictions.csv
# Predictions saved to NPY file: magnesium/volza/predictions/40/CNN_256_filters_3_kernels_predictions.npy

# %%
# #Volza Only Features
# aggregated_df = data.copy()
# VOLZA_FEATURES = [VALUE_COLUMN, UNIT_RATE_COLUMN, QUANTITY_COLUMN, GROSS_WEIGHT_COLUMN]
# X, y = data_processing.prepare_features_and_target(aggregated_df, VOLZA_FEATURES, 'spikes')
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test = data_processing.scale_features(X_train, X_test)

# X_train, y_train = data_processing.create_sequences(X_train, y_train, SPIKES_WINDOW_SIZE)
# X_test, y_test = data_processing.create_sequences(X_test, y_test, SPIKES_WINDOW_SIZE)

# output_file_path = f'{COMMODITY}_results_volza_only.csv'
# models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path)

# %%
# #Volza and AIS Features
# aggregated_df = data.copy()
# VOLZA_AIS_FEATURES = [VALUE_COLUMN, UNIT_RATE_COLUMN, QUANTITY_COLUMN, GROSS_WEIGHT_COLUMN,SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN ]
# aggregated_df[VOLZA_AIS_FEATURES] = aggregated_df[VOLZA_AIS_FEATURES].fillna(0)

# X, y = data_processing.prepare_features_and_target(aggregated_df, VOLZA_AIS_FEATURES, 'spikes')
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test = data_processing.scale_features(X_train, X_test)

# X_train, y_train = data_processing.create_sequences(X_train, y_train, SPIKES_WINDOW_SIZE)
# X_test, y_test = data_processing.create_sequences(X_test, y_test, SPIKES_WINDOW_SIZE)

# output_file_path = f'{COMMODITY}_results_volza_ais.csv'
# models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path)

# %%
# #AIS Features
# aggregated_df = data.copy()
# AIS_FEATURES = [SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN]
# # aggregated_df = aggregated_df.dropna(subset=[SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN])
# aggregated_df[AIS_FEATURES] = aggregated_df[AIS_FEATURES].fillna(method=FILL_METHOD)
# X, y = data_processing.prepare_features_and_target(aggregated_df, AIS_FEATURES, 'spikes')
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test = data_processing.scale_features(X_train, X_test)

# X_train, y_train = data_processing.create_sequences(X_train, y_train, SPIKES_WINDOW_SIZE)
# X_test, y_test = data_processing.create_sequences(X_test, y_test, SPIKES_WINDOW_SIZE)

# # print(y_test)
# output_file_path = f'{COMMODITY}_results_ais_only.csv'
# models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path)

# %%
# #AIS and Volza with Price ARIMA
# import pmdarima as pm

# aggregated_df = data.copy()

# columns_of_interest = ['Price', 'spikes']  # Add other columns as necessary

# aggregated_df = aggregated_df.dropna(subset=columns_of_interest)
# # Fit an Auto ARIMA model to the 'Price' series
# model = pm.auto_arima(aggregated_df['Price'], seasonal=True, m=12, suppress_warnings=True, stepwise=True, error_action='ignore')

# # Forecast the series using the model (in-sample prediction)
# forecast = model.predict_in_sample()

# # Calculate residuals (difference between actual and forecasted values)
# residuals = aggregated_df[TARGET_COLUMN] - forecast

# # Append residuals to DataFrame as a new feature (using residuals as a way to detect spike / anomaly)
# aggregated_df = aggregated_df.copy()
# aggregated_df['ARIMA_Residuals'] = residuals

# # Prepare features and target
# FEATURE_COLUMNS = [TARGET_COLUMN,VALUE_COLUMN, UNIT_RATE_COLUMN, QUANTITY_COLUMN, GROSS_WEIGHT_COLUMN,SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN, 'ARIMA_Residuals']  # Adjust as needed
# aggregated_df[FEATURE_COLUMNS] = aggregated_df[FEATURE_COLUMNS].fillna(0)
# X, y = data_processing.prepare_features_and_target(aggregated_df, FEATURE_COLUMNS, 'spikes')

# # Split data (using sklearn's train_test_split)
# X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# # Scale features
# X_train_scaled, X_test_scaled = data_processing.scale_features(X_train_raw, X_test_raw)

# # Create sequences
# X_train, y_train = data_processing.create_sequences(X_train_scaled, y_train, SPIKES_WINDOW_SIZE)
# X_test, y_test = data_processing.create_sequences(X_test_scaled, y_test, SPIKES_WINDOW_SIZE)

# # Evaluate all models & save in file
# output_file_path = f'{COMMODITY}_results_volza_ais_arima.csv'
# models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path)

# %%
# #Binarise the data
# def discretize(df, columns, bins):
#     est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='kmeans')
#     df[columns] = est.fit_transform(df[columns])
#     return df

# aggregated_df = data.copy()
# VOLZA_AIS_FEATURES = [VALUE_COLUMN, UNIT_RATE_COLUMN, QUANTITY_COLUMN, GROSS_WEIGHT_COLUMN,SHIP_COUNT_COLUMN, PORT_COUNT_COLUMN ]
# aggregated_df[VOLZA_AIS_FEATURES] = aggregated_df[VOLZA_AIS_FEATURES].fillna(0)
# binary_columns = discretize(aggregated_df, VOLZA_AIS_FEATURES, 2)

# X, y = data_processing.prepare_features_and_target(binary_columns, VOLZA_AIS_FEATURES, 'spikes')
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
# X_train, X_test = data_processing.scale_features(X_train, X_test)

# X_train, y_train = data_processing.create_sequences(X_train, y_train, SPIKES_WINDOW_SIZE)
# X_test, y_test = data_processing.create_sequences(X_test, y_test, SPIKES_WINDOW_SIZE)

# output_file_path = f'{COMMODITY}_results_volza_ais_binary_med.csv'
# models.evaluate_all(X_train, y_train, X_test, y_test, output_file_path)

# %% [markdown]
# # Try Spectral Residuals
