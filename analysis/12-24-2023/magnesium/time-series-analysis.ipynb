# %%
# %pip install statsmodels
# %pip install pandas
# %pip install matplotlib

# %%
VOLZA_FILE_PATH = '../../../volza/magnesium/magnesium.csv'

# The number of countries to analyze. 10 is the default, but you can change it to whatever you want
# We will only analyze the top 10 countries by the number of samples
NUMBER_OF_COUNTRIES_TO_ANALYZE = 5

# Column names just so we don't have to constantly type them
VALUE_COLUMN='Value'
COUNTRY_OF_ORIGIN_COLUMN='Country of Origin'
COUNTRY_OF_DESTINATION_COLUMN='Country of Destination'

TIME_METRIC = '7D'

# %%
import pandas
data = pandas.read_csv(VOLZA_FILE_PATH)
data['Date'] = pandas.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)
data.set_index('Date', inplace=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Stationarity**

# %% [markdown]
# ### **ADF Test** (Stationarity)

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(df):
    result = adfuller(df.values)

    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value), end=' \t')
        print('\tIs stationary: %s' % ('No', 'Yes')[1 if result[0] < result[4][key] else 0])

# %% [markdown]
# ### **KPSS Test** (Trend Stationarity)

# %%
from statsmodels.tsa.stattools import kpss
def kpss_test(df):
  """Tests for stationarity, null hypothesis is that the series is stationary"""
  statistic, p_value, n_lags, critical_values = kpss(df.values)
  print(f'KPSS Statistic: {statistic}')
  print(f'p-value: {p_value}')
  print(f'num lags: {n_lags}')
  print('Critial Values:')
  for key, value in critical_values.items():
    print('\t%s: %.3f' % (key, value), end=' \t')
    print('\tIs stationary: %s' % ('No', 'Yes')[1 if p_value < float(key[:-1]) else 0])

# %% [markdown]
# # **Autocorrelation / Partial Autocorrelation**

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

def autocorrelation_plots(df, lag):
  fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
  plot_acf(df, lags=lag, ax=axes[0])
  plot_pacf(df, lags=lag, ax=axes[1], method='ywm')
  plt.show()

# %% [markdown]
# ### **Pearson and Spearman Correlation**

# %%
from scipy.stats import pearsonr, spearmanr

def spearman_correlation(original, target):
  print("Spearman Correlation")
  print(spearmanr(original, target))

def pearson_correlation(original, target):
  print("Pearson Correlation")
  print(pearsonr(original, target))

# %% [markdown]
# # **Granger Causality Test**

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# Granger causality test which accounts for unmatched lengths of the two series
def grangercausality_test(combined, maxlag):
  grangercausalitytests(combined, maxlag=maxlag, verbose=True)

# %%
def perform_analysis(dataframe, countries):
    for country in countries:
        print("=====================================")
        print(country)
        print("=====================================")

        # Get sum of Value each day
        data_for_country = dataframe.get_group(country)
        data_for_country = data_for_country[VALUE_COLUMN].resample(TIME_METRIC).sum()

        # Stationarity tests
        adf_test(data_for_country)
        kpss_test(data_for_country)

        # Autocorrelation plots
        autocorrelation_plots(data_for_country, lag=10)

        # Granger Causality Test
        for other_country in countries:
            if other_country != country:
                data_for_other_country = dataframe.get_group(other_country)[VALUE_COLUMN].resample(TIME_METRIC).sum()
                combined = pandas.DataFrame({'original': data_for_country, 'target': data_for_other_country}).fillna(0)
                grangercausality_test(combined, maxlag=3)
                print(f'Granger Causality Test: {country} | {other_country}')
                try:
                    spearman_correlation(combined['original'], combined['target'])
                    pearson_correlation(combined['original'], combined['target'])
                except: pass
                print()
                print()

        print()
        print()
        print()
        print()
        print()

print("===============================================================================================================")
print("Country of Origin")
print("===============================================================================================================")
COUNTRY_OF_ORIGINS_TO_ANALYZE = data.groupby(COUNTRY_OF_ORIGIN_COLUMN).size().sort_values(ascending=False).head(10).index.values.tolist()
data_grouped_by_country_of_origin = data.groupby(COUNTRY_OF_ORIGIN_COLUMN)
perform_analysis(data_grouped_by_country_of_origin, COUNTRY_OF_ORIGINS_TO_ANALYZE)

print("===============================================================================================================")
print("Country of Destination")
print("===============================================================================================================")
COUNTRY_OF_DESTINATIONS_TO_ANALYZE = data.groupby(COUNTRY_OF_DESTINATION_COLUMN).size().sort_values(ascending=False).head(NUMBER_OF_COUNTRIES_TO_ANALYZE).index.values.tolist()
data_grouped_by_country_of_destination = data.groupby(COUNTRY_OF_DESTINATION_COLUMN)
perform_analysis(data_grouped_by_country_of_destination, COUNTRY_OF_DESTINATIONS_TO_ANALYZE)
# Out:
# ===============================================================================================================
# Country of Origin
# ===============================================================================================================
# =====================================
# China
# =====================================
# ADF Statistics: -2.089025
# p-value: 0.248951
# Critical values:
# 	1%: -3.475 		Is stationary: No
# 	5%: -2.881 		Is stationary: No
# 	10%: -2.577 		Is stationary: No
# KPSS Statistic: 0.6834146937415495
# p-value: 0.015053209659859134
# num lags: 7
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.3451  , p=0.0388  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=4.4303  , p=0.0353  , df=1
# likelihood ratio test: chi2=4.3686  , p=0.0366  , df=1
# parameter F test:         F=4.3451  , p=0.0388  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6552  , p=0.0282  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=7.5541  , p=0.0229  , df=2
# likelihood ratio test: chi2=7.3758  , p=0.0250  , df=2
# parameter F test:         F=3.6552  , p=0.0282  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8394  , p=0.0111  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=12.0667 , p=0.0072  , df=3
# likelihood ratio test: chi2=11.6173 , p=0.0088  , df=3
# parameter F test:         F=3.8394  , p=0.0111  , df_denom=147, df_num=3
# Granger Causality Test: China | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=0.685570239261553, pvalue=3.9620469963115865e-23)
# Pearson Correlation
# (0.5444068942128468, 1.7083396400914524e-13)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.3414  , p=0.0222  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=5.4462  , p=0.0196  , df=1
# likelihood ratio test: chi2=5.3533  , p=0.0207  , df=1
# parameter F test:         F=5.3414  , p=0.0222  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.1759  , p=0.0446  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=6.5634  , p=0.0376  , df=2
# likelihood ratio test: chi2=6.4283  , p=0.0402  , df=2
# parameter F test:         F=3.1759  , p=0.0446  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.3386  , p=0.0005  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=19.9213 , p=0.0002  , df=3
# likelihood ratio test: chi2=18.7341 , p=0.0003  , df=3
# parameter F test:         F=6.3386  , p=0.0005  , df_denom=147, df_num=3
# Granger Causality Test: China | Germany
# Spearman Correlation
# SpearmanrResult(correlation=0.6666750546634574, pvalue=1.5648421285031763e-21)
# Pearson Correlation
# (0.4270574424009871, 2.4365718601303727e-08)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=35.6618 , p=0.0000  , df_denom=271, df_num=1
# ssr based chi2 test:   chi2=36.0566 , p=0.0000  , df=1
# likelihood ratio test: chi2=33.8737 , p=0.0000  , df=1
# parameter F test:         F=35.6618 , p=0.0000  , df_denom=271, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=17.9232 , p=0.0000  , df_denom=268, df_num=2
# ssr based chi2 test:   chi2=36.5153 , p=0.0000  , df=2
# likelihood ratio test: chi2=34.2712 , p=0.0000  , df=2
# parameter F test:         F=17.9232 , p=0.0000  , df_denom=268, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=13.9137 , p=0.0000  , df_denom=265, df_num=3
# ssr based chi2 test:   chi2=42.8436 , p=0.0000  , df=3
# likelihood ratio test: chi2=39.7865 , p=0.0000  , df=3
# parameter F test:         F=13.9137 , p=0.0000  , df_denom=265, df_num=3
# Granger Causality Test: China | Turkey
# Spearman Correlation
# SpearmanrResult(correlation=-0.7373813611449511, pvalue=1.9864591738016942e-48)
# Pearson Correlation
# (-0.16896511349918836, 0.004962869494231799)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.4377  , p=0.0360  , df_denom=303, df_num=1
# ssr based chi2 test:   chi2=4.4816  , p=0.0343  , df=1
# likelihood ratio test: chi2=4.4491  , p=0.0349  , df=1
# parameter F test:         F=4.4377  , p=0.0360  , df_denom=303, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9334  , p=0.1464  , df_denom=300, df_num=2
# ssr based chi2 test:   chi2=3.9313  , p=0.1401  , df=2
# likelihood ratio test: chi2=3.9062  , p=0.1418  , df=2
# parameter F test:         F=1.9334  , p=0.1464  , df_denom=300, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=58.6127 , p=0.0000  , df_denom=297, df_num=3
# ssr based chi2 test:   chi2=179.9824, p=0.0000  , df=3
# likelihood ratio test: chi2=141.3663, p=0.0000  , df=3
# parameter F test:         F=58.6127 , p=0.0000  , df_denom=297, df_num=3
# Granger Causality Test: China | South Korea
# Spearman Correlation
# SpearmanrResult(correlation=-0.21351522246396795, pvalue=0.00016364979498937254)
# Pearson Correlation
# (-0.056097077595247534, 0.3272528484965479)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7080  , p=0.1932  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=1.7415  , p=0.1870  , df=1
# likelihood ratio test: chi2=1.7318  , p=0.1882  , df=1
# parameter F test:         F=1.7080  , p=0.1932  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5718  , p=0.2111  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=3.2484  , p=0.1971  , df=2
# likelihood ratio test: chi2=3.2148  , p=0.2004  , df=2
# parameter F test:         F=1.5718  , p=0.2111  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2727  , p=0.2860  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=3.9999  , p=0.2615  , df=3
# likelihood ratio test: chi2=3.9489  , p=0.2670  , df=3
# parameter F test:         F=1.2727  , p=0.2860  , df_denom=147, df_num=3
# Granger Causality Test: China | Italy
# Spearman Correlation
# SpearmanrResult(correlation=0.6521231887657369, pvalue=2.2225145058952667e-20)
# Pearson Correlation
# (0.3794602343059814, 9.525320296348679e-07)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.8535  , p=0.0515  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=3.9290  , p=0.0475  , df=1
# likelihood ratio test: chi2=3.8804  , p=0.0489  , df=1
# parameter F test:         F=3.8535  , p=0.0515  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8848  , p=0.1554  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=3.8952  , p=0.1426  , df=2
# likelihood ratio test: chi2=3.8471  , p=0.1461  , df=2
# parameter F test:         F=1.8848  , p=0.1554  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5372  , p=0.2073  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=4.8313  , p=0.1846  , df=3
# likelihood ratio test: chi2=4.7570  , p=0.1905  , df=3
# parameter F test:         F=1.5372  , p=0.2073  , df_denom=147, df_num=3
# Granger Causality Test: China | Slovenia
# Spearman Correlation
# SpearmanrResult(correlation=0.672176962688107, pvalue=5.517315083115022e-22)
# Pearson Correlation
# (0.4459675486562735, 4.814194703484578e-09)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2269  , p=0.1377  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=2.2706  , p=0.1318  , df=1
# likelihood ratio test: chi2=2.2542  , p=0.1332  , df=1
# parameter F test:         F=2.2269  , p=0.1377  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.1210  , p=0.0002  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=18.8502 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.7891 , p=0.0001  , df=2
# parameter F test:         F=9.1210  , p=0.0002  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.3301  , p=0.0059  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=13.6088 , p=0.0035  , df=3
# likelihood ratio test: chi2=13.0408 , p=0.0045  , df=3
# parameter F test:         F=4.3301  , p=0.0059  , df_denom=147, df_num=3
# Granger Causality Test: China | Poland
# Spearman Correlation
# SpearmanrResult(correlation=0.6740088403117119, pvalue=3.879916215466661e-22)
# Pearson Correlation
# (0.38055016042734574, 8.813357021134232e-07)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8995  , p=0.1701  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=1.9368  , p=0.1640  , df=1
# likelihood ratio test: chi2=1.9249  , p=0.1653  , df=1
# parameter F test:         F=1.8995  , p=0.1701  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8029  , p=0.1684  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=3.7261  , p=0.1552  , df=2
# likelihood ratio test: chi2=3.6820  , p=0.1587  , df=2
# parameter F test:         F=1.8029  , p=0.1684  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4856  , p=0.0630  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=7.8119  , p=0.0501  , df=3
# likelihood ratio test: chi2=7.6203  , p=0.0545  , df=3
# parameter F test:         F=2.4856  , p=0.0630  , df_denom=147, df_num=3
# Granger Causality Test: China | France
# Spearman Correlation
# SpearmanrResult(correlation=0.6324337386783393, pvalue=6.445707392702412e-19)
# Pearson Correlation
# (0.5100345829949772, 8.917337686546949e-12)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6105  , p=0.2063  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=1.6421  , p=0.2000  , df=1
# likelihood ratio test: chi2=1.6335  , p=0.2012  , df=1
# parameter F test:         F=1.6105  , p=0.2063  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4069  , p=0.2481  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=2.9075  , p=0.2337  , df=2
# likelihood ratio test: chi2=2.8806  , p=0.2369  , df=2
# parameter F test:         F=1.4069  , p=0.2481  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9359  , p=0.4250  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=2.9415  , p=0.4007  , df=3
# likelihood ratio test: chi2=2.9138  , p=0.4051  , df=3
# parameter F test:         F=0.9359  , p=0.4250  , df_denom=147, df_num=3
# Granger Causality Test: China | Spain
# Spearman Correlation
# SpearmanrResult(correlation=0.706032966493718, pvalue=5.329385273040036e-25)
# Pearson Correlation
# (0.5097921905843448, 9.155371618726738e-12)
#
#
#
#
#
#
#
# =====================================
# Netherlands
# =====================================
# ADF Statistics: -1.592620
# p-value: 0.487300
# Critical values:
# 	1%: -3.478 		Is stationary: No
# 	5%: -2.882 		Is stationary: No
# 	10%: -2.578 		Is stationary: No
# KPSS Statistic: 0.3101298637677548
# p-value: 0.1
# num lags: 57
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.3410  , p=0.0222  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=5.4457  , p=0.0196  , df=1
# likelihood ratio test: chi2=5.3528  , p=0.0207  , df=1
# parameter F test:         F=5.3410  , p=0.0222  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8911  , p=0.0586  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=5.9749  , p=0.0504  , df=2
# likelihood ratio test: chi2=5.8626  , p=0.0533  , df=2
# parameter F test:         F=2.8911  , p=0.0586  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=9.5285  , p=0.0000  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=29.9466 , p=0.0000  , df=3
# likelihood ratio test: chi2=27.3647 , p=0.0000  , df=3
# parameter F test:         F=9.5285  , p=0.0000  , df_denom=147, df_num=3
# Granger Causality Test: Netherlands | China
# Spearman Correlation
# SpearmanrResult(correlation=0.6855702392615531, pvalue=3.9620469963114166e-23)
# Pearson Correlation
# (0.5444068942128468, 1.7083396400914524e-13)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4333  , p=0.2331  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=1.4619  , p=0.2266  , df=1
# likelihood ratio test: chi2=1.4550  , p=0.2277  , df=1
# parameter F test:         F=1.4333  , p=0.2331  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3724  , p=0.0968  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=4.9062  , p=0.0860  , df=2
# likelihood ratio test: chi2=4.8286  , p=0.0894  , df=2
# parameter F test:         F=2.3724  , p=0.0968  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.8765  , p=0.0029  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=15.3406 , p=0.0015  , df=3
# likelihood ratio test: chi2=14.6104 , p=0.0022  , df=3
# parameter F test:         F=4.8765  , p=0.0029  , df_denom=144, df_num=3
# Granger Causality Test: Netherlands | Germany
# Spearman Correlation
# SpearmanrResult(correlation=0.8346001336115761, pvalue=3.352935157634401e-41)
# Pearson Correlation
# (0.8230475730780162, 3.558689144506432e-39)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.0184 , p=0.0002  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=14.1759 , p=0.0002  , df=1
# likelihood ratio test: chi2=13.8163 , p=0.0002  , df=1
# parameter F test:         F=14.0184 , p=0.0002  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=15.3300 , p=0.0000  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=31.2408 , p=0.0000  , df=2
# likelihood ratio test: chi2=29.5559 , p=0.0000  , df=2
# parameter F test:         F=15.3300 , p=0.0000  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.9840  , p=0.0000  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=27.6748 , p=0.0000  , df=3
# likelihood ratio test: chi2=26.3372 , p=0.0000  , df=3
# parameter F test:         F=8.9840  , p=0.0000  , df_denom=261, df_num=3
# Granger Causality Test: Netherlands | Turkey
# Spearman Correlation
# SpearmanrResult(correlation=-0.30388934368752957, pvalue=3.384671690912689e-07)
# Pearson Correlation
# (-0.16395648759273335, 0.006832148696674925)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=12.6374 , p=0.0004  , df_denom=299, df_num=1
# ssr based chi2 test:   chi2=12.7642 , p=0.0004  , df=1
# likelihood ratio test: chi2=12.5019 , p=0.0004  , df=1
# parameter F test:         F=12.6374 , p=0.0004  , df_denom=299, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0878  , p=0.0001  , df_denom=296, df_num=2
# ssr based chi2 test:   chi2=18.4827 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.9374 , p=0.0001  , df=2
# parameter F test:         F=9.0878  , p=0.0001  , df_denom=296, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=11.5101 , p=0.0000  , df_denom=293, df_num=3
# ssr based chi2 test:   chi2=35.3552 , p=0.0000  , df=3
# likelihood ratio test: chi2=33.4223 , p=0.0000  , df=3
# parameter F test:         F=11.5101 , p=0.0000  , df_denom=293, df_num=3
# Granger Causality Test: Netherlands | South Korea
# Spearman Correlation
# SpearmanrResult(correlation=-0.08992467346483846, pvalue=0.1182866580957238)
# Pearson Correlation
# (-0.05427245342741922, 0.3464465188620973)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0910  , p=0.7633  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=0.0928  , p=0.7606  , df=1
# likelihood ratio test: chi2=0.0928  , p=0.7606  , df=1
# parameter F test:         F=0.0910  , p=0.7633  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1538  , p=0.8576  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=0.3181  , p=0.8529  , df=2
# likelihood ratio test: chi2=0.3178  , p=0.8531  , df=2
# parameter F test:         F=0.1538  , p=0.8576  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2845  , p=0.8365  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=0.8953  , p=0.8266  , df=3
# likelihood ratio test: chi2=0.8927  , p=0.8272  , df=3
# parameter F test:         F=0.2845  , p=0.8365  , df_denom=143, df_num=3
# Granger Causality Test: Netherlands | Italy
# Spearman Correlation
# SpearmanrResult(correlation=0.9201164893207974, pvalue=2.3665916433060963e-63)
# Pearson Correlation
# (0.6107169926215514, 5.202800712030684e-17)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4792  , p=0.4899  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=0.4888  , p=0.4844  , df=1
# likelihood ratio test: chi2=0.4881  , p=0.4848  , df=1
# parameter F test:         F=0.4792  , p=0.4899  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6884  , p=0.5040  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=1.4240  , p=0.4907  , df=2
# likelihood ratio test: chi2=1.4173  , p=0.4923  , df=2
# parameter F test:         F=0.6884  , p=0.5040  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2289  , p=0.3015  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=3.8670  , p=0.2762  , df=3
# likelihood ratio test: chi2=3.8180  , p=0.2818  , df=3
# parameter F test:         F=1.2289  , p=0.3015  , df_denom=143, df_num=3
# Granger Causality Test: Netherlands | Slovenia
# Spearman Correlation
# SpearmanrResult(correlation=0.9413219772465865, pvalue=4.0634497825130765e-73)
# Pearson Correlation
# (0.7814724051860809, 9.628845903090743e-33)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0123  , p=0.9118  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=0.0126  , p=0.9108  , df=1
# likelihood ratio test: chi2=0.0126  , p=0.9108  , df=1
# parameter F test:         F=0.0123  , p=0.9118  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0134  , p=0.9867  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=0.0277  , p=0.9863  , df=2
# likelihood ratio test: chi2=0.0277  , p=0.9863  , df=2
# parameter F test:         F=0.0134  , p=0.9867  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0281  , p=0.9936  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=0.0885  , p=0.9932  , df=3
# likelihood ratio test: chi2=0.0885  , p=0.9932  , df=3
# parameter F test:         F=0.0281  , p=0.9936  , df_denom=143, df_num=3
# Granger Causality Test: Netherlands | Poland
# Spearman Correlation
# SpearmanrResult(correlation=0.946582244737525, pvalue=4.1267103835738075e-76)
# Pearson Correlation
# (0.8055587927224948, 3.817759114584135e-36)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1387  , p=0.0785  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=3.2019  , p=0.0736  , df=1
# likelihood ratio test: chi2=3.1686  , p=0.0751  , df=1
# parameter F test:         F=3.1387  , p=0.0785  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4219  , p=0.2446  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=2.9411  , p=0.2298  , df=2
# likelihood ratio test: chi2=2.9129  , p=0.2331  , df=2
# parameter F test:         F=1.4219  , p=0.2446  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8220  , p=0.4838  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=2.5867  , p=0.4598  , df=3
# likelihood ratio test: chi2=2.5647  , p=0.4637  , df=3
# parameter F test:         F=0.8220  , p=0.4838  , df_denom=143, df_num=3
# Granger Causality Test: Netherlands | France
# Spearman Correlation
# SpearmanrResult(correlation=0.8712726643096457, pvalue=1.574618254273334e-48)
# Pearson Correlation
# (0.8776955330039253, 4.2475859234618873e-50)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3317  , p=0.5655  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.3382  , p=0.5608  , df=1
# likelihood ratio test: chi2=0.3379  , p=0.5611  , df=1
# parameter F test:         F=0.3317  , p=0.5655  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3006  , p=0.7408  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.6212  , p=0.7330  , df=2
# likelihood ratio test: chi2=0.6200  , p=0.7335  , df=2
# parameter F test:         F=0.3006  , p=0.7408  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4338  , p=0.7291  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=1.3633  , p=0.7142  , df=3
# likelihood ratio test: chi2=1.3573  , p=0.7156  , df=3
# parameter F test:         F=0.4338  , p=0.7291  , df_denom=147, df_num=3
# Granger Causality Test: Netherlands | Spain
# Spearman Correlation
# SpearmanrResult(correlation=0.8772293887089576, pvalue=2.9143894912163875e-51)
# Pearson Correlation
# (0.7951630830528014, 1.7029974433063643e-35)
#
#
#
#
#
#
#
# =====================================
# Germany
# =====================================
# ADF Statistics: -1.846325
# p-value: 0.357717
# Critical values:
# 	1%: -3.478 		Is stationary: No
# 	5%: -2.882 		Is stationary: No
# 	10%: -2.578 		Is stationary: No
# KPSS Statistic: 0.37854792971151396
# p-value: 0.08640175443469225
# num lags: 23
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0070  , p=0.9334  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.0072  , p=0.9326  , df=1
# likelihood ratio test: chi2=0.0072  , p=0.9326  , df=1
# parameter F test:         F=0.0070  , p=0.9334  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0708  , p=0.9317  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.1463  , p=0.9295  , df=2
# likelihood ratio test: chi2=0.1463  , p=0.9295  , df=2
# parameter F test:         F=0.0708  , p=0.9317  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2847  , p=0.2819  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=4.0377  , p=0.2574  , df=3
# likelihood ratio test: chi2=3.9857  , p=0.2630  , df=3
# parameter F test:         F=1.2847  , p=0.2819  , df_denom=147, df_num=3
# Granger Causality Test: Germany | China
# Spearman Correlation
# SpearmanrResult(correlation=0.6666750546634576, pvalue=1.5648421285031426e-21)
# Pearson Correlation
# (0.4270574424009871, 2.4365718601303727e-08)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1237  , p=0.7255  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=0.1262  , p=0.7224  , df=1
# likelihood ratio test: chi2=0.1261  , p=0.7225  , df=1
# parameter F test:         F=0.1237  , p=0.7255  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2208  , p=0.8021  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=0.4567  , p=0.7958  , df=2
# likelihood ratio test: chi2=0.4560  , p=0.7961  , df=2
# parameter F test:         F=0.2208  , p=0.8021  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5361  , p=0.6583  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=1.6865  , p=0.6399  , df=3
# likelihood ratio test: chi2=1.6772  , p=0.6420  , df=3
# parameter F test:         F=0.5361  , p=0.6583  , df_denom=144, df_num=3
# Granger Causality Test: Germany | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=0.834600133611576, pvalue=3.3529351576345923e-41)
# Pearson Correlation
# (0.8230475730780162, 3.558689144506432e-39)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0396  , p=0.0049  , df_denom=268, df_num=1
# ssr based chi2 test:   chi2=8.1296  , p=0.0044  , df=1
# likelihood ratio test: chi2=8.0100  , p=0.0047  , df=1
# parameter F test:         F=8.0396  , p=0.0049  , df_denom=268, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.4243 , p=0.0000  , df_denom=265, df_num=2
# ssr based chi2 test:   chi2=21.2420 , p=0.0000  , df=2
# likelihood ratio test: chi2=20.4478 , p=0.0000  , df=2
# parameter F test:         F=10.4243 , p=0.0000  , df_denom=265, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.1419  , p=0.0018  , df_denom=262, df_num=3
# ssr based chi2 test:   chi2=15.8378 , p=0.0012  , df=3
# likelihood ratio test: chi2=15.3891 , p=0.0015  , df=3
# parameter F test:         F=5.1419  , p=0.0018  , df_denom=262, df_num=3
# Granger Causality Test: Germany | Turkey
# Spearman Correlation
# SpearmanrResult(correlation=-0.351999907969891, pvalue=2.3613286239550634e-09)
# Pearson Correlation
# (-0.18062025846225194, 0.002791829584943864)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.3932  , p=0.0209  , df_denom=300, df_num=1
# ssr based chi2 test:   chi2=5.4471  , p=0.0196  , df=1
# likelihood ratio test: chi2=5.3988  , p=0.0202  , df=1
# parameter F test:         F=5.3932  , p=0.0209  , df_denom=300, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6419  , p=0.0274  , df_denom=297, df_num=2
# ssr based chi2 test:   chi2=7.4063  , p=0.0246  , df=2
# likelihood ratio test: chi2=7.3170  , p=0.0258  , df=2
# parameter F test:         F=3.6419  , p=0.0274  , df_denom=297, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.9901  , p=0.0022  , df_denom=294, df_num=3
# ssr based chi2 test:   chi2=15.3266 , p=0.0016  , df=3
# likelihood ratio test: chi2=14.9491 , p=0.0019  , df=3
# parameter F test:         F=4.9901  , p=0.0022  , df_denom=294, df_num=3
# Granger Causality Test: Germany | South Korea
# Spearman Correlation
# SpearmanrResult(correlation=-0.10400786024367976, pvalue=0.07015903464233372)
# Pearson Correlation
# (-0.05977331812007283, 0.298888877704682)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0127  , p=0.9105  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=0.0129  , p=0.9095  , df=1
# likelihood ratio test: chi2=0.0129  , p=0.9095  , df=1
# parameter F test:         F=0.0127  , p=0.9105  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0149  , p=0.9852  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=0.0308  , p=0.9847  , df=2
# likelihood ratio test: chi2=0.0308  , p=0.9847  , df=2
# parameter F test:         F=0.0149  , p=0.9852  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0309  , p=0.9927  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=0.0971  , p=0.9922  , df=3
# likelihood ratio test: chi2=0.0971  , p=0.9922  , df=3
# parameter F test:         F=0.0309  , p=0.9927  , df_denom=144, df_num=3
# Granger Causality Test: Germany | Italy
# Spearman Correlation
# SpearmanrResult(correlation=0.8420815296532873, pvalue=1.3433074951294871e-42)
# Pearson Correlation
# (0.6653892092105352, 4.830363460852011e-21)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1564  , p=0.6930  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=0.1596  , p=0.6896  , df=1
# likelihood ratio test: chi2=0.1595  , p=0.6896  , df=1
# parameter F test:         F=0.1564  , p=0.6930  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2781  , p=0.7576  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=0.5751  , p=0.7501  , df=2
# likelihood ratio test: chi2=0.5740  , p=0.7505  , df=2
# parameter F test:         F=0.2781  , p=0.7576  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6605  , p=0.5777  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=2.0777  , p=0.5564  , df=3
# likelihood ratio test: chi2=2.0636  , p=0.5593  , df=3
# parameter F test:         F=0.6605  , p=0.5777  , df_denom=144, df_num=3
# Granger Causality Test: Germany | Slovenia
# Spearman Correlation
# SpearmanrResult(correlation=0.8612540271552498, pvalue=1.5423221771464788e-46)
# Pearson Correlation
# (0.7712293272146953, 1.2721275595514776e-31)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0152  , p=0.9019  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=0.0155  , p=0.9008  , df=1
# likelihood ratio test: chi2=0.0155  , p=0.9008  , df=1
# parameter F test:         F=0.0152  , p=0.9019  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0339  , p=0.9667  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=0.0701  , p=0.9656  , df=2
# likelihood ratio test: chi2=0.0701  , p=0.9656  , df=2
# parameter F test:         F=0.0339  , p=0.9667  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0833  , p=0.9690  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=0.2621  , p=0.9670  , df=3
# likelihood ratio test: chi2=0.2619  , p=0.9670  , df=3
# parameter F test:         F=0.0833  , p=0.9690  , df_denom=144, df_num=3
# Granger Causality Test: Germany | Poland
# Spearman Correlation
# SpearmanrResult(correlation=0.8697604850477982, pvalue=1.762730510707701e-48)
# Pearson Correlation
# (0.6562695634288715, 2.489398727172371e-20)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1030  , p=0.7488  , df_denom=150, df_num=1
# ssr based chi2 test:   chi2=0.1050  , p=0.7459  , df=1
# likelihood ratio test: chi2=0.1050  , p=0.7459  , df=1
# parameter F test:         F=0.1030  , p=0.7488  , df_denom=150, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1021  , p=0.9030  , df_denom=147, df_num=2
# ssr based chi2 test:   chi2=0.2112  , p=0.8998  , df=2
# likelihood ratio test: chi2=0.2110  , p=0.8999  , df=2
# parameter F test:         F=0.1021  , p=0.9030  , df_denom=147, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2507  , p=0.8607  , df_denom=144, df_num=3
# ssr based chi2 test:   chi2=0.7888  , p=0.8522  , df=3
# likelihood ratio test: chi2=0.7867  , p=0.8526  , df=3
# parameter F test:         F=0.2507  , p=0.8607  , df_denom=144, df_num=3
# Granger Causality Test: Germany | France
# Spearman Correlation
# SpearmanrResult(correlation=0.7820717631287816, pvalue=4.982247530664384e-33)
# Pearson Correlation
# (0.7712617920450131, 1.2601825834756404e-31)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0011  , p=0.9731  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.0012  , p=0.9728  , df=1
# likelihood ratio test: chi2=0.0012  , p=0.9728  , df=1
# parameter F test:         F=0.0011  , p=0.9731  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0108  , p=0.9893  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.0223  , p=0.9889  , df=2
# likelihood ratio test: chi2=0.0223  , p=0.9889  , df=2
# parameter F test:         F=0.0108  , p=0.9893  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0448  , p=0.9874  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=0.1408  , p=0.9865  , df=3
# likelihood ratio test: chi2=0.1408  , p=0.9865  , df=3
# parameter F test:         F=0.0448  , p=0.9874  , df_denom=147, df_num=3
# Granger Causality Test: Germany | Spain
# Spearman Correlation
# SpearmanrResult(correlation=0.8008723471819897, pvalue=2.4188072465415562e-36)
# Pearson Correlation
# (0.5917153511344365, 3.3355962465282114e-16)
#
#
#
#
#
#
#
# =====================================
# Turkey
# =====================================
# ADF Statistics: -1.740499
# p-value: 0.410376
# Critical values:
# 	1%: -3.492 		Is stationary: No
# 	5%: -2.888 		Is stationary: No
# 	10%: -2.581 		Is stationary: No
# KPSS Statistic: 1.4895091577801152
# p-value: 0.01
# num lags: 5
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=36.0031 , p=0.0000  , df_denom=271, df_num=1
# ssr based chi2 test:   chi2=36.4016 , p=0.0000  , df=1
# likelihood ratio test: chi2=34.1785 , p=0.0000  , df=1
# parameter F test:         F=36.0031 , p=0.0000  , df_denom=271, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.1675  , p=0.0009  , df_denom=268, df_num=2
# ssr based chi2 test:   chi2=14.6025 , p=0.0007  , df=2
# likelihood ratio test: chi2=14.2253 , p=0.0008  , df=2
# parameter F test:         F=7.1675  , p=0.0009  , df_denom=268, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.5638  , p=0.0039  , df_denom=265, df_num=3
# ssr based chi2 test:   chi2=14.0530 , p=0.0028  , df=3
# likelihood ratio test: chi2=13.7020 , p=0.0033  , df=3
# parameter F test:         F=4.5638  , p=0.0039  , df_denom=265, df_num=3
# Granger Causality Test: Turkey | China
# Spearman Correlation
# SpearmanrResult(correlation=-0.7373813611449511, pvalue=1.9864591738016942e-48)
# Pearson Correlation
# (-0.16896511349918836, 0.004962869494231799)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=59.7815 , p=0.0000  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=60.4532 , p=0.0000  , df=1
# likelihood ratio test: chi2=54.5516 , p=0.0000  , df=1
# parameter F test:         F=59.7815 , p=0.0000  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=23.0722 , p=0.0000  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=47.0184 , p=0.0000  , df=2
# likelihood ratio test: chi2=43.3330 , p=0.0000  , df=2
# parameter F test:         F=23.0722 , p=0.0000  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.0502 , p=0.0000  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=46.3614 , p=0.0000  , df=3
# likelihood ratio test: chi2=42.7611 , p=0.0000  , df=3
# parameter F test:         F=15.0502 , p=0.0000  , df_denom=261, df_num=3
# Granger Causality Test: Turkey | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=-0.30388934368752957, pvalue=3.384671690912689e-07)
# Pearson Correlation
# (-0.16395648759273335, 0.006832148696674925)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=28.6930 , p=0.0000  , df_denom=268, df_num=1
# ssr based chi2 test:   chi2=29.0142 , p=0.0000  , df=1
# likelihood ratio test: chi2=27.5637 , p=0.0000  , df=1
# parameter F test:         F=28.6930 , p=0.0000  , df_denom=268, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.6850 , p=0.0000  , df_denom=265, df_num=2
# ssr based chi2 test:   chi2=23.8109 , p=0.0000  , df=2
# likelihood ratio test: chi2=22.8189 , p=0.0000  , df=2
# parameter F test:         F=11.6850 , p=0.0000  , df_denom=265, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.4103  , p=0.0001  , df_denom=262, df_num=3
# ssr based chi2 test:   chi2=22.8250 , p=0.0000  , df=3
# likelihood ratio test: chi2=21.9081 , p=0.0001  , df=3
# parameter F test:         F=7.4103  , p=0.0001  , df_denom=262, df_num=3
# Granger Causality Test: Turkey | Germany
# Spearman Correlation
# SpearmanrResult(correlation=-0.351999907969891, pvalue=2.3613286239550634e-09)
# Pearson Correlation
# (-0.18062025846225194, 0.002791829584943864)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.7828 , p=0.0000  , df_denom=264, df_num=1
# ssr based chi2 test:   chi2=25.0645 , p=0.0000  , df=1
# likelihood ratio test: chi2=23.9568 , p=0.0000  , df=1
# parameter F test:         F=24.7828 , p=0.0000  , df_denom=264, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.9374  , p=0.0079  , df_denom=261, df_num=2
# ssr based chi2 test:   chi2=10.0639 , p=0.0065  , df=2
# likelihood ratio test: chi2=9.8782  , p=0.0072  , df=2
# parameter F test:         F=4.9374  , p=0.0079  , df_denom=261, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7296  , p=0.0119  , df_denom=258, df_num=3
# ssr based chi2 test:   chi2=11.4923 , p=0.0093  , df=3
# likelihood ratio test: chi2=11.2501 , p=0.0104  , df=3
# parameter F test:         F=3.7296  , p=0.0119  , df_denom=258, df_num=3
# Granger Causality Test: Turkey | South Korea
# Spearman Correlation
# SpearmanrResult(correlation=-0.17732159174537113, pvalue=0.0035863376920808286)
# Pearson Correlation
# (-0.10438204091554885, 0.0881045322681687)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=23.6966 , p=0.0000  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=23.9628 , p=0.0000  , df=1
# likelihood ratio test: chi2=22.9585 , p=0.0000  , df=1
# parameter F test:         F=23.6966 , p=0.0000  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.5379  , p=0.0001  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=19.4372 , p=0.0001  , df=2
# likelihood ratio test: chi2=18.7670 , p=0.0001  , df=2
# parameter F test:         F=9.5379  , p=0.0001  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.2928  , p=0.0004  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=19.3849 , p=0.0002  , df=3
# likelihood ratio test: chi2=18.7159 , p=0.0003  , df=3
# parameter F test:         F=6.2928  , p=0.0004  , df_denom=261, df_num=3
# Granger Causality Test: Turkey | Italy
# Spearman Correlation
# SpearmanrResult(correlation=-0.2908678051366859, pvalue=1.1053107036350754e-06)
# Pearson Correlation
# (-0.11877746350395547, 0.050795273248654314)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=35.3850 , p=0.0000  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=35.7826 , p=0.0000  , df=1
# likelihood ratio test: chi2=33.6022 , p=0.0000  , df=1
# parameter F test:         F=35.3850 , p=0.0000  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=19.1063 , p=0.0000  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=38.9364 , p=0.0000  , df=2
# likelihood ratio test: chi2=36.3639 , p=0.0000  , df=2
# parameter F test:         F=19.1063 , p=0.0000  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=12.8426 , p=0.0000  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=39.5611 , p=0.0000  , df=3
# likelihood ratio test: chi2=36.9001 , p=0.0000  , df=3
# parameter F test:         F=12.8426 , p=0.0000  , df_denom=261, df_num=3
# Granger Causality Test: Turkey | Slovenia
# Spearman Correlation
# SpearmanrResult(correlation=-0.2820201392032251, pvalue=2.3902039373889086e-06)
# Pearson Correlation
# (-0.15761990886401145, 0.009348939217256769)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=35.0011 , p=0.0000  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=35.3943 , p=0.0000  , df=1
# likelihood ratio test: chi2=33.2591 , p=0.0000  , df=1
# parameter F test:         F=35.0011 , p=0.0000  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=17.0109 , p=0.0000  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=34.6662 , p=0.0000  , df=2
# likelihood ratio test: chi2=32.6076 , p=0.0000  , df=2
# parameter F test:         F=17.0109 , p=0.0000  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=11.2909 , p=0.0000  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=34.7810 , p=0.0000  , df=3
# likelihood ratio test: chi2=32.7021 , p=0.0000  , df=3
# parameter F test:         F=11.2909 , p=0.0000  , df_denom=261, df_num=3
# Granger Causality Test: Turkey | Poland
# Spearman Correlation
# SpearmanrResult(correlation=-0.2820201392032251, pvalue=2.3902039373889086e-06)
# Pearson Correlation
# (-0.12795880221426698, 0.03525709439621615)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=44.0720 , p=0.0000  , df_denom=267, df_num=1
# ssr based chi2 test:   chi2=44.5672 , p=0.0000  , df=1
# likelihood ratio test: chi2=41.2495 , p=0.0000  , df=1
# parameter F test:         F=44.0720 , p=0.0000  , df_denom=267, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=21.7141 , p=0.0000  , df_denom=264, df_num=2
# ssr based chi2 test:   chi2=44.2508 , p=0.0000  , df=2
# likelihood ratio test: chi2=40.9667 , p=0.0000  , df=2
# parameter F test:         F=21.7141 , p=0.0000  , df_denom=264, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=14.3207 , p=0.0000  , df_denom=261, df_num=3
# ssr based chi2 test:   chi2=44.1144 , p=0.0000  , df=3
# likelihood ratio test: chi2=40.8386 , p=0.0000  , df=3
# parameter F test:         F=14.3207 , p=0.0000  , df_denom=261, df_num=3
# Granger Causality Test: Turkey | France
# Spearman Correlation
# SpearmanrResult(correlation=-0.3124225364048353, pvalue=1.5095763408870096e-07)
# Pearson Correlation
# (-0.16242189034507437, 0.007378591760131473)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=35.2657 , p=0.0000  , df_denom=271, df_num=1
# ssr based chi2 test:   chi2=35.6561 , p=0.0000  , df=1
# likelihood ratio test: chi2=33.5196 , p=0.0000  , df=1
# parameter F test:         F=35.2657 , p=0.0000  , df_denom=271, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=16.5759 , p=0.0000  , df_denom=268, df_num=2
# ssr based chi2 test:   chi2=33.7702 , p=0.0000  , df=2
# likelihood ratio test: chi2=31.8392 , p=0.0000  , df=2
# parameter F test:         F=16.5759 , p=0.0000  , df_denom=268, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.8988 , p=0.0000  , df_denom=265, df_num=3
# ssr based chi2 test:   chi2=33.5602 , p=0.0000  , df=3
# likelihood ratio test: chi2=31.6457 , p=0.0000  , df=3
# parameter F test:         F=10.8988 , p=0.0000  , df_denom=265, df_num=3
# Granger Causality Test: Turkey | Spain
# Spearman Correlation
# SpearmanrResult(correlation=-0.31075517971319755, pvalue=1.4355765200718128e-07)
# Pearson Correlation
# (-0.1192095504757266, 0.04827837222868744)
#
#
#
#
#
#
#
# =====================================
# South Korea
# =====================================
# ADF Statistics: -2.801621
# p-value: 0.058043
# Critical values:
# 	1%: -3.476 		Is stationary: No
# 	5%: -2.882 		Is stationary: No
# 	10%: -2.578 		Is stationary: Yes
# KPSS Statistic: 0.8722148355247286
# p-value: 0.01
# num lags: 5
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.0890 , p=0.0010  , df_denom=303, df_num=1
# ssr based chi2 test:   chi2=11.1988 , p=0.0008  , df=1
# likelihood ratio test: chi2=10.9987 , p=0.0009  , df=1
# parameter F test:         F=11.0890 , p=0.0010  , df_denom=303, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2374  , p=0.0058  , df_denom=300, df_num=2
# ssr based chi2 test:   chi2=10.6493 , p=0.0049  , df=2
# likelihood ratio test: chi2=10.4676 , p=0.0053  , df=2
# parameter F test:         F=5.2374  , p=0.0058  , df_denom=300, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=25.2367 , p=0.0000  , df_denom=297, df_num=3
# ssr based chi2 test:   chi2=77.4945 , p=0.0000  , df=3
# likelihood ratio test: chi2=69.0289 , p=0.0000  , df=3
# parameter F test:         F=25.2367 , p=0.0000  , df_denom=297, df_num=3
# Granger Causality Test: South Korea | China
# Spearman Correlation
# SpearmanrResult(correlation=-0.21351522246396792, pvalue=0.00016364979498937254)
# Pearson Correlation
# (-0.056097077595247534, 0.3272528484965479)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=25.7150 , p=0.0000  , df_denom=299, df_num=1
# ssr based chi2 test:   chi2=25.9730 , p=0.0000  , df=1
# likelihood ratio test: chi2=24.9163 , p=0.0000  , df=1
# parameter F test:         F=25.7150 , p=0.0000  , df_denom=299, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.0229 , p=0.0000  , df_denom=296, df_num=2
# ssr based chi2 test:   chi2=24.4520 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.5095 , p=0.0000  , df=2
# parameter F test:         F=12.0229 , p=0.0000  , df_denom=296, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.8671  , p=0.0000  , df_denom=293, df_num=3
# ssr based chi2 test:   chi2=24.1653 , p=0.0000  , df=3
# likelihood ratio test: chi2=23.2413 , p=0.0000  , df=3
# parameter F test:         F=7.8671  , p=0.0000  , df_denom=293, df_num=3
# Granger Causality Test: South Korea | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=-0.08992467346483847, pvalue=0.1182866580957238)
# Pearson Correlation
# (-0.05427245342741922, 0.3464465188620973)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.6930  , p=0.0556  , df_denom=300, df_num=1
# ssr based chi2 test:   chi2=3.7299  , p=0.0534  , df=1
# likelihood ratio test: chi2=3.7071  , p=0.0542  , df=1
# parameter F test:         F=3.6930  , p=0.0556  , df_denom=300, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8605  , p=0.1574  , df_denom=297, df_num=2
# ssr based chi2 test:   chi2=3.7836  , p=0.1508  , df=2
# likelihood ratio test: chi2=3.7601  , p=0.1526  , df=2
# parameter F test:         F=1.8605  , p=0.1574  , df_denom=297, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3184  , p=0.2685  , df_denom=294, df_num=3
# ssr based chi2 test:   chi2=4.0495  , p=0.2562  , df=3
# likelihood ratio test: chi2=4.0225  , p=0.2590  , df=3
# parameter F test:         F=1.3184  , p=0.2685  , df_denom=294, df_num=3
# Granger Causality Test: South Korea | Germany
# Spearman Correlation
# SpearmanrResult(correlation=-0.10400786024367975, pvalue=0.07015903464233371)
# Pearson Correlation
# (-0.05977331812007283, 0.298888877704682)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=22.8339 , p=0.0000  , df_denom=264, df_num=1
# ssr based chi2 test:   chi2=23.0934 , p=0.0000  , df=1
# likelihood ratio test: chi2=22.1488 , p=0.0000  , df=1
# parameter F test:         F=22.8339 , p=0.0000  , df_denom=264, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.6070 , p=0.0000  , df_denom=261, df_num=2
# ssr based chi2 test:   chi2=21.6205 , p=0.0000  , df=2
# likelihood ratio test: chi2=20.7867 , p=0.0000  , df=2
# parameter F test:         F=10.6070 , p=0.0000  , df_denom=261, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.2885  , p=0.0001  , df_denom=258, df_num=3
# ssr based chi2 test:   chi2=22.4588 , p=0.0001  , df=3
# likelihood ratio test: chi2=21.5577 , p=0.0001  , df=3
# parameter F test:         F=7.2885  , p=0.0001  , df_denom=258, df_num=3
# Granger Causality Test: South Korea | Turkey
# Spearman Correlation
# SpearmanrResult(correlation=-0.17732159174537113, pvalue=0.0035863376920808286)
# Pearson Correlation
# (-0.10438204091554885, 0.0881045322681687)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0144  , p=0.9045  , df_denom=299, df_num=1
# ssr based chi2 test:   chi2=0.0146  , p=0.9040  , df=1
# likelihood ratio test: chi2=0.0146  , p=0.9040  , df=1
# parameter F test:         F=0.0144  , p=0.9045  , df_denom=299, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2405  , p=0.7864  , df_denom=296, df_num=2
# ssr based chi2 test:   chi2=0.4891  , p=0.7830  , df=2
# likelihood ratio test: chi2=0.4888  , p=0.7832  , df=2
# parameter F test:         F=0.2405  , p=0.7864  , df_denom=296, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2010  , p=0.8957  , df_denom=293, df_num=3
# ssr based chi2 test:   chi2=0.6174  , p=0.8924  , df=3
# likelihood ratio test: chi2=0.6167  , p=0.8926  , df=3
# ...
# Pearson Correlation
# (-0.16840022638789887, 0.002757379422693189)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=19.1005 , p=0.0000  , df_denom=306, df_num=1
# ssr based chi2 test:   chi2=19.2877 , p=0.0000  , df=1
# likelihood ratio test: chi2=18.7097 , p=0.0000  , df=1
# parameter F test:         F=19.1005 , p=0.0000  , df_denom=306, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.2401  , p=0.0022  , df_denom=303, df_num=2
# ssr based chi2 test:   chi2=12.6862 , p=0.0018  , df=2
# likelihood ratio test: chi2=12.4319 , p=0.0020  , df=2
# parameter F test:         F=6.2401  , p=0.0022  , df_denom=303, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.1923  , p=0.0063  , df_denom=300, df_num=3
# ssr based chi2 test:   chi2=12.8705 , p=0.0049  , df=3
# likelihood ratio test: chi2=12.6080 , p=0.0056  , df=3
# parameter F test:         F=4.1923  , p=0.0063  , df_denom=300, df_num=3
# Granger Causality Test: United States | France
# Spearman Correlation
# SpearmanrResult(correlation=-0.20674791005705687, pvalue=0.0002471993996603635)
# Pearson Correlation
# (-0.12761568712897736, 0.024638492055028896)
#
#
#
#
#
#
#
# =====================================
# Netherlands
# =====================================
# ADF Statistics: -1.717251
# p-value: 0.422247
# Critical values:
# 	1%: -3.478 		Is stationary: No
# 	5%: -2.882 		Is stationary: No
# 	10%: -2.578 		Is stationary: No
# KPSS Statistic: 0.32182209413526924
# p-value: 0.1
# num lags: 37
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7160  , p=0.0180  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=5.8281  , p=0.0158  , df=1
# likelihood ratio test: chi2=5.7218  , p=0.0168  , df=1
# parameter F test:         F=5.7160  , p=0.0180  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0555  , p=0.0002  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=18.7148 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.6684 , p=0.0001  , df=2
# parameter F test:         F=9.0555  , p=0.0002  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=19.5713 , p=0.0000  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=61.5098 , p=0.0000  , df=3
# likelihood ratio test: chi2=51.7523 , p=0.0000  , df=3
# parameter F test:         F=19.5713 , p=0.0000  , df_denom=147, df_num=3
# Granger Causality Test: Netherlands | India
# Spearman Correlation
# SpearmanrResult(correlation=0.09082971253731446, pvalue=0.2579125712430013)
# Pearson Correlation
# (0.1986228122530723, 0.012640273690869844)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.0415  , p=0.0255  , df_denom=306, df_num=1
# ssr based chi2 test:   chi2=5.0909  , p=0.0241  , df=1
# likelihood ratio test: chi2=5.0494  , p=0.0246  , df=1
# parameter F test:         F=5.0415  , p=0.0255  , df_denom=306, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.9583  , p=0.0076  , df_denom=303, df_num=2
# ssr based chi2 test:   chi2=10.0802 , p=0.0065  , df=2
# likelihood ratio test: chi2=9.9188  , p=0.0070  , df=2
# parameter F test:         F=4.9583  , p=0.0076  , df_denom=303, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.0931  , p=0.0273  , df_denom=300, df_num=3
# ssr based chi2 test:   chi2=9.4957  , p=0.0234  , df=3
# likelihood ratio test: chi2=9.3518  , p=0.0250  , df=3
# parameter F test:         F=3.0931  , p=0.0273  , df_denom=300, df_num=3
# Granger Causality Test: Netherlands | United States
# Spearman Correlation
# SpearmanrResult(correlation=-0.23467842575622067, pvalue=2.9971810322357427e-05)
# Pearson Correlation
# (-0.10709945536597196, 0.059634877692197115)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.6382  , p=0.0064  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=7.7880  , p=0.0053  , df=1
# likelihood ratio test: chi2=7.5998  , p=0.0058  , df=1
# parameter F test:         F=7.6382  , p=0.0064  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.3442  , p=0.0009  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=15.1780 , p=0.0005  , df=2
# likelihood ratio test: chi2=14.4801 , p=0.0007  , df=2
# parameter F test:         F=7.3442  , p=0.0009  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.2434  , p=0.0000  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=25.9079 , p=0.0000  , df=3
# likelihood ratio test: chi2=23.9459 , p=0.0000  , df=3
# parameter F test:         F=8.2434  , p=0.0000  , df_denom=147, df_num=3
# Granger Causality Test: Netherlands | Vietnam
# Spearman Correlation
# SpearmanrResult(correlation=0.2189130708740307, pvalue=0.005877354523414785)
# Pearson Correlation
# (0.17468086132165106, 0.0286618744436253)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7438  , p=0.1887  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=1.7789  , p=0.1823  , df=1
# likelihood ratio test: chi2=1.7686  , p=0.1836  , df=1
# parameter F test:         F=1.7438  , p=0.1887  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6953  , p=0.0709  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=5.5751  , p=0.0616  , df=2
# likelihood ratio test: chi2=5.4747  , p=0.0647  , df=2
# parameter F test:         F=2.6953  , p=0.0709  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.0787  , p=0.0023  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=15.9819 , p=0.0011  , df=3
# likelihood ratio test: chi2=15.1865 , p=0.0017  , df=3
# parameter F test:         F=5.0787  , p=0.0023  , df_denom=143, df_num=3
# Granger Causality Test: Netherlands | France
# Spearman Correlation
# SpearmanrResult(correlation=0.9206788693024863, pvalue=1.418442092069057e-63)
# Pearson Correlation
# (0.8883376317795433, 6.658535553664068e-53)
#
#
#
#
#
#
#
# =====================================
# Vietnam
# =====================================
# ADF Statistics: -3.652369
# p-value: 0.004835
# Critical values:
# 	1%: -3.474 		Is stationary: Yes
# 	5%: -2.880 		Is stationary: Yes
# 	10%: -2.577 		Is stationary: Yes
# KPSS Statistic: 0.856369410384351
# p-value: 0.01
# num lags: 7
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=17.9432 , p=0.0000  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=18.2951 , p=0.0000  , df=1
# likelihood ratio test: chi2=17.2994 , p=0.0000  , df=1
# parameter F test:         F=17.9432 , p=0.0000  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.0441 , p=0.0001  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=20.7578 , p=0.0000  , df=2
# likelihood ratio test: chi2=19.4806 , p=0.0001  , df=2
# parameter F test:         F=10.0441 , p=0.0001  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.9986  , p=0.0025  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=15.7097 , p=0.0013  , df=3
# likelihood ratio test: chi2=14.9591 , p=0.0019  , df=3
# parameter F test:         F=4.9986  , p=0.0025  , df_denom=147, df_num=3
# Granger Causality Test: Vietnam | India
# Spearman Correlation
# SpearmanrResult(correlation=0.4899590771506257, pvalue=7.378285752044019e-11)
# Pearson Correlation
# (0.33458244683323957, 1.8447210956093727e-05)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=22.8106 , p=0.0000  , df_denom=310, df_num=1
# ssr based chi2 test:   chi2=23.0313 , p=0.0000  , df=1
# likelihood ratio test: chi2=22.2234 , p=0.0000  , df=1
# parameter F test:         F=22.8106 , p=0.0000  , df_denom=310, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.1615  , p=0.0024  , df_denom=307, df_num=2
# ssr based chi2 test:   chi2=12.5237 , p=0.0019  , df=2
# likelihood ratio test: chi2=12.2789 , p=0.0022  , df=2
# parameter F test:         F=6.1615  , p=0.0024  , df_denom=307, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8902  , p=0.0094  , df_denom=304, df_num=3
# ssr based chi2 test:   chi2=11.9393 , p=0.0076  , df=3
# likelihood ratio test: chi2=11.7159 , p=0.0084  , df=3
# parameter F test:         F=3.8902  , p=0.0094  , df_denom=304, df_num=3
# Granger Causality Test: Vietnam | United States
# Spearman Correlation
# SpearmanrResult(correlation=-0.3886672921577958, pvalue=9.164593971466035e-13)
# Pearson Correlation
# (-0.16840022638789887, 0.002757379422693189)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2099  , p=0.6475  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.2140  , p=0.6436  , df=1
# likelihood ratio test: chi2=0.2139  , p=0.6438  , df=1
# parameter F test:         F=0.2099  , p=0.6475  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3162  , p=0.7294  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=0.6534  , p=0.7213  , df=2
# likelihood ratio test: chi2=0.6520  , p=0.7218  , df=2
# parameter F test:         F=0.3162  , p=0.7294  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5521  , p=0.6475  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=1.7351  , p=0.6292  , df=3
# likelihood ratio test: chi2=1.7254  , p=0.6313  , df=3
# parameter F test:         F=0.5521  , p=0.6475  , df_denom=147, df_num=3
# Granger Causality Test: Vietnam | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=0.2189130708740307, pvalue=0.005877354523414785)
# Pearson Correlation
# (0.17468086132165106, 0.0286618744436253)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8779  , p=0.3503  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=0.8951  , p=0.3441  , df=1
# likelihood ratio test: chi2=0.8925  , p=0.3448  , df=1
# parameter F test:         F=0.8779  , p=0.3503  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4918  , p=0.6125  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=1.0164  , p=0.6016  , df=2
# likelihood ratio test: chi2=1.0131  , p=0.6026  , df=2
# parameter F test:         F=0.4918  , p=0.6125  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6310  , p=0.1847  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=5.1260  , p=0.1628  , df=3
# likelihood ratio test: chi2=5.0426  , p=0.1687  , df=3
# parameter F test:         F=1.6310  , p=0.1847  , df_denom=147, df_num=3
# Granger Causality Test: Vietnam | France
# Spearman Correlation
# SpearmanrResult(correlation=0.23179268618909865, pvalue=0.0034887083960969466)
# Pearson Correlation
# (0.236933990239245, 0.0028107402293374405)
#
#
#
#
#
#
#
# =====================================
# France
# =====================================
# ADF Statistics: -1.428538
# p-value: 0.568521
# Critical values:
# 	1%: -3.478 		Is stationary: No
# 	5%: -2.882 		Is stationary: No
# 	10%: -2.578 		Is stationary: No
# KPSS Statistic: 0.4078112100419739
# p-value: 0.07378827153363193
# num lags: 25
# Critial Values:
# 	10%: 0.347 		Is stationary: Yes
# 	5%: 0.463 		Is stationary: Yes
# 	2.5%: 0.574 		Is stationary: Yes
# 	1%: 0.739 		Is stationary: Yes
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6752  , p=0.1040  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=2.7277  , p=0.0986  , df=1
# likelihood ratio test: chi2=2.7041  , p=0.1001  , df=1
# parameter F test:         F=2.6752  , p=0.1040  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.9132  , p=0.0034  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=12.2206 , p=0.0022  , df=2
# likelihood ratio test: chi2=11.7628 , p=0.0028  , df=2
# parameter F test:         F=5.9132  , p=0.0034  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=17.9328 , p=0.0000  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=56.3601 , p=0.0000  , df=3
# likelihood ratio test: chi2=48.0277 , p=0.0000  , df=3
# parameter F test:         F=17.9328 , p=0.0000  , df_denom=147, df_num=3
# Granger Causality Test: France | India
# Spearman Correlation
# SpearmanrResult(correlation=0.046491790723215104, pvalue=0.5631303708506626)
# Pearson Correlation
# (0.1051575267737755, 0.18994967140002653)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.7303  , p=0.0099  , df_denom=306, df_num=1
# ssr based chi2 test:   chi2=6.7963  , p=0.0091  , df=1
# likelihood ratio test: chi2=6.7227  , p=0.0095  , df=1
# parameter F test:         F=6.7303  , p=0.0099  , df_denom=306, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.1781  , p=0.0009  , df_denom=303, df_num=2
# ssr based chi2 test:   chi2=14.5932 , p=0.0007  , df=2
# likelihood ratio test: chi2=14.2580 , p=0.0008  , df=2
# parameter F test:         F=7.1781  , p=0.0009  , df_denom=303, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8825  , p=0.0095  , df_denom=300, df_num=3
# ssr based chi2 test:   chi2=11.9194 , p=0.0077  , df=3
# likelihood ratio test: chi2=11.6938 , p=0.0085  , df=3
# parameter F test:         F=3.8825  , p=0.0095  , df_denom=300, df_num=3
# Granger Causality Test: France | United States
# Spearman Correlation
# SpearmanrResult(correlation=-0.20674791005705687, pvalue=0.0002471993996603635)
# Pearson Correlation
# (-0.12761568712897736, 0.024638492055028896)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1588  , p=0.6908  , df_denom=149, df_num=1
# ssr based chi2 test:   chi2=0.1620  , p=0.6873  , df=1
# likelihood ratio test: chi2=0.1619  , p=0.6874  , df=1
# parameter F test:         F=0.1588  , p=0.6908  , df_denom=149, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2757  , p=0.7595  , df_denom=146, df_num=2
# ssr based chi2 test:   chi2=0.5702  , p=0.7519  , df=2
# likelihood ratio test: chi2=0.5691  , p=0.7523  , df=2
# parameter F test:         F=0.2757  , p=0.7595  , df_denom=146, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6613  , p=0.5772  , df_denom=143, df_num=3
# ssr based chi2 test:   chi2=2.0809  , p=0.5558  , df=3
# likelihood ratio test: chi2=2.0666  , p=0.5587  , df=3
# parameter F test:         F=0.6613  , p=0.5772  , df_denom=143, df_num=3
# Granger Causality Test: France | Netherlands
# Spearman Correlation
# SpearmanrResult(correlation=0.9206788693024864, pvalue=1.418442092068936e-63)
# Pearson Correlation
# (0.8883376317795433, 6.658535553664068e-53)
#
#
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.3868  , p=0.0379  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=4.4729  , p=0.0344  , df=1
# likelihood ratio test: chi2=4.4099  , p=0.0357  , df=1
# parameter F test:         F=4.3868  , p=0.0379  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.2263  , p=0.0164  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=8.7343  , p=0.0127  , df=2
# likelihood ratio test: chi2=8.4971  , p=0.0143  , df=2
# parameter F test:         F=4.2263  , p=0.0164  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.6871  , p=0.0001  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=24.1593 , p=0.0000  , df=3
# likelihood ratio test: chi2=22.4417 , p=0.0001  , df=3
# parameter F test:         F=7.6871  , p=0.0001  , df_denom=147, df_num=3
# Granger Causality Test: France | Vietnam
# Spearman Correlation
# SpearmanrResult(correlation=0.23179268618909865, pvalue=0.0034887083960969466)
# Pearson Correlation
# (0.236933990239245, 0.0028107402293374405)
